# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt

DATA_PATH = r"data\nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

# sample = random.sample(puzzles_available, 10_000)

# sample puzzles from EVEN days
sample = [puzz for puzz in puzzles_available if puzz[-1]%2==0]

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)
clue_answer_pairs
# Out:
# [('Capital of Ghana', 'ACCRA'),
#  ('Shows wear, as a chair cushion', 'SAGS'),
#  ('Progeny of an old block', 'CHIP'),
#  ('Yugoslav native', 'CROAT'),
#  ("Guy Fawkes's forte", 'PLOT'),
#  ('Window part', 'PANE'),
#  ('Well-known drudge', 'CINDERELLA'),
#  ('Status quo ___ bellum', 'ANTE'),
#  ('Clocked', 'TIMED'),
#  ('Bedroom piece', 'DRESSER'),
#  ('Bull-rider of myth', 'EUROPA'),
#  ('Thus, to Caesar', 'ITA'),
#  ('Prior to', 'ERE'),
#  ('Roman 1501', 'MDI'),
#  ('Harvest goddess', 'OPS'),
#  ('Haul', 'LUG'),
#  ('Hallucinogen', 'LSD'),
#  ('Word with after or new', 'MATH'),
#  ('Condescended', 'STOOPED'),
#  ('Alaskan native', 'ALEUT'),
#  ('Common-Market initials', 'EEC'),
#  ('Kind of transit', 'RAPID'),
#  ('Custom-made in London', 'BESPOKE'),
#  ('___ chance (no way)', 'NOTA'),
#  ('Mil. man', 'SGT'),
#  ('Turntable abbr.', 'RPM'),
#  ('Holy day: Abbr.', 'SAB'),
#  ('Handed or headed', 'RED'),
#  ('Kind of text or cursor', 'PRE'),
#  ("Bill's partner", 'COO'),
#  ('Stomach: Prefix', 'GASTRO'),
#  ('Composer Victor', 'HERBERT'),
#  ('"Thar she ___!"', 'BLOWS'),
#  ('Heating vessel', 'ETNA'),
#  ('Victims of 8 Down', 'THREEBEARS'),
#  ('Estate or life', 'REAL'),
#  ('Poetic times', 'EENS'),
#  ('Good-by', 'ADIOS'),
#  ('She, in Paris', 'ELLE'),
#  ('Mild oath', 'DRAT'),
#  ('Moisten', 'BEDEW'),
#  ('Grammar case: Abbr.', 'ACC'),
#  ('Dernier ___', 'CRI'),
#  ('Penitent', 'CONTRITE'),
#  ("TV's brother", 'RADIO'),
#  ('Musical direction', 'ATEMPO'),
#  ('Rushed', 'SPED'),
#  ('Still and ___', 'ALL'),
#  ('Well-known intruder', 'GOLDILOCKS'),
#  ('Turn on, as an engine', 'STARTUP'),
#  ('Auditors: Abbr.', 'CPAS'),
#  ('Well-known oven user', 'HANSEL'),
#  ('Buries', 'INTERS'),
#  ('Looked closely', 'PEERED'),
#  ('Gathers', 'REAPS'),
#  ("Rarin' to go", 'EAGER'),
#  ('Anarchist Goldman', 'EMMA'),
#  ('System of land tenure', 'UDAL'),
#  ('Exploiter of 17 Across', 'STEPMOTHER'),
#  ('Center of activity', 'HUB'),
#  ('Fed. aid agency', 'OEO'),
#  ('Mr. Beard', 'DAN'),
#  ('Canonical hour', 'TERCE'),
#  ('Mideast city', 'PORTSAID'),
#  ('Passage, in anatomy', 'ITER'),
#  ('Pedestal part', 'DADO'),
#  ('Displayed', 'SPORTED'),
#  ('National emblem', 'EAGLE'),
#  ('Celestial music maker', 'SPHERE'),
#  ('Co-conspirator of 11 Down', 'GRETEL'),
#  ('Threefold', 'TERNAL'),
#  ('African tree', 'BAOBAB'),
#  ('Bergman, e.g.', 'SWEDE'),
#  ('Poetic misery', 'BALE'),
#  ('Overcome', 'BEST'),
#  ('Nucleic-acid initials', 'RNA'),
#  ('Small deer', 'ROE'),
#  ('Compass point', 'SSW'),
#  ('W. W. II org.', 'OPA'),
#  ('Synthetic', 'ERSATZ'),
#  ('Nicholas, e.g.', 'TSAR'),
#  ('Bridge mishap', 'SET'),
#  ('"___ Kapital"', 'DAS'),
#  ("Fresh-air fiend's advice", 'BREATHE'),
#  ('Go on about', 'RAVE'),
#  ('Imitate', 'APE'),
#  ('Feminine suffix', 'ESS'),
#  ('Threw off course', 'DERAILED'),
#  ('Thames landmark', 'ETON'),
#  ('Disencumber', 'RID'),
#  ('Become involved', 'STEPIN'),
#  ('Concrete strip', 'SLAB'),
#  ('F.D.R. program', 'NEWDEAL'),
#  ('Neighbor of Naples', 'SORRENTO'),
#  ('Rich fabric', 'SAMITE'),
#  ('Particle', 'ATOM'),
#  ('Type of well', 'ARTESIAN'),
#  ("Ethan Allen's conquest", 'TICONDEROGA'),
#  ('Dispatched', 'SENT'),
#  ('King of the old South', 'COTTON'),
#  ('Piddling salute', 'ONEGUN'),
#  ('Soft foods', 'PAPS'),
#  ('Please, in Bonn', 'GEFALLEN'),
#  ('Fountain specialties', 'SUNDAES'),
#  ('Month: Abbr.', 'OCT'),
#  ('Cable-making machine', 'STRANDER'),
#  ('Lively dance', 'HORA'),
#  ('Recording system', 'STEREO'),
#  ('Roman statesman', 'CATO'),
#  ('Undeveloped', 'RAW'),
#  ('French cleric', 'ABBE'),
#  ('Final confrontation', 'SURRENDEROFCORNWALLIS'),
#  ('Major poem', 'EPOS'),
#  ('Noun suffix', 'ERY'),
#  ('Mud, in France', 'BOUE'),
#  ('Zealous', 'ARDENT'),
#  ('Resorts', 'SPAS'),
#  ('Church musical rite', 'SUNGMASS'),
#  ('Long ___', 'AGO'),
#  ('Spotted cat', 'LEOPARD'),
#  ('Swiss town', 'WINDISCH'),
#  ('At the peak', 'ATOP'),
#  ('Fly', 'AVIATE'),
#  ('Sore', 'CANKER'),
#  ('Aunts, in Spain', 'TIAS'),
#  ('The low point', 'VALLEYFORGE'),
#  ('New Jersey battle', 'MONMOUTH'),
#  ('Stake', 'ANTE'),
#  ('Confine', 'INTERN'),
#  ('Site of U.S. base in Canada', 'ARGENTIA'),
#  ('Adirondack river', 'SARANAC'),
#  ('Times or tack', 'HARD'),
#  ('Wobble', 'TEETER'),
#  ('Packing unit: Abbr.', 'CTN'),
#  ('Batty', 'LOCO'),
#  ('___ contempt (accused in court)', 'CITEDFOR'),
#  ('Period', 'ERA'),
#  ('Korean soldier', 'ROK'),
#  ('Region: Abbr.', 'TERR'),
#  ('Offensive or defensive', 'PLATOON'),
#  ('British medical org.', 'RCS'),
#  ('Office holders', 'INS'),
#  ('Vehicle', 'SLED'),
#  ('Aver', 'ALLEGE'),
#  ('Its, in Paris', 'SES'),
#  ('Black Sea port', 'ODESSA'),
#  ('Pulpit occupant', 'PASTOR'),
#  ('Declare', 'ASSERT'),
#  ('Goof', 'ERR'),
#  ('Subject of Kant critique', 'REASON'),
#  ('Move easily', 'SAIL'),
#  ('Titan with a burden', 'ATLAS'),
#  ('Early confrontation', 'THEBATTLEOFBUNKERHILL'),
#  ('British letter', 'ZED'),
#  ("Hessians' Waterloo", 'TRENTON'),
#  ('Shiny fabric', 'SATEEN'),
#  ('Swear', 'AVOW'),
#  ('Tear', 'REND'),
#  ('Site of the turning point', 'SARATOGA'),
#  ('Postscript to a play', 'EPILOGUE'),
#  ('Kennedy', 'TED'),
#  ('Vermont battle', 'BENNINGTON'),
#  ('This: Ger.', 'DIESE'),
#  ('Journalism', 'PRESS'),
#  ('Like an otary', 'EARED'),
#  ('Spud', 'TATER'),
#  ('Clerical headwear', 'MITER'),
#  ('Religious picture', 'ICON'),
#  ("France's Le ___", 'MANS'),
#  ('Unsmiling', 'DOUR'),
#  ('Sicilian city', 'ENNA'),
#  ('Atlantic islands', 'CANARY'),
#  ('" . . . grow too ___ dream"', 'OLDTO'),
#  ('Nemesis of bad guys', 'POSSE'),
#  ('Misbehave', 'ACTUP'),
#  ('Feather: Prefix', 'PTERO'),
#  ('Sharp setbacks', 'FACERS'),
#  ('Disseminated', 'SOWN'),
#  ('Holy ___', 'SEE'),
#  ("Sultans' collections", 'HAREMS'),
#  ('B. &amp; O., etc.', 'RRS'),
#  ('Redden, in Paris', 'ROUGIR'),
#  ('City official: Abbr.', 'ALD'),
#  ("Goat's cry", 'BLEAT'),
#  ('Church fund-raiser', 'BINGO'),
#  ('Bar legally', 'ESTOP'),
#  ('___ Sea scrolls', 'DEAD'),
#  ("Vogue's Nast", 'CONDE'),
#  ('The C.I.C.', 'WASHINGTON'),
#  ('___ gratia artis', 'ARS'),
#  ('Glut', 'SATE'),
#  ('Victim', 'PREY'),
#  ('Scorch', 'SINGE'),
#  ('Expert on lines', 'ACTOR'),
#  ('Footing at Mauna Loa', 'LAVA'),
#  ("Northwestern's home", 'EVANSTON'),
#  ('Bayonne, N.J., sights', 'OILTANKS'),
#  ('More feeble', 'PALER'),
#  ('Kind of hog', 'WART'),
#  ('In unison', 'ASONE'),
#  ('Site of a widely-heard shot', 'CONCORD'),
#  ('Eastern ruler', 'AMEER'),
#  ('Small coach', 'FIACRE'),
#  ('Midday-sun sharer', 'MADDOG'),
#  ('Says', 'UTTERS'),
#  ('Wine measure', 'TIERCE'),
#  ('Worry', 'HARASS'),
#  ('Port of Brazil', 'NATAL'),
#  ('Heights: Abbr.', 'ALTS'),
#  ('Mr. Coward', 'NOEL'),
#  ('Network', 'RETE'),
#  ('Dernier ___', 'CRI'),
#  ('Auditor: Abbr.', 'CPA'),
#  ('Adversary', 'FOE'),
#  ('Bible book', 'ACTS'),
#  ('Seize', 'GRAB'),
#  ('Counterfeit', 'SHAM'),
#  ('Heart action', 'BEAT'),
#  ('Garbo', 'GRETA'),
#  ('Franchot', 'TONE'),
#  ('Canyon mouth', 'ABRA'),
#  ('"___, Macduff"', 'LAYON'),
#  ('Karenina', 'ANNA'),
#  ("Object of Thomas Paine's scorn", 'SUNSHINEPATRIOT'),
#  ('Crewmen', 'HANDS'),
#  ('Insect egg', 'NIT'),
#  ('Sal, e.g.', 'GAL'),
#  ('British-firm abbr.', 'LTD'),
#  ('"The Sleeping Beauty" et al.', 'BALLETS'),
#  ('Biographer of Henry James', 'EDEL'),
#  ('Koran chapter', 'SURA'),
#  ('Ipse ___', 'DIXIT'),
#  ('Fall field sight', 'SHEAF'),
#  ('Swindle', 'CON'),
#  ('Growing out', 'ENATE'),
#  ('Rich cake', 'TORTE'),
#  ("Mason's burdens", 'HODS'),
#  ('Stamp backing', 'GLUE'),
#  ('Rapture', 'ECSTASY'),
#  ('Asian sheep', 'SHA'),
#  ('Recipe abbr.', 'TSP'),
#  ('Id ___ (that is)', 'EST'),
#  ('Perfumes: Var.', 'ATARS'),
#  ('Joseph Conrad story', 'HEARTOFDARKNESS'),
#  ('Enthusiastic', 'AVID'),
#  ('Jail-door sound', 'CLANK'),
#  ('"___ virumque cano"', 'ARMA'),
#  ('Mother of Helen', 'LEDA'),
#  ('Sorts', 'KINDS'),
#  ('Mend', 'KNIT'),
#  ('Salver', 'TRAY'),
#  ('Health resorts', 'SPAS'),
#  ('Punta del ___', 'ESTE'),
#  ('Down with, in Paris', 'ABAS'),
#  ('Philippine island', 'CEBU'),
#  ('Mountain lake', 'TARN'),
#  ('Secrete', 'STASH'),
#  ('Luxembourg, e.g.', 'GRANDDUCHY'),
#  ('Kings, in Spain', 'REYES'),
#  ('On', 'ATOP'),
#  ('Basis of a certain split', 'BANANA'),
#  ('Causing surprise', 'STARTLING'),
#  ('"___ soit qui . . . "', 'HONI'),
#  ('___ Domini', 'ANNO'),
#  ('Essential part', 'MEAT'),
#  ('Flashes', 'GLINTS'),
#  ('Actor Holbrook', 'HAL'),
#  ('Diacritical mark', 'TILDE'),
#  ('Beau ___', 'GESTE'),
#  ('Kind of committee', 'ADHOC'),
#  ('Ogles', 'LEERS'),
#  ('Park fixtures', 'BANDSTANDS'),
#  ('Glorify', 'EXALT'),
#  ('Roman emperor', 'TITUS'),
#  ('Soak', 'STEEP'),
#  ('Like some saints', 'LATTERDAY'),
#  ('Marsupial, for short', 'ROO'),
#  ("Belshazzar's party", 'FEAST'),
#  ('Shovelheads', 'SHARKS'),
#  ('Big Board listings', 'STOCKS'),
#  ('Neighbor of Okla.', 'ARK'),
#  ('Turkish city', 'ADANA'),
#  ('Oil source of a sort', 'SNAKE'),
#  ('Crippled', 'HALT'),
#  ('For ___ and a day', 'EVER'),
#  ('Operatic heroine', 'AIDA'),
#  ('Impertinent', 'FLIP'),
#  ('Birds of prey', 'ERNS'),
#  ('Struck', 'SMIT'),
#  ('Cloy', 'SATE'),
#  ('African stockade', 'BOMA'),
#  ('Utmost degree', 'ACME'),
#  ('Feudal lord', 'LIEGE'),
#  ('Magnetites', 'ORES'),
#  ('Checkroom fixture', 'COATHANGER'),
#  ('Body english, in a way', 'WISHFULTHINKING'),
#  ('City-map unit', 'LOT'),
#  ('East, in Madrid', 'ESTE'),
#  ('Lets', 'LEASES'),
#  ('Kind of drum', 'SNARE'),
#  ('Bridge bid: Abbr.', 'DBL'),
#  ('Crimean river', 'ALMA'),
#  ('Pledges', 'ASSURES'),
#  ('Place for a token', 'SLOT'),
#  ('Port of Arabia', 'ADEN'),
#  ('Pointless', 'INANE'),
#  ("Gambler's dream", 'TOHITTHEJACKPOT'),
#  ('The vowels', 'AEIOU'),
#  ('Asteroid', 'EROS'),
#  ('"___ long, long way to . . . "', 'ITSA'),
#  ('Kind of general', 'TWOSTAR'),
#  ('Full extent', 'SPAN'),
#  ('Gardner of cartoons', 'REA'),
#  ('Golden calf et al.', 'IDOLS'),
#  ("Moat's protégé, in a way", 'CASTLE'),
#  ('Kettle or snare', 'DRUM'),
#  ('___ Testament', 'NEW'),
#  ('Kaufman-Hart play', 'ONCEINALIFETIME'),
#  ('Get out of the way', 'STANDASIDE'),
#  ('Cross', 'ROOD'),
#  ('Pastries', 'TARTS'),
#  ('Biblical priest', 'EBER'),
#  ('Miss Bancroft', 'ANNE'),
#  ('Rose, Cotton, etc.', 'BOWLS'),
#  ('Hunter of the sky', 'ORION'),
#  ('Hostess Perle', 'MESTA'),
#  ('Cinder', 'ASH'),
#  ('Needle, in old Rome', 'ACUS'),
#  ('Belmont entry', 'COLT'),
#  ('Matched', 'MATED'),
#  ('Ordinal suffix', 'ETH'),
#  ('Highway unit', 'LANE'),
#  ('"___ Dinka Doo"', 'INKA'),
#  ('Shield', 'EGIS'),
#  ('Hackman or Tierney', 'GENE'),
#  ('Work units', 'ERGS'),
#  ('Quirinal and Bunker, e.g.', 'HILLS'),
#  ('Sense', 'FEEL'),
#  ('Fractions', 'RATIOS'),
#  ('Minstrel-show instruments', 'BANJOS'),
#  ('Doorstep fixture', 'MAT'),
#  ('Cling to', 'ADHERE'),
#  ('"___ transit gloria . . . "', 'SIC'),
#  ('Harsh', 'UNKIND'),
#  ('Engrossed', 'RAPT'),
#  ("Seth's son", 'ENOS'),
#  ('Bristle', 'SETA'),
#  ('Photocopy', 'STAT'),
#  ('Movie-chain name', 'LOEW'),
#  ("Louisville's river", 'OHIO'),
#  ('Poetic word', 'EER'),
#  ('Mild rebuke', 'TUT'),
#  ('Viper', 'ASP'),
#  ('Sports place', 'ARENA'),
#  ('Love, in France', 'AIME'),
#  ('Improvise', 'ADLIB'),
#  ('Kind of ring', 'ONION'),
#  ('Kind of ade', 'LEMON'),
#  ('Bjorn Borg, e.g.', 'SWEDE'),
#  ('Expense', 'COST'),
#  ('Wall pier', 'ANTA'),
#  ('Unpleasant aftermath', 'SCAR'),
#  ("Omar's product", 'TENT'),
#  ('Covers', 'LIDS'),
#  ('___ out (endure)', 'RIDE'),
#  ('Shore, in Bonn', 'UFER'),
#  ('Enzyme suffix', 'ASE'),
#  ('___-la', 'TRA'),
#  ('Talks on and on', 'PRATES'),
#  ('Meal', 'REPAST'),
#  ('Kind of control', 'REMOTE'),
#  ('Springy', 'ELASTIC'),
#  ('Patriots of 1776', 'CONTINENTALARMY'),
#  ('Consumed', 'ATE'),
#  ('Giveaway-ad words', 'TAKEONE'),
#  ("Poet's word", 'EER'),
#  ("Parishioner's place", 'PEW'),
#  ('German article', 'EIN'),
#  ('___ the line', 'TOE'),
#  ('Nautical reading', 'ESE'),
#  ('Like some seals', 'EARLESS'),
#  ('Large cask', 'TUN'),
#  ('Meanders', 'STROLLS'),
#  ('Give orders', 'DICTATE'),
#  ('City way: Abbr.', 'AVE'),
#  ('Chinese leader', 'MAO'),
#  ('Have', 'POSSESS'),
#  ('Certain musician', 'HARPIST'),
#  ('Emmet', 'ANT'),
#  ('Protestant nonconformist', 'SECTARY'),
#  ('French sea', 'MER'),
#  ('Certain vote', 'YEA'),
#  ('Morsel', 'ORT'),
#  ('Be indebted', 'OWE'),
#  ('"___ in the stilly night"', 'OFT'),
#  ('___ pensée (hidden motive)', 'ARRIERE'),
#  ('Channel', 'GAT'),
#  ('Declaration signers', 'FOUNDINGFATHERS'),
#  ('Interdicted', 'FORBADE'),
#  ('Let go', 'UNHAND'),
#  ('Joined up with', 'TEAMED'),
#  ('Hosiery threads', 'LISLES'),
#  ('Dissent', 'PROTEST'),
#  ('Library user, at times', 'RENEWER'),
#  ('Quantity: Abbr.', 'AMT'),
#  ('Roof, in Paris', 'TOIT'),
#  ('Lab vessel', 'ETNA'),
#  ('Ones with a quest', 'SEEKERS'),
#  ('Modified colors again', 'RETONED'),
#  ('Spirit', 'ELAN'),
#  ('Lacking vigor', 'PALE'),
#  ('Blind ___ bat', 'ASA'),
#  ('Musical passage', 'STRETTA'),
#  ('Recess', 'TIMEOUT'),
#  ('Libyan resort', 'CYRENE'),
#  ("Matadors' needs", 'CAPES'),
#  ('Armstrong', 'NEIL'),
#  ('Little people', 'ELVES'),
#  ('Scabbard lining: Fr.', 'ALESE'),
#  ('Loose jacket', 'SIMAR'),
#  ('Frightening', 'SCARY'),
#  ('Western alliance', 'OAS'),
#  ('Spinner', 'TOP'),
#  ('Retribution', 'PAYOFF'),
#  ('Twelve inches', 'ONEFOOT'),
#  ('Importance', 'STATURE'),
#  ('" . . . like a woman ___"', 'SCORNED'),
#  ('Odious', 'HATEFUL'),
#  ('Miss Coca', 'IMOGENE'),
#  ('___ Folly (Alaska)', 'SEWARDS'),
#  ('Waste allowances', 'TRETS'),
#  ('Neat', 'TRIG'),
#  ('Genesis man', 'ADAM'),
#  ('Take for a ___', 'RIDE'),
#  ('Hindu queen', 'RANI'),
#  ('Anglo-Saxon letters', 'ETHS'),
#  ("Knicks' league: Abbr.", 'NBA'),
#  ('Prince ___', 'HAL'),
#  ("Skiers' lifts", 'TOWS'),
#  ('Midwest city', 'OMAHA'),
#  ('Bible book', 'ACTS'),
#  ('One of the five', 'ERIE'),
#  ('___ colony', 'PENAL'),
#  ('Hindu goddess of beauty', 'SHRI'),
#  ('Lofty words in an atlas', 'CANADIANROCKIES'),
#  ('Enlarges', 'ADDSONTO'),
#  ("MIG's and SST's", 'PLANES'),
#  ('Aviator Post', 'WILEY'),
#  ('Hashhouse', 'BEANERY'),
#  ('Like a knife', 'BLADED'),
#  ('Divides again', 'RECUTS'),
#  ('Ventilated', 'AIRED'),
#  ('Sensational', 'LURID'),
#  ('Compass point', 'ENE'),
#  ('Star in Cygnus', 'SADR'),
#  ('Buddhist writing', 'SUTRA'),
#  ('Prurient matter', 'SMUT'),
#  ('Silkworm', 'ERI'),
#  ('Shoddy', 'TATTY'),
#  ('Monotonous sound', 'CHANT'),
#  ('Obdurate: Var.', 'STONEY'),
#  ('Alternative', 'CHOICE'),
#  ('Plateaus', 'UPLANDS'),
#  ('Inexperienced', 'GREEN'),
#  ('Tricks', 'PRANKS'),
#  ("Referees' needs", 'WHISTLES'),
#  ('Narrow words in an atlas', 'SINGAPORESTRAIT'),
#  ('Taro root', 'EDDO'),
#  ('Miss Bordoni', 'IRENE'),
#  ('Nine: Prefix', 'ENNE'),
#  ('Hardy girl', 'TESS'),
#  ('Bivouac ingredients', 'TENTS'),
#  ('Paradise', 'EDEN'),
#  ('Mexican Indian', 'TECA'),
#  ('Toward the mouth', 'ORAD'),
#  ('Little words in a atlas', 'WINDWARDISLANDS'),
#  ('Coast dweller', 'SEASIDER'),
#  ('Thought', 'OPINED'),
#  ('Substantial', 'MEATY'),
#  ('___ Domini', 'ANNO'),
#  ('Cambridge university: Abbr.', 'HAR'),
#  ('Baldness', 'ALOPECIA'),
#  ('Obliquely', 'ASKANT'),
#  ('Big words in an atlas', 'CHINESEMAINLAND'),
#  ('Shoe-factory worker', 'TREER'),
#  ('Timid one', 'SISSY'),
#  ('Parceled out', 'DOLED'),
#  ("Man's name", 'CLAUD'),
#  ('Black, blue or straw', 'BERRY'),
#  ('Low', 'BASE'),
#  ('Prevaricator', 'LIAR'),
#  ('Like old roads', 'RUTTY'),
#  ('Musical instruments', 'LUTES'),
#  ('___ Dimittis', 'NUNC'),
#  ('Feminine ending', 'ETTE'),
#  ('Small point of land', 'SANDSPIT'),
#  ('Closet item', 'SHOETREE'),
#  ('Tropical bean', 'TONKA'),
#  ('Community ___', 'CHEST'),
#  ('Dances', 'TANGOS'),
#  ('Turning points', 'CRISES'),
#  ('In a dither', 'UPSET'),
#  ("Fall's precursor", 'PRIDE'),
#  ('Belgian city', 'GHENT'),
#  ('Songbird', 'WREN'),
#  ('German article', 'EINE'),
#  ('British gun', 'STEN'),
#  ('Smeltery material', 'ORE'),
#  ('Biblical mount', 'PISGAH'),
#  ('Musical introductions', 'PRELUDES'),
#  ('Prompt', 'ONTIME'),
#  ('Firmly determined', 'RESOLUTE'),
#  ('Roger Kahn novel', 'THEBOYSOFSUMMER'),
#  ('Axe, e.g.', 'HEWER'),
#  ('Curved moldings', 'OGEES'),
#  ('In favor of', 'PRO'),
#  ('Old English moneys', 'ORAS'),
#  ('Reporters: Abbr.', 'CORRS'),
#  ('Lairs', 'DENS'),
#  ('Celtic Neptune', 'LER'),
#  ('Siberian native', 'TATAR'),
#  ('___ mistake (erred)', 'MADEA'),
#  ('Minstrel-show performers', 'ENDMEN'),
#  ('Of the cheek', 'MALAR'),
#  ('French philosopher', 'STSIMON'),
#  ('Romantic demonstrations', 'LOVEINS'),
#  ('Asparagus unit', 'SPEAR'),
#  ('Failed to', 'DIDNOT'),
#  ('Make ___ (rendezvous)', 'ADATE'),
#  ('Affirmations', 'YESES'),
#  ('Moscow affiliate: Abbr.', 'SSR'),
#  ('Celsius units: Abbr.', 'DEGS'),
#  ('Nile dam site', 'ASWAN'),
#  ('Shower affection on', 'DOTE'),
#  ('Paddle', 'OAR'),
#  ('Done in', 'SLAIN'),
#  ('Soft drinks', 'COLAS'),
#  ('Subject of 17 Across', 'BROOKLYNDODGERS'),
#  ('Came from', 'EMANATED'),
#  ('Reveal', 'EVINCE'),
#  ('Ervin et al.', 'SENATORS'),
#  ('Fractions', 'NINTHS'),
#  ('Threats to auto axles', 'POTHOLES'),
#  ('Innate', 'INHERENT'),
#  ('Flight attendants', 'STEWARDS'),
#  ('Taunts', 'GIBES'),
#  ('Eros', 'AMOR'),
#  ('Attention-getter', 'HEY'),
#  ('Playbill', 'PROGRAM'),
#  ("Asterisk's function", 'REFERRAL'),
#  ('Letters', 'ESSES'),
#  ('Gehrig et al.', 'LOUS'),
#  ('Danube city', 'ULM'),
#  ('Unloaded', 'DUMPED'),
#  ('Everlasting, formerly', 'ETERNE'),
#  ('Insect membrane', 'SEROSA'),
#  ('Relative of fly ash', 'SOOT'),
#  ('Kayak', 'CANOE'),
#  ('Was adventurous', 'DARED'),
#  ('Phoenix suburb', 'TEMPE'),
#  ('Song thrush', 'MAVIS'),
#  ('Atomizer outputs', 'MISTS'),
#  ('Thick woolen cloth', 'LODEN'),
#  ('Contrary one', 'NAYSAYER'),
#  ('Disrespectful', 'INSOLENT'),
#  ('Collar-washing instruction', 'NOSTARCH'),
#  ('Emphasizes', 'STRESSES'),
#  ('Tape-recorder buttons', 'REWINDS'),
#  ('Earthen bricks', 'ADOBES'),
#  ('Alas!', 'DEARME'),
#  ('Let out ___ (show frustration)', 'AGROAN'),
#  ('Hourglass filler', 'SAND'),
#  ('___ the good', 'ALLTO'),
#  ('___ the manger', 'DOGIN'),
#  ('Card game', 'SKAT'),
#  ('Roman 406', 'CDVI'),
#  ('"Cat ___ Hot Tin Roof"', 'ONA'),
#  ('Wine: Prefix', 'OEN'),
#  ('Fix a hose hole', 'DARN'),
#  ("Strains, as one's brains", 'RACKS'),
#  ("Torero's wear", 'CAPA'),
#  ('Tropical oil tree', 'EBOE'),
#  ("Atlantic convoy's foe", 'UBOAT'),
#  ('Swan genus', 'OLOR'),
#  ('Certain sixth sense', 'WOMANSINTUITION'),
#  ('Allows', 'SUPPOSES'),
#  ('Pipe-bowl residue', 'DOTTLE'),
#  ('Prefix with fold or dent', 'TRI'),
#  ('"I ___ man with . . . "', 'META'),
#  ('City on the Arno', 'PISA'),
#  ('Like a friar', 'MONASTIC'),
#  ('Family members', 'MAIDENAUNTS'),
#  ('Mrs. Johnson', 'OSA'),
#  ('Early thrall', 'ESNE'),
#  ('Jet plane', 'SST'),
#  ('Hair coils', 'BUNS'),
#  ('Man of briefs: Abbr.', 'ATT'),
#  ('Worldly parent', 'MOTHEREARTH'),
#  ("Mother's order to child", 'DOASISAY'),
#  ('Cloth measures', 'ELLS'),
#  ('Shade givers', 'ELMS'),
#  ('Harden', 'GEL'),
#  ('Breastbone: Prefix', 'STERNO'),
#  ('___ the Mount', 'SERMONON'),
#  ('Fiancées, in a way', 'LADIESINWAITING'),
#  ('Helm direction', 'ALEE'),
#  ('Like some walls', 'IVIED'),
#  ('Work on copy', 'EDIT'),
#  ('___ wear', 'MENS'),
#  ('Cavalry piece', 'SABRE'),
#  ('Sleuths: Abbr.', 'DETS'),
#  ('Moistens', 'DEWS'),
#  ('Arabian father', 'ABOU'),
#  ('Cut a dido', 'ROMP'),
#  ('Ocean current', 'NEAPTIDE'),
#  ('Ballet or bank', 'RUSSIAN'),
#  ("Rose's Romeo", 'ABIE'),
#  ('Swindles', 'CONS'),
#  ('Arabian tea', 'KAT'),
#  ('Matriculant', 'STUDENT'),
#  ('Priestly surplices', 'COTTAS'),
#  ('Came down', 'ALIT'),
#  ('Relative of a cartel', 'POOL'),
#  ('British composer', 'ARNE'),
#  ('People of Bergen', 'NORSE'),
#  ('Small bits', 'IOTAS'),
#  ('Casino card game', 'MONTE'),
#  ('Ship of exploring fame', 'PINTA'),
#  ('Like an overripe melon', 'MUSHY'),
#  ("Cook's offerings", 'TOURS'),
#  ('"___ It Romantic?"', 'ISNT'),
#  ('Wherewithal', 'CASH'),
#  ('Lake or Margaret', 'MEAD'),
#  ('Concerning', 'ASTO'),
#  ('Movie dog et al.', 'ASTAS'),
#  ('Went to the polls', 'BALLOTED'),
#  ('A.A. ___', 'MILNE'),
#  ('Subtle absorption', 'OSMOSIS'),
#  ('Do a road job', 'REGRADE'),
#  ('Tropical resin', 'ELEMI'),
#  ('World ___', 'SERIES'),
#  ('Bridge bid', 'SLAM'),
#  ('Narrative', 'TALE'),
#  ('British P.M.', 'EDEN'),
#  ('Rebuff, Scottish style', 'SNIB'),
#  ('Pitcher', 'EWER'),
#  ('Brood of pheasants', 'NIDE'),
#  ('" . . . with a blue ribbon ___"', 'ONIT'),
#  ('Theater-ad abbr.', 'NGTS'),
#  ('Ragweed genus', 'IVA'),
#  ('"Uncle Vanya" author', 'CHEKHOV'),
#  ('Holy city', 'MECCA'),
#  ('Word with legs or cuffs', 'TROUSER'),
#  ('Dramatist of the absurd', 'IONESCO'),
#  ('One of a French trio', 'ATHOS'),
#  ('Great joy', 'RAPTURE'),
#  ('Potters', 'CLAYMEN'),
#  ('Hotel-desk postings', 'CHECKOUTTIMES'),
#  ('Intends', 'AIMS'),
#  ('Aardvark food', 'ANTS'),
#  ('Contents of certain books', 'CHECKS'),
#  ('Milk: Prefix', 'LACT'),
#  ('___ volente', 'DEO'),
#  ('Recent: Prefix', 'NEO'),
#  ('Bypass closely', 'SKIRT'),
#  ('Factions', 'SECTS'),
#  ('Irish cry', 'ARRA'),
#  ("Arthur's nephew", 'GAWAIN'),
#  ('Great Barrier Island', 'OTEA'),
#  ('Geste or Nash', 'BEAU'),
#  ('Sea flier', 'ERN'),
#  ('Sing loudly, with "out"', 'BELT'),
#  ('Palm leaf: Var.', 'OLA'),
#  ('English game pebble', 'CHECKSTONE'),
#  ('Makes inquiries', 'CHECKSUPON'),
#  ('Humperdinck boy', 'HANSEL'),
#  ('Base runner, at times', 'STEALER'),
#  ('Treatment', 'USAGE'),
#  ('Common abbr.', 'ETC'),
#  ('___ code', 'AREA'),
#  ('Ground defense: Abbr.', 'LAA'),
#  ('African native', 'SOMALI'),
#  ('Stopovers for game pieces', 'CHECKERBOARDSQUARES'),
#  ('Whistle stop', 'HAMLET'),
#  ('Gold tinctures', 'ORS'),
#  ('Plaster item', 'CAST'),
#  ("Rockefeller's oil: Abbr.", 'STD'),
#  ('Miss Adoree', 'RENEE'),
#  ("Contract's predecessor", 'AUCTION'),
#  ('Coin', 'SPECIE'),
#  ('Realists', 'ACTUALISTS'),
#  ('Full go-ahead', 'BLANKCHECK'),
#  ('Estes and Menlo: Abbr.', 'PKS'),
#  ('Bird plumage', 'RUFF'),
#  ('Owned', 'HAD'),
#  ("Creil's river", 'OISE'),
#  ('Elbe tributary', 'EGER'),
#  ('Object of perception', 'SENSUM'),
#  ('"What ___ God wrought!"', 'HATH'),
#  ('Samantha', 'EGGAR'),
#  ('Miss Kett et al.', 'ETTAS'),
#  ('Roman way', 'VIA'),
#  ('Relative: Abbr.', 'BRO'),
#  ('Skin', 'DERM'),
#  ('Sleigh puller', 'DASHER'),
#  ('Show surprise', 'GASP'),
#  ('Small herring', 'BRIT'),
#  ('Accurate one', 'DOUBLECHECKER'),
#  ('Most trim', 'TIDIEST'),
#  ("Harmonizers' girl", 'ADELINE'),
#  ('Type of song', 'THEME'),
#  ('Set apart', 'ISOLATE'),
#  ('Picks', 'SELECTS'),
#  ('As good ___', 'ASNEW'),
#  ('Early stringed instrument', 'CHEKKER'),
#  ('Large insect', 'CICADA'),
#  ('"___ than thou"', 'HOLIER'),
#  ('Charm', 'ENAMOR'),
#  ('Florida sights', 'KEYS'),
#  ('Royal initials', 'HSM'),
#  ('Kind of ography', 'OCEAN'),
#  ('Author Kurt', 'VONNEGUT'),
#  ('Raincoats, for short', 'MACS'),
#  ('Moral: Abbr.', 'ETH'),
#  ('Begin a hotel visit', 'CHECKIN'),
#  ('Chinese fowl', 'COCHIN'),
#  ('Suppliant', 'ASKER'),
#  ('Japanese bastion of W.W. II', 'TRUK'),
#  ('Zounds!', 'RATS'),
#  ('Decide', 'OPT'),
#  ('Practical', 'UTILE'),
#  ('Common field plant', 'SUMAC'),
#  ('Establish', 'ERECT'),
#  ('Shelters or hostels', 'RESTS'),
#  ('1905 manifesto', 'OCTOBER'),
#  ('___ tee', 'TOA'),
#  ('Hindu garment', 'SAREE'),
#  ('Japanese orange', 'SATSUMA'),
#  ('Fundamentals', 'ABCS'),
#  ('Traveled widely', 'WENTABOUT'),
#  ("Flatfoot's relative", 'TEC'),
#  ('Social-club member', 'ELK'),
#  ('Squeeze out', 'EKE'),
#  ('Abate, old style', 'ASLAKE'),
#  ('Give out iridescence', 'OPALESCE'),
#  ('Of a military science', 'LOGISTIC'),
#  ('Carbon: Suffix', 'ANE'),
#  ('Guevara', 'CHE'),
#  ('Kind of girl', 'HATCHECK'),
#  ('Delights', 'ENCHANTS'),
#  ('Dare: Fr.', 'OSER'),
#  ("Goodman's instr.", 'CLAR'),
#  ('Sniffles', 'HEADCOLDS'),
#  ('Asian grass', 'USAR'),
#  ('As ___ resort', 'ALAST'),
#  ('Soak', 'RET'),
#  ('Trafalgar and Times: Abbr.', 'SQS'),
#  ('Excel in the slalom', 'OUTSKI'),
#  ('Tall bird', 'EMEU'),
#  ('Less smoggy', 'CLEARER'),
#  ('Grampuses', 'ORCS'),
#  ('Arabian capital', 'SANA'),
#  ('Ten: Prefix', 'DEK'),
#  ('Door sound', 'RAP'),
#  ('___ as a daisy', 'ASFRESH'),
#  ('Borneo natives', 'IBANS'),
#  ('Portions: Abbr.', 'PCS'),
#  ('Querying sounds', 'EHEH'),
#  ('Haul', 'LUG'),
#  ('Bowstring hemp', 'IFE'),
#  ('Based on moral law', 'NOMISTIC'),
#  ('Listen carefully', 'HEARKEN'),
#  ('Crams, in Scotland', 'STECHS'),
#  ('Grape', 'UVA'),
#  ('Take ___ (rest)', 'ABREAK'),
#  ('Sad, in Dijon', 'TRISTE'),
#  ('More biting', 'HOTTER'),
#  ('Norse tales', 'EDDAS'),
#  ('Hollow stone', 'GEODE'),
#  ('Thin cereal', 'GRUEL'),
#  ('Stroll along', 'AMBLE'),
#  ('Greek letter', 'THETA'),
#  ('Clownlike', 'APISH'),
#  ('Parking-lot hazard', 'DENT'),
#  ('Honor cards', 'ACES'),
#  ('Expanded', 'GREW'),
#  ('Swindle', 'BILK'),
#  ('Auto plate: Abbr.', 'LIC'),
#  ('Uncle, in Perth', 'EME'),
#  ('Deer', 'DOE'),
#  ('___ ground (regress)', 'LOSE'),
#  ('Big success', 'SMASH'),
#  ('Blue or poker', 'CHIP'),
#  ('To ___', 'AMAN'),
#  ('Put aside', 'PIGEONHOLE'),
#  ('Proceeds steadily', 'HOLDSONESCOURSE'),
#  ('Seafood delicacy', 'ROE'),
#  ('Greek goddess', 'ERIS'),
#  ('Kind of tube', 'INNER'),
#  ('Barracudas', 'SPETS'),
#  ('___ out (spend)', 'FORK'),
#  ('Network', 'LACIS'),
#  ('"___ were the days"', 'THOSE'),
#  ('Greek letter', 'CHI'),
#  ('Key', 'ISLET'),
#  ('Fatha Hines', 'EARL'),
#  ('Hangar', 'SHED'),
#  ('In ___ (eventually)', 'THECOURSEOFTIME'),
#  ('Present', 'HERE'),
#  ('Jets', 'SSTS'),
#  ('Where strikes are appreciated', 'LANES'),
#  ('Arctic native: Abbr.', 'ESK'),
#  ('Influence', 'GETAT'),
#  ('Abounding in: Suffix', 'ULENT'),
#  ('Foot: Prefix', 'PEDO'),
#  ('Arctic sights', 'FLOES'),
#  ("Nora's creator", 'IBSEN'),
#  ('Tale-teller', 'LIAR'),
#  ('___ up (delight in)', 'EAT'),
#  ('Let things ___ (leave alone)', 'TAKETHEIRCOURSE'),
#  ('One shifted to a new post', 'TRANSFEREE'),
#  ('___-do-well', 'NEER'),
#  ("Stable-owner's purchase", 'OATS'),
#  ('Kind of conscious', 'CLASS'),
#  ('Cheese', 'EDAM'),
#  ('Memorable comic', 'LAHR'),
#  ('Melville creation', 'OMOO'),
#  ('Store employee', 'SALESCLERK'),
#  ('Result', 'END'),
#  ('Kind of shirt', 'SPORT'),
#  ('Cares for', 'MINISTERSTO'),
#  ('Stone et al.', 'AGES'),
#  ('His, in Le Mans', 'SES'),
#  ('Ad ___', 'HOC'),
#  ('Piece', 'CHUNK'),
#  ('___ in (interfere)', 'HORN'),
#  ("Girl's name in Bonn", 'ILSE'),
#  ('Titled one', 'PEER'),
#  ('Black, in France', 'NOIRE'),
#  ('Looks after', 'SEESTO'),
#  ('Word with work or meal', 'PIECE'),
#  ("Rangers' concerns", 'FORESTFIRES'),
#  ('European capital', 'OSLO'),
#  ('Supple', 'LITHE'),
#  ('Residue', 'ASHES'),
#  ('___ luego (good-by)', 'HASTA'),
#  ('Color', 'CHINESERED'),
#  ('Virile ones', 'HEMEN'),
#  ('Common Latin phrase', 'IDEST'),
#  ('Like some jokes', 'STALE'),
#  ('Put into practice', 'USED'),
#  ('Chemical prefix', 'FLUORO'),
#  ('Chaps', 'GENTS'),
#  ('Hammer parts', 'PEENS'),
#  ('Spikes the punch', 'LACES'),
#  ('"Tell ___ the Marines"', 'ITTO'),
#  ('Theda', 'BARA'),
#  ('Card game', 'SKAT'),
#  ('European money', 'LIRA'),
#  ('Bewildered', 'ASEA'),
#  ('Duration', 'TERM'),
#  ('Electrical abbr.', 'HFC'),
#  ('Slippery one', 'EEL'),
#  ('French article', 'UNE'),
#  ('Hemingway', 'PAPA'),
#  ('Bout', 'SETTO'),
#  ('Declines', 'EBBS'),
#  ('Final or midterm event', 'EXAM'),
#  ('Group character', 'ETHOS'),
#  ('Mrs. Nick Charles', 'NORA'),
#  ("Like Dali's watches", 'LIMP'),
#  ('Rec and living', 'ROOMS'),
#  ('Hamilton-Burr meet', 'DUEL'),
#  ('Recipe abbr.', 'TSP'),
#  ('"Je ___ beaucoup"', 'TAIME'),
#  ("Guy's friend", 'GAL'),
#  ('Furor', 'HOOPLA'),
#  ('Four score', 'EIGHTY'),
#  ('"We ___" (with 43 Across)', 'HOLDTHESETRUTHS'),
#  ('Garbo, e.g.', 'SWEDE'),
#  ('He had not yet begun to fight', 'JONES'),
#  ('Asian holiday', 'TET'),
#  ('Madison Square Garden, e.g.', 'ARENA'),
#  ('___ Jeanne', 'STE'),
#  ('Musical symbol', 'GCLEF'),
#  ('Turns up a card', 'FACES'),
#  ('See 28 Across', 'TOBESELFEVIDENT'),
#  ('Bryant and Loos', 'ANITAS'),
#  ('Ace, as part of a blackjack', 'ELEVEN'),
#  ('Knowledge', 'KEN'),
#  ('Derrick', 'CRANE'),
#  ('Also', 'AND'),
#  ('Catchall abbr.', 'ETAL'),
#  ('Affirm', 'POSIT'),
#  ('Canal', 'ERIE'),
#  ('Shredded', 'TORE'),
#  ('Unique', 'ALONE'),
#  ("___ days' wonder", 'NINE'),
#  ('Former movie czar Will', 'HAYS'),
#  ('Approached an end', 'WANED'),
#  ('Soft ___ (flattery)', 'SOAP'),
#  ('Hide', 'PELT'),
#  ('W. W. II losers', 'AXIS'),
#  ('"Common Sense," e.g.', 'PAMPHLET'),
#  ('Elec. unit', 'AMP'),
#  ('Angel', 'SERAPH'),
#  ("Paris's Place d' ___", 'ETOILE'),
#  ('Author of 28 Across', 'THOMASJEFFERSON'),
#  ('Scholarly volume', 'TOME'),
#  ('W. W. II agency', 'OSS'),
#  ('Wind up', 'END'),
#  ('Bribed, as a public official', 'BOUGHT'),
#  ('Slightest hint', 'BREATH'),
#  ('Kellerman and Rand', 'SALLYS'),
#  ('Carry', 'TOTE'),
#  ('___ man out', 'ODD'),
#  ('Volcano', 'ETNA'),
#  ('Choler', 'IRE'),
#  ('Astronaut Grissom', 'GUS'),
#  ('White House monogram', 'HST'),
#  ('Be in the red', 'OWE'),
#  ('Time period', 'EON'),
#  ('Beverages', 'ALES'),
#  ('Kind of pronoun: Abbr.', 'REL'),
#  ("Film-director's bible", 'SCENARIO'),
#  ('Sawbuck', 'TEN'),
#  ('Part of i.e.', 'EST'),
#  ('Fetch', 'GET'),
#  ("Lee's group: Abbr.", 'CSA'),
#  ('Fin', 'FIVE'),
#  ('Summer cooler', 'ADE'),
#  ('"And the Lord ___ away"', 'TAKETH'),
#  ('___ customer', 'ONETOA'),
#  ('Consisting of two', 'BINARY'),
#  ('Miss Stritch', 'ELAINE'),
#  ("Loosed, as one's fury", 'VENTED'),
#  ('Soft drink', 'COLA'),
#  ("Pinta's partner", 'NINA'),
#  ('Intense', 'DEEP'),
#  ('French article', 'LES'),
#  ('Handle roughly', 'PAW'),
#  ('Type measures', 'ENS'),
#  ('Pith helmet', 'TOPI'),
#  ('Halloween choice', 'TRICK'),
#  ('Church area', 'APSE'),
#  ('N.C. College', 'ELON'),
#  ('Tidal wave', 'EAGRE'),
#  ('Fish bait', 'CHUM'),
#  ('Obvious', 'SELFEXPLANATORY'),
#  ('Trifled', 'TOYED'),
#  ('Awkward boat', 'TUB'),
#  ('Water pots of India', 'LOTAS'),
#  ('___ and Thummim', 'URIM'),
#  ('Spanish painter', 'MIRO'),
#  ('Newspaper section: Abbr.', 'FIN'),
#  ('Asian palm', 'TALIPOT'),
#  ('Prod', 'JAB'),
#  ('Besides', 'ALSO'),
#  ('Wanderer', 'NOMAD'),
#  ('___ de force', 'TOUR'),
#  ('Coin of Iran', 'RIAL'),
#  ('Century plant', 'AGAVE'),
#  ('Rough', 'RUDE'),
#  ('Attractive', 'CUTE'),
#  ('Roman menswear', 'TOGAS'),
#  ('Silkworm', 'ERIA'),
#  ("Ostrich's relative", 'EMU'),
#  ('Takes umbrage', 'RESENTS'),
#  ('Land of ___', 'NOD'),
#  ('Dissolute one', 'ROUE'),
#  ('Mental discipline', 'YOGA'),
#  ('Freshwater fish', 'ROACH'),
#  ('Shinto temple', 'SHA'),
#  ("La Scala's locale", 'MILAN'),
#  ('Cannibal', 'ANTHROPOPHAGITE'),
#  ('Brain passage', 'ITER'),
#  ('Jewish festival', 'PURIM'),
#  ("One of Ibsen's homes", 'OSLO'),
#  ('Ore deposit', 'LODE'),
#  ('Indian coins', 'ANNAS'),
#  ('Feds', 'TMEN'),
#  ('Exam', 'TEST'),
#  ('Toast additive', 'OLEO'),
#  ('Like 2 Down', 'POLYUNSATURATED'),
#  ('Conclude', 'INFER'),
#  ('Ritter or Antoine', 'TEX'),
#  ('Transported', 'RAPT'),
#  ('Eskimo hut', 'IGLU'),
#  ('Curmudgeon', 'CRAB'),
#  ('Understanding', 'KEN'),
#  ('Performer', 'ACTOR'),
#  ('Special type of reporting', 'PHOTOJOURNALISM'),
#  ('Koran chapter', 'SURA'),
#  ('Tortoise genus', 'EMYS'),
#  ('Work on copy', 'EDIT'),
#  ('Landed', 'ALIT'),
#  ('Sea cow', 'MANATEE'),
#  ('Decorum', 'MODESTY'),
#  ("Molière's forte", 'FARCE'),
#  ('Troy, to Caesar', 'ILIUM'),
#  ...]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (602694, 604)

# %%
# Vectorize Clues
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(strip_accents="unicode", stop_words="english")
X_train = vectorizer.fit_transform(np.array(clues_train))
X_train

# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)
# Out:
# <602694x69151 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1250019 stored elements in Compressed Sparse Row format>

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors().fit(X_train)
model
# Out:
# NearestNeighbors()

# %%
# Define a guesser function (just for testing; real one defined in guesser.py)
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector = vectorizer.transform([clue])
    distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
    raw_guesses = [answers_train[i] for i in indices[0]]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue.lower()
        return o
    
    guesses = [(g, d) for g, d in zip(raw_guesses, distances[0]) if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
i = random.randint(0, len(clues_test))
test_clue, test_answer = clues_test[i], answers_test[i]
print("clue:", test_clue)
print("answer:", test_answer)

# distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# print("guesses:", [answers_train[i] for i in indices[0]])

guesses = guess(test_clue, slot_length=len(test_answer))
print("guesses:", guesses)
# Out:
# clue: Stable sound
# answer: SNORT
# guesses: [('SNORT', 0.0), ('SNORT', 0.0), ('SNORT', 0.0), ('SNORT', 0.0), ('SNORT', 0.0)]

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
    if i % 100 == 0: print(i)
    guesses = guess(clue, len(answer), max_guesses=5)
    if answer in [g for g, _  in guesses]:
        correct_pairs.append((clue, answer, guesses))
    else:
        incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# Accuracy: 53.477%

# %%
incorrect_pairs
# Out:
# [('Home to Mongolian nomads',
#   'GOBI',
#   [('ROAM', 0.7718960938600217),
#    ('LIAO', 0.977808721976523),
#    ('AWRY', 0.9999999999999999),
#    ('REAP', 0.9999999999999999),
#    ('SOME', 0.9999999999999999)]),
#  ('Not quite shut',
#   'AJAR',
#   [('AJAR', 0.0),
#    ('PENT', 0.7362248697839477),
#    ('COOP', 0.7362248697839477),
#    ('PENT', 0.7362248697839477),
#    ('PENT', 0.7362248697839477)]),
#  ('Where to spend soles',
#   'PERU',
#   [('FORK', 0.8754835397567163),
#    ('STAY', 0.9740120920664912),
#    ('ERST', 1.0),
#    ('OVER', 1.0),
#    ('CHIT', 1.0)]),
#  ('Conjunctions',
#   'ANDS',
#   [('ANDS', 0.0),
#    ('ANDS', 0.5839765929007059),
#    ('ANDS', 0.5839765929007059),
#    ('NORS', 0.672840283611738),
#    ('NETS', 1.0)]),
#  ('It can take your breath away', 'AEROBICEXERCISE', []),
#  ('Kind of soldier',
#   'FOOT',
#   [('AWOL', 0.5539443648594926),
#    ('AWOL', 0.5539443648594926),
#    ('EASE', 0.6509340806138205),
#    ('UNIT', 0.7999843462250305),
#    ('YANK', 0.8300782705937487)]),
#  ('Landing info, briefly',
#   'ETA',
#   [('ETA', 0.6372291038315453),
#    ('ETD', 0.9225427245848414),
#    ('ETA', 0.9225427245848414),
#    ('ETA', 0.9225427245848414),
#    ('ETA', 0.9225427245848414)]),
#  ('"Harvey" hero Elwood P. ___',
#   'DOWD',
#   [('DOWD', 0.5482271783431057),
#    ('SCAN', 0.9999999999999999),
#    ('SWAP', 0.9999999999999999),
#    ('OHNO', 0.9999999999999999),
#    ('HAST', 0.9999999999999999)]),
#  ('Silent star with opera star', 'NALDIANDTEBALDI', []),
#  ("Andy's partner",
#   'AMOS',
#   [('AMOS', 0.0), ('AMOS', 0.0), ('AMOS', 0.0), ('AMOS', 0.0), ('AMOS', 0.0)]),
#  ('Its page numbers are often Roman numerals',
#   'FOREWORD',
#   [('SEPARATE', 0.9999999999999999)]),
#  ('Soprano Eames',
#   'EMMA',
#   [('EMMA', 0.0),
#    ('EMMA', 0.0),
#    ('EMMA', 0.0),
#    ('EMMA', 0.0),
#    ('EMMA', 0.889879690899407)]),
#  ('Catkins',
#   'AMENTS',
#   [('AMENTS', 0.0),
#    ('AMENTS', 0.0),
#    ('AMENTS', 0.0),
#    ('ALDERS', 0.6492881606424158),
#    ('AMENTS', 0.7890216128507419)]),
#  ('Twaddle', 'DRIVEL', [('DRIVEL', 0.0), ('DRIVEL', 0.0), ('UNLESS', 1.0)]),
#  ('Where Ogden is',
#   'UTAH',
#   [('NASH', 0.5904427428287713),
#    ('NASH', 0.5904427428287713),
#    ('NASH', 0.5904427428287713),
#    ('NASH', 0.5904427428287713),
#    ('NASH', 0.5904427428287713)]),
#  ("John Wayne's last film", 'THESHOOTIST', []),
#  ('Old coin?', 'EAGLEEAGLE', []),
#  ('"___ Noster"',
#   'PATER',
#   [('PATER', 0.0),
#    ('PRAYS', 0.9223848560519567),
#    ('STERN', 1.0),
#    ('ASTIR', 1.0),
#    ('EARLY', 1.0)]),
#  ('Where to locate 30 Down',
#   'ATLAS',
#   [('TRACE', 0.8487912751896458),
#    ('PEARL', 0.8916982840999015),
#    ('HORSE', 0.8916982840999015),
#    ('TITLE', 0.8916982840999015),
#    ('STAVE', 0.8916982840999015)]),
#  ('Winner of a race',
#   'ELECTEE',
#   [('ENTRIES', 0.7169851757465673), ('QUICKEN', 0.7169851757465673)]),
#  ('Pianist Templeton',
#   'ALEC',
#   [('ALEC', 0.0), ('ALEC', 0.0), ('ALEC', 0.0), ('ALEC', 0.0), ('ALEC', 0.0)]),
#  ('Much simpler time', 'STONEAGE', []),
#  ('With 64-Down, a down-home pronoun',
#   'YOU',
#   [('DEL', 0.8242389066834729),
#    ('MRS', 0.8242389066834729),
#    ('SOL', 0.8242389066834729),
#    ('ITS', 0.8990843687013308),
#    ('ONE', 0.8990843687013308)]),
#  ('Blow', 'ERUPT', [('IRATE', 0.0), ('ERUPT', 0.0), ('SNORE', 0.0)]),
#  ('Moslem spirit',
#   'JINNI',
#   [('MOXIE', 0.7638246474691818),
#    ('SHADE', 0.7638246474691818),
#    ('GUSTO', 0.7638246474691818),
#    ('GENIE', 0.7638246474691818),
#    ('GENIE', 0.7638246474691818)]),
#  ('Daze',
#   'STUPOR',
#   [('STUPOR', 0.0),
#    ('TRANCE', 0.0),
#    ('STUPOR', 0.0),
#    ('BENUMB', 0.0),
#    ('STUPOR', 0.0)]),
#  ('Anthem for a monarch',
#   'GODSAVETHEQUEEN',
#   [('FRANCISSCOTTKEY', 0.8948220419423215),
#    ('FRANCISSCOTTKEY', 0.8948220419423215),
#    ('DAWNSEARLYLIGHT', 0.9112997632766224),
#    ('ROCKETSREDGLARE', 0.9112997632766224),
#    ('SEATOSHININGSEA', 0.9149656260480785)]),
#  ('Man of tales',
#   'ELIA',
#   [('LAMB', 0.0),
#    ('LAMB', 0.0),
#    ('ELIA', 0.0),
#    ('LORE', 0.612544066533444),
#    ('TALL', 0.7698777149979666)]),
#  ('River with the Reichenbach Falls',
#   'AARE',
#   [('LAGS', 0.5828371620620026),
#    ('BUYS', 0.5828371620620026),
#    ('LAGS', 0.5828371620620026),
#    ('LAGS', 0.5828371620620026),
#    ('LAGS', 0.5828371620620026)]),
#  ('Jump',
#   'LEAP',
#   [('LEAP', 0.0), ('SKIP', 0.0), ('OMIT', 0.0), ('OMIT', 0.0), ('LEAP', 0.0)]),
#  ("Girl's name",
#   'DIANE',
#   [('KATHY', 0.0), ('CARLA', 0.0), ('DELIA', 0.0), ('MISSY', 0.0)]),
#  ('"S.W.A.T." lieutenant of 70\'s TV',
#   'HONDO',
#   [('LOOEY', 0.9009642348940162),
#    ('JUANA', 0.9263768088848205),
#    ('DAVID', 0.9263768088848205),
#    ('SLANG', 0.9263768088848205),
#    ('ALLEN', 0.9263768088848205)]),
#  ('Cartoon film art',
#   'CEL',
#   [('DOH', 0.8313008822403865), ('EEK', 0.8313008822403865)]),
#  ('Quasi',
#   'ASIF',
#   [('ASIF', 0.0),
#    ('ASIF', 0.0),
#    ('ASIF', 0.0),
#    ('OLEO', 0.7717903097405843),
#    ('IRAE', 1.0)]),
#  ('Peeping Tom',
#   'SPIER',
#   [('SPIER', 0.0),
#    ('SPIER', 0.0),
#    ('SPYER', 0.0),
#    ('CREEP', 0.0),
#    ('PAINE', 0.9053905420489573)]),
#  ('Chinese secret society',
#   'TONG',
#   [('TONG', 0.0), ('TONG', 0.0), ('TONG', 0.0), ('TONG', 0.0), ('TONG', 0.0)]),
#  ('Furniture launched from the starship Enterprise?', 'FUTONTORPEDOES', []),
#  ('Others, in Latin',
#   'ALII',
#   [('ESSE', 0.0), ('ALII', 0.0), ('ESSE', 0.0), ('ERAT', 0.0), ('ESSE', 0.0)]),
#  ('Former filly',
#   'MARE',
#   [('MARE', 0.0),
#    ('LASS', 0.0),
#    ('OATS', 0.0),
#    ('FOAL', 0.0),
#    ('SIRE', 0.6126846869163223)]),
#  ("Director's order",
#   'AGAIN',
#   [('STONE', 0.7563710641124056),
#    ('ARROW', 0.7563710641124056),
#    ('ASHBY', 0.7563710641124056),
#    ('CAPRA', 0.7563710641124056),
#    ('ALIGN', 0.77434456084092)]),
#  ('Popular rock/rap/funk group', 'HOTCHILIPEPPERS', []),
#  ('Mentalist Geller',
#   'URI',
#   [('URI', 0.0), ('URI', 0.0), ('URI', 0.0), ('URI', 0.0), ('URI', 0.0)]),
#  ("Dep's. counterpart",
#   'ARR',
#   [('STA', 0.6618666172974951),
#    ('STA', 0.6618666172974951),
#    ('STA', 0.6618666172974951),
#    ('STA', 0.6618666172974951),
#    ('STA', 0.6618666172974951)]),
#  ('Balance sheet heading', 'PAYABLES', [('UNEVENLY', 0.8912409012565852)]),
#  ('Like cherry-flavored things',
#   'RED',
#   [('DRY', 1.0), ('LED', 1.0), ('NIL', 1.0), ('NIL', 1.0)]),
#  ('Date-book abbr.',
#   'APPT',
#   [('APPT', 0.6018849494639515),
#    ('APPT', 0.6018849494639515),
#    ('ESTD', 0.6018849494639515),
#    ('ESTD', 0.6018849494639515),
#    ('DDAY', 0.7856117503986287)]),
#  ('___ judgment (misthinks)', 'ERRSIN', [('SANELY', 0.33308581384234787)]),
#  ('Most fastidious', 'NEATEST', [('AVERAGE', 1.0)]),
#  ('South American monkey',
#   'TITI',
#   [('TITI', 0.0), ('TITI', 0.0), ('TITI', 0.0), ('TITI', 0.0), ('TITI', 0.0)]),
#  ('"Scram!"',
#   'GIT',
#   [('GIT', 0.0), ('GIT', 0.0), ('GIT', 0.0), ('GIT', 0.0), ('GIT', 0.0)]),
#  ('Hit TV show that ended in 2011',
#   'OPRAH',
#   [('ADELE', 0.9253384214646949),
#    ('RENEW', 0.9999999999999999),
#    ('AHYES', 0.9999999999999999),
#    ('PERKY', 0.9999999999999999)]),
#  ('Comic Sahl',
#   'MORT',
#   [('MORT', 0.5837369459368646),
#    ('MORT', 0.5837369459368646),
#    ('MORT', 0.8057671541234834),
#    ('MORT', 0.8341605749755469),
#    ('MORT', 0.8466387785290027)]),
#  ('Degree div.',
#   'MIN',
#   [('MIN', 0.0),
#    ('DOD', 0.6910999084719605),
#    ('SYL', 0.8358088378446193),
#    ('PHD', 0.8384170793764303),
#    ('PHD', 0.8384170793764303)]),
#  ('Natural disasters', 'CATACLYSMS', []),
#  ('Trillionth: Prefix',
#   'PICO',
#   [('PICO', 0.0),
#    ('PICO', 0.0),
#    ('PICO', 0.7840633643372514),
#    ('PSEC', 0.8881443153300794),
#    ('NOTA', 1.0)]),
#  ('Campus area',
#   'QUAD',
#   [('QUAD', 0.0),
#    ('QUAD', 0.0),
#    ('QUAD', 0.0),
#    ('DEAN', 0.7088789733901837),
#    ('DEAN', 0.7088789733901837)]),
#  ('Stone and Iron',
#   'AGES',
#   [('AGES', 0.0),
#    ('AGES', 0.0),
#    ('CLUB', 0.7397877837860738),
#    ('WOOD', 0.7397877837860738),
#    ('PELT', 0.7908001012671816)]),
#  ('Part of a golf ball', 'DIMPLE', []),
#  ('Nymphets', 'LOLITAS', []),
#  ('Somewhat tardy',
#   'LATISH',
#   [('LATISH', 0.0),
#    ('FAIRLY', 0.8212228124112971),
#    ('INPART', 0.8212228124112971)]),
#  ('Pop',
#   'DAD',
#   [('DAD', 0.0), ('PER', 0.0), ('DAD', 0.0), ('PER', 0.0), ('DAD', 0.0)]),
#  ('Frankfurt-to-Copenhagen dir.',
#   'NNE',
#   [('AUS', 0.8756614845329742),
#    ('SSE', 0.8928781080497192),
#    ('SSE', 0.8928781080497192),
#    ('ORE', 0.9928853527941396),
#    ('ICH', 0.9972946573356686)]),
#  ('Put into a computer',
#   'ENTER',
#   [('EVITE', 0.0),
#    ('ERROR', 0.42196779289799025),
#    ('ENIAC', 0.7377030554284284),
#    ('ENIAC', 0.7377030554284284)]),
#  ('Form a league',
#   'FEDERATE',
#   [('SUBPOENA', 0.8818122438428481), ('NATIONAL', 0.8877392215633557)]),
#  ('Salvation Army donation receptacle',
#   'KETTLE',
#   [('DONATE', 0.9245296516687896)]),
#  ('Classic novel that ends with two weddings',
#   'EMMA',
#   [('SWAP', 1.0), ('ABED', 1.0), ('BETS', 1.0), ('ERAT', 1.0), ('DATE', 1.0)]),
#  ('In ___ (disordered)',
#   'AMESS',
#   [('MESSY', 0.2802317045446426),
#    ('MESSY', 0.2802317045446426),
#    ('EVERY', 0.44676017897669634),
#    ('AGAIN', 1.0),
#    ('GRADE', 1.0)]),
#  ('To me, to Michel',
#   'AMOI',
#   [('AMOI', 0.0),
#    ('MONT', 0.6185483407947449),
#    ('ARME', 0.873748289683632),
#    ('CONS', 1.0),
#    ('ATTY', 1.0)]),
#  ('Pucker-inducing fruit',
#   'LEMON',
#   [('CRIMP', 0.8333492161037916),
#    ('PURSE', 0.8333492161037916),
#    ('PURSE', 0.8333492161037916),
#    ('LEMON', 0.9576888405337595),
#    ('EATIN', 0.9916734665081541)]),
#  ('Food in red paraffin',
#   'EDAM',
#   [('EDAM', 0.8129279552084716),
#    ('EDAM', 0.9701909522035789),
#    ('INTO', 1.0),
#    ('AFEW', 1.0),
#    ('AMID', 1.0)]),
#  ("San Francisco's ___ Valley",
#   'NOE',
#   [('NOE', 0.0),
#    ('NOE', 0.0),
#    ('NOB', 0.7638139039958162),
#    ('NOB', 0.7638139039958162),
#    ('NOB', 0.7638139039958162)]),
#  ('Extra added detraction?', 'FINANCECHARGE', []),
#  ('Buried treasure site, maybe',
#   'ISLE',
#   [('MINE', 0.5880323119846311), ('LOVE', 0.9491329735971151)]),
#  ('Charlie Brown expletive',
#   'RATS',
#   [('RATS', 0.0),
#    ('RATS', 0.789575468529754),
#    ('UGHS', 0.810818982505971),
#    ('OATH', 0.850021696577009),
#    ('OATH', 0.850021696577009)]),
#  ('"Power" star, 1986',
#   'GERE',
#   [('DINT', 0.9014982463992715),
#    ('RULE', 0.9014982463992715),
#    ('FUEL', 0.9014982463992715),
#    ('USSR', 0.9014982463992715),
#    ('UTIL', 0.9014982463992715)]),
#  ('Plastic building block',
#   'LEGO',
#   [('LEGO', 0.668125609024345),
#    ('LEGO', 0.668125609024345),
#    ('ATOM', 0.8059395572694097),
#    ('LEGO', 0.8206935824644074),
#    ('LEGO', 0.8206935824644074)]),
#  ('Of an Islamic mysticism',
#   'SUFIC',
#   [('EMEER', 0.8630242608618278),
#    ('ARISE', 1.0),
#    ('SORRY', 1.0),
#    ('CHASE', 1.0),
#    ('LATIN', 1.0)]),
#  ("Gen. Pershing's command",
#   'AEF',
#   [('AEF', 0.30478142425872634),
#    ('AEF', 0.565351800288948),
#    ('AEF', 0.565351800288948),
#    ('AEF', 0.565351800288948),
#    ('AEF', 0.7930702105222415)]),
#  ('Bothers',
#   'AILS',
#   [('ADOS', 0.0), ('IRKS', 0.0), ('ADOS', 0.0), ('IRKS', 0.0), ('IRKS', 0.0)]),
#  ('Hit song by Donovan, 1966', 'MELLOWYELLOW', []),
#  ("Item in a photog's file",
#   'NEG',
#   [('NEG', 0.608469730938092),
#    ('ENL', 0.8719401843155341),
#    ('ENL', 0.8719401843155341),
#    ('ENL', 0.8719401843155341),
#    ('ENL', 0.8719401843155341)]),
#  ('Coveleski of Cooperstown',
#   'STAN',
#   [('COBB', 0.8804427418805546),
#    ('DEAN', 0.8804427418805546),
#    ('TRIS', 0.8804427418805546),
#    ('MAYS', 0.8804427418805546),
#    ('STAN', 0.957352811712068)]),
#  ('"___ Abby"',
#   'DEAR',
#   [('DEAR', 0.0),
#    ('DEAR', 0.0),
#    ('DEAR', 0.581469399073179),
#    ('DEAR', 0.6593385446622007),
#    ('TWIN', 0.7437685233527888)]),
#  ('Washbowl',
#   'BASIN',
#   [('BASIN', 0.0),
#    ('BASIN', 0.0),
#    ('BASIN', 0.6646275067430109),
#    ('ASYET', 1.0),
#    ('YESES', 1.0)]),
#  ('Poker term',
#   'ANTE',
#   [('ANTE', 0.0),
#    ('ANTE', 0.0),
#    ('IMIN', 0.7694986458039068),
#    ('HILO', 0.914825535028296),
#    ('ALEE', 0.9499758489034288)]),
#  ('Row in reverse', 'BACKWATER', []),
#  ('Uneven',
#   'EROSE',
#   [('EROSE', 0.0),
#    ('EROSE', 0.0),
#    ('EROSE', 0.0),
#    ('EROSE', 0.0),
#    ('EROSE', 0.0)]),
#  ('Knuckleballer ___ Wilhelm',
#   'HOYT',
#   [('EINE', 0.8347837311022831),
#    ('HOYT', 0.9637912091919134),
#    ('ERST', 1.0),
#    ('SHED', 1.0),
#    ('ESSE', 1.0)]),
#  ('Hot',
#   'SEXY',
#   [('IRED', 0.0), ('SEXY', 0.0), ('MILD', 0.0), ('RAGE', 0.0), ('SOSO', 0.0)]),
#  ('Where Venetians bask',
#   'LIDO',
#   [('LIDO', 0.8825296701364915),
#    ('LIDO', 0.8825296701364915),
#    ('COST', 1.0),
#    ('NETS', 1.0),
#    ('SCAT', 1.0)]),
#  ('Grasped', 'SENSED', [('UNLESS', 1.0), ('FIGURE', 1.0)]),
#  ('N.C.A.A. part: Abbr.', 'ASSOC', []),
#  ('Air for Amara',
#   'ARIA',
#   [('AURA', 0.0), ('MIEN', 0.0), ('ODOR', 0.0), ('IFFY', 0.0), ('MIEN', 0.0)]),
#  ('Flying machines, for short',
#   'AEROS',
#   [('ALOFT', 0.8948146453077318),
#    ('SLOTS', 0.9882813773424298),
#    ('ASTIR', 1.0),
#    ('TOTAL', 1.0)]),
#  ('Mata ___',
#   'HARI',
#   [('HARI', 0.0), ('HARI', 0.0), ('HARI', 0.0), ('HARI', 0.0), ('HARI', 0.0)]),
#  ('Suffix with diet or planet',
#   'ARY',
#   [('OID', 0.6808087740236722),
#    ('OID', 0.6808087740236722),
#    ('OID', 0.6808087740236722),
#    ('FAT', 0.8483510055232668),
#    ('ORB', 0.869744094392776)]),
#  ("Debbie Reynolds role on B'way",
#   'IRENE',
#   [('IRENE', 0.3400179342161786), ('HASTO', 1.0), ('PERSE', 1.0)]),
#  ('You are: Sp.',
#   'ERES',
#   [('ESTO', 0.0), ('OTRO', 0.0), ('ESTA', 0.0), ('OTRA', 0.0), ('ESTA', 0.0)]),
#  ('Hit with skits, for short',
#   'SNL',
#   [('SNL', 0.9490201816863202),
#    ('AHA', 1.0),
#    ('OWE', 1.0),
#    ('YET', 1.0),
#    ('OCS', 1.0)]),
#  ('Musical direction that means "lyrical" in Italian',
#   'CANTABILE',
#   [('WAXPOETIC', 0.9410697541934622)]),
#  ('Mrs. Leonowens',
#   'ANNA',
#   [('ANNA', 0.0),
#    ('SIAM', 0.866512351271455),
#    ('BESS', 0.9497131615616992),
#    ('SIAM', 0.9545686059727675),
#    ('SIAM', 0.9545686059727675)]),
#  ('Pulitzer-winning biographer Leon',
#   'EDEL',
#   [('EDEL', 0.0),
#    ('EDEL', 0.6753170608160393),
#    ('EDEL', 0.7033937901157415),
#    ('EDEL', 0.7033937901157415),
#    ('EDEL', 0.8570053266718773)]),
#  ("Lady's man",
#   'SIR',
#   [('SIR', 0.0),
#    ('SIR', 0.0),
#    ('EVE', 0.692572987728251),
#    ('EVE', 0.692572987728251),
#    ('EVE', 0.692572987728251)]),
#  ('They like action',
#   'DOERS',
#   [('DOING', 0.562737310875357),
#    ('ARENA', 0.562737310875357),
#    ('ARENA', 0.562737310875357),
#    ('EXERT', 0.562737310875357),
#    ('EXERT', 0.562737310875357)]),
#  ('Bride, in Bari',
#   'SPOSA',
#   [('PESCE', 0.7964277116006653),
#    ('AMICO', 0.8133537123653782),
#    ('COTTA', 0.8687833773518169),
#    ('AWARE', 1.0),
#    ('ABIDE', 1.0)]),
#  ('Trim symmetrically',
#   'EVEN',
#   [('PARE', 0.0), ('CROP', 0.0), ('PARE', 0.0), ('NEAT', 0.0), ('PARE', 0.0)]),
#  ('Ryan\'s "Love Story" co-star',
#   'ALI',
#   [('ALI', 0.0), ('ALI', 0.0), ('ALI', 0.0), ('ALI', 0.0), ('ALI', 0.0)]),
#  ('Many truckers',
#   'CBERS',
#   [('SEMIS', 0.7291271441681452),
#    ('REACH', 1.0),
#    ('ISSUE', 1.0),
#    ('IDLER', 1.0),
#    ('ORDER', 1.0)]),
#  ('Clio candidate',
#   'TVSPOT',
#   [('RUNNER', 0.8376620842695847),
#    ('THALIA', 0.8861130368847607),
#    ('THALIA', 0.8861130368847607)]),
#  ('Foot part <--> apparel part',
#   'INSTEP',
#   [('INSTEP', 0.845799581389639),
#    ('INSTEP', 0.845799581389639),
#    ('INSTEP', 0.845799581389639),
#    ('INSTEP', 0.845799581389639),
#    ('INSTEP', 0.845799581389639)]),
#  ('Wahine wear',
#   'LEI',
#   [('LEI', 0.0),
#    ('LEI', 0.8229331571002332),
#    ('LEI', 0.8229331571002332),
#    ('LEI', 0.8490202429413376),
#    ('LEI', 0.8594966757707294)]),
#  ('Visit',
#   'STOPIN',
#   [('STOPBY', 0.0),
#    ('DROPIN', 0.0),
#    ('STOPBY', 0.0),
#    ('STOPIN', 0.6387861438815609),
#    ('LOOKIN', 0.6986911771704458)]),
#  ('Used the aerie',
#   'NESTED',
#   [('EAGLET', 0.8543354367361251), ('EAGLET', 0.9157086053067028)]),
#  ('Actress Garr',
#   'TERI',
#   [('TERI', 0.0), ('TERI', 0.0), ('TERI', 0.0), ('TERI', 0.0), ('TERI', 0.0)]),
#  ("Gladys Knight's companions",
#   'PIPS',
#   [('ERGO', 1.0), ('STAT', 1.0), ('SEAT', 1.0), ('ABET', 1.0), ('NONE', 1.0)]),
#  ('Main trunk',
#   'AORTA',
#   [('AORTA', 0.7145768231986848),
#    ('AORTA', 0.7145768231986848),
#    ('TORSO', 0.7145768231986848),
#    ('TORSO', 0.7145768231986848),
#    ('TORSO', 0.7145768231986848)]),
#  ('Court cry',
#   'OYES',
#   [('ASHE', 0.0), ('OYEZ', 0.0), ('ASHE', 0.0), ('OYEZ', 0.0), ('OYEZ', 0.0)]),
#  ('_____ glance',
#   'ATA',
#   [('ATA', 0.0),
#    ('ATA', 0.6435673027668697),
#    ('ATA', 0.6435673027668697),
#    ('ATA', 0.6435673027668697),
#    ('ATA', 0.6435673027668697)]),
#  ('Hammer parts',
#   'CLAWS',
#   [('PEENS', 0.0),
#    ('PEENS', 0.0),
#    ('PEENS', 0.0),
#    ('PEENS', 0.0),
#    ('PIANO', 0.85406770234549)]),
#  ('Soviet ___',
#   'ERA',
#   [('KGB', 0.7201430204800143), ('SSR', 0.7267547533794404)]),
#  ('Algerian port',
#   'ORAN',
#   [('ORAN', 0.0), ('ORAN', 0.0), ('ORAN', 0.0), ('ORAN', 0.0), ('ORAN', 0.0)]),
#  ('Eastern V.I.P.',
#   'AMIR',
#   [('AMIR', 0.0), ('EMIR', 0.0), ('EMIR', 0.0), ('RAJA', 0.0), ('EMIR', 0.0)]),
#  ('Slangy affirmative',
#   'YEP',
#   [('YEP', 0.0),
#    ('YEP', 0.0),
#    ('YEH', 0.0),
#    ('YEP', 0.0),
#    ('YEA', 0.7451037966806762)]),
#  ('Screening device',
#   'SIEVE',
#   [('VCHIP', 0.0),
#    ('VCHIP', 0.5142736457030207),
#    ('WANDS', 0.923968188851904),
#    ('GISMO', 0.9288391864695745),
#    ('DATER', 0.9288391864695745)]),
#  ('Pork place?',
#   'STY',
#   [('PEN', 0.0),
#    ('STY', 0.0),
#    ('SHU', 0.9309817697062867),
#    ('SHU', 0.9309817697062867),
#    ('SHU', 0.9309817697062867)]),
#  ('Funnyman Brooks',
#   'MEL',
#   [('MEL', 0.8122188623851347),
#    ('MEL', 0.8122188623851347),
#    ('TIM', 0.9189049998946874),
#    ('EMO', 0.9725759404418841),
#    ('EMO', 0.9725759404418841)]),
#  ('This separates "Ta" and "Boom"',
#   'RARA',
#   [('CIAO', 0.9340616023508738),
#    ('CIAO', 0.9340616023508738),
#    ('CIAO', 0.9340616023508738),
#    ('SPAR', 0.9641590856820639),
#    ('SPAR', 0.9641590856820639)]),
#  ('Plant, vegetable or herb',
#   'WORT',
#   [('BEET', 0.8704624641078099),
#    ('OKRA', 0.8704624641078099),
#    ('ROOT', 0.9691734595920896),
#    ('ANNO', 1.0),
#    ('ANEW', 1.0)]),
#  ('See 22-Across', 'WISLAWASZYMBORSKA', []),
#  ('W.W. II Pres.',
#   'HST',
#   [('HST', 0.5868553922616272),
#    ('ABS', 0.642163892774055),
#    ('CIC', 0.8352021308462471),
#    ('HST', 0.8503262186957112),
#    ('GEN', 0.8852545129285267)]),
#  ('___ Dame',
#   'NOTRE',
#   [('NOTRE', 0.0),
#    ('NOTRE', 0.0),
#    ('NOTRE', 0.0),
#    ('NOTRE', 0.0),
#    ('NOTRE', 0.0)]),
#  ('Commandment word',
#   'SHALT',
#   [('SHALT', 0.0),
#    ('SHALT', 0.0),
#    ('HONOR', 0.0),
#    ('COVET', 0.8051515899192904),
#    ('SHALT', 0.8084818997422911)]),
#  ('Joe ___',
#   'BLOW',
#   [('JAVA', 0.3739821432131083),
#    ('JAVA', 0.3739821432131083),
#    ('JAVA', 0.5678621209934118),
#    ('RUDI', 0.6385143855290749),
#    ('AGUY', 0.6718241862368357)]),
#  ('1970 Kinks hit',
#   'LOLA',
#   [('LOLA', 1.4901161193847656e-08),
#    ('LOLA', 1.4901161193847656e-08),
#    ('LOLA', 1.4901161193847656e-08),
#    ('LOLA', 1.4901161193847656e-08),
#    ('LOLA', 1.4901161193847656e-08)]),
#  ('Health resort',
#   'SPA',
#   [('SPA', 0.0), ('SPA', 0.0), ('SPA', 0.0), ('SPA', 0.0), ('SPA', 0.0)]),
#  ('Target for Crenshaw',
#   'PIN',
#   [('TEE', 0.7811082743868756),
#    ('MOB', 0.9872033528920434),
#    ('APT', 0.9872033528920434),
#    ('ERR', 0.9872033528920434),
#    ('APT', 0.9872033528920434)]),
#  ('Odic stanza',
#   'STROPHE',
#   [('STROPHE', 0.0),
#    ('COUPLET', 0.0),
#    ('STROPHE', 0.0),
#    ('STROPHE', 0.6097811731744284),
#    ('STROPHE', 0.6434134247910082)]),
#  ('Replies to a host',
#   'RSVPS',
#   [('EMCEE', 0.887131602786787),
#    ('EMCEE', 0.887131602786787),
#    ('EMCEE', 0.887131602786787),
#    ('EMCEE', 0.887131602786787),
#    ('EMCEE', 0.887131602786787)]),
#  ('Auricle',
#   'EAR',
#   [('EAR', 0.0), ('EAR', 0.0), ('ITS', 1.0), ('ORE', 1.0), ('TSK', 1.0)]),
#  ('Letter writing: Abbr.',
#   'CORR',
#   [('ENCL', 0.7593651514533589),
#    ('ENCL', 0.7593651514533589),
#    ('ENCL', 0.7593651514533589),
#    ('ATTN', 0.7593651514533589),
#    ('NOUN', 0.7713605140744182)]),
#  ('Pitching need',
#   'ARM',
#   [('ARM', 0.7075677055597605),
#    ('ACE', 0.8128019583961119),
#    ('WOO', 0.8332312936994135),
#    ('TAR', 0.8723811534395501),
#    ('TAR', 0.8723811534395501)]),
#  ('Brief time',
#   'SEC',
#   [('NAP', 0.0),
#    ('SEC', 0.2856639111712446),
#    ('SEC', 0.6098054094674136),
#    ('THO', 0.6382533245797956),
#    ('THO', 0.6382533245797956)]),
#  ('Start of something big?',
#   'SUPER',
#   [('ONSET', 0.7327943636286841),
#    ('ONSET', 0.7327943636286841),
#    ('ALPHA', 0.7327943636286841),
#    ('ONSET', 0.7327943636286841),
#    ('INTRO', 0.7327943636286841)]),
#  ('Rifles', 'LOOTS', [('ASYET', 1.0), ('YESES', 1.0), ('ENTER', 1.0)]),
#  ('Antique shop item',
#   'CURIO',
#   [('CURIO', 0.0),
#    ('CURIO', 0.7179854842587129),
#    ('CLASS', 0.9170365170346233),
#    ('STORE', 0.9170365170346233),
#    ('ATTIC', 0.9387998558816087)]),
#  ("She came to Theseus' aid",
#   'ARIADNE',
#   [('ARIADNE', 0.9625355161271318),
#    ('ARRIVED', 0.9684797170243422),
#    ('EMERGED', 0.9684797170243422),
#    ('EMERGED', 0.9684797170243422)]),
#  ('Bores, informally',
#   'DRIPS',
#   [('TIRES', 0.5542633338563425),
#    ('TIRES', 0.5542633338563425),
#    ('TIRES', 0.5542633338563425),
#    ('ROTHS', 0.9668982151592775),
#    ('GONNA', 0.9668982151592775)]),
#  ('Erwin', 'DESERTFOXROMMEL', []),
#  ('Foot: Suffix', 'PUS', []),
#  ('Historic structure between China and Mongolia',
#   'GREATWALL',
#   [('DELINEATE', 1.0)]),
#  ('Hosiery shade',
#   'NUDE',
#   [('ECRU', 0.0), ('ECRU', 0.0), ('ECRU', 0.0), ('ECRU', 0.0), ('NUDE', 0.0)]),
#  ('"Let us _____"',
#   'PRAY',
#   [('EMIT', 0.6746385942080153),
#    ('EASE', 0.6746385942080153),
#    ('EASE', 0.6746385942080153),
#    ('BATE', 0.6746385942080153),
#    ('RENT', 0.6746385942080153)]),
#  ('Yoko ___',
#   'ONO',
#   [('ONO', 0.0), ('ONO', 0.0), ('ONO', 0.0), ('ONO', 0.0), ('ONO', 0.0)]),
#  ('Cowboy', 'BUCKAROO', [('WRANGLER', 0.0), ('BUCKAROO', 0.0)]),
#  ('Patent',
#   'OVERT',
#   [('OVERT', 0.0),
#    ('OVERT', 0.0),
#    ('IDEAS', 0.7187399152949426),
#    ('THESE', 1.0),
#    ('RIFLE', 1.0)]),
#  ('Lake Ontario feeder',
#   'GENESEE',
#   [('TORONTO', 0.6822054666460751),
#    ('GENESEE', 0.6946792889353991),
#    ('TORONTO', 0.9263373858222121),
#    ('TORONTO', 0.940628479025091),
#    ('OTTAWAS', 0.992145779410608)]),
#  ('Garland',
#   'LEI',
#   [('LEI', 0.0), ('LEI', 0.0), ('LEI', 0.0), ('LEI', 0.0), ('LEI', 0.0)]),
#  ('Nest egg, of a sort: Abbr.',
#   'IRA',
#   [('HEN', 0.6345348394189806),
#    ('IRA', 0.7557061611014279),
#    ('IRA', 0.7883268236588282),
#    ('IRA', 0.8142630486703306),
#    ('IRA', 0.8142630486703306)]),
#  ('Ended',
#   'OVER',
#   [('OVER', 0.0),
#    ('OVER', 0.0),
#    ('OVER', 0.0),
#    ('WWII', 0.5931024469220617),
#    ('WWII', 0.5931024469220617)]),
#  ('Rapid movements in music',
#   'ALLEGROS',
#   [('ALLEGROS', 0.9805793975422484),
#    ('ALLEGROS', 0.9805793975422484),
#    ('ASLONGAS', 1.0)]),
#  ('Pedal appendages',
#   'TOES',
#   [('TAGS', 0.7470843588415909),
#    ('TAPS', 0.9202443173577823),
#    ('AWNS', 0.9357768173588499),
#    ('RACE', 0.9685464579694095),
#    ('SPED', 0.9685464579694095)]),
#  ('Troubadour',
#   'BARD',
#   [('BARD', 0.0),
#    ('LOVE', 0.5804107724561798),
#    ('LUTE', 0.6143698959563586),
#    ('LAIS', 0.6904004870962668),
#    ('EROS', 0.7351785052774518)]),
#  ("Tunisian city ('taint photocopy!)",
#   'SFAX',
#   [('SFAX', 0.893697050129193),
#    ('STAT', 0.9438412463732127),
#    ('STAT', 0.9438412463732127),
#    ('SEEN', 1.0),
#    ('ERAT', 1.0)]),
#  ('Casual wear',
#   'CHINOS',
#   [('DENIMS', 0.0),
#    ('DRESSY', 0.6561577893927086),
#    ('ENDURE', 0.8719636806529434),
#    ('ABRADE', 0.8719636806529434),
#    ('ATTIRE', 0.8719636806529434)]),
#  ('Pollster Roper',
#   'ELMO',
#   [('ELMO', 0.0), ('ELMO', 0.0), ('ELMO', 0.0), ('ELMO', 0.0), ('ELMO', 0.0)]),
#  ('Rat-a-tat',
#   'RAP',
#   [('TIT', 0.742778164983641),
#    ('TIT', 0.742778164983641),
#    ('TIT', 0.742778164983641),
#    ('TIT', 0.742778164983641),
#    ('TIT', 0.742778164983641)]),
#  ('___-Japanese War',
#   'SINO',
#   [('SINO', 0.0), ('SINO', 0.0), ('SINO', 0.0), ('SINO', 0.0), ('SINO', 0.0)]),
#  ('Cretan peak',
#   'IDA',
#   [('IDA', 0.0),
#    ('IDA', 0.0),
#    ('IDA', 0.8146820163057471),
#    ('IDA', 0.8669918240193433),
#    ('IDA', 0.8873226339810789)]),
#  ('Shade of green',
#   'OLIVE',
#   [('CEDRE', 0.0),
#    ('OLIVE', 0.0),
#    ('OLIVE', 0.0),
#    ('LODEN', 0.0),
#    ('ALOES', 0.0)]),
#  ('All smiles?', 'FULLOFBEAMS', []),
#  ('Possible penicillin target',
#   'STREP',
#   [('STREP', 0.5453956321116656),
#    ('STREP', 0.6528215965479042),
#    ('STREP', 0.6528215965479042),
#    ('EVERY', 0.9749615444548514),
#    ('EVERY', 0.9749615444548514)]),
#  ('Kitchen items that ding',
#   'TIMERS',
#   [('TOWELS', 0.9866316337802564),
#    ('TRENDY', 0.9999999999999999),
#    ('SPURON', 0.9999999999999999)]),
#  ('Source of some clicking', 'TAPDANCE', []),
#  ('Beef',
#   'GRIPE',
#   [('GRIPE', 0.0),
#    ('ADDTO', 0.0),
#    ('ADDTO', 0.0),
#    ('STEER', 0.6559633571825273),
#    ('BARON', 0.6842680928642746)]),
#  ('Iron Mike',
#   'TYSON',
#   [('TYSON', 0.0),
#    ('PRESS', 0.8250487220260654),
#    ('PRESS', 0.8250487220260654),
#    ('PRESS', 0.8250487220260654),
#    ('SCRAP', 0.8819091456305245)]),
#  ('"The ___ eve . . . "', 'STAGAT', []),
#  ('Fertility goddess',
#   'ISIS',
#   [('ISIS', 0.0),
#    ('ISIS', 0.5563532843384115),
#    ('ISIS', 0.5563532843384115),
#    ('ISIS', 0.5563532843384115),
#    ('ISIS', 0.5563532843384115)]),
#  ('Reply to the Little Red Hen',
#   'NOTI',
#   [('NOTI', 0.0), ('NOTI', 0.0), ('NOTI', 0.0), ('NOTI', 0.0), ('NOTI', 0.0)]),
#  ('Lure',
#   'SEDUCE',
#   [('ENTICE', 0.0),
#    ('ENTICE', 0.0),
#    ('ENTICE', 0.0),
#    ('ENTICE', 0.0),
#    ('ENTRAP', 0.7148799581365199)]),
#  ('Subjects to detrition',
#   'ERODES',
#   [('ERODES', 0.0),
#    ('THEMES', 0.9054612554348356),
#    ('TOPICS', 0.9054612554348356),
#    ('ELEVEN', 1.0),
#    ('ASSUME', 1.0)]),
#  ('Cry of defeat',
#   'UNCLE',
#   [('WORST', 0.0),
#    ('UPEND', 0.0),
#    ('WORST', 0.0),
#    ('UNCLE', 0.0),
#    ('WORST', 0.0)]),
#  ('Roman spirits',
#   'MANES',
#   [('LARES', 0.6529433092298653),
#    ('AURAS', 0.6645181063270489),
#    ('MEDOC', 0.8497280489597326),
#    ('NOMEN', 0.8639842408516926),
#    ('IGNIS', 0.8639842408516926)]),
#  ('A Karamazov',
#   'IVAN',
#   [('IVAN', 0.0),
#    ('IVAN', 0.6076442545812879),
#    ('IVAN', 0.6381875986966896),
#    ('IVAN', 0.7609676576908142),
#    ('IVAN', 0.9067601219919927)]),
#  ('Opposite', 'FLIPSIDE', [('COLDFEET', 0.0)]),
#  ('Enclose a waterway',
#   'EMBANK',
#   [('SWATHE', 0.7074040287654685),
#    ('INCASE', 0.7074040287654685),
#    ('ENCYST', 0.9599918345213411),
#    ('ATONED', 0.9999999999999999),
#    ('ODDMAN', 0.9999999999999999)]),
#  ('Chopper blade',
#   'ROTOR',
#   [('ROTOR', 0.7100648358552797),
#    ('ROTOR', 0.7100648358552797),
#    ('ROTOR', 0.7100648358552797),
#    ('WIPER', 0.9275223808355859),
#    ('ROTOR', 0.9275223808355859)]),
#  ('Neighbor of Helsinki',
#   'ESPOO',
#   [('FINNS', 0.8388166355701604), ('SHORT', 0.960755043785887)]),
#  ('Absolute ruler',
#   'TSAR',
#   [('CZAR', 0.0),
#    ('CZAR', 0.0),
#    ('TSAR', 0.8489703427994433),
#    ('TSAR', 0.8489703427994433),
#    ('TSAR', 0.8489703427994433)]),
#  ('Ultimately becomes',
#   'ENDSUP',
#   [('ATLAST', 0.0), ('DELANO', 1.0), ('ELAPSE', 1.0), ('CLONES', 1.0)]),
#  ('Crockery',
#   'CHINA',
#   [('CHINA', 0.0), ('ANNOY', 1.0), ('UNCLE', 1.0), ('AREAR', 1.0)]),
#  ('Chills, so to speak',
#   'RELAXES',
#   [('RELAXES', 0.0),
#    ('LOUNGES', 0.0),
#    ('ADDRESS', 0.8907990394558275),
#    ('EVENNOW', 0.8907990394558275)]),
#  ('___ Raymonde, player of Alex Rousseau on "Lost"',
#   'TANIA',
#   [('TANIA', 0.8863877856156156),
#    ('TANIA', 0.8863877856156156),
#    ('NADIR', 0.9999999999999999),
#    ('START', 0.9999999999999999),
#    ('DEUCE', 0.9999999999999999)]),
#  ('College track, for short',
#   'PREMED',
#   [('SIDING', 0.6286720147309616),
#    ('DERAIL', 0.8448993083158409),
#    ('LOCATE', 0.8448993083158409),
#    ('ASTRAY', 0.8448993083158409),
#    ('LOCATE', 0.8448993083158409)]),
#  ('Extremely agitated', 'ALLRILEDUP', []),
#  ('Mlle., in Madrid',
#   'SRTA',
#   [('SRTA', 0.0),
#    ('SRTA', 0.0),
#    ('SRTA', 0.8516889788724981),
#    ('OTRO', 0.8525711532957921),
#    ('ESTA', 0.8525711532957921)]),
#  ('Beethoven\'s "Für ___"',
#   'ELISE',
#   [('ELISE', 0.0),
#    ('ELISE', 0.0),
#    ('ELISE', 0.0),
#    ('ELISE', 0.0),
#    ('ELISE', 0.0)]),
#  ('Circus performer, e.g.', 'ARTISTE', [('ACROBAT', 0.0), ('ACROBAT', 0.0)]),
#  ('TV backdrop',
#   'OLEO',
#   [('OLEO', 0.0), ('OLEO', 0.0), ('OLEO', 0.0), ('OLEO', 0.0), ('OLEO', 0.0)]),
#  ('An 11 Down armed with a net',
#   'RETIARIUS',
#   [('PRIMETIME', 0.9699679062817316)]),
#  ('Play the goldbricker',
#   'LOAF',
#   [('ROLE', 0.0), ('ACTS', 0.0), ('GOOF', 0.0), ('ROLE', 0.0), ('ROLE', 0.0)]),
#  ('King or poet',
#   'LEAR',
#   [('LEAR', 0.0),
#    ('LEAR', 0.0),
#    ('MORN', 0.7496898124904646),
#    ('ENOW', 0.7496898124904646)]),
#  ('Paten',
#   'DISC',
#   [('DISK', 0.0), ('STAT', 1.0), ('SAVE', 1.0), ('WEEP', 1.0), ('HEAL', 1.0)]),
#  ('"I never ___ moor": Emily Dickinson',
#   'SAWA',
#   [('SAWA', 0.5995999029636163),
#    ('UNTO', 0.7895741725694976),
#    ('TWAS', 0.9830936765588223),
#    ('ONCE', 0.9999999999999999),
#    ('OMIT', 0.9999999999999999)]),
#  ('Family member, for short',
#   'SIS',
#   [('SIS', 0.0),
#    ('SIS', 0.0),
#    ('SIB', 0.5352134011705577),
#    ('SON', 0.5352134011705577),
#    ('SON', 0.5352134011705577)]),
#  ('Catalyst of a sort',
#   'ALTERANT',
#   [('INASENSE', 0.9678135048798949), ('INASENSE', 0.9678135048798949)]),
#  ('They might be zapped', 'ADS', [('ITS', 1.0)]),
#  ("30's singer MacDonald",
#   'JEANETTE',
#   [('CARALARM', 0.9154670855840932), ('LAUGHING', 0.9154670855840932)]),
#  ('As a friend, to Frédéric',
#   'ENAMI',
#   [('DUPED', 1.0), ('OMEGA', 1.0), ('VERSA', 1.0), ('SANER', 1.0)]),
#  ('Trap',
#   'SETUP',
#   [('SNARE', 0.0),
#    ('SNARE', 0.0),
#    ('SNARE', 0.0),
#    ('SNARE', 0.0),
#    ('SNARE', 0.0)]),
#  ('Astrologer to the rich and famous',
#   'OMARR',
#   [('MAGUS', 0.9047574315789882),
#    ('IFOLD', 0.9795715270966304),
#    ('IMOUT', 0.9795715270966304),
#    ('OMARR', 0.9881851419089991),
#    ('OMARR', 0.9881851419089991)]),
#  ('Korean statesman',
#   'RHEE',
#   [('RHEE', 0.0),
#    ('RHEE', 0.0),
#    ('RHEE', 0.0),
#    ('EBAN', 0.8008692634086281),
#    ('RHEE', 0.9241023620374492)]),
#  ('"Dies ___"',
#   'IRAE',
#   [('IRAE', 0.0), ('IRAE', 0.0), ('IRAE', 0.0), ('IRAE', 0.0), ('IRAE', 0.0)]),
#  ('Back up',
#   'ABET',
#   [('EACH', 0.0), ('RAVE', 0.0), ('AREA', 0.0), ('QUOD', 0.0), ('WEAR', 0.0)]),
#  ('Get gussied up',
#   'PREEN',
#   [('ALLOF', 1.0),
#    ('ITSOK', 1.0),
#    ('BOOST', 1.0),
#    ('SATES', 1.0),
#    ('NADIR', 1.0)]),
#  ('Old English letter',
#   'ETH',
#   [('WEN', 0.0), ('EDH', 0.0), ('EDH', 0.0), ('EDH', 0.0), ('EDH', 0.0)]),
#  ('Thin wood strip',
#   'LATH',
#   [('LATH', 0.0), ('SLAT', 0.0), ('LATH', 0.0), ('SLAT', 0.0), ('SLAT', 0.0)]),
#  ('Bind or constrict',
#   'STRAP',
#   [('STRAP', 0.9433506445071048),
#    ('HENCE', 0.9999999999999999),
#    ('RISEN', 0.9999999999999999)]),
#  ('Mean cur, typically', 'BITER', [('YKNOW', 0.98337690499464)]),
#  ('Spokes',
#   'RADII',
#   [('RADII', 0.0),
#    ('RADII', 0.0),
#    ('RADII', 0.0),
#    ('RADII', 0.0),
#    ('RADII', 0.0)]),
#  ('Fibber',
#   'LIAR',
#   [('LIAR', 0.0), ('LIAR', 0.0), ('LIAR', 0.0), ('LIAR', 0.0), ('LIAR', 0.0)]),
#  ('___-majesté',
#   'LESE',
#   [('LESE', 0.0), ('LESE', 0.0), ('LESE', 0.0), ('LESE', 0.0), ('LESE', 0.0)]),
#  ('___-relief',
#   'BAS',
#   [('BAS', 0.0), ('BAS', 0.0), ('BAS', 0.0), ('BAS', 0.0), ('BAS', 0.0)]),
#  ('Ranting preacher, in old lingo',
#   'TUBMAN',
#   [('CURATE', 0.794803535143327),
#    ('JARGON', 0.8769382177951511),
#    ('OATERS', 0.9706811181638951),
#    ('REPENT', 0.9988052549495864)]),
#  ('Viewer-supported TV',
#   'PBS',
#   [('ACT', 0.9999999999999999), ('DEM', 0.9999999999999999)]),
#  ('Passenger status',
#   'STANDBY',
#   [('COEQUAL', 0.9120896040710114), ('STRAPIN', 0.9652951000029795)]),
#  ('Himalayan sight?',
#   'YETI',
#   [('NARD', 0.856579739274),
#    ('AFAR', 0.8760486413321019),
#    ('ESPY', 0.8760486413321019)]),
#  ('Brazilian seaport',
#   'NATAL',
#   [('NATAL', 0.0),
#    ('BELEM', 0.0),
#    ('NATAL', 0.0),
#    ('BELEM', 0.0),
#    ('BELEM', 0.0)]),
#  ('Bottleneck', 'IMPASSE', [('RESCIND', 1.0)]),
#  ('New beginning ... or what 16-, 23-, 31-, 38- and 45-Across each have?',
#   'FRESHSTART',
#   []),
#  ('Platoon members, for short',
#   'GIS',
#   [('GIS', 0.6282074508711118),
#    ('SFC', 0.7465209120921993),
#    ('SFC', 0.7465209120921993),
#    ('SFC', 0.7465209120921993),
#    ('NAM', 0.9059803760946322)]),
#  ('Martin nickname',
#   'DINO',
#   [('DINO', 0.496243381001619),
#    ('DINO', 0.6795464950164577),
#    ('REMY', 0.793728012416307),
#    ('REMY', 0.793728012416307),
#    ('SHAQ', 0.8073002375074642)]),
#  ('"Eh"',
#   'SOSO',
#   [('WHAT', 0.0), ('FAIR', 0.0), ('ATTY', 1.0), ('SPTS', 1.0), ('SATE', 1.0)]),
#  ('"The Millionairess" star',
#   'LOREN',
#   [('LOREN', 0.5348440526934277),
#    ('NOTON', 0.9999999999999999),
#    ('TODAY', 0.9999999999999999),
#    ('GOTIT', 0.9999999999999999)]),
#  ('Person behind a curtain, maybe',
#   'VOTER',
#   [('DRAPE', 0.7790955252665446),
#    ('VOILE', 0.9457060359698071),
#    ('SCRIM', 0.9457060359698071),
#    ('NINON', 0.9457060359698071),
#    ('AGENT', 0.9504258088597456)]),
#  ('"___ of One\'s Own": Woolf',
#   'AROOM',
#   [('AROOM', 0.0),
#    ('AROOM', 0.0),
#    ('AROOM', 0.0),
#    ('AROOM', 0.0),
#    ('AROOM', 0.0)]),
#  ('Kind of boom',
#   'SONIC',
#   [('SONIC', 0.0),
#    ('SONIC', 0.0),
#    ('SONIC', 0.0),
#    ('SONIC', 0.0),
#    ('SONIC', 0.0)]),
#  ('Nevada city',
#   'RENO',
#   [('ELKO', 0.0), ('ELKO', 0.0), ('ELKO', 0.0), ('ELKO', 0.0), ('ELKO', 0.0)]),
#  ('Third-year hurdles, for some', 'ORALEXAMS', []),
#  ('Check', 'DETER', [('GOSEE', 0.0), ('SCOPE', 0.0), ('DETER', 0.0)]),
#  ('Express or tail predecessor', 'PONY', []),
#  ('Perfumery rootstock',
#   'ORRIS',
#   [('ORRIS', 0.7133518095710163),
#    ('ORRIS', 0.9072287186659264),
#    ('ORRIS', 0.9072287186659264),
#    ('PETAL', 0.9477487407160904),
#    ('NEROL', 0.9546474040697208)]),
#  ('TV\'s "The ___ Squad": 1968-73',
#   'MOD',
#   [('MOD', 0.827340114910009),
#    ('MOD', 0.827340114910009),
#    ('MOD', 0.827340114910009),
#    ('MOD', 0.8617942592300387),
#    ('WOW', 0.93190006549741)]),
#  ('Castor or pillbox',
#   'HAT',
#   [('HAT', 0.6870334115714539),
#    ('HAT', 0.6870334115714539),
#    ('SEN', 0.9999999999999999),
#    ('ERE', 0.9999999999999999),
#    ('EUR', 0.9999999999999999)]),
#  ('French soldier',
#   'POILU',
#   [('POILU', 0.0),
#    ('POILU', 0.0),
#    ('POILU', 0.0),
#    ('POILU', 0.0),
#    ('POILU', 0.6183885227364694)]),
#  ('Fashion photographer Herb',
#   'RITTS',
#   [('RITTS', 0.0),
#    ('RITTS', 0.8006108264033226),
#    ('PASSE', 0.9651272522982332),
#    ('STYLE', 0.9651272522982332),
#    ('KARAN', 0.9651272522982332)]),
#  ('Person who is sui generis',
#   'ONER',
#   [('ONER', 0.0),
#    ('ONER', 0.41394885953419575),
#    ('ONER', 0.41394885953419575),
#    ('LESS', 1.0),
#    ('DATE', 1.0)]),
#  ('Beach toy',
#   'PAIL',
#   [('PAIL', 0.0),
#    ('PAIL', 0.0),
#    ('KITE', 0.0),
#    ('KITE', 0.6072445957324157),
#    ('PAIL', 0.6086318238315432)]),
#  ('Parts of dollhouse dinner table settings?', 'MINIGLASSES', []),
#  ('Faulty',
#   'AMISS',
#   [('AMISS', 0.0),
#    ('AMISS', 0.0),
#    ('AMISS', 0.0),
#    ('ERRED', 0.0),
#    ('LEAKY', 0.7291140606864382)]),
#  ('Full stop', 'IMPASSE', []),
#  ("Jack's links rival",
#   'ARNIE',
#   [('ARNIE', 0.7124837081336385),
#    ('HOIST', 0.9265528772887445),
#    ('KNAVE', 0.9265528772887445),
#    ('KNAVE', 0.9265528772887445),
#    ('KNAVE', 0.9265528772887445)]),
#  ("Bit of advice when packing anglers' lunches?", 'REELMENDONTEATQUICHE', []),
#  ('___-cone',
#   'SNO',
#   [('SNO', 0.0), ('SNO', 0.0), ('SNO', 0.0), ('SNO', 0.0), ('SNO', 0.0)]),
#  ('Wheel turner',
#   'AXLE',
#   [('AXLE', 0.0),
#    ('AXLE', 0.0),
#    ('AXLE', 0.0),
#    ('AXLE', 0.0),
#    ('LANA', 0.758286887446175)]),
#  ('Short-story writer',
#   'OHENRY',
#   [('RUNYON', 0.5633916390192604), ('RECANT', 0.8397376580624178)]),
#  ('Cheese selections', 'CHEDDARS', []),
#  ('___ Hari',
#   'MATA',
#   [('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0)]),
#  ('Red Cross work',
#   'AID',
#   [('AID', 0.8375566376325355), ('AID', 0.8392514196577235)]),
#  ('Bronx Bomber',
#   'YANK',
#   [('ISUP', 0.835875797650337),
#    ('BTWO', 0.8518757864600355),
#    ('BTEN', 0.8611027509878141),
#    ('BTEN', 0.8869235544514947),
#    ('USAF', 0.9304991195493792)]),
#  ('Top-notch',
#   'ACE',
#   [('VEE', 0.0), ('ACE', 0.0), ('ACE', 0.0), ('ACE', 0.0)]),
#  ('"This ___ shall pass"', 'TOO', [('TOO', 0.0), ('END', 0.8572844090909638)]),
#  ('Ice-cream container',
#   'CONE',
#   [('SOFT', 0.7235996463833348),
#    ('SODA', 0.7329710478403747),
#    ('EDYS', 0.7932152434412294),
#    ('EDYS', 0.7932152434412294),
#    ('EDYS', 0.7932152434412294)]),
#  ('Old-fashioned greeting',
#   'TOPOFTHEMORNING',
#   [('KATIEBARTHEDOOR', 0.8702957382798246)]),
#  ('Fencing thrust: Var.',
#   'RIPOST',
#   [('LUNGED', 0.844147010129097), ('ELEVEN', 1.0), ('ENTIRE', 1.0)]),
#  ('Salon supplies',
#   'DYES',
#   [('DYES', 0.0),
#    ('DYES', 0.0),
#    ('BASE', 0.9219400658651139),
#    ('SNIP', 0.9363628448397145),
#    ('SNIP', 0.9363628448397145)]),
#  ('Dostoyevsky novel, with "The"',
#   'IDIOT',
#   [('IDIOT', 0.0),
#    ('IDIOT', 0.0),
#    ('IDIOT', 0.0),
#    ('IDIOT', 0.2687091852375056),
#    ('FEDOR', 0.6092980746415024)]),
#  ('Lock up', 'ENCAGE', [('ENCAGE', 0.0)]),
#  ('Squealed',
#   'SANG',
#   [('SANG', 0.0),
#    ('EEKS', 0.6034963690829666),
#    ('HOUR', 1.0),
#    ('LESS', 1.0),
#    ('ANTE', 1.0)]),
#  ('Like the words of Jesus',
#   'ARAMAIC',
#   [('ARAMAIC', 0.4201712564102267),
#    ('SEMITIC', 0.5514141631750892),
#    ('ARAMAIC', 0.9227203100873048),
#    ('ARAMAIC', 0.9498380184753242),
#    ('ARAMAIC', 0.9498380184753242)]),
#  ('Brand with a red arrow through its logo',
#   'SUNOCO',
#   [('SUNOCO', 0.8167977086222411),
#    ('NESTEA', 0.930779928196878),
#    ('EMBLEM', 0.9436234831019203),
#    ('ORTEGA', 0.9775992227061159),
#    ('ATHOME', 1.0)]),
#  ('Resident of 211 Central Park West: 1917-27', 'SARATEASDALE', []),
#  ('Purse holder',
#   'STRAP',
#   [('STAKE', 0.6422334066326288), ('LINER', 0.8299932062314748)]),
#  ('Carlsbad feature',
#   'CAVERN',
#   [('CAVERN', 0.0),
#    ('CAVERN', 0.7792711460862942),
#    ('POPTOP', 0.9937441595713095),
#    ('ACROSS', 1.0),
#    ('ETALII', 1.0)]),
#  ('Officeholders',
#   'INS',
#   [('INS', 0.0), ('INS', 0.0), ('INS', 0.0), ('INS', 0.0), ('INS', 0.0)]),
#  ('"___ Hagen Girl," Reagan film',
#   'THAT',
#   [('THAT', 0.0), ('THAT', 0.0), ('THAT', 0.0), ('ALSO', 1.0), ('ASSN', 1.0)]),
#  ("Children's author Carle",
#   'ERIC',
#   [('ERIC', 0.0),
#    ('SEEN', 0.9787616938508976),
#    ('ANNO', 1.0),
#    ('VOID', 1.0),
#    ('FIVE', 1.0)]),
#  ('Aunt, to Pedro',
#   'TIA',
#   [('TIA', 0.0),
#    ('TIA', 0.0),
#    ('ORA', 0.7330116091497139),
#    ('ESO', 0.7330116091497139),
#    ('SAN', 0.7910628002916219)]),
#  ('___-Novo (capital of Benin)',
#   'PORTO',
#   [('PORTO', 0.0),
#    ('PORTO', 0.0),
#    ('PORTO', 0.0),
#    ('PORTO', 0.9313888250565268),
#    ('ACCRA', 0.9579638929837175)]),
#  ('___ a time',
#   'ONEAT',
#   [('SANDS', 0.0),
#    ('ONEAT', 0.0),
#    ('UPONA', 0.0),
#    ('ONEAT', 0.0),
#    ('AHARD', 0.0)]),
#  ('Rock',
#   'TEETER',
#   [('TOTTER', 0.0),
#    ('OFAGES', 0.44368100060362603),
#    ('OFAGES', 0.44368100060362603)]),
#  ('Citizen of Vientiane',
#   'LAO',
#   [('LAO', 0.0),
#    ('LAO', 0.0),
#    ('LAO', 0.8705039795069156),
#    ('LAO', 0.8705039795069156),
#    ('LAO', 0.8705039795069156)]),
#  ('Garbage pail, maybe',
#   'ICON',
#   [('BAIL', 0.9245038562754101),
#    ('SEAU', 0.9763532310751829),
#    ('ELSE', 0.9999999999999999),
#    ('ALER', 0.9999999999999999),
#    ('ERAT', 0.9999999999999999)]),
#  ("Rosinante's rider", 'QUIXOTE', [('UNITARY', 0.9999999999999999)]),
#  ('Casbah country', 'ALGERIA', []),
#  ('"Sk8er ___," 2002 top 10 hit',
#   'BOI',
#   [('SKY', 1.0), ('SKY', 1.0), ('HER', 1.0), ('STS', 1.0), ('LOS', 1.0)]),
#  ('Ill-wisher',
#   'FOE',
#   [('FOE', 0.0),
#    ('FOE', 0.0),
#    ('FOE', 0.0),
#    ('FOE', 0.0),
#    ('HAD', 0.9065459471746523)]),
#  ('Rodeo tools',
#   'LARIATS',
#   [('NOOSING', 0.9435424686633348),
#    ('OUTRODE', 0.9467151963902982),
#    ('BARRELS', 0.9483404897869868)]),
#  ('Holders of many selfies',
#   'CELLS',
#   [('GRADS', 0.0),
#    ('EARLS', 0.640000229633573),
#    ('TILLS', 0.6867165137199991),
#    ('CRIBS', 0.7163581606220885),
#    ('VASES', 0.7206764784011431)]),
#  ('Self-help category',
#   'HOWTO',
#   [('GENRE', 0.8702502132204193),
#    ('GENRE', 0.8702502132204193),
#    ('GENRE', 0.8702502132204193),
#    ('GENRE', 0.8702502132204193),
#    ('CLASS', 0.8702502132204193)]),
#  ('Keystone character',
#   'KOP',
#   [('KOP', 0.0),
#    ('KOP', 0.6591290419037416),
#    ('KOP', 0.7992018306179173),
#    ('KOP', 0.7992018306179173),
#    ('KOP', 0.8542784429322864)]),
#  ('Mild oath',
#   'EGAD',
#   [('EGAD', 0.0), ('EGAD', 0.0), ('EGAD', 0.0), ('EGAD', 0.0), ('EGAD', 0.0)]),
#  ('Designer known for his "American look"',
#   'ELLIS',
#   [('FAMED', 0.9739449964174481),
#    ('FAMED', 0.9739449964174481),
#    ('FAMED', 0.9739449964174481),
#    ('FAMED', 0.9739449964174481),
#    ('NOTED', 0.9739449964174481)]),
#  ('Competitor of 39-Across',
#   'SERTA',
#   [('BROWN', 0.702875924254383),
#    ('AMICI', 0.702875924254383),
#    ('LOVER', 0.702875924254383),
#    ('TROLL', 0.702875924254383),
#    ('SHOUT', 0.702875924254383)]),
#  ('Done in',
#   'SLAIN',
#   [('DENSE', 0.0),
#    ('DAVID', 0.0),
#    ('RENEW', 0.0),
#    ('SPENT', 0.0),
#    ('PEASE', 0.0)]),
#  ('Gadgets for Norman',
#   'TEES',
#   [('TEES', 0.9032165716191114),
#    ('CAEN', 0.9281076241227493),
#    ('CAEN', 0.9281076241227493),
#    ('CAEN', 0.9281076241227493),
#    ('TEES', 0.9359770160595305)]),
#  ('Rum-soaked cake',
#   'BABA',
#   [('BABA', 0.6874135120506175),
#    ('BABA', 0.6874135120506175),
#    ('BABA', 0.6874135120506175),
#    ('BABA', 0.6874135120506175),
#    ('BABA', 0.6874135120506175)]),
#  ('What a few volts might be enough to do?', 'DRIVEONEBATTERY', []),
#  ('Takes, without being completely happy about it', 'SETTLESFOR', []),
#  ('Vicinity',
#   'AREA',
#   [('NEAR', 0.0), ('AREA', 0.0), ('AREA', 0.0), ('AREA', 0.0), ('AREA', 0.0)]),
#  ('Avril follower',
#   'MAI',
#   [('MAI', 0.0), ('MAI', 0.0), ('MAI', 0.0), ('MAI', 0.0), ('MAI', 0.0)]),
#  ('Leaps',
#   'VAULTS',
#   [('VAULTS', 0.0),
#    ('ELOPES', 0.7080920356898726),
#    ('REVERT', 1.0),
#    ('REHASH', 1.0)]),
#  ('Prefix with skeleton',
#   'EXO',
#   [('EXO', 0.0), ('EXO', 0.0), ('EXO', 0.0), ('EXO', 0.0), ('EXO', 0.0)]),
#  ('Q&A query', 'ANYONEELSE', []),
#  ('Cut',
#   'SHEAR',
#   [('SEVER', 0.0),
#    ('HEWED', 0.0),
#    ('SHARE', 0.0),
#    ('SEVER', 0.0),
#    ('SLICE', 0.0)]),
#  ('Covers',
#   'COATS',
#   [('INBED', 0.0),
#    ('TARPS', 0.6943413315668338),
#    ('TTOPS', 0.6943413315668338),
#    ('ARILS', 0.7120656494843749),
#    ('ARILS', 0.7120656494843749)]),
#  ('Bathed', 'SHOWERED', []),
#  ('"The Man ___," 1924 song',
#   'ILOVE',
#   [('ILOVE', 0.0),
#    ('ILOVE', 0.0),
#    ('ITHAD', 0.4822389161511223),
#    ('HADTO', 0.4822389161511223),
#    ('HADTO', 0.4822389161511223)]),
#  ('"The ___ Sanctions": Trevanian',
#   'LOO',
#   [('OKS', 0.8066439709141844),
#    ('LOO', 0.9410017012726513),
#    ('LOO', 0.9410017012726513),
#    ('LOO', 0.9410017012726513),
#    ('LOO', 0.9410017012726513)]),
#  ("Editor's note",
#   'STET',
#   [('STET', 0.0),
#    ('DELE', 0.0),
#    ('STET', 0.0),
#    ('STET', 0.7012418115399681),
#    ('SPOT', 0.8285828739427131)]),
#  ('Hardly frugal with',
#   'WASTING',
#   [('SPARTAN', 0.6561313391092063), ('SCRIMPS', 0.6561313391092063)]),
#  ('CENTO member',
#   'IRAN',
#   [('IRAN', 0.0), ('BASS', 1.0), ('ANTI', 1.0), ('AWRY', 1.0), ('SHOW', 1.0)]),
#  ('Dash', 'SMIDGEN', [('PANACHE', 0.0), ('PIZZAZZ', 0.0)]),
#  ('Word on a wine label',
#   'SEC',
#   [('SEC', 0.0),
#    ('SEC', 0.7184981782881646),
#    ('TAG', 0.8117481511360779),
#    ('TAB', 0.8117481511360779),
#    ('TAG', 0.8117481511360779)]),
#  ('Fiddle with',
#   'ADJUST',
#   [('SECOND', 0.5090900133527692),
#    ('REBECK', 0.5313932026170518),
#    ('STOOGE', 0.6363649768209434)]),
#  ('"Desire hath ___": Burton',
#   'NOREST',
#   [('NOREST', 0.0), ('ASHREW', 0.8939095551108428)]),
#  ('Pupil cover',
#   'CORNEA',
#   [('CORNEA', 0.0),
#    ('SHROUD', 0.8471092225650607),
#    ('CLOTHE', 0.8471092225650607),
#    ('ENCASE', 0.8471092225650607),
#    ('ENROBE', 0.8471092225650607)]),
#  ('What "Lucy in the Sky With Diamonds" may or may not be about',
#   'LSD',
#   [('ICE', 0.8811096526888822),
#    ('ICE', 0.8811096526888822),
#    ('PIE', 0.9714354180619418)]),
#  ('"The Simpsons" storekeeper',
#   'APU',
#   [('APU', 0.0),
#    ('DOH', 0.8789037237874866),
#    ('APU', 0.9465623464851113),
#    ('AIL', 0.9999999999999999),
#    ('YET', 0.9999999999999999)]),
#  ('Lustrous fabric',
#   'PANNE',
#   [('SATIN', 0.0),
#    ('SATIN', 0.0),
#    ('SATIN', 0.0),
#    ('HONAN', 0.0),
#    ('NITID', 0.6513666373478648)]),
#  ('Diane Sawyer, for one',
#   'ANCHOR',
#   [('DIANES', 0.794181094375034),
#    ('DIANES', 0.794181094375034),
#    ('COSTAR', 0.939168388625893),
#    ('DIANES', 0.9904520630959498),
#    ('GENTLY', 1.0)]),
#  ('Stable sound',
#   'SNORT',
#   [('SNORT', 0.0),
#    ('SNORT', 0.0),
#    ('SNORT', 0.0),
#    ('SNORT', 0.0),
#    ('SNORT', 0.0)]),
#  ('Casual denial',
#   'NAH',
#   [('NAY', 0.7798714815913832),
#    ('NAY', 0.7798714815913832),
#    ('FRI', 0.8557736309670231),
#    ('FRI', 0.8557736309670231),
#    ('NOT', 0.9085465701257434)]),
#  ('Hunter or Kelly',
#   'GREEN',
#   [('MOIRA', 0.8835884693614502),
#    ('MOIRA', 0.8835884693614502),
#    ('DRYER', 0.9523753581522734)]),
#  ('Checks',
#   'STEMS',
#   [('CURBS', 0.0),
#    ('STEMS', 0.0),
#    ('STEMS', 0.0),
#    ('STEMS', 0.0),
#    ('STEMS', 0.0)]),
#  ('Place to go with a flashlight',
#   'CAVERN',
#   [('DCELLS', 0.8987124819028327),
#    ('RETAIN', 0.9999999999999999),
#    ('ATHOME', 0.9999999999999999),
#    ('CAMERA', 0.9999999999999999)]),
#  ('Comfort',
#   'EASE',
#   [('EASE', 0.0), ('EASE', 0.0), ('EASE', 0.0), ('EASE', 0.0), ('EASE', 0.0)]),
#  ('___ to kill (dress smashingly)', 'LOOKFIT', []),
#  ('Sex researcher Hite',
#   'SHERE',
#   [('SHERE', 0.921683387860064),
#    ('SHERE', 0.9535389439967846),
#    ('SHERE', 0.9535389439967846),
#    ('SHERE', 0.9535389439967846),
#    ('SHERE', 0.9535389439967846)]),
#  ('Craps action',
#   'BET',
#   [('SUE', 0.9227324909938395),
#    ('CPR', 0.9227324909938395),
#    ('SUE', 0.9227324909938395),
#    ('VII', 0.9502581194938956)]),
#  ('Reasonably priced ... or a hint to 17-, 19-, 26-, 34-, 42- and 51-Across',
#   'WITHINCOST',
#   []),
#  ('Gaelic',
#   'ERSE',
#   [('ERSE', 0.0), ('ERSE', 0.0), ('ERSE', 0.0), ('ERSE', 0.0), ('ERSE', 0.0)]),
#  ('Corrida shouts',
#   'OLES',
#   [('OLES', 0.0),
#    ('OLES', 0.8848458267951548),
#    ('URLA', 0.902723698400419),
#    ('AHAS', 0.9035031099118087),
#    ('EEKS', 0.9121608168664778)]),
#  ('Escape clauses, e.g.',
#   'OUTS',
#   [('OUTS', 0.0),
#    ('FLEE', 0.8742717851501463),
#    ('FLEE', 0.8742717851501463),
#    ('FATE', 0.8742717851501463),
#    ('FLEE', 0.8742717851501463)]),
#  ('Pop',
#   'DAD',
#   [('DAD', 0.0), ('PER', 0.0), ('DAD', 0.0), ('PER', 0.0), ('DAD', 0.0)]),
#  ('Columbia, vis-a-vis the ocean', 'GEM', [('ARM', 0.7447355418129735)]),
#  ('Entre ___',
#   'NOUS',
#   [('NOUS', 0.0), ('NOUS', 0.0), ('NOUS', 0.0), ('NOUS', 0.0), ('NOUS', 0.0)]),
#  ('Ends',
#   'TERMINI',
#   [('LINEMEN', 0.0),
#    ('ADDENDA', 0.6533988405672918),
#    ('PERIODS', 0.6533988405672918),
#    ('AITCHES', 0.6571397915955551),
#    ('LETSOUT', 0.7306574469956173)]),
#  ('Space',
#   'AREA',
#   [('AREA', 0.0), ('AREA', 0.0), ('AREA', 0.0), ('AREA', 0.0), ('ROOM', 0.0)]),
#  ('Ointment ingredient',
#   'ALOE',
#   [('NARD', 0.6273938398075076),
#    ('BALM', 0.6273938398075076),
#    ('NARD', 0.6273938398075076),
#    ('NARD', 0.6273938398075076),
#    ('NARD', 0.6273938398075076)]),
#  ('Curved molding',
#   'OGEE',
#   [('OGEE', 0.0), ('OGEE', 0.0), ('OGEE', 0.0), ('OGEE', 0.0), ('OGEE', 0.0)]),
#  ('I, in Berlin',
#   'ICH',
#   [('EHE', 0.0), ('IHR', 0.0), ('EIN', 0.0), ('EIN', 0.0), ('ACH', 0.0)]),
#  ('Gaza or Sunset',
#   'STRIP',
#   [('HAMAS', 0.8043161090066671),
#    ('VOWEL', 1.0),
#    ('ROGER', 1.0),
#    ('OLIVE', 1.0),
#    ('CREME', 1.0)]),
#  ('It may be coed',
#   'DORM',
#   [('EXAM', 0.5551221748415233),
#    ('DORM', 0.645382303361614),
#    ('ELLE', 0.7679971486780498),
#    ('EMIT', 1.0),
#    ('EVER', 1.0)]),
#  ('Speaker of baseball',
#   'TRIS',
#   [('TRIS', 0.0), ('TRIS', 0.0), ('TRIS', 0.0), ('TRIS', 0.0), ('TRIS', 0.0)]),
#  ('Where many arrests take place, for short',
#   'ERS',
#   [('TOO', 1.0), ('SPT', 1.0), ('LOS', 1.0), ('GUN', 1.0), ('FEW', 1.0)]),
#  ('Mattress problems',
#   'LUMPS',
#   [('LISPS', 0.8035465548652916),
#    ('SMOGS', 0.8035465548652916),
#    ('SEALY', 0.8979601616182613),
#    ('SERTA', 0.8979601616182613),
#    ('SERTA', 0.8979601616182613)]),
#  ('Big bill',
#   'CNOTE',
#   [('NOTED', 0.0),
#    ('OBESE', 0.0),
#    ('WEEST', 0.0),
#    ('DRDRE', 0.0),
#    ('AMPLE', 0.0)]),
#  ('"___ du lieber!"',
#   'ACH',
#   [('ACH', 0.0),
#    ('ACH', 0.0),
#    ('ACH', 0.0),
#    ('ACH', 0.0),
#    ('ACH', 0.457297915648528)]),
#  ('When repeated, a dolphin',
#   'MAHI',
#   [('COVE', 0.8538970164465742),
#    ('ONCE', 0.8557487745741199),
#    ('HUSH', 0.8557487745741199),
#    ('INIA', 0.9016773859719229),
#    ('INIA', 0.9016773859719229)]),
#  ('Within an ___ (very close)',
#   'ACEOF',
#   [('SHAVE', 0.0),
# ...
#  ('German camera',
#   'LEICA',
#   [('LEICA', 0.0),
#    ('LEICA', 0.5745481387241246),
#    ('STILL', 0.8396958760548484)]),
#  ('Scylla or Charybdis',
#   'PERIL',
#   [('PERIL', 0.0),
#    ('NAIAD', 0.7653668647301797),
#    ('VOWEL', 1.0),
#    ('ALIEN', 1.0),
#    ('AGREE', 1.0)]),
#  ('God-fearing',
#   'PIOUS',
#   [('DEITY', 0.0),
#    ('MAKER', 0.0),
#    ('MAKER', 0.0),
#    ('LOGOS', 0.0),
#    ('AGNES', 0.43873577053186225)]),
#  ('Coasters',
#   'SLEDS',
#   [('LUGES', 0.0),
#    ('SLEDS', 0.0),
#    ('SLEDS', 0.0),
#    ('SLEDS', 0.6444386036507982),
#    ('WHEES', 0.817046984840179)]),
#  ('Draws a bead on',
#   'AIMS',
#   [('DROP', 0.7464287161058444),
#    ('TAPS', 0.7842249511725243),
#    ('TIES', 0.7842249511725243),
#    ('TIES', 0.7842249511725243),
#    ('USES', 0.7842249511725243)]),
#  ('Rent',
#   'TORE',
#   [('TORN', 0.0), ('TEAR', 0.0), ('TORN', 0.0), ('TORN', 0.0), ('TORE', 0.0)]),
#  ('1/12 of a ruler',
#   'INCH',
#   [('TSAR', 0.7534087875803394),
#    ('OTTO', 0.7534087875803394),
#    ('TSAR', 0.7534087875803394),
#    ('OTHO', 0.7534087875803394),
#    ('TSAR', 0.7534087875803394)]),
#  ('Arthur Murray instruction',
#   'STEPS',
#   [('RUMBA', 0.847445919589209),
#    ('STEPS', 0.8818580974135928),
#    ('INITS', 0.9999999999999999)]),
#  ('Ford Explorer, e.g.: Abbr.',
#   'SUV',
#   [('SUV', 0.4066238080260246),
#    ('LTD', 0.8370798041712956),
#    ('LTD', 0.8370798041712956),
#    ('LTD', 0.9656613175205655),
#    ('LTD', 0.9656613175205655)]),
#  ('Venomous, as a snake',
#   'ASPISH',
#   [('ASPISH', 0.0),
#    ('ASPISH', 0.0),
#    ('HISSER', 0.8479504432115319),
#    ('HISSER', 0.8479504432115319)]),
#  ('Author of a 1952 novel published in full in Life magazine',
#   'ERNESTHEMINGWAY',
#   []),
#  ('Moves aimlessly, with "about"',
#   'GADS',
#   [('ROVE', 0.6999786885662849),
#    ('ROAM', 0.6999786885662849),
#    ('AWES', 0.8298100829178408),
#    ('ROAM', 0.9239697890722444),
#    ('ROVE', 0.9405733401496608)]),
#  ('Bite lightly into',
#   'NIPAT',
#   [('NIPAT', 0.0),
#    ('TRYIT', 0.7775803898964199),
#    ('NIPAT', 0.7775803898964199)]),
#  ('Shackles', 'CHAINS', [('ITSAGO', 1.0)]),
#  ('Apocopate', 'ELIDE', [('ELIDE', 0.0)]),
#  ("Nameless one's name", 'JANEDOE', [('ONEMORE', 1.0)]),
#  ('Steven Bochco series',
#   'LALAW',
#   [('LALAW', 0.0),
#    ('LALAW', 0.9749074652125498),
#    ('MOVER', 1.0000000000000002),
#    ('IMSET', 1.0000000000000002),
#    ('PRATE', 1.0000000000000002)]),
#  ('Havoc',
#   'RUIN',
#   [('RUIN', 0.0),
#    ('RUIN', 0.0),
#    ('JUNE', 0.8328990099645376),
#    ('AMID', 1.0),
#    ('COST', 1.0)]),
#  ("Doesn't tarry",
#   'HIES',
#   [('STAY', 0.6197964780882077),
#    ('STAY', 0.6197964780882077),
#    ('BIDE', 0.6197964780882077),
#    ('TREY', 0.9063291557006479),
#    ('TREY', 0.9063291557006479)]),
#  ('Ball or strike',
#   'CALL',
#   [('CALL', 0.0),
#    ('DELE', 0.7063647711432155),
#    ('DELE', 0.7063647711432155),
#    ('DELE', 0.7063647711432155),
#    ('WALK', 0.7063647711432155)]),
#  ('Craft with a paddle',
#   'CANOE',
#   [('WHACK', 0.6566118250541001),
#    ('CANOE', 0.7128978625703452),
#    ('TRADE', 0.8715310838457992),
#    ('TRADE', 0.8715310838457992)]),
#  ('Evaluate',
#   'ASSESS',
#   [('REVIEW', 0.0),
#    ('ASSESS', 0.0),
#    ('ASSESS', 0.0),
#    ('ASSESS', 0.0),
#    ('ASSESS', 0.0)]),
#  ('Former big-game guns',
#   'ROERS',
#   [('REARM', 0.7421813939822447),
#    ('STENS', 0.7421813939822447),
#    ('EMIRS', 0.7702958664776205),
#    ('MOOSE', 0.7884324465078572),
#    ('STENS', 0.917836101234325)]),
#  ('Neighborhoods',
#   'AREAS',
#   [('AREAS', 0.0),
#    ('AREAS', 0.0),
#    ('AREAS', 0.0),
#    ('REHEM', 1.0),
#    ('WAIVE', 1.0)]),
#  ('1/2 and 1/3 parts', 'SLASHES', [('FINALES', 0.0), ('ASUNDER', 0.0)]),
#  ("Atty.'s org.",
#   'ABA',
#   [('ABA', 0.0),
#    ('ABA', 0.0),
#    ('GEN', 0.6272173630048591),
#    ('ESQ', 0.7580739533035629),
#    ('ESQ', 0.7580739533035629)]),
#  ('Apollo 11 astronaut',
#   'ALDRIN',
#   [('EISELE', 0.5697057877759993),
#    ('GORDON', 0.7647077157532026),
#    ('BORMAN', 0.780893187152371),
#    ('LOVELL', 0.8091235458927397),
#    ('LYRIST', 0.9097270643084252)]),
#  ('Jolly good fellow',
#   'CHAP',
#   [('HESA', 0.23469221084035946),
#    ('HESA', 0.23469221084035946),
#    ('HESA', 0.6709441072043144),
#    ('HESA', 0.6709441072043144),
#    ('HESA', 0.6709441072043144)]),
#  ('Aquafina alternative',
#   'EVIAN',
#   [('EVIAN', 0.7129001634986166),
#    ('NOTES', 0.9999999999999999),
#    ('CLEFS', 0.9999999999999999),
#    ('RECAP', 0.9999999999999999),
#    ('DEPTH', 0.9999999999999999)]),
#  ('Nine-digit ID',
#   'SSN',
#   [('SSN', 0.3667234169259976),
#    ('SSN', 0.3667234169259976),
#    ('SSA', 0.6590027128310046),
#    ('TOE', 0.7337474331039973),
#    ('ONE', 0.7337474331039973)]),
#  ('Career of the parent who typed up the Career Day schedule?',
#   'NOVELWRITER',
#   []),
#  ('Chess pcs.',
#   'KTS',
#   [('KTS', 0.0),
#    ('LAN', 0.8875060683096636),
#    ('HPS', 0.8897986777690131),
#    ('LAN', 0.9543900824659487),
#    ('HIS', 1.0)]),
#  ('Trinitrotoluene', 'TNT', [('TNT', 0.0), ('YET', 1.0), ('DON', 1.0)]),
#  ('"Philebus" author',
#   'PLATO',
#   [('TRYON', 0.0),
#    ('ROLLO', 0.0),
#    ('CAPEK', 0.0),
#    ('OATES', 0.0),
#    ('OATES', 0.0)]),
#  ('Richard of NBC News',
#   'ENGEL',
#   [('COWAN', 0.8060471925767685),
#    ('IKNOW', 0.9828528531126862),
#    ('JIMMY', 0.9828528531126862),
#    ('ERRED', 1.0),
#    ('ENDED', 1.0)]),
#  ('Harrow blade',
#   'DISK',
#   [('DISC', 0.0),
#    ('DISC', 0.7163188780986637),
#    ('ETON', 0.7163188780986637),
#    ('TINE', 0.7163188780986637),
#    ('TINE', 0.7163188780986637)]),
#  ('Emerged',
#   'AROSE',
#   [('RHETT', 0.8024643362993203),
#    ('REHEM', 1.0),
#    ('WAIVE', 1.0),
#    ('BOOST', 1.0),
#    ('BUILT', 1.0)]),
#  ('Reversals',
#   'UTURNS',
#   [('UTURNS', 0.0), ('UNHURT', 1.0), ('MYOHMY', 1.0), ('APPEAR', 1.0)]),
#  ('Earth, to Brahms',
#   'ERDE',
#   [('ABER', 0.6223838208700713),
#    ('DIRT', 0.9039019259377512),
#    ('SOIL', 0.9039019259377512),
#    ('HERE', 0.9039019259377512),
#    ('SOIL', 0.9039019259377512)]),
#  ("Viscount's superior",
#   'EARL',
#   [('EARL', 0.0),
#    ('EARL', 0.0),
#    ('EARL', 0.0),
#    ('LAKE', 0.849674824258686),
#    ('ATOP', 0.849674824258686)]),
#  ('Pass over',
#   'OMIT',
#   [('OMIT', 0.0), ('OMIT', 0.0), ('GOBY', 0.0), ('OMIT', 0.0), ('OMIT', 0.0)]),
#  ('French Protestant', 'HUGUENOT', [('LUTHERAN', 0.7258906865056335)]),
#  ('Western ___',
#   'OMELET',
#   [('OMELET', 0.0), ('OMELET', 0.0), ('OMELET', 0.42178503912045706)]),
#  ('Statement made with a tsk, tsk',
#   'ITSAMESS',
#   [('TISAPITY', 0.3744242973985252),
#    ('FORSHAME', 0.3744242973985252),
#    ('ONEORTWO', 0.9999999999999999)]),
#  ('Real',
#   'INESSE',
#   [('INESSE', 0.0),
#    ('INESSE', 0.0),
#    ('ACTUAL', 0.0),
#    ('ACTUAL', 0.0),
#    ('ACTUAL', 0.0)]),
#  ('Santa ___ winds',
#   'ANA',
#   [('ANA', 0.0), ('ANA', 0.0), ('ANA', 0.0), ('ANA', 0.0), ('ANA', 0.0)]),
#  ('Unbending',
#   'RIGID',
#   [('RIGID', 0.0),
#    ('RIGID', 0.0),
#    ('RIGID', 0.0),
#    ('STIFF', 0.0),
#    ('RIGID', 0.0)]),
#  ('Is overly fond',
#   'DOTES',
#   [('DOTER', 0.0),
#    ('DOTED', 0.0),
#    ('DOTER', 0.0),
#    ('DOTES', 0.0),
#    ('DOTER', 0.7569239861766708)]),
#  ('Seventh sign',
#   'LIBRA',
#   [('LIBRA', 0.6754085214674791),
#    ('BLISS', 0.9023907357835271),
#    ('ENROL', 0.916254211266108),
#    ('ARIES', 0.916254211266108)]),
#  ("Grenoble's river",
#   'ISERE',
#   [('ISERE', 0.0),
#    ('ISERE', 0.0),
#    ('ISERE', 0.0),
#    ('ISERE', 0.0),
#    ('ISERE', 0.0)]),
#  ("Macbeth's tragic flaw", 'AMBITION', []),
#  ('Ruckus',
#   'ROW',
#   [('ADO', 0.0), ('ROW', 0.0), ('ADO', 0.0), ('DIN', 0.0), ('ADO', 0.0)]),
#  ('Bon follower',
#   'AMI',
#   [('MOT', 0.0),
#    ('MOT', 0.6911277788587308),
#    ('MOT', 0.6911277788587308),
#    ('AMI', 0.6911277788587308),
#    ('MOT', 0.6911277788587308)]),
#  ('Collect',
#   'AMASS',
#   [('AMASS', 0.0),
#    ('AMASS', 0.0),
#    ('AMASS', 0.0),
#    ('AMASS', 0.0),
#    ('AMASS', 0.0)]),
#  ('Comic ___',
#   'OPERA',
#   [('SERIO', 0.0),
#    ('SERIO', 0.7110160701834612),
#    ('SERIO', 0.7531132735927761),
#    ('SERIO', 0.7531132735927761),
#    ('SERIO', 0.7531132735927761)]),
#  ('Wash again, as the floor',
#   'REMOP',
#   [('BATHE', 0.7615736447258457),
#    ('ELUTE', 0.7615736447258457),
#    ('LAPAT', 0.7615736447258457),
#    ('RINSE', 0.7615736447258457),
#    ('ELUTE', 0.7615736447258457)]),
#  ('Emulate Everett',
#   'ORATE',
#   [('CLEFS', 1.0), ('AMAIN', 1.0), ('HENCE', 1.0), ('DRONE', 1.0)]),
#  ('Item in a laundry',
#   'IRON',
#   [('IRON', 0.0),
#    ('WASH', 0.6155636563481568),
#    ('WASH', 0.6155636563481568),
#    ('WASH', 0.6155636563481568),
#    ('WASH', 0.6155636563481568)]),
#  ('Danish-American journalist-reformer',
#   'RIIS',
#   [('RIIS', 0.5319487464745761),
#    ('RIIS', 0.8315646435571336),
#    ('RIIS', 0.8658840495666752),
#    ('RIIS', 0.930626752972128),
#    ('RIIS', 0.930626752972128)]),
#  ('Doing business',
#   'OPEN',
#   [('OPEN', 0.0),
#    ('IDLE', 0.7054540230132252),
#    ('IDLE', 0.7054540230132252),
#    ('IDLE', 0.7054540230132252),
#    ('IDLE', 0.7054540230132252)]),
#  ('Orly sights',
#   'SSTS',
#   [('SSTS', 0.8543132899620226),
#    ('SSTS', 0.8543132899620226),
#    ('SKIS', 0.8792937538965269),
#    ('SSTS', 0.8792937538965269),
#    ('TOUR', 0.8792937538965269)]),
#  ('Imperiled',
#   'ATRISK',
#   [('MYOHMY', 1.0), ('ISLAND', 1.0), ('UNHURT', 1.0), ('APPEAR', 1.0)]),
#  ('Ancient meeting places',
#   'AGORAS',
#   [('CRYPTS', 0.7713721507385705),
#    ('LODGES', 0.8004955853154765),
#    ('ATTEND', 0.8458383277355208),
#    ('POWWOW', 0.8458383277355208)]),
#  ("Sif's husband",
#   'THOR',
#   [('THOR', 0.0),
#    ('SAVE', 0.9386288984913906),
#    ('THIS', 0.9999999999999999),
#    ('ANEW', 0.9999999999999999),
#    ('BONY', 0.9999999999999999)]),
#  ('Legal thing',
#   'RES',
#   [('RES', 0.0), ('RES', 0.0), ('RES', 0.0), ('RES', 0.0), ('RES', 0.0)]),
#  ('High spirits',
#   'UPNESS',
#   [('GAIETY', 0.0),
#    ('JOVIAL', 0.0),
#    ('UPBEAT', 0.0),
#    ('LIQUOR', 0.6272182675903711),
#    ('GENIES', 0.6272182675903711)]),
#  ("Havana's last section",
#   'STUB',
#   [('ESTA', 0.6538760179465688),
#    ('OLIN', 0.8115837454105573),
#    ('CUBA', 0.8204841514105204),
#    ('CASA', 0.8467948833879663),
#    ('CASA', 0.8467948833879663)]),
#  ('Yule tree for little Fritz', 'TANNENBAUM', []),
#  ('Brand of nonstick cookware',
#   'TFAL',
#   [('TFAL', 0.7371318077453478),
#    ('POTS', 0.8841049821621373),
#    ('OLLA', 0.9795626143195559),
#    ('LIMN', 1.0),
#    ('PAST', 1.0)]),
#  ('Inspire horror', 'TERRIFY', [('ATLASES', 1.0)]),
#  ('Catch',
#   'BAG',
#   [('BAG', 0.0), ('RUB', 0.0), ('GET', 0.0), ('GET', 0.0), ('BAG', 0.0)]),
#  ('An alum',
#   'GRAD',
#   [('GRAD', 0.0), ('GRAD', 0.0), ('GRAD', 0.0), ('GRAD', 0.0), ('SALT', 0.0)]),
#  ('Bewildered',
#   'ATSEA',
#   [('ATSEA', 0.0),
#    ('ATSEA', 0.0),
#    ('ATSEA', 0.0),
#    ('ATSEA', 0.0),
#    ('MAZED', 0.0)]),
#  ('God of death who underwent resurrection',
#   'OSIRIS',
#   [('OSIRIS', 0.5391418110875654), ('ATTEND', 0.9999999999999999)]),
#  ('Decline again', 'RESLIDE', [('RESLIDE', 0.0), ('ABATING', 0.0)]),
#  ("Jeweler's measure",
#   'CARAT',
#   [('KARAT', 0.0),
#    ('KARAT', 0.0),
#    ('KARAT', 0.7055947343268028),
#    ('KARAT', 0.8086081075459708),
#    ('CARAT', 0.8086081075459708)]),
#  ('Melt',
#   'SOFTEN',
#   [('RENDER', 0.5919941655072569),
#    ('RENDER', 0.6379203225138491),
#    ('NETHER', 1.0)]),
#  ('Honey, in prescriptions',
#   'MEL',
#   [('OMN', 0.6982932815206744),
#    ('EAD', 0.6982932815206744),
#    ('UBI', 0.6982932815206744),
#    ('OMN', 0.6982932815206744),
#    ('RXS', 0.8289935691518441)]),
#  ('Infamous Amin',
#   'IDI',
#   [('IDI', 0.0),
#    ('IDI', 0.792485782424581),
#    ('IDI', 0.792485782424581),
#    ('IDI', 0.792485782424581),
#    ('IDI', 0.792485782424581)]),
#  ("Sinatra's gift",
#   'VOICE',
#   [('VOICE', 0.7714330870749455),
#    ('VOICE', 0.7714330870749455),
#    ('OFGAB', 0.8798608601225391),
#    ('OFGAB', 0.8798608601225391),
#    ('OFGAB', 0.8798608601225391)]),
#  ('Final: Abbr.',
#   'ULT',
#   [('ULT', 0.0), ('ULT', 0.0), ('ULT', 0.0), ('ULT', 0.0), ('ULT', 0.0)]),
#  ("Bruins' home",
#   'UCLA',
#   [('UCLA', 0.0),
#    ('UCLA', 0.0),
#    ('UCLA', 0.45671771302092823),
#    ('UCLA', 0.5525276288416391),
#    ('UCLA', 0.5525276288416391)]),
#  ("Serpent's tail?",
#   'INE',
#   [('INE', 0.0),
#    ('INE', 0.0),
#    ('INE', 0.0),
#    ('ASP', 0.7054302596752449),
#    ('END', 0.824508597628949)]),
#  ('Dodecanese island',
#   'KOS',
#   [('KOS', 0.0),
#    ('ORE', 0.9999999999999999),
#    ('HEY', 0.9999999999999999),
#    ('BAR', 0.9999999999999999),
#    ('CHI', 0.9999999999999999)]),
#  ('Encumbrance',
#   'LIEN',
#   [('LIEN', 0.0), ('LIEN', 0.0), ('ONUS', 0.0), ('LOAD', 0.0), ('LIEN', 0.0)]),
#  ('Horsley\'s "Guns of Paradise" role',
#   'CORD',
#   [('CEDE', 1.0), ('SATE', 1.0), ('GENL', 1.0), ('LAST', 1.0), ('GOER', 1.0)]),
#  ('Box-elder genus',
#   'ACER',
#   [('ACER', 0.0),
#    ('ACER', 0.0),
#    ('HOMO', 0.9361498374986256),
#    ('HOMO', 0.9361498374986256),
#    ('SPAR', 0.9838918685952235)]),
#  ('Its first sale was a broken laser pointer',
#   'EBAY',
#   [('DISC', 0.9670849944608699),
#    ('ELSE', 1.0),
#    ('ELSE', 1.0),
#    ('ELSE', 1.0),
#    ('SANE', 1.0)]),
#  ('March syllable',
#   'HUP',
#   [('TSE', 0.7352485319619924),
#    ('ANT', 0.7952831972860528),
#    ('HUT', 0.7952831972860528),
#    ('TRA', 0.8991445268305872),
#    ('TRA', 0.8991445268305872)]),
#  ('Hwy.',
#   'RTE',
#   [('RTE', 0.0), ('RTE', 0.0), ('RTE', 0.0), ('RTE', 0.0), ('RTE', 0.0)]),
#  ('Drinks at sidewalk stands',
#   'ADES',
#   [('ADES', 0.781020008629131),
#    ('NOUN', 0.9074342764192032),
#    ('ICON', 0.9074342764192032),
#    ('ASIT', 0.944241240536703),
#    ('ALES', 0.9775625801311254)]),
#  ('Privy to',
#   'INON',
#   [('INON', 0.0), ('INON', 0.0), ('INON', 0.0), ('INON', 0.0), ('INON', 0.0)]),
#  ('Price',
#   'COST',
#   [('COST', 0.0), ('RATE', 0.0), ('COST', 0.0), ('COST', 0.0), ('COST', 0.0)]),
#  ("Dr. Seuss's Thidwick",
#   'MOOSE',
#   [('MOOSE', 0.0),
#    ('CATIN', 0.8626816012713876),
#    ('HOPON', 0.9098309327864004)]),
#  ('Gulf of Aqaba port',
#   'ELATH',
#   [('EILAT', 0.0),
#    ('ELATH', 0.0),
#    ('EILAT', 0.0),
#    ('EILAT', 0.0),
#    ('EILAT', 0.0)]),
#  ('Had on',
#   'WORE',
#   [('EACH', 0.0), ('RAVE', 0.0), ('AREA', 0.0), ('QUOD', 0.0), ('WEAR', 0.0)]),
#  ('"Get outta here!"',
#   'GOHOME',
#   [('SCRAMS', 0.7869341823174457),
#    ('AFRESH', 1.0),
#    ('ENTIRE', 1.0),
#    ('OFFICE', 1.0)]),
#  ('One who wants in on the deal', 'CARDPLAYER', []),
#  ('Gypsy',
#   'ROMANY',
#   [('GITANO', 0.0),
#    ('ROMANY', 0.6651612287364072),
#    ('ROMANY', 0.7142457031498711),
#    ('TAROTS', 0.716119991105744)]),
#  ('Scrape (out)',
#   'EKE',
#   [('EKE', 0.0), ('EKE', 0.0), ('EKE', 0.0), ('EKE', 0.0), ('EKE', 0.0)]),
#  ("They're good for crying out loud",
#   'SOBS',
#   [('YELL', 0.894356013672762),
#    ('YELL', 0.894356013672762),
#    ('ROAR', 0.894356013672762),
#    ('DELE', 1.0),
#    ('ISAY', 1.0)]),
#  ('Chemical ending',
#   'ANE',
#   [('INE', 0.0), ('ENE', 0.0), ('ENE', 0.0), ('ATE', 0.0), ('INE', 0.0)]),
#  ('Env. contents',
#   'LTR',
#   [('LTR', 0.0),
#    ('LTR', 0.0),
#    ('LTR', 0.0),
#    ('PKG', 0.8175397270101548),
#    ('ENC', 0.8682347704134383)]),
#  ('Degree for an att.',
#   'LLB',
#   [('LLB', 0.0),
#    ('ABA', 0.7404715598370645),
#    ('DEF', 0.844683478437007),
#    ('MBA', 0.9306979497103417),
#    ('MBA', 0.9306979497103417)]),
#  ('See 70-Across', 'THOREAU', []),
#  ('Uno, due, ___',
#   'TRE',
#   [('TRE', 0.0), ('TRE', 0.0), ('TRE', 0.0), ('TRE', 0.0), ('TRE', 0.0)]),
#  ('High in the French Alps',
#   'HAUT',
#   [('HAUT', 0.4827843133626171),
#    ('ELSE', 1.0),
#    ('FLEE', 1.0),
#    ('PRES', 1.0),
#    ('ALSO', 1.0)]),
#  ('Furtive movement',
#   'SIDLE',
#   [('OVERT', 0.7011395307656578),
#    ('SLIER', 0.7011395307656578),
#    ('SLYER', 0.7011395307656578),
#    ('SLIER', 0.7011395307656578),
#    ('CAUSE', 0.8286822721444789)]),
#  ('Stropped',
#   'HONED',
#   [('DENSE', 0.0),
#    ('DAVID', 0.0),
#    ('RENEW', 0.0),
#    ('SPENT', 0.0),
#    ('PEASE', 0.0)]),
#  ('Sandra or Ruby',
#   'DEE',
#   [('DEE', 0.0), ('DEE', 0.0), ('DEE', 0.0), ('DEE', 0.0), ('DEE', 0.0)]),
#  ('Blackleg in Bristol',
#   'SCAB',
#   [('SCAB', 0.7291271441681452),
#    ('SCAB', 0.8619671449306565),
#    ('SCAB', 0.8619671449306565),
#    ('AVON', 0.901326248379311),
#    ('AVON', 0.942089212720833)]),
#  ('___ Lanka',
#   'SRI',
#   [('SRI', 0.0), ('SRI', 0.0), ('SRI', 0.0), ('SRI', 0.0), ('SRI', 0.0)]),
#  ('"Falling Skies" airer',
#   'TNT',
#   [('TBS', 0.9643062572346572),
#    ('TNN', 0.9643062572346572),
#    ('ERR', 1.0),
#    ('NIL', 1.0),
#    ('ERR', 1.0)]),
#  ('Take in or let out',
#   'ALTER',
#   [('ADMIT', 0.0),
#    ('ABATE', 0.0),
#    ('STEAM', 0.0),
#    ('UNPEN', 0.0),
#    ('ABATE', 0.0)])]

# %%
guess("opposite of NNE")
# Out:
# [('SSW', 0.0),
#  ('SSW', 0.0),
#  ('SSW', 0.0),
#  ('LILLE', 0.8641961592218417),
#  ('LILLE', 0.8641961592218417)]

# %%
# # serialize and save model
# import pickle

# TRAINED_MODEL_PATH = "trained_model.p"

# pickle.dump((answers_train, vectorizer, model), open(TRAINED_MODEL_PATH, "wb"))
