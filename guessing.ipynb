# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt

DATA_PATH = "C:/Users/Russell/Documents/School-Work/CMSC470/crossword_puzzles/data/nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

sample = random.sample(puzzles_available, 10_000)

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)
clue_answer_pairs
# Out:
# [('"Jabberwocky" start', 'TWAS'),
#  ('Female W.W. II-era enlistees', 'WAACS'),
#  ('Sorento and Sedona', 'KIAS'),
#  ('Brewery fixture', 'OAST'),
#  ('Is sporting', 'HASON'),
#  ('Just sitting', 'IDLE'),
#  ('Zuider Zee sight', 'DIKE'),
#  ('Midway alternative', 'OHARE'),
#  ('Legal basis of a repo', 'LIEN'),
#  ('Bone-related', 'OSTEAL'),
#  ('What you might do while driving to an unfamiliar place', 'GETLOST'),
#  ('Rich dessert', 'TORTE'),
#  ('Jumbo and colossal', 'SIZES'),
#  ('Words of woe', 'OHME'),
#  ('F equivalent', 'ESHARP'),
#  ('Ancient theaters', 'ODEA'),
#  ("Vintner's prefix", 'OENO'),
#  ('"I ___ Parade"', 'LOVEA'),
#  ('What you might do next?', 'FINDAGASSTATION'),
#  ('Water nymph', 'NAIAD'),
#  ('Garland\'s "cowardly" co-star', 'LAHR'),
#  ('Manuscript encl.', 'SASE'),
#  ('Seasoned vet', 'OLDPRO'),
#  ('Southwest art center', 'TAOS'),
#  ('Hardly garrulous', 'TERSE'),
#  ('Ph.D. hurdles', 'ORALS'),
#  ('What you might do next?', 'BUYAMAP'),
#  ('Local lingo', 'PATOIS'),
#  ('Melville mariner', 'AHAB'),
#  ('Leader of the Mel-Tones', 'TORME'),
#  ('Sierra Club concern: Abbr.', 'ECOL'),
#  ('Game turn, maybe', 'ROLL'),
#  ('Quilt stuffing', 'EIDER'),
#  ('Gull-like predator', 'SKUA'),
#  ("South Korea's first president", 'RHEE'),
#  ('Some side dishes', 'SLAWS'),
#  ('Communicate with modern-style', 'TEXT'),
#  ('List heading', 'TODO'),
#  ("Tailor's measurement", 'WAIST'),
#  ("Request one's presence at", 'ASKTO'),
#  ('Be in control', 'STEER'),
#  ('All out', 'WHOLEHOG'),
#  ('Sighed word', 'AAH'),
#  ('Fat-pig filler?', 'ASA'),
#  ('Welsh breed', 'CORGI'),
#  ('Cause for a blessing?', 'SNEEZE'),
#  ('Volleyball spikes, say', 'KILLSHOTS'),
#  ('Peculiar: Prefix', 'IDIO'),
#  ("Publican's stock", 'ALES'),
#  ('Made rhapsodic', 'SENT'),
#  ('___ Z', 'ATO'),
#  ('___ coil (1891 invention)', 'TESLA'),
#  ('Able to feel', 'SENSATE'),
#  ('Prix fixe offering', 'MEAL'),
#  ('Adidas alternative', 'AVIA'),
#  ('Model T contemporaries', 'REOS'),
#  ('Frame filler', 'PANE'),
#  ('___ consequence', 'OFNO'),
#  ('Old-fashioned phone feature', 'DIAL'),
#  ('Sooner city', 'ENID'),
#  ('Not fixed', 'ADAPTABLE'),
#  ('Arm of the Dept. of Labor', 'OSHA'),
#  ('Relevant, in law', 'ADREM'),
#  ('Smokeys', 'TROOPERS'),
#  ('Emulates Daniel Webster', 'ORATES'),
#  ('Málaga Mrs.', 'SRA'),
#  ('Be too good to', 'SPOIL'),
#  ('Bikini event, once', 'ATEST'),
#  ('John who wrote "Wherever Law ends, Tyranny begins"', 'LOCKE'),
#  ('Victors at Little Bighorn', 'SIOUX'),
#  ('Roseanne, again', 'BARR'),
#  ('"Here comes trouble!"', 'UHOH'),
#  ('Where the Clintons met', 'YALE'),
#  ('Blind part', 'SLAT'),
#  ('Nutritional abbr.', 'RDA'),
#  ('Catty remark?', 'MEW'),
#  ('Indian state', 'ASSAM'),
#  ('Mime', 'APER'),
#  ('"___ steals my purse . . . ": Iago', 'WHO'),
#  ('Emulated Gretzky', 'SKATED'),
#  ('Whence testimony is given', 'STAND'),
#  ('Carnival attraction', 'SIDESHOW'),
#  ('Guarantee against loss', 'INSURE'),
#  ('Michigan title', 'PONTIACCAPTION'),
#  ('High-kicking dance', 'CANCAN'),
#  ('Tip', 'END'),
#  ('Acapulco gold', 'POT'),
#  ('What money does', 'TALKS'),
#  ('Waistcoats', 'VESTS'),
#  ('The facts guide his acts', 'REALIST'),
#  ('"In Reverse" painter', 'MIRO'),
#  ('Before febrero', 'ENERO'),
#  ('Like sea water', 'SALINE'),
#  ('Oregon men', 'SALEMMALES'),
#  ('Agcy. aiding opera, etc.', 'NEA'),
#  ("Hermia's father", 'EGEUS'),
#  ('Units of loudness', 'SONES'),
#  ('Wagon follower', 'ETTE'),
#  ('NCO', 'CPL'),
#  ('Bench, for one', 'RED'),
#  ('Metric weight', 'KILO'),
#  ("Croc's cousin", 'GATOR'),
#  ('Wind in rings', 'COIL'),
#  ('Maine shoe', 'BANGORBROGAN'),
#  ('March man', 'SOUSA'),
#  ("Crusader's foe", 'SALADIN'),
#  ('Transoceanic ship', 'LINER'),
#  ('Sparing', 'SCANTY'),
#  ('Flow forth', 'EMANATE'),
#  ('"Nothing could be ___ . . . "', 'FINER'),
#  ('Alarm', 'STARTLE'),
#  ('Fable adjuncts', 'MORALS'),
#  ('Kafka hero', 'SAMSA'),
#  ('Bound', 'TRUSSED'),
#  ('S. Johnson drama', 'IRENE'),
#  ('Wyoming predicament', 'CASPERSCRAPE'),
#  ('Dravidian language', 'TODA'),
#  ('Carries on', 'RANTS'),
#  ('Sulk', 'POUT'),
#  ("Matelot's milieu", 'MER'),
#  ('Prefix with bar', 'ISO'),
#  ("Commedia dell'___", 'ARTE'),
#  ('Perfume', 'SCENT'),
#  ('Make baskets', 'WEAVE'),
#  ("Bill's partner", 'COO'),
#  ('Ohio holy book', 'AKRONKORAN'),
#  ('Pungent bulb', 'GARLIC'),
#  ('Bendix role', 'RILEY'),
#  ('Building beam', 'IBAR'),
#  ('Wear away by abrasion', 'CORRADE'),
#  ("Didn't possess", 'HADNT'),
#  ('View from Bogotá', 'ANDES'),
#  ('River island', 'AIT'),
#  ('Legal matter', 'RES'),
#  ('Colorless, liquid solvent', 'ACETAL'),
#  ('Wisconsin realms', 'MADISONDOMAINS'),
#  ('Like bright nights', 'STARRY'),
#  ('Sham', 'PRETENSE'),
#  ('Quickly', 'APACE'),
#  ('Covered with hair', 'PILOSE'),
#  ('Neighbor of Leb.', 'SYR'),
#  ('Bring up', 'REAR'),
#  ('Propelled a keelboat', 'POLED'),
#  ('Vilifying villain', 'ASPERSER'),
#  ('Prehistoric time', 'STONEAGE'),
#  ('Wearing huaraches', 'SANDALED'),
#  ('Formicary denizen', 'ANT'),
#  ('16th-century opener', 'MDI'),
#  ('Kind of tie', 'ASCOT'),
#  ('Early invader of Britain', 'PICT'),
#  ('Author LeShan', 'EDA'),
#  ('Agama or anole', 'REPTILE'),
#  ('Former', 'WHILOM'),
#  ("Pan's foe", 'HOOK'),
#  ('Confesses', 'OWNS'),
#  ('Oft-bracketed word', 'SIC'),
#  ('Varlets', 'KNAVES'),
#  ('Lou Grant portrayer', 'ASNER'),
#  ('Arizona nobility', 'TUCSONCOUNTS'),
#  ('Part of Q.E.D.', 'ERAT'),
#  ('Iniquitous places', 'DENS'),
#  ('Intense looks', 'STARES'),
#  ('Chevet', 'APSE'),
#  ('Blackbirds of N.Y.', 'LIU'),
#  ('Electees', 'INS'),
#  ('Demesne house', 'MANOR'),
#  ('Singer John', 'ELTON'),
#  ('___-do-well', 'NEER'),
#  ('"Star Wars" captain', 'SOLO'),
#  ('Emaciated', 'MEAGER'),
#  ('Rose essence', 'ATTAR'),
#  ('Long letter', 'EPISTLE'),
#  ('Put fears to rest', 'ALLAYED'),
#  ('Hasso', 'SIGNE'),
#  ('Winter wear', 'KNITS'),
#  ('"But don\'t ___ the water"', 'GONEAR'),
#  ('Rough', 'COARSE'),
#  ('Split ingredient', 'BANANA'),
#  ('Allan-___', 'ADALE'),
#  ('Light aircraft', 'BLIMPS'),
#  ('Laundry cycle', 'RINSE'),
#  ('Bay duck', 'SCAUP'),
#  ('Arabic or Aramaic', 'SEMITIC'),
#  ('Tenderly, in music', 'AMOROSO'),
#  ('Texas hardship', 'LAREDOORDEAL'),
#  ('Layer: Prefix', 'STRAT'),
#  ('Secure', 'FASTEN'),
#  ('Walk proudly', 'STRUT'),
#  ('___ Domingo', 'SANTO'),
#  ('Lug', 'CARRY'),
#  ('Slender stalk', 'SPEAR'),
#  ('Direct a helmsman', 'CONN'),
#  ('Casanova', 'RAKE'),
#  ('Afflicted with paludism', 'MALARIAL'),
#  ('Proof', 'EVIDENCE'),
#  ('Took a break', 'RECESSED'),
#  ('Amen', 'SOBEIT'),
#  ('More vulgar', 'CRASSER'),
#  ('Kind of bond', 'WAR'),
#  ('Be human', 'ERR'),
#  ('Busy places in June', 'ALTARS'),
#  ('Joker', 'KIDDER'),
#  ('___ pieces', 'GOTO'),
#  ('Musical passage', 'INTRO'),
#  ('Fall beverage', 'CIDER'),
#  ('Fastener', 'HASP'),
#  ('Overture follower', 'ACTI'),
#  ('Elec. units', 'AMPS'),
#  ('Not one, in Dogpatch', 'NARY'),
#  ('Amphora feature', 'ANSA'),
#  ('Soap ingredient', 'LYE'),
#  ('A follower', 'ONE'),
#  ('Cartogram', 'MAP'),
#  ('Mil. address', 'APO'),
#  ('Light beer', 'LAGER'),
#  ('Dress-shirt fastener', 'STUD'),
#  ('Discharge', 'EMIT'),
#  ('Battery terminal', 'ANODE'),
#  ('Ape', 'COPY'),
#  ('___ avis', 'RARA'),
#  ('Girder material', 'STEEL'),
#  ("Muscat's locale", 'OMAN'),
#  ('Neighbor of Syria', 'IRAK'),
#  ('Brownish red', 'TERRACOTTA'),
#  ('Mention in support', 'CITE'),
#  ('Dog that went to Oz', 'TOTO'),
#  ('Glossy fabric', 'SATEEN'),
#  ('Vex', 'BOTHER'),
#  ('Bandleader Miller', 'MITCH'),
#  ("Rose's lover", 'ABIE'),
#  ('"___ Lynne," Victorian best seller', 'EAST'),
#  ('Wading bird', 'HERON'),
#  ('Kind of kale', 'COLLARD'),
#  ('Barren', 'STERILE'),
#  ('A spiral', 'HELIX'),
#  ('What Deseret became', 'UTAH'),
#  ('___ Grasso, memorable governor', 'ELLA'),
#  ('OPEC ship', 'OILER'),
#  ('Make beloved', 'ENDEAR'),
#  ('Waterloo, e.g.', 'BATTLE'),
#  ('Movie dog', 'ASTA'),
#  ('Suffix with cell', 'ULAR'),
#  ("Bureaucrat's preoccupation", 'REDTAPEISM'),
#  ('"It Ain\'t Gonna Rain ___," 1923 song', 'NOMO'),
#  ('Conversational filler', 'ISEE'),
#  ("Katharina's home town", 'PADUA'),
#  ('Lad', 'CHAP'),
#  ("Junior's expletive", 'DARN'),
#  ("Tinker's target", 'EVERS'),
#  ('Beast with a cleft upper lip', 'HARE'),
#  ('Brit. Commonwealth member', 'AUST'),
#  ('Adjust a clock', 'RESET'),
#  ('Continue in vigor', 'LAST'),
#  ('Feed the kitty', 'ANTE'),
#  ('Church or movie follower', 'GOER'),
#  ('German river', 'EDER'),
#  ('Detail', 'RELATE'),
#  ('Skedaddle', 'SCOOT'),
#  ('Drums along the Mohawk, once', 'TOMTOMS'),
#  ('Browning\'s "___ a Villa . . . "', 'UPAT'),
#  ('Hereditary ruler', 'DYNAST'),
#  ('Greenland colonizer', 'ERICTHERED'),
#  ('Actress Wilson', 'MARIE'),
#  ('Nettled', 'IRATE'),
#  ('Possessed', 'TAKEN'),
#  ('Kitchen device', 'CORER'),
#  ('Throb', 'ACHE'),
#  ('"Illusions" author: 1977', 'BACH'),
#  ('Reed', 'OBOE'),
#  ('Cultivate', 'TILL'),
#  ('Reddish purple', 'HELIOTROPE'),
#  ('"___ boy!"', 'ITSA'),
#  ('In unison, musically', 'ADUE'),
#  ('Raise hackles', 'RILE'),
#  ('Spicy stew', 'OLLA'),
#  ('Close by', 'NEAR'),
#  ('Branch angle', 'AXIL'),
#  ('Greek letter', 'THETA'),
#  ('Merchants', 'TRADERS'),
#  ('Spanish city or province', 'LERIDA'),
#  ('Somnolent one', 'NAPPER'),
#  ('Cluster; tuft', 'BUNCH'),
#  ('Don Ho salutation', 'ALOHA'),
#  ("David's daughter", 'TAMAR'),
#  ('Tax', 'STENT'),
#  ('Name meaning "hairy"', 'ESAU'),
#  ('Roof edge', 'EAVE'),
#  ('June 13, e.g.', 'IDES'),
#  ('Unfailing', 'SURE'),
#  ('Part of a crane', 'MAST'),
#  ('Adroitness', 'EASE'),
#  ('22-Across product', 'LAGER'),
#  ('English Leather alternative', 'AFTA'),
#  ('Interjections from the obtuse', 'DUHS'),
#  ('Searches for signs in a hospital', 'EXAMS'),
#  ('Queen with a degree from Princeton', 'NOOR'),
#  ('___-Z', 'IROC'),
#  ('Its shadow is often cast', 'DOUBT'),
#  ('Decoration', 'TRIM'),
#  ('"Gnarly waves, dude!"', 'COWABUNGA'),
#  ('Pabst brand', 'PIELS'),
#  ('Foil', 'TRIPUP'),
#  ('Like some exchange rates', 'UNPEGGED'),
#  ('Less like nuts?', 'SANER'),
#  ('Where to get a citation while surfing', 'WIKIQUOTE'),
#  ('Like two Kennedy brothers', 'SLAIN'),
#  ('Portions', 'QUANTA'),
#  ('Hang-up', 'RUB'),
#  ('Watt-hour fraction', 'ERG'),
#  ('Small team', 'DUO'),
#  ('You might get a charge out of it', 'EEL'),
#  ('Secure the aid of', 'ENLIST'),
#  ("They're lined up on a neck", 'FRETS'),
#  ('Kind of test associated with the null hypothesis', 'CHISQUARE'),
#  ('Practice with the Wheel of the Year', 'WICCA'),
#  ('27-Across, e.g.', 'RESOURCE'),
#  ('Wet behind the ears', 'CALLOW'),
#  ('Directive obeyed by Alice', 'EATME'),
#  ('City where "Smokey and the Bandit" begins', 'TEXARKANA'),
#  ('Fit to finish?', 'ATEE'),
#  ('Like many dreamers', 'INBED'),
#  ("Pap's son, in literature", 'HUCK'),
#  ('La., e.g., once', 'TERR'),
#  ('Like la nuit', 'NOIRE'),
#  ('Scored together?', 'ADUE'),
#  ('Brand that has Dibs', 'EDYS'),
#  ('Telecom giant headquartered in Denver', 'QWEST'),
#  ('Fork-tailed flier', 'TERN'),
#  ('Subjects are expected to follow them', 'EDICTS'),
#  ('Polar region phenomenon', 'AURORA'),
#  ('Greet and seat', 'SHOWIN'),
#  ('Things some cons are pros at', 'ESCAPES'),
#  ('Preceded, with "to"', 'LEDUP'),
#  ('Impulse carrier', 'AXON'),
#  ('Van Gogh threatened him with a razor blade', 'GAUGUIN'),
#  ('Keep from spilling over, in a way', 'EMBANK'),
#  ('U leaders?', 'RST'),
#  ("St. John's is its capital", 'ANTIGUA'),
#  ('Like some conclusions', 'FOREGONE'),
#  ('Grooming routine', 'TOILETTE'),
#  ('Missiles may be delivered in one', 'ARMSDEAL'),
#  ('Tom Stoppard\'s "Travesties," e.g.', 'BURLESQUE'),
#  ('Chief Sassacus led one side in it', 'PEQUOTWAR'),
#  ('Nettle', 'PIQUE'),
#  ('Easily changeable locks', 'WIG'),
#  ('Pianist Schnabel', 'ARTUR'),
#  ('Play', 'RECREATE'),
#  ('Like many swimming pools', 'UNHEATED'),
#  ('Severely sunburned, say', 'BLISTERY'),
#  ('Producer for 50 Cent, familiarly', 'DRE'),
#  ('Atomically related compounds', 'ISOMERS'),
#  ('Prize in Cracker Jacks, e.g.', 'FREEBIE'),
#  ('Part of morning dress', 'SILKHAT'),
#  ('Ad imperative', 'ACTNOW'),
#  ('Rains in a studio', 'CLAUDE'),
#  ('Go along (with)', 'CONCUR'),
#  ('Arouse', 'AWAKEN'),
#  ('Massachusetts Maritime Academy student, e.g.', 'CADET'),
#  ('MTV generation', 'XERS'),
#  ('It may be judicial: Abbr.', 'INQ'),
#  ('Fix', 'SUIT'),
#  ('Outer, anatomically', 'ECTAL'),
#  ('Stable infant', 'FOAL'),
#  ('Frogner Park locale', 'OSLO'),
#  ('Word with jet or prop', 'TURBO'),
#  ('Concerning', 'INRE'),
#  ('Start of a quip', 'THEDICTIONARYIS'),
#  ("Wyo.'s ___ Range", 'TETON'),
#  ('Affair of honor', 'DUEL'),
#  ('Indian carved pole', 'XAT'),
#  ('"___ pro nobis"', 'ORA'),
#  ('Arrived', 'CAME'),
#  ('Isr. neighbor', 'LEB'),
#  ('More of the quip', 'THEONLYPLACE'),
#  ('Between pie and mode', 'ALA'),
#  ('Hamlet\'s "___ take arms . . . "', 'ORTO'),
#  ('Jury', 'PANEL'),
#  ('Fuel gas', 'PROPANE'),
#  ('Sat', 'ROOSTED'),
#  ('Sharp', 'ACRID'),
#  ('A ___ Able', 'ASIN'),
#  ('"___ the season . . . "', 'TIS'),
#  ('More of the quip', 'WHERESUCCESS'),
#  ('N.Y.C. or Balt.', 'SPT'),
#  ('___ avis', 'RARA'),
#  ('___ de tête (headache)', 'MAL'),
#  ('Health club', 'SPA'),
#  ('Armadillo', 'TATU'),
#  ('New Zealand aborigine', 'MAORI'),
#  ('End of the quip', 'COMESBEFOREWORK'),
#  ('Hodgepodge', 'OLIO'),
#  ('Caine role', 'ALFIE'),
#  ('Medicinal plant', 'ALOE'),
#  ('Rolls of money', 'WADS'),
#  ('Inventor Nikola', 'TESLA'),
#  ('Exhibit boredom', 'YAWN'),
#  ('___ voce', 'SOTTO'),
#  ('Member of the wedding', 'USHER'),
#  ('"___ Song Go . . . "', 'ILETA'),
#  ('Fuss', 'TODO'),
#  ('Common abbr.', 'ETC'),
#  ("Film director's cry", 'CUT'),
#  ("Neptune's emblem", 'TRIDENT'),
#  ('___ Ben Adhem', 'ABOU'),
#  ('Desolate', 'LONELY'),
#  ('Evergreen', 'FIR'),
#  ('Gemstone', 'ONYX'),
#  ('"Vissi d\'arte," for one', 'ARIA'),
#  ('For fear that', 'LEST'),
#  ('Part of a foot', 'INCH'),
#  ('Syrian city', 'ALEPPO'),
#  ('Long, long time', 'AEON'),
#  ('Jeanne of "Jules et Jim"', 'MOREAU'),
#  ('Detonations', 'BLASTS'),
#  ('Snouted mammals', 'TAPIRS'),
#  ('Roman cuirass', 'LORICA'),
#  ('Oppositionist', 'ANTI'),
#  ('Fair grades', 'CEES'),
#  ('Antiquity, in poesy', 'ELD'),
#  ('Chief', 'ARCH'),
#  ('Knowledge', 'LORE'),
#  ('Handle roughly', 'PAW'),
#  ('Experts', 'ADEPTS'),
#  ('Lulu', 'ONER'),
#  ('Napes', 'SCRUFFS'),
#  ('Rossini\'s "___ Mater"', 'STABAT'),
#  ('Ditto', 'SAME'),
#  ('Cabbage; bread', 'MOOLA'),
#  ('Pointer', 'ARROW'),
#  ('Compare', 'LIKEN'),
#  ('Harbor sight', 'SCOW'),
#  ('Negri of silents', 'POLA'),
#  ('In the center of', 'AMID'),
#  ('Far: Comb. form', 'TELE'),
#  ('Gone', 'AWAY'),
#  ('Aurora, to Aristotle', 'EOS'),
#  ("J. R.'s concern", 'OIL'),
#  ('Cartoonist Gardner', 'REA'),
#  ('Ice-cream measures', 'DIPS'),
#  ('Tussle', 'SCRAP'),
#  ('Bed part', 'SLAT'),
#  ('One of the Andreanofs', 'ADAK'),
#  ('Partner of ho', 'HEAVE'),
#  ('Swanky', 'POSH'),
#  ('Embassy member', 'MILITARYATTACHE'),
#  ('Stances', 'POSTURES'),
#  ('Origin of the Euphrates', 'TURKEY'),
#  ('Three, in Málaga', 'TRES'),
#  ('Letter beginning', 'SIRS'),
#  ('Go up', 'ASCEND'),
#  ('Disagreed', 'DIFFERED'),
#  ('Surprisers of Goldilocks', 'BEARS'),
#  ('Cyclades island', 'MELOS'),
#  ('Lend an ___', 'EAR'),
#  ('Coffee brewers', 'URNS'),
#  ("Gog's associate", 'MAGOG'),
#  ('Allot', 'METE'),
#  ('Phoebus', 'SUN'),
#  ('Pops', 'COLAS'),
#  ('What an evangelist does', 'SAVES'),
#  ('Gives out', 'EMANATES'),
#  ('Discourages', 'DETERS'),
#  ('Freeman Gosden', 'AMOS'),
#  ('Italian finger game', 'MORA'),
#  ('Not so hard', 'EASIER'),
#  ('Milton locale', 'PARADISE'),
#  ('Tactful group', 'DIPLOMATICCORPS'),
#  ('Dies ___', 'IRAE'),
#  ('Guam capital', 'AGANA'),
#  ('Sterlet and shad eggs', 'ROES'),
#  ('Care for', 'TEND'),
#  ('Count ___', 'NOSES'),
#  ("Snicker's", 'SNEE'),
#  ('Like some cellars', 'DAMP'),
#  ('Personal: Prefix', 'IDIO'),
#  ('Buddies', 'PALS'),
#  ('Glides lightly', 'SKITTERS'),
#  ('Participated in', 'SHARED'),
#  ('Small planet', 'CERES'),
#  ('Sting and X', 'RAYS'),
#  ("Girl's name", 'AVA'),
#  ('Quibble over trifles', 'PETTIFOG'),
#  ('Rare', 'SPARSE'),
#  ('Soo feature', 'LOCK'),
#  ('Arthur of tennis', 'ASHE'),
#  ('"___ also serve . . .  "', 'THEY'),
#  ('___ on the heat', 'TURNS'),
#  ('Sods', 'TURFS'),
#  ("Places for ICBM's", 'SILOS'),
#  ('Treat badly', 'ABUSE'),
#  ('Injection material', 'SERUM'),
#  ('Large-leafed plant', 'CANNA'),
#  ('Contemporary of Manet', 'DEGAS'),
#  ('Town officer', 'REEVE'),
#  ('Gourmand or gourmet', 'EATER'),
#  ('Kind of parade or circle', 'DRESS'),
#  ('Certain people', 'MALES'),
#  ('Subway-crew member', 'MOTORMAN'),
#  ('Certain swordsmen', 'MATADORS'),
#  ('Brief acting role', 'CAMEO'),
#  ('Ice pinnacle', 'SERAC'),
#  ('___ down (made final)', 'NAILED'),
#  ('Biblical sewer', 'DORCAS'),
#  ('Havana memory', 'MAINE'),
#  ('Do copy-desk work', 'EDIT'),
#  ('Atmosphere, in Aragon', 'AIRE'),
#  ('Hand measure', 'SPAN'),
#  ('School groups: Abbr.', 'PTAS'),
#  ('Curtain or ore', 'IRON'),
#  ('Graf von ___', 'SPEE'),
#  ('Common Latin word', 'ESSE'),
#  ('Past', 'AGO'),
#  ('Filch', 'SWIPE'),
#  ("Cook's canful", 'LARD'),
#  ('Burn a bit', 'CHAR'),
#  ('Garbage can insert', 'LINER'),
#  ('S-shaped curve', 'OGEE'),
#  ('Swear words?', 'OATH'),
#  ('Blazing', 'AFIRE'),
#  ('It has "county" and "city" inside', 'COMMUNITY'),
#  ('Software test version', 'BETA'),
#  ('"Tiger Lilies" novelist Sidney', 'LANIER'),
#  ('Kipling classic', 'KIM'),
#  ('Urge forward', 'IMPEL'),
#  ('Speak evil of', 'TRADUCE'),
#  ("Kuwait's peninsula", 'ARABIA'),
#  ('Subway entrance', 'STILE'),
#  ('It has "round" inside', 'ROTUND'),
#  ('Curiosity victim', 'CAT'),
#  ('God with a hammer', 'THOR'),
#  ('Prepared to be dubbed', 'KNELT'),
#  ('Zilch', 'NIL'),
#  ('Tick off', 'PEEVE'),
#  ('Thompson of "Pollock"', 'SADA'),
#  ('Hall &amp; Oates, e.g.', 'DUO'),
#  ('It has "bare" inside', 'BARREN'),
#  ('Prepare for competition', 'TRAIN'),
#  ('Show the ropes to', 'ORIENT'),
#  ('Avian messengers', 'PIGEONS'),
#  ("Diviner's deck", 'TAROT'),
#  ("N.Y.C.'s Park, e.g.", 'AVE'),
#  ('Tackle box gizmo', 'SCALER'),
#  ('Saws with the grain', 'RIPS'),
#  ('It has "can" and "tin" inside', 'CONTAINER'),
#  ('Gem surface', 'FACET'),
#  ("Toledo's lake", 'ERIE'),
#  ('Tenn. neighbor', 'NCAR'),
#  ('Geographical "boot"', 'ITALY'),
#  ('Turned blue, perhaps', 'DYED'),
#  ('Inheritance factor', 'GENE'),
#  ('Fax forerunner', 'TELEX'),
#  ('Bacon portion', 'SLAB'),
#  ("Bachelor's lack", 'WIFE'),
#  ('Welcomed as a brother', 'INITIATED'),
#  ('It has "amble" and "ramble" inside', 'PERAMBULATE'),
#  ("Bard's before", 'ERE'),
#  ('Milk train, e.g.', 'LOCAL'),
#  ('Literary conflict', 'AGON'),
#  ('Payment', 'REMITTAL'),
#  ('Mark for misconduct', 'DEMERIT'),
#  ('Hoodwink', 'CON'),
#  ('Japanese verse', 'HAIKU'),
#  ('Web site?', 'ATTIC'),
#  ("What 11-Down doesn't do", 'RHYME'),
#  ('Caspian feeder', 'URAL'),
#  ('Sinker material', 'LEAD'),
#  ('Stout serving', 'PINT'),
#  ('It has "rot" and "die" inside', 'DETERIORATE'),
#  ('Commodious boats', 'ARKS'),
#  ('Gossipy Barrett', 'RONA'),
#  ('It has "son" inside', 'SCION'),
#  ('Dissenting, to the church', 'HERETICAL'),
#  ('Place for a roast', 'OVEN'),
#  ('Monopoly payment', 'RENT'),
#  ('Dennis, to Mr. Wilson', 'NUISANCE'),
#  ("Henry VIII's sixth", 'PARR'),
#  ('Ballroom activity', 'DANCING'),
#  ('Tusked animal', 'BOAR'),
#  ('Parks in 1955 news', 'ROSA'),
#  ('Waited for baby?', 'PACED'),
#  ("Poacher's haul", 'IVORY'),
#  ('One to rub out?', 'GENIE'),
#  ('___ Haute, Ind.', 'TERRE'),
#  ('Like good hamburger meat', 'LEAN'),
#  ('Soccer icon', 'PELE'),
#  ("Charon's waterway", 'STYX'),
#  ('Mack of early TV', 'TED'),
#  ('Athletic', 'FIT'),
#  ('Miles or Sammy, Jr.', 'DAVIS'),
#  ("Weapon in Macbeth's belt", 'DAGGER'),
#  ('Kind of "Eyes" in a song', 'SPANISH'),
#  ("Guinea pig's cousin", 'AGOUTI'),
#  ('White house daughter', 'MARGARETTRUMAN'),
#  ('Void', 'ANNUL'),
#  ("Projectionists' concerns", 'REELS'),
#  ('Fiction of a sort', 'LIES'),
#  ('___ off (went in twos)', 'PAIRED'),
#  ('Dallas campus: Abbr.', 'SMU'),
#  ("Arithmetician's concern: Abbr.", 'LCD'),
#  ('Jettisons', 'DUMPS'),
#  ('Rise', 'GOUP'),
#  ('Group for a jury', 'PANEL'),
#  ('Obeys a road sign', 'YIELDS'),
#  ('White House daughter', 'CAROLINEKENNEDY'),
#  ('Amatory', 'EROTIC'),
#  ('Do no more', 'CEASE'),
#  ('Colleen', 'LASS'),
#  ('Francis ___ Harte', 'BRETT'),
#  ('___ Mitzvah (ceremony for girls)', 'BAS'),
#  ('White House daughter', 'AMY'),
#  ("BBQ-ers' garb", 'APRONS'),
#  ('Shake', 'JOLT'),
#  ('Scatter', 'STREW'),
#  ('Fictional elephant', 'BABAR'),
#  ('White House daughters', 'JULIEANDTRICIA'),
#  ('Positive charges', 'ANODES'),
#  ('Innisfail', 'IRELAND'),
#  ('Ruler, pro tem', 'REGENT'),
#  ('In the ___ of  (among)', 'MIDST'),
#  ('"I\'ll be ___!"', 'DARNED'),
#  ('Cattle breed', 'ANGUS'),
#  ('Test tube', 'VIAL'),
#  ('Kibbutz land: Abbr.', 'ISR'),
#  ('Pronoun for a daughter', 'SHE'),
#  ("Librarians' devices", 'DATERS'),
#  ('Coincide', 'AGREE'),
#  ('Elliot from Brooklyn', 'GOULD'),
#  ('Settings for molars', 'GUMS'),
#  ('Zeta follower', 'ETA'),
#  ('"Oysters ___ season"', 'RIN'),
#  ('Lower-case', 'SMALL'),
#  ('Kind of button', 'PANIC'),
#  ("Secretariat's coup", 'TRIPLECROWN'),
#  ('Carthaginian', 'PUNIC'),
#  ('Prayer word', 'AMEN'),
#  ('Food fish', 'SOLE'),
#  ('TV newsman Roger', 'MUDD'),
#  ('"___ daisy!"', 'UPSY'),
#  ('Painter of limp watches', 'DALI'),
#  ('Tierney or Tunney', 'GENE'),
#  ('Kitchenware', 'POTS'),
#  ('Nobelist for literature: 1923', 'YEATS'),
#  ('Smithsonian is one: Abbr.', 'INST'),
#  ('That, in Tours', 'CELA'),
#  ('Saroyan hero', 'ARAM'),
#  ('Apple-cheeked', 'ROSY'),
#  ('Acute', 'KEEN'),
#  ('Kind of plate', 'BREAST'),
#  ('Bay lynx', 'BOBCAT'),
#  ('Actor Delon', 'ALAIN'),
#  ('Violin, for short', 'STRAD'),
#  ('" . . . ___ in the affairs of men"', 'ATIDE'),
#  ('Dress fastidiously', 'PREEN'),
#  ('Imprisons', 'JAILS'),
#  ('Plod through the mud', 'SLOG'),
#  ('Raised', 'BRED'),
#  ('Clash', 'JAR'),
#  ('Half of deux', 'UNE'),
#  ('Ill-lit', 'DIM'),
#  ('Numerical prefix', 'TRI'),
#  ("Capp's ___ Iggle", 'BALD'),
#  ('Takes game', 'BAGS'),
#  ("Egoist's love", 'SELF'),
#  ('In a tumult', 'ARIOT'),
#  ('Be contiguous', 'ABUT'),
#  ('Saranac Lakes, e.g.', 'TRIO'),
#  ('___ Sea (Mare Germanicum)', 'NORTH'),
#  ('Word with Star or Eagle', 'LONE'),
#  ('"The ___ of the Ancient Mariner"', 'RIME'),
#  ('Wiesbaden, for one', 'WATERINGPLACE'),
#  ('Author LeShan', 'EDA'),
#  ('Facilitated', 'EASED'),
#  ('Thingumbobs', 'DOODADS'),
#  ('Booth in the Hall of Fame', 'EDWIN'),
#  ("Sault Ste. Marie's prov.", 'ONT'),
#  ('Metrical foot', 'IAMB'),
#  ('Light-colored cigar', 'CLARO'),
#  ('Something beyond recall', 'WATEROVERTHEDAM'),
#  ("Baker's utensil", 'SIEVE'),
#  ('Water jug', 'EWER'),
#  ('Letters on an airport sign', 'ETA'),
#  ('"To ___ human . . . ": Pope', 'ERRIS'),
#  ('Treated silk', 'WATERED'),
#  ('Three-dimensional', 'CUBIC'),
#  ('Tom of old westerns', 'MIX'),
#  ("Richard Adams's best seller: 1975", 'WATERSHIPDOWN'),
#  ('Literary pen name', 'SAKI'),
#  ('Templeton or Waugh', 'ALEC'),
#  ('For this case only', 'ADHOC'),
#  ('Ruler at Asgard', 'ODIN'),
#  ('Relief organization', 'CARE'),
#  ('Soprano Tetrazzini: 1847–1940', 'LUISA'),
#  ('Deleting, with "out"', 'XING'),
#  ('Relative of a sheik', 'EMIR'),
#  ('Dam', 'STEM'),
#  ('Outlaw', 'BAN'),
#  ('Like ___ of pins', 'AROW'),
#  ('Capri coin', 'LIRA'),
#  ('Stippled', 'DOTTED'),
#  ('"Morning of the World" island', 'BALI'),
#  ('Have ___ to pick', 'ABONE'),
#  ('Din, the water carrier', 'GUNGA'),
#  ("Rome's Spanish attraction", 'STEPS'),
#  ('Take both sides', 'STRADDLE'),
#  ('Famed sailor', 'ERIC'),
#  ('Juice for a tar', 'LIME'),
#  ('Yamamoto, to Nimitz', 'FOE'),
#  ('Bara', 'THEDA'),
#  ('Kind of activity', 'RADIO'),
#  ('Hanger-on', 'LEECH'),
#  ('Search for water', 'DOWSE'),
#  ('Walking ___ (elated)', 'ONAIR'),
#  ('Web-footed mammal', 'OTTER'),
#  ("Perform a lifeguard's feat", 'SAVE'),
#  ('Sandpiper of snipe', 'WADER'),
#  ('Steamed up', 'IRATE'),
#  ('He has herd, will move', 'NOMAD'),
#  ('Gull or its sound', 'MEW'),
#  ('Thirst quencher', 'BREW'),
#  ('Forcing out', 'EVICTING'),
#  ('Mine a narrow vein', 'RESUE'),
#  ('Type of steamer', 'TRAMP'),
#  ('Kind of wave or river', 'TIDAL'),
#  ('Biblical source of Red Sea miracle', 'EXODUS'),
#  ('Rope on a square-rigged ship', 'BRACE'),
#  ("Moslems' faith", 'ISLAM'),
#  ("Parisienne's boyfriend", 'CHERI'),
#  ('River bed, often dry', 'WADI'),
#  ('Consanguineous', 'AKIN'),
#  ('Champagne bucket', 'ICER'),
#  ('Jot', 'WHIT'),
#  ('Prow of a ship', 'NOSE'),
#  ('White or Red', 'SOX'),
#  ('Ouse territory', 'CAM'),
#  ('Lock of hair', 'TRESS'),
#  ('Being, to Aquinas', 'ESSE'),
#  ('Jupiter', 'JOVE'),
#  ('Surveillance', 'WATCH'),
#  ('Bates or Hale', 'ALAN'),
#  ('Summit', 'APEX'),
#  ('Rectangular pillars', 'ANTAE'),
#  ('Crosspiece', 'RUNG'),
#  ('Character builder?', 'GENE'),
#  ('Place for philatelists?', 'STAMPINGGROUNDS'),
#  ('Dame Myra', 'HESS'),
#  ('A constellation', 'ARA'),
#  ('Gather together', 'MUSTER'),
#  ('Surplus', 'OVERAGE'),
#  ('___ den Linden', 'UNTER'),
#  ('Minty herb', 'SAGE'),
#  ('Div. of time', 'CEN'),
#  ('Wears orthopedic shoes?', 'STANDSCORRECTED'),
#  ('One, to Hans', 'EIN'),
#  ('Receipts', 'TAKE'),
#  ('End of a lariat', 'NOOSE'),
#  ('Pastry or pudding', 'DESSERT'),
#  ('Made night noises', 'SNORED'),
#  ('Mao ___-tung', 'TSE'),
#  ('London district', 'SOHO'),
#  ('Provides a king-size bunk?', 'GIVESAWIDEBERTH'),
#  ('Concept', 'IDEA'),
#  ('Wise men', 'MAGI'),
#  ('Gene Tierney role', 'LAURA'),
#  ('Heap', 'LOAD'),
#  ('Sea eagles', 'ERNS'),
#  ('Fragrant compound', 'ESTER'),
#  ('Triple Entente nation', 'ALLY'),
#  ('Musical sign', 'REST'),
#  ('Contest prize', 'STAKE'),
#  ('Start of a C. Moore poem', 'TWAS'),
#  ('Bombast', 'RANT'),
#  ('Kett of the comics', 'ETTA'),
#  ('Con game', 'SCAM'),
#  ('Flock guardian', 'SHEPHERD'),
#  ('Merits', 'EARNS'),
#  ('Garden pests', 'SLUGS'),
#  ('Squealed', 'SANG'),
#  ('Printmaker', 'ENGRAVER'),
#  ('Large cat', 'JAGUAR'),
#  ('Sign on a store door', 'OPEN'),
#  ("Ply one's wares", 'VEND'),
#  ('Former spouses', 'EXES'),
#  ('Comparative suffix', 'IER'),
#  ('Pay dirt', 'ORE'),
#  ('Pondered', 'MUSED'),
#  ('Let loose', 'UNTIE'),
#  ('Laurel and Musial', 'STANS'),
#  ('Take ___ (rest)', 'TEN'),
#  ('Windigo', 'OGRE'),
#  ('Thespian', 'ACTOR'),
#  ('Silly people', 'GEESE'),
#  ('Over', 'ENDED'),
#  ("Ella's forte", 'SCAT'),
#  ('Copacetic', 'AOK'),
#  ('Banner', 'STREAMER'),
#  ('Elevates', 'ENNOBLES'),
#  ('Companion of bill', 'COO'),
#  ('Beau', 'STEADY'),
#  ('Tee preceder', 'ESS'),
#  ('Haggard novel', 'SHE'),
#  ('Omens', 'SIGNS'),
#  ('Poet', 'ODIST'),
#  ('Kind of monster', 'GILA'),
#  ('Adored one', 'IDOL'),
#  ('Calf', 'VEAL'),
#  ('Hard or soft', 'WARE'),
#  ('Sunrise spot', 'EAST'),
#  ('___ Lee of "Funny Face"', 'RUTA'),
#  ('Arduous journey', 'TREK'),
#  ('Leveret, e.g.', 'HARE'),
#  ("Crow's cry", 'CAW'),
#  ('After-dinner sweet', 'MINT'),
#  ('Moved quickly', 'SPED'),
#  ('Operatic solo', 'ARIA'),
#  ('Melville work', 'OMOO'),
#  ('Worry', 'CARE'),
#  ('Glut on the market', 'OVERSUPPLY'),
#  ('Algerian seaport', 'ORAN'),
#  ('Best', 'FINEST'),
#  ("Hotspur's fault", 'RASHNESS'),
#  ('Level', 'FLAT'),
#  ('"Pater Noster" finale', 'AMEN'),
#  ('Yet, to Shakespeare', 'EEN'),
#  ('Sackcloth and ___', 'ASHES'),
#  ('Expedite', 'HASTEN'),
#  ('Canadian peninsula', 'GASPE'),
#  ('Flower', 'ASTER'),
#  ('"___ Maria"', 'AVE'),
#  ('Accumulated', 'AMASSED'),
#  ('Power losses', 'OUTAGES'),
#  ('Title of respect', 'SIR'),
#  ("Bow's opposite", 'STERN'),
#  ('Happening', 'EVENT'),
#  ('Noted English archeologist-Egyptologist: 1853–1942', 'PETRIE'),
#  ('Scene of four major W.W. I battles', 'AISNE'),
#  ('Cry of triumph', 'OHO'),
#  ('Mussolini title', 'DUCE'),
#  ('Housecoat', 'ROBE'),
#  ('___ medicine (type of jurisprudence)', 'FORENSIC'),
#  ('Crushed', 'MASHED'),
#  ('San ___ Obispo', 'LUIS'),
#  ('Appease', 'PROPITIATE'),
#  ("Jacob's twin", 'ESAU'),
#  ('Fever and chills', 'AGUE'),
#  ('Wrongdoing, to a judge', 'TORT'),
#  ('Snakelike fish', 'EELS'),
#  ('Take it easy', 'REST'),
#  ('Mamie Eisenhower, ___ Doud', 'NEE'),
#  ('Quibble', 'CAVIL'),
#  ('Sporting area', 'ARENA'),
#  ('Kin of "bugs"', 'WIRETAPS'),
#  ('Swab', 'MOP'),
#  ("Leave one's mark", 'IMPRESS'),
#  ('Lynn ___ Ryan of baseball', 'NOLAN'),
#  ('Pre-Christmas best sellers', 'TOYS'),
#  ('Scottish cakes', 'SCONES'),
#  ('Family-tree item', 'PARENTAGE'),
#  ('Historical periods', 'ERAS'),
#  ('Lairs', 'DENS'),
#  ('Beast of burden', 'ASS'),
#  ('Out of tune', 'OFF'),
#  ('Beehive State', 'UTAH'),
#  ('Encourage', 'HEARTEN'),
#  ('Union general', 'MEADE'),
#  ('Group meeting', 'SESSION'),
#  ('Cicero\'s "Alas!"', 'HEU'),
#  ('Flush', 'EVEN'),
#  ('Shelter for a shoveler', 'NEST'),
#  ('Struggle for air', 'GASP'),
#  ('Girlfriend: Fr.', 'AMIE'),
#  ("Of men's attire", 'SARTORIAL'),
#  ('Invigorating potion', 'TONIC'),
#  ('Juillet, août, etc.', 'ETE'),
#  ('Intense dislike', 'AVERSION'),
#  ('Loud and rowdy', 'RAUCOUS'),
#  ('Research monkey', 'RHESUS'),
#  ('Tractor-trailer', 'SEMI'),
#  ('Lament', 'DIRGE'),
#  ('Chicago airport', 'OHARE'),
#  ('Actress Davis', 'BETTE'),
#  ('Dutch commune', 'EDE'),
#  ('Run away from home', 'FLEE'),
#  ('Name of three English rivers', 'OUSE'),
#  ('Box', 'SPAR'),
#  ('D.A.', 'ATT'),
#  ('Favorite', 'PET'),
#  ('Minnesota ___', 'FATS'),
#  ('Neighbor of Cameroon', 'CHAD'),
#  ('___ Alpha Epsilon fraternity', 'SIGMA'),
#  ('1997 Peter Fonda role', 'ULEE'),
#  ('Despise', 'HATE'),
#  ('Subsequently', 'AFTER'),
#  ('Start of a quip about weight loss', 'DIETSAREFORFOLK'),
#  ('Minnesotan', 'GOPHER'),
#  ('"Heavens!"', 'MERCY'),
#  ('Soissons saison', 'ETE'),
#  ('Kind of code or drive', 'ZIP'),
#  ('Classic TV brand', 'RCA'),
#  ('Where St. Pete is', 'FLA'),
#  ('Mover and shaker', 'DOER'),
#  ('Household name', 'SIS'),
#  ("Scarlett's first love", 'ASHLEY'),
#  ('Ants, in dialect', 'EMMETS'),
#  ('Make fun of', 'TEASE'),
#  ('Middle of the quip', 'WHOARETHICK'),
#  ('In the lead', 'AHEAD'),
#  ('Kissy-kiss', 'SMOOCH'),
#  ('Popular carpet style', 'BERBER'),
#  ('Nearly worthless coin', 'SOU'),
#  ('Biblical country', 'EDOM'),
#  ('"Evita" character', 'CHE'),
#  ('Ump', 'REF'),
#  ('Kind of particle', 'PSI'),
#  ('Comic Philips', 'EMO'),
#  ('Trap', 'SNARE'),
#  ('Michael of Disney', 'EISNER'),
#  ('End of the quip', 'ANDTIREDOFITALL'),
#  ('Spanish port from which Columbus sailed, 1493', 'CADIZ'),
#  ('Window part', 'SILL'),
#  ('Robt. ___', 'ELEE'),
#  ('"Voilà!"', 'THERE'),
#  ('Actress Lamarr', 'HEDY'),
#  ('Feel sorry for', 'PITY'),
#  ("Wasn't 100% honest", 'FUDGED'),
#  ('Former San Francisco Mayor Joseph', 'ALIOTO'),
#  ("Crow's home", 'TEEPEE'),
#  ('Clockmaker Thomas', 'SETH'),
#  ('J.F.K. appeal', 'CHARISMA'),
#  ('Laugh sound', 'HAR'),
#  ('"Up and ___!"', 'ATEM'),
#  ('Put off', 'DEFER'),
#  ('Like some humor', 'SARCASTIC'),
#  ('Uncertain', 'IFFY'),
#  ('Car that\'s "really lookin\' fine," in a 1960\'s song', 'GTO'),
#  ('Danny\'s "Lethal" co-star', 'MEL'),
#  ('Biblical boat', 'ARK'),
#  ('"___ who?"', 'SEZ'),
#  ('Killer whale', 'ORCA'),
#  ('Wharves', 'PIERS'),
#  ('Criticism', 'FLAK'),
#  ('"___ Miz"', 'LES'),
#  ('Yachtie\'s "yes"', 'AYE'),
#  ('Curative center', 'REHAB'),
#  ('Flower holders?', 'STEMS'),
#  ('Actress Anne', 'HECHE'),
#  ('Update', 'MODERNIZE'),
#  ('Posture problem', 'STOOP'),
#  ('"As you ___"', 'WERE'),
#  ("Swatter's target", 'HOUSEFLY'),
#  ('Agatha Christie\'s "The ___ Murders"', 'ABC'),
#  ('Laugh sound', 'HEH'),
#  ('Bring up', 'REAR'),
#  ("Mt. McKinley's Indian name", 'DENALI'),
#  ('Bad place to find shells', 'OMELET'),
#  ('Newsman Safer', 'MORLEY'),
#  ('Unwilted', 'FRESH'),
#  ('"Richard ___"', 'III'),
#  ('Ado', 'STIR'),
#  ('Singer Adams', 'EDIE'),
#  ("Dance instructor's call", 'STEP'),
#  ('Deed', 'ACT'),
#  ('"Uh-uh!"', 'NAH'),
#  ('Presidential inits.', 'DDE'),
#  ('Archaic', 'OLD'),
#  ('Carson role', 'HOST'),
#  ('Furnish', 'EQUIP'),
#  ('Wax', 'GROW'),
#  ('Agrippina, e.g.', 'UXOR'),
#  ('A.k.a. Saki', 'MUNRO'),
#  ('Timber wolf', 'LOBO'),
#  ('Popular flavoring', 'COLA'),
#  ('Disguised the meaning', 'CODED'),
#  ('Mélange', 'OLIO'),
#  ('With 13 Down, tried to avert bad luck', 'KNOCKEDON'),
#  ('Durable fabric', 'TWEED'),
#  ('Ship feature', 'KEEL'),
#  ('Where to find a needle', 'ETUI'),
#  ('Impersonate', 'APE'),
#  ('Act the diaskeuast', 'EDIT'),
#  ('Baroque', 'ORNATE'),
#  ('___ to (introduced)', 'LEDUP'),
#  ('U.K. post-Christmas event', 'BOXINGDAY'),
#  ('Cognate', 'AKIN'),
#  ('Brilliant', 'JEWEL'),
#  ('Actress Damita', 'LILI'),
#  ('Outdated', 'MOTHEATEN'),
#  ('"Don Juan" poet', 'BYRON'),
#  ('View', 'BEHOLD'),
#  ('Ark messenger', 'DOVE'),
#  ('Neighbor of Ire.', 'ENG'),
#  ('Painter Mondrian', 'PIET'),
#  ('He got many a kick out of his job', 'PELE'),
#  ('Whence sherry comes', 'JEREZ'),
#  ('Study of snakes', 'OPHIOLOGY'),
#  ('This precedes beth', 'ALEF'),
#  ('Song of praise', 'CAROL'),
#  ('Cordon ___', 'BLEU'),
#  ('Oxlike animal', 'ZEBU'),
#  ('Unburnt brick', 'ADOBE'),
#  ('Cacholong', 'OPAL'),
#  ...]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (847201, 849)

# %%
# Vectorize Clues
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(strip_accents="unicode", stop_words="english")
X_train = vectorizer.fit_transform(np.array(clues_train))
X_train

# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)
# Out:
# <847201x76969 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1760159 stored elements in Compressed Sparse Row format>

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors().fit(X_train)
model
# Out:
# NearestNeighbors()

# %%
# Define a guesser function
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector = vectorizer.transform([clue])
    distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
    raw_guesses = [answers_train[i] for i in indices[0]]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue.lower()
        return o
    
    guesses = [g for g in raw_guesses if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
i = random.randint(0, len(clues_test))
test_clue, test_answer = clues_test[i], answers_test[i]
print("clue:", test_clue)
print("answer:", test_answer)

# distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# print("guesses:", [answers_train[i] for i in indices[0]])

guesses = guess(test_clue, slot_length=len(test_answer))
print("guesses:", guesses)
# Out:
# clue: One on a trail, perhaps
# answer: SLEUTH
# guesses: ['OREGON', 'OREGON']

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
    if i % 100 == 0: print(i)
    guesses = guess(clue, len(answer), max_guesses=5)
    if answer in guesses:
        correct_pairs.append((clue, answer, guesses))
    else:
        incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12176/3606335696.py in <module>
#       4 for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
#       5     if i % 100 == 0: print(i)
# ----> 6     guesses = guess(clue, len(answer), max_guesses=5)
#       7     if answer in guesses:
#       8         correct_pairs.append((clue, answer, guesses))
#
# ~\AppData\Local\Temp/ipykernel_12176/2879444122.py in guess(clue, slot_length, max_guesses, max_guesses_raw)
#       2 def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
#       3     clue_vector = vectorizer.transform([clue])
# ----> 4     distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
#       5     raw_guesses = [answers_train[i] for i in indices[0]]
#       6     # print([clues_train[i] for i in indices[0]])
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     703                 kwds = self.effective_metric_params_
#     704
# --> 705             chunked_results = list(pairwise_distances_chunked(
#     706                 X, self._fit_X, reduce_func=reduce_func,
#     707                 metric=self.effective_metric_, n_jobs=n_jobs,
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1621         else:
#    1622             X_chunk = X[sl]
# -> 1623         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
#    1624                                      n_jobs=n_jobs, **kwds)
#    1625         if ((X is Y or Y is None)
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1788         func = partial(distance.cdist, metric=metric, **kwds)
#    1789
# -> 1790     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1791
#    1792
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\Russell\Documents\School-Work\CMSC470\env\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     312         # if dtype is already float64, no need to chunk and upcast
#     313         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
# --> 314         distances += XX
#     315         distances += YY
#     316     np.maximum(distances, 0, out=distances)
#
# KeyboardInterrupt:

# %%
incorrect_pairs
# Out:
# [("Technical writer's target", 'ENDUSER', []),
#  ('The "W" in R.W.E.', 'WALDO', ['DRONE', 'UNDER', 'ATBAY', 'GEESE', 'ACCTS']),
#  ("G. &amp; S.'s Lord High Everything ___",
#   'ELSE',
#   ['ISIT', 'ISIT', 'ALAD', 'PEER', 'RULE']),
#  ('Rap stars often have them',
#   'POSSES',
#   ['HIPHOP', 'DEARME', 'KISMET', 'COMERS']),
#  ('Lemon appendage', 'ADE', ['TAG', 'ARM', 'DUD', 'RAG', 'DUD']),
#  ('Let go of', 'RELEASE', ['RELIEVE']),
#  ('Features of some Amerindian embroidery',
#   'PORCUPINEQUILLS',
#   ['EIGHTTIMESTHREE']),
#  ('Inclined', 'TRENDED', ['OFAMIND']),
#  ('Old-fashioned farm apparatus',
#   'CHURN',
#   ['DATED', 'MOSSY', 'DOWDY', 'DATED', 'DATED']),
#  ('Foes at Gaugamela', 'ALEXANDERDARIUS', []),
#  ('Pods of flax', 'BOLLS', ['CACAO', 'CAROB', 'OKRAS', 'LINEN', 'LINEN']),
#  ('Deal a mighty blow',
#   'SMITE',
#   ['ERUPT', 'ERUPT', 'ERUPT', 'ERUPT', 'GOOFF']),
#  ('Round dance', 'ONESTEP', ['SPHERED']),
#  ('Ripkin of the Orioles', 'CAL', ['TRY', 'HAH', 'PRO']),
#  ('Thomas Moore ballad locale',
#   'TARA',
#   ['ERIN', 'ERIN', 'POEM', 'TALE', 'SONG']),
#  ('Most of N.Y. outside N.Y.C.', 'UPSTATE', []),
#  ('Interlace', 'WATTLE', ['ONEDAY', 'ATONOF', 'AMIDST']),
#  ('Most deliberate', 'SLOWEST', ['HASTIER', 'STALLER', 'CAMPILY', 'TOOMANY']),
#  ('Assailed', 'FLEWAT', ['MONADS', 'IAGREE', 'DEMEAN']),
#  ('Calls off, as a mission',
#   'ABORTS',
#   ['ERRAND', 'ERRAND', 'ERRAND', 'SENTBY', 'VISITS']),
#  ('___-Christum', 'ANTE', ['BEEN', 'FROM', 'ISIT', 'HOOF', 'OFME']),
#  ('Pervasive quality', 'AROMA', ['TRAIT', 'TRAIT', 'BOXES', 'GROSS']),
#  ('1984 movie with a 100% positive rating on Rotten Tomatoes, with "The"',
#   'TERMINATOR',
#   ['ENTERPRISE']),
#  ('1998 animated film featuring the voice of Pierce Brosnan',
#   'QUESTFORCAMELOT',
#   ['REMINGTONSTEELE']),
#  ('"The ___ Spring": Stravinsky', 'RITEOF', []),
#  ('Actress Verdugo et al.', 'ELENAS', []),
#  ('Deal in sweet tubers?', 'TRAFFICYAMS', []),
#  ('"___ Zauberberg": Mann', 'DER', ['ACH', 'WEE']),
#  ('"The Phantom Menace" in the "Star Wars" series', 'EPISODEI', ['SPECTRAL']),
#  ('Valuable violin', 'CREMONA', []),
#  ('Rudder controls', 'HELMS', ['ABAFT', 'REINS', 'KNOBS', 'KNOBS', 'STERN']),
#  ('Edge: Abbr.', 'MARG', ['TRIM', 'ABUT', 'HONE', 'SAND', 'HONE']),
#  ('Forelimb bones', 'RADII', ['ULNAE', 'ULNAS', 'GAUNT', 'STOCK', 'ALIEN']),
#  ('Occupied, as a saddle',
#   'SATUPON',
#   ['ASTRIDE', 'ASTRIDE', 'ENGLISH', 'POMMELS']),
#  ('Crockpot', 'SLOWCOOKER', []),
#  ('Rubenesque', 'ZAFTIG', ['NETHER', 'ARISEN', 'AVENGE']),
#  ("In Bartlett's, e.g.", 'QUOTED', ['QUOTES', 'ADAGES']),
#  ('A lot', 'SWARMS', ['EYEFUL', 'KISMET', 'BUSHEL', 'EYEFUL', 'MYRIAD']),
#  ('"You can say that again!"', 'AMEN', ['AVOW', 'AVER', 'WHEN']),
#  ('Dependent, often', 'MINOR', ['HANGS', 'NEEDY', 'CATCH', 'GONER']),
#  ('At last: Fr.', 'ENFIN', ['AUSSI', 'ENTRE', 'ENTRE', 'AVOIR', 'AVOIR']),
#  ("It's hard to walk on", 'CORN', ['HOOF', 'PAVE', 'HOOF', 'GAIT', 'CANE']),
#  ('Indemnify', 'PAY', ['OWE', 'ONE', 'LEE']),
#  ('Makes too rare', 'UNDERDOES', []),
#  ('Poster', 'SIGN', ['BEDS', 'IDOL', 'IDOL', 'IDOL']),
#  ("Dickens's Trent et al.", 'NELLS', ['INSTS', 'BACKS', 'GORES', 'GORES']),
#  ('Calif. city', 'CARMEL', ['FRESNO', 'FRESNO', 'POMONA', 'LAMESA', 'FRESNO']),
#  ('Give out', 'EMIT', ['STAT', 'MERE', 'TOSS', 'HUSH', 'MOST']),
#  ('Hardly a he-man', 'WUSS', ['NARY', 'BLUR', 'ONCE', 'NARY', 'ISLE']),
#  ("Capt.'s direction", 'SSE', ['ESE', 'ESE', 'MAJ', 'RET', 'ENE']),
#  ('"___ but the Lonely Heart"',
#   'NONE',
#   ['BEEN', 'MISS', 'PEGO', 'PEGO', 'PEGO']),
#  ("Parents' embarrassment", 'BRAT', ['OOPS', 'TRIP', 'ADAM']),
#  ('Drawers in some college dorm rooms?', 'ARTMAJORS', ['ANIMATORS']),
#  ('Billhooks', 'SNAGGERS', []),
#  ('High times', 'UPS', ['HER', 'KPS', 'EDS']),
#  ('Sticker figure', 'PRICE', ['EPOXY', 'DECAL', 'THORN', 'STAMP', 'LABEL']),
#  ('No-___ (gnat)', 'SEEUM', ['MIDGE', 'NOSEE', 'PESKY', 'BITER', 'HASTO']),
#  ('Put aside for later', 'INRESERVE', []),
#  ('44-Across, e.g.', 'WIFE', ['PENN', 'ALAI', 'TROY', 'RICE', 'DDAY']),
#  ('Fed. farm-aid bureau', 'REA', ['ATF', 'OEO']),
#  ('Agnus ___ (religious figures)', 'DEIS', []),
#  ("Actor's first performance", 'DEBUT', ['REVUE', 'YODEL']),
#  ("Mira's constellation",
#   'CETUS',
#   ['STARS', 'VIRGO', 'ORION', 'ORION', 'ARIES']),
#  ('Accept officially, as a package',
#   'SIGNFOR',
#   ['ADAPTTO', 'RECEIVE', 'AGREETO', 'YIELDTO']),
#  ('Jump at a noise, e.g.', 'REACT', ['TRASH', 'BROAD']),
#  ('Santa reindeer-turned-zombie?', 'DONNERTHEDEAD', []),
#  ('Yielding readily', 'SPINELESS', ['ATONETIME']),
#  ('Look toward the sun', 'SQUINT', []),
#  ("Spaniard's greeting", 'HOLA', ['OTRO', 'PITO', 'GDAY', 'AGUA', 'AMID']),
#  ('Employment', 'JOB', ['USE', 'USE', 'WPA', 'AFC', 'TOO']),
#  ('Saint honored on September 1',
#   'GILES',
#   ['FETED', 'FETED', 'KNELT', 'VIRGO', 'MORNS']),
#  ('Bonanza State', 'MONTANA', []),
#  ('Nice guy', 'GENT', ['OGRE', 'OGRE', 'DEUX', 'RIEN', 'VICE']),
#  ('"___ you ready?"', 'ARE', ['SET', 'AIM', 'NOT', 'AIM', 'SET']),
#  ('Far from easygoing', 'ADAMANT', ['STERNER', 'AWESOME', 'UPTONOW']),
#  ('Yearly information book', 'ALMANAC', []),
#  ('Not level', 'INCLINED', ['TEARDOWN']),
#  ('Gives a thrashing', 'FLAILS', ['YIELDS', 'ALLOTS', 'YIELDS']),
#  ('Thus, to Caesar', 'ITA', ['UBI', 'EGO', 'SID', 'SID', 'HIC']),
#  ('First ___', 'AID', ['HOW', 'IVE', 'WOE', 'ARE', 'NOI']),
#  ('Clerihew and idyll', 'POEMS', ['ASTIR', 'OFTEN', 'ERECT', 'ERECT']),
#  ('"Can Do" is their motto', 'SEABEES', ['PROVERS', 'LIBERTE', 'NEITHER']),
#  ('Neighbor of Fort Myers, Fla.', 'PINEISLAND', []),
#  ('Medium for Wyeth', 'OILS', ['SIZE', 'SIZE', 'SOSO', 'RARE', 'SITS']),
#  ("Egypt's Gamal ___ Nasser",
#   'ABDEL',
#   ['ANWAR', 'DYING', 'REACH', 'MORSE', 'TOAST']),
#  ('Places longshoremen work', 'DOCKS', ['ACCTS', 'ANENT', 'ALIAS', 'HASTO']),
#  ('Instrument board', 'PANEL', ['TABLE', 'GETON', 'ENTER', 'GETON', 'TABLE']),
#  ('Superman and Mr. Hyde', 'ALTEREGOS', ['REINSTALL']),
#  ('Each', 'APIECE', ['NETHER', 'ARISEN', 'AVENGE']),
#  ('Get back on the horse', 'REMOUNT', ['STEPPER', 'ASTRIDE', 'TRESTLE']),
#  ('Clowns', 'BOZOS', ['MIMES', 'RODEO', 'RODEO', 'LEGIT', 'IDAHO']),
#  ('What a sphere lacks', 'EDGE', []),
#  ('"Choice" fellow', 'HOBSON', ['MISTER']),
#  ('Speaks carelessly', 'SLURS', ['DRAPE', 'SLOSH']),
#  ('___ Bueller, Broderick role',
#   'FERRIS',
#   ['SLOANE', 'ACCESS', 'RECOUP', 'ASWELL', 'INTACT']),
#  ('French pronoun', 'TOI', ['ILS', 'TES', 'MOI', 'MOI', 'SES']),
#  ('Calendar event, with 66 Across',
#   'LEAP',
#   ['RTES', 'POET', 'KIRI', 'RTES', 'RTES']),
#  ('1945 Roy Rogers-Dale Evans western',
#   'UTAH',
#   ['AFAR', 'STAT', 'ERAT', 'SHOW', 'AIDE']),
#  ('Gets into Monk music', 'BEBOPS', ['BOARDS', 'SKIRTS', 'ARISES', 'ANNOYS']),
#  ('Stationed', 'PUT', ['OPT', 'IKE', 'SPT']),
#  ('Stock exchange worker who was cheated?', 'FURIOUSTRADER', []),
#  ('Lynn ___, top bridge player',
#   'DEAS',
#   ['EAST', 'WEST', 'BARI', 'FRED', 'SLAM']),
#  ('One on the chopping block',
#   'CLEAVER',
#   ['MINCING', 'BARRIER', 'OCCLUDE', 'OCCLUDE']),
#  ('Cardinal for 22 years', 'STANMUSIAL', ['HOLYPERSON', 'ABOVEBOARD']),
#  ("Saint Jerome's pre-Vulgate Bible", 'ITALA', ['ABOAT', 'TOTAL', 'TOAST']),
#  ('Popular pop-up preventer', 'ADAWARE', ['WHEELIE']),
#  ('Bold, merry women', 'PEATS', ['GUTSY', 'DARER', 'SHIER', 'SHIER', 'TIMID']),
#  ('"Put up your ___"', 'DUKES', ['ARIDE', 'RARIN', 'NARYA', 'ARENT', 'ISONE']),
#  ('Problem in grade school', 'SUM', ['SCI', 'SCI', 'IOO', 'CEE', 'CEE']),
#  ('Stride loftily', 'STALK', ['GRADE']),
#  ('Kneepan', 'PATELLA', ['DOWORSE', 'PRIORTO']),
#  ('See 8-Down', 'CAR', ['INN', 'SIL', 'ITS', 'PER', 'OWE']),
#  ('Right-rear challenge on an alley', 'TENPIN', ['HEINIE', 'TAGEND']),
#  ('Give the slip to', 'EVADE', ['GLIDE', 'ELUDE', 'LAPSE', 'ERROR', 'ERROR']),
#  ('Hold responsible', 'BLAME', ['SEETO', 'STALL', 'TABLE', 'STAVE']),
#  ('Highlighter colors, often',
#   'NEONS',
#   ['TINTS', 'TINTS', 'MUTED', 'ABOVE', 'ONEUP']),
#  ('Reception', 'TEA', ['URN']),
#  ('___ clock', 'TIME', ['TENO', 'BEAT', 'WEST', 'SWAT', 'HAND']),
#  ('To___mildly', 'PUTIT', ['DRONE', 'UNDER', 'ATBAY', 'GEESE', 'ACCTS']),
#  ('21-Across, for one', 'DEA', ['AGE', 'ALL']),
#  ('Tracts reclaimed by dams or dikes', 'POLDERS', ['DERIDED']),
#  ('I.R.S. employee: Abbr.', 'AUD', ['AGT', 'AGT', 'AGT', 'AGT', 'CPA']),
#  ('Sounded like a cannon',
#   'BOOMED',
#   ['ORATED', 'ORATED', 'HISSED', 'MEOWED', 'PEEPED']),
#  ('Gut-busting side', 'JUMBOFRIES', []),
#  ('"___ wrap!"', 'ITSA', ['SARI', 'SARI']),
#  ('Twist (in)', 'SCREW', ['SNEER', 'WRING', 'GNARL', 'GNARL', 'CRAZE']),
#  ('Pitcher Bedard', 'ERIK', ['EWER', 'EWER', 'EWER', 'EWER', 'SOSA']),
#  ('Regal Egyptian name',
#   'RAMSES',
#   ['DIADEM', 'AUGUST', 'ERMINE', 'ERMINE', 'ERMINE']),
#  ('Unlawful', 'ILLICIT', ['ILICITO', 'INITIAL']),
#  ('*Popular tune around Halloween', 'MONSTERMASH', ['SLASHERFILM']),
#  ("One of Job's visitors",
#   'ELIHU',
#   ['AMAHL', 'AMAHL', 'PLACE', 'HEIST', 'ABLER']),
#  ('Catwoman, to Batman', 'FOE', ['BAM', 'ZAP', 'BAM', 'ZAP', 'RID']),
#  ('Deposits', 'LAYS', ['ORES', 'ORES', 'ORES', 'ORES', 'BINS']),
#  ('Police conveyance', 'PATRICKWAGON', []),
#  ('Area enframed by an arch', 'LUNETTE', ['STLOUIS']),
#  ('Easy win', 'SHOOIN', ['ENDEAR', 'ENDEAR', 'ENDEAR', 'REEARN', 'SEDUCE']),
#  ('Place to get off: Abbr.', 'STA', ['PSN', 'LOC', 'PUT', 'LAY', 'APT']),
#  ('93-Down, relatively', 'TALKTOYOULATER', ['FEELINGTHEHEAT']),
#  ('Where bottles of alcohol sit', 'BACKBAR', ['PROTEST']),
#  ('De Maupassant', 'GUY', ['MOI', 'AMI', 'AMI', 'AMI', 'UNE']),
#  ('Years and years and years',
#   'EONS',
#   ['AGED', 'AGES', 'ONCE', 'AGED', 'AGES']),
#  ('Frangible', 'CRISP', ['ASTIR', 'ENDED', 'OFTEN', 'ERECT', 'ERECT']),
#  ('Cruise around the Web', 'NETSURF', []),
#  ('Type of post', 'RADING', ['RESEND']),
#  ('Office piece', 'FILE', ['TGIF', 'ASST', 'TEMP', 'MEMO', 'EXEC']),
#  ('See 51-Down: Abbr.', 'GEN', ['OLD', 'PET', 'LEE', 'FAR', 'CAR']),
#  ('Cloths with repeating patterns',
#   'CALICOS',
#   ['ECHOING', 'DESIGNS', 'ALITTLE', 'GOAHEAD']),
#  ('Act the mime', 'APE', ['EMS']),
#  ('The African Queen, e.g.', 'BOAT', ['AGEE', 'AGEE', 'AGEE', 'AGEE', 'AGEE']),
#  ('Gym shoes, for short', 'SNEAKS', []),
#  ("Dapple's digs?", 'SPOTTEDHORSEWY', []),
#  ('Québec assent', 'OUI', ['YES', 'NOD', 'YEA', 'YES', 'YEA']),
#  ('Nonsense word repeated before "oxen free"',
#   'OLLY',
#   ['BOMP', 'LATE', 'LATE', 'YAKS', 'RARE']),
#  ('Must', 'NEEDTO', ['NETHER', 'ARISEN', 'AVENGE']),
#  ('Unite', 'TIE', ['WED', 'WED', 'WED', 'WED', 'WED']),
#  ('" . . . dreary everywhere ___"',
#   'IROAM',
#   ['DRONE', 'DIRGE', 'BLEAK', 'ASTIR', 'HASTO']),
#  ('Teeth, slangily', 'IVORIES', ['CANINES', 'CHATTER', 'SERRATE']),
#  ('Close an oxford', 'LACE', ['SHOE', 'SHOE', 'SHOE', 'SHOE', 'SHOE']),
#  ('Succeed in a big way',
#   'ACEIT',
#   ['GOFAR', 'GOFAR', 'ENSUE', 'ENSUE', 'GETON']),
#  ('Hail?', 'PLACEFORSINNERS', []),
#  ('Like some amusement park passes',
#   'ALLDAY',
#   ['GOKART', 'SLIDES', 'TICKET', 'ENACTS']),
#  ('French Foreign ___', 'LEGION', ['EXOTIC', 'ENDIVE', 'POODLE']),
#  ('Use a divan', 'SIT', []),
#  ('Tenth of a century', 'DECADE', ['SAPPHO']),
#  ('D, often', 'NONEOFTHEABOVE', []),
#  ('Full of sound and fury', 'ALLTALK', []),
#  ('Fire', 'CAN', ['INN', 'SIL', 'ITS', 'PER', 'OWE']),
#  ('Reference marks', 'OBELI', ['ASFOR', 'ASFOR', 'ERASE', 'ERASE', 'ERASE']),
#  ('Simp', 'GOOF', ['NERD', 'RATE', 'CARD', 'EVER', 'AMEN']),
#  ('London transportation', 'UNDERGROUND', ['OLIVERTWIST']),
#  ('Bottom of some scales', 'ONE', ['TEN', 'TEN', 'WWW']),
#  ('Effect of tightening an extra-tight belt, maybe',
#   'MUFFINTOP',
#   ['SCATTERED']),
#  ('Get-up-and-go', 'BRIO', ['STAT', 'MERE', 'TOSS', 'HUSH', 'MOST']),
#  ('Film feline', 'ELSA', ['WAUL', 'MEOW', 'PURR', 'PURR', 'MEOW']),
#  ('Responsibilities', 'CONCERNS', ['ETCETERA']),
#  ('Wolves',
#   'MASHERS',
#   ['LOAFERS', 'COYOTES', 'STEPPES', 'CANINES', 'STUFFED']),
#  ('Tailor', 'SARTOR', ['MENDER', 'SEAMER', 'SHEARS', 'SHEARS', 'NEEDLE']),
#  ("Eastern border of Manhattan's Tompkins Square Park",
#   'AVENUEB',
#   ['ITSALIE', 'AVERAGE', 'CENTRAL']),
#  ('Singer with the #1 hit "All I Have"', 'JENNIFERLOPEZ', []),
#  ('Natives of Beirut', 'LEBANESE', []),
#  ('Easily swayed', 'PLIANT', ['REELED', 'SLIPON', 'SLIPON']),
#  ('Hit man?', 'KASEM', ['CADET', 'VALET', 'FAKER']),
#  ('___ off (annoyed)', 'TEED', ['SORE', 'SORE']),
#  ('Not so dumb', 'WARES', ['WISER', 'INANE', 'INANE', 'DENSE', 'WISER']),
#  ("Awed by leading man's pickup?", 'STARSTRUCK', ['SPEECHLESS']),
#  ('"So what?"', 'WHOCARES', []),
#  ('Steady', 'MAINSQUEEZE', []),
#  ('Possible result of an appeal', 'REVERSEDECISION', ['LOSTOPPORTUNITY']),
#  ('Colonus', 'SERF', ['LAID', 'LONE', 'CARD', 'RATE', 'EVER']),
#  ('Cisterns', 'SUMPS', ['TANKS', 'TANKS', 'BRACE', 'TROVE', 'HENCE']),
#  ('White elephant events', 'SALES', ['ATTIC', 'EIDER']),
#  ('Impetuous, N.R.A. style?', 'TRIGGERHAPPY', []),
#  ('Where Jacques walks barefoot',
#   'PARC',
#   ['SHOD', 'SHOD', 'SHOD', 'SHOD', 'ETRE']),
#  ('Forming opinions', 'DEEMING', ['RULINGS', 'ENSUITE', 'ENSUITE']),
#  ('One of the Beatles',
#   'STARR',
#   ['MANIA', 'IDOLS', 'ICALL', 'SIXTY', 'OLDIE']),
#  ('Crooked', 'ASLANT', []),
#  ('Former TV sitcom', 'ENOS', ['MASH', 'AMEN', 'MASH', 'AMEN', 'AMEN']),
#  ('Force, in ancient Rome', 'VIS', ['VIR', 'EGO', 'EGO', 'AES', 'REX']),
#  ('What an article may refer to',
#   'NOUN',
#   ['CITE', 'CITE', 'CITE', 'CITE', 'CITE']),
#  ('A Butler slept here', 'TARA', ['HELP', 'ATOP', 'ALOG', 'ELBA', 'ELBA']),
#  ('Pretentiously showy', 'ARTSY', ['SLOTH', 'BYNOW']),
#  ('Four front?', 'PETIT', ['DRONE', 'UNDER', 'ATBAY', 'GEESE', 'ACCTS']),
#  ('Machree of songdom', 'MOTHER', ['SERENE', 'ERRING', 'SHAPER']),
#  ('Royal initials', 'HSM', ['HRH', 'HSH', 'TIH', 'HIH', 'ITT']),
#  ('Rover and Ryder', 'REDS', ['HERE', 'MARS', 'VANS', 'SPOT', 'FIDO']),
#  ('Mixers', 'SELTZERS', []),
#  ('Harmful', 'BAD', ['ILL']),
#  ('Lions', 'ROARERS', ['ELEVENS', 'NFLTEAM']),
#  ('*The Tommy Dorsey Orchestra, e.g.', 'BIGBAND', ['INCLINE']),
#  ('Nest-building S.A. fish',
#   'ACARA',
#   ['NIDUS', 'EIDER', 'ERECT', 'MARES', 'MARES']),
#  ('When repeated, cry often made with a hand up',
#   'IDO',
#   ['AID', 'YET', 'YET', 'YET']),
#  ('Luminaries', 'STARS', ['NEONS', 'ASTIR', 'OFTEN', 'ERECT', 'ERECT']),
#  ('Plath ploys', 'SIMILES', ['MERGERS', 'REVISIT']),
#  ("Padova's region", 'VENETO', []),
#  ('Young legacy?', 'UTAH', ['HEIR', 'TYKE', 'TYKE', 'TYKE', 'TYKE']),
#  ('Point of interest', 'LOCUS', ['TERSE', 'TERSE', 'INAPT', 'SOFAR', 'UNTIL']),
#  ('Where the bag of gifts is stowed on a sleigh',
#   'REAR',
#   ['SLED', 'PUNG', 'ESSE', 'ERAT', 'CLEF']),
#  ('Chaste?', 'YESBUTIRANFASTER', []),
#  ('Holds up in court',
#   'ESTOPS',
#   ['DETERS', 'REPELS', 'DELAYS', 'DELAYS', 'DELAYS']),
#  ('Humble home', 'SHED', ['MEEK']),
#  ('Tulsa time: Abbr.', 'CST', ['ORU', 'ORU', 'ORU', 'ORU', 'ORU']),
#  ('Gas in lighters',
#   'BUTANE',
#   ['FLINTS', 'AERATE', 'AERATE', 'REFUEL', 'HEREAT']),
#  ('Comic Don', 'KNOTTS', ['COSBYS', 'AMUSER']),
#  ('Sings like a bird',
#   'TRILLS',
#   ['CROONS', 'YODELS', 'CANARY', 'CROONS', 'EXTOLS']),
#  ('It may come from a crib', 'COO', ['WAH', 'BIN', 'BIN', 'WAH', 'GOO']),
#  ('Shelter org.', 'ASPCA', ['HAVEN', 'COVER']),
#  ('It may require you to use your head',
#   'SOCCER',
#   ['OBLIGE', 'ENTAIL', 'ENTAIL']),
#  ('Secretly tie the knot',
#   'ELOPE',
#   ['ALTAR', 'UNITE', 'ALTAR', 'GROOM', 'GNARL']),
#  ('Some movie theaters', 'AMCS', ['LOEW', 'ODEA', 'ODEA', 'RKOS', 'ODEA']),
#  ('"Anchors Aweigh" grp.', 'USN', ['PRO', 'ION', 'OWN', 'PER']),
#  ('Words said with the hands pressed together',
#   'OLORD',
#   ['URGED', 'URGED', 'URGED', 'URGED', 'URGED']),
#  ('English Channel port',
#   'DOVER',
#   ['POOLE', 'POOLE', 'POOLE', 'SEINE', 'SOMME']),
#  ('Highest part', 'ROOF', ['SMAJ', 'NOON', 'ACME', 'ACME', 'ACME']),
#  ('Respected', 'ESTEEMED', []),
#  ('Marks with furrows', 'STRIATES', ['STRIATED']),
#  ('N.F.L. divs.', 'QTRS', ['SYLS', 'RGTS', 'REGS', 'SSRS', 'CENS']),
#  ('Build up', 'ACCRUE', []),
#  ('Old Olympics award', 'LAUREL', ['BRONZE', 'PLAQUE']),
#  ('Soften', 'RELAX', ['RIPEN', 'ABUTS']),
#  ('Position on the briny', 'ABEAM', ['ATSEA', 'ATSEA', 'ATSEA']),
#  ('Pachacuti was one', 'INCA', ['EMIT', 'NIGH', 'THEN', 'AFAR', 'CHIT']),
#  ('Dromedary feature', 'HUMP', ['OLDS', 'RING', 'TYPE', 'EVER', 'BETS']),
#  ('Wishy-washy response', 'YESANDNO', ['DECISIVE']),
#  ('One-celled alga',
#   'DIATOM',
#   ['DESMID', 'NOSTOC', 'AMOEBA', 'AMOEBA', 'AMOEBA']),
#  ('Breath of wind', 'WAFT', ['GASP', 'PNEA', 'COIL', 'ALEE', 'ALEE']),
#  ('Tough tail', 'NESS', ['THUG', 'GOON', 'HOOD', 'CDEF']),
#  ('Graffiti artist, perhaps', 'VANDAL', ['BANKSY', 'GOATEE', 'ABASER']),
#  ('Tree whose name sounds like a letter of the alphabet',
#   'YEW',
#   ['EAU', 'EAU', 'ARI', 'PER', 'DON']),
#  ('Unsmiling', 'STERN', ['SOBER', 'ADMIT', 'ADMIT', 'ENDED', 'BOXES']),
#  ('___ in (inducted)', 'SWORN', ['COLON', 'ENEMY', 'LEAVE', 'CIRCA']),
#  ('Price preceder', 'LIST', ['COST', 'COST', 'COST', 'COST', 'COST']),
#  ('Alternatives to chips, say',
#   'IOUS',
#   ['NOSH', 'ANTE', 'RICH', 'ANTE', 'ANTE']),
#  ('Trenet\'s "La ___"', 'MER', ['TRA', 'TRA', 'TRA', 'TRA', 'TRA']),
#  ('Durable cover', 'SLATEROOF', ['HEAVYDUTY']),
#  ('Part of a possessive supermarket brand name',
#   'EDY',
#   ['HER', 'OUR', 'HER', 'HIS', 'OUR']),
#  ('Genuflect*', 'NEIL', ['CHIT', 'EMIT', 'AHSO', 'ERAT', 'STAR']),
#  ('Discussions', 'TALKS', ['MORSE', 'ABUTS', 'HENCE', 'ASTIR', 'ADOPT']),
#  ('One-for-one transaction', 'SWAP', ['DEAL', 'DEAL', 'DEAL', 'DEAL', 'LOAN']),
#  ('Right, left and U', 'TURNS', ['PUNCH', 'GUARD', 'TORAH', 'TORAH', 'STEER']),
#  ('Longtime "Nightline" host', 'TEDKOPPEL', ['MATTLAUER']),
#  ('1979 film with a Best Actress nomination', 'THEROSE', []),
#  ('Dakar or Danzig: Abbr.', 'SPT', ['GPA', 'ADD', 'AEI', 'FRO', 'LID']),
#  ('Branches', 'ARMS', ['RAMI', 'RAMI', 'RAMI', 'RAMI', 'RAMI']),
#  ('Be a member of a group', 'BELONG', ['SENATE']),
#  ('Any minute', 'SOON', ['IOTA', 'ANON', 'TINY', 'DRAM', 'IOTA']),
#  ('Ltd., in Paris', 'CIE', ['ICI', 'ICI', 'ICI', 'SES', 'SES']),
#  ('Metal cement', 'SOLDER', ['SILICA', 'SLURRY', 'REHANG']),
#  ('Start of a Soho toast', 'ERES', ['ARTY', 'ARTY', 'CHAR']),
#  ('People with saving accounts?',
#   'RESCUERS',
#   ['APPEARTO', 'NUMBERED', 'NESTEGGS']),
#  ('QB Steve who won a Payton Award',
#   'MCNAIR',
#   ['WALTER', 'PLURAL', 'ENCORE', 'ELAPSE']),
#  ('"Don\'t you know there\'s ___ on?"',
#   'AWAR',
#   ['IACT', 'ASWE', 'OATS', 'YESI']),
#  ('Say "You can\'t do that!" to, say', 'DARE', ['AVOW', 'AVER', 'WHEN']),
#  ('Hit song of 1939', 'BEERBARRELPOLKA', ['GODBLESSAMERICA']),
#  ('Like anatomical anvils', 'OTIC', ['EARS', 'EARS', 'DIBS', 'SOAR', 'EVER']),
#  ('Burn balms', 'ALOES', ['ODORS', 'SCALD', 'SCALD', 'SCALD', 'SCALD']),
#  ('Spot for old toys', 'ATTIC', ['SANTA', 'KITES', 'KITES', 'PAILS', 'PAILS']),
#  ('"I don\'t believe it!"', 'OHNO', ['MYTH', 'DEEM', 'DEEM', 'DEEM']),
#  ('Satiated', 'FED', ['OWN', 'DON', 'TIL', 'BUT', 'REF']),
#  ('Five-card or seven-card game', 'STUDPOKER', []),
#  ('Churchman: Abbr.', 'MSGR', ['ABBE', 'PARK', 'SAVE', 'ERGO', 'VOWS']),
#  ('Where dentists sail?', 'ROOTCANAL', ['ABSCESSES', 'TOOTHFAIR']),
#  ('Unfreezes', 'THAWS', ['DRONE', 'UNDER', 'ATBAY', 'GEESE', 'ACCTS']),
#  ("Miller's output", 'BEERS', ['STEEL', 'STEEL', 'PAPER', 'STEEL', 'YIELD']),
#  ('Food processors', 'STOMACHS', ['VICTUALS']),
#  ('Ice ace, once', 'ORR', ['ONE', 'PRO', 'ANA', 'AON', 'AON']),
#  ('Abbr. in two state names', 'DAK', ['USS', 'USS', 'INC', 'NEW', 'USS']),
#  ('Hunk', 'PIECE', ['HEMAN', 'DIVOT']),
#  ("Skater's attire, at times",
#   'TUTU',
#   ['AXEL', 'GARB', 'GARB', 'GARB', 'GARB']),
#  ('Shrub of the verbena family',
#   'VITEX',
#   ['TEAKS', 'LILAC', 'ROGER', 'OTHER', 'TOTAL']),
#  ('Madden', 'IRE', ['BAM', 'HEY', 'FRO', 'NEE', 'SIL']),
#  ("Captain Kirk's records", 'LOGS', ['PIKE', 'KHAN', 'LISA', 'LISA', 'LISA']),
#  ('Nobelist in Physiology: 1970',
#   'EULER',
#   ['DEBAR', 'NOTAS', 'ATSEA', 'ELIOT']),
#  ('Not on paper', 'ORAL', ['REAM', 'NEWS', 'TERM', 'TERM', 'RICE']),
#  ('Seam material', 'ORE', ['HEM', 'SEW', 'SEW', 'SEW', 'TIN']),
#  ('Loc. of Mayor Dinkins', 'NYC', ['CIT', 'CIT', 'HER', 'ERE']),
#  ('Late comic genius', 'ROBINWILLIAMS', []),
#  ('Speaker of the A.L.', 'TRIS', ['CBER', 'BOSE', 'IAGO', 'NEWT', 'DAIS']),
#  ('One of the Spanish', 'UNO', ['ESA', 'ESA', 'ESA', 'ESA', 'ESA']),
#  ('Not hypothetical',
#   'INESSE',
#   ['WHATIF', 'BIOGEN', 'APEMAN', 'BIOGEN', 'BIOGEN']),
#  ("Artist Piet Mondrian's anagrammatic epigram", 'IPAINTMODERN', []),
#  ('Meas. equaling 3.7854 liters', 'GAL', ['VOL', 'YET', 'DUB', 'PER']),
#  ('Bygone political slogan', 'EYELIKEIKE', []),
#  ('Zoo of a sort', 'NOAHSARK', []),
#  ('Miami daily', 'HERALD', ['TRIBES']),
#  ('Military sleuths: Abbr.', 'IGS', ['RET', 'CWO', 'ENL', 'RET', 'RET']),
#  ('In which 49 is 100', 'BASESEVEN', ['DIANAROSS']),
#  ('Food fish', 'SAUREL', []),
#  ('Goose eggs', 'NILS', ['OOOO', 'STEP', 'STEP', 'NEST']),
#  ('"It is the sea / Gone with the sun," wrote Rimbaud',
#   'ETERNITY',
#   ['BEFITTED', 'AFTERALL']),
#  ('Letter in runes', 'EDH', ['MME', 'DIS', 'DON']),
#  ('Target for Trevino', 'PIN', ['PGA', 'PGA', 'LEE', 'LEE', 'LEE']),
#  ('Off the job', 'IDLE', ['ABLE', 'LINE', 'SCAM', 'SPEC', 'TASK']),
#  ('Tariffs hinder it', 'OPENTRADE', ['FORESTALL']),
#  ('Bleat', 'MAA', ['BAA', 'BAA', 'BAA', 'BAA', 'BAA']),
#  ('"Success is a great deodorant" speaker, informally', 'LIZTAYLOR', []),
#  ('Passes effortlessly',
#   'SAILSBY',
#   ['ELAPSES', 'ELAPSES', 'ELAPSES', 'ELAPSES', 'RIDESBY']),
#  ('Sailed in a small boat', 'SKIFFED', []),
#  ('Visibly shaken', 'ASHEN', ['AGLOW', 'AGLOW', 'ATALL', 'AHEAD', 'DENSE']),
#  ('Isle off Labrador', 'BELLE', ['IGLUS', 'FLOES', 'CAPRI', 'WIGHT', 'CABOT']),
#  ('"Hit Parade" group',
#   'TOPIO',
#   ['FLOAT', 'STRUT', 'LOVEA', 'ILOVE', 'ILOVE']),
#  ('Purifying sac.', 'BAP', ['CUL', 'CUL', 'CUL', 'CUL', 'CUL']),
#  ('Popular poultry entree', 'CHICKENTARRAGON', ['BREASTOFCHICKEN']),
#  ('Ideally', 'ATBEST', ['HEALER', 'ENDURE']),
#  ('Shakespearean manipulator',
#   'IAGO',
#   ['USER', 'USER', 'USER', 'USER', 'USER']),
#  ('Word blindness', 'ALEXIA', ['ARISEN', 'ALLTOO', 'PRIMAL']),
#  ('"The ___ of Frankenstein" (Peter Cushing film)',
#   'EVIL',
#   ['CEDE', 'WORE', 'OWED', 'ANTI', 'WEND']),
#  ("Cowboy's concern", 'CALF', ['HERD', 'ECOL', 'AWOL', 'CARE', 'ATOM']),
#  ('Longtime La Scala music director',
#   'MUTI',
#   ['DIVA', 'POCO', 'AIDA', 'ARIA', 'SING']),
#  ("TV technicians' equipment", 'HANDHELDCAMERAS', []),
#  ("Queens' homes", 'HIVES', ['RANIS', 'LAKES', 'NESTS']),
#  ('Treated for preservation, maybe', 'SALTED', ['STYLES', 'CAVEAT', 'EFFORT']),
#  ('Man, e.g.', 'BIPED', ['JARED', 'CADET', 'AGENT', 'VALET', 'OHWOW']),
#  ('Against', 'ANTI', ['STAT', 'MERE', 'TOSS', 'HUSH', 'MOST']),
#  ('N.Y.S.E. and Nasdaq, e.g.',
#   'MKTS',
#   ['ASSN', 'ASSN', 'NYSE', 'NYSE', 'NYSE']),
#  ('___ Hopkins University',
#   'JOHNS',
#   ['OTAGO', 'OTAGO', 'OTAGO', 'EVERY', 'RURAL']),
#  ('In hidden fashion', 'BETWEENTHELINES', []),
#  ("Editor's work: Abbr.", 'MSS', ['BOK']),
#  ("Buffalo Bill's targets: Var.",
#   'BISONS',
#   ['STAINS', 'AIMSAT', 'AIMSAT', 'AIMSAT', 'BOVINE']),
#  ('U.K. network', 'BBC', ['WEB', 'WEB', 'CBS', 'WEB', 'WEB']),
#  ('" ? and the ___ shall be first": Matthew',
#   'LAST',
#   ['ASON', 'WANT', 'ASON', 'AHME', 'OHNO']),
#  ('Part of A.D.', 'ANNO', ['STAT', 'MERE', 'TOSS', 'HUSH', 'MOST']),
#  ('Olfactory clue', 'SMELL', ['SCENT', 'ADOPT', 'START', 'OCCUR', 'ATSEA']),
#  ('Part of U.A.R.', 'ARAB', ['STAT', 'MERE', 'TOSS', 'HUSH', 'MOST']),
#  ('Show, informally', 'DEMO', ['RELO', 'GRAB', 'BUCK', 'MEGA', 'RELO']),
#  ('Not on', 'OFF', ['INN', 'SIL', 'ITS', 'PER', 'OWE']),
#  ('Lively musical passages', 'ALLEGROS', ['SOSENUOS', 'ANIMATED', 'SPIRITED']),
#  ('Aid for one who is almost able',
#   'CANE',
#   ['ONTO', 'ONTO', 'UPTO', 'IERE', 'ASIN']),
#  ('One whose head is turned',
#   'SCREW',
#   ['LEFTS', 'ONEND', 'ONLOW', 'AROSE', 'AROSE']),
#  ("Help that's always available", 'LIVEINMAID', ['UPFORGRABS']),
#  ('Fast', 'SPORTY', ['PRESTO', 'HANGON', 'SLOWER', 'SLOWER', 'STREAK']),
#  ('Heaps', 'LOTS', ['ATON', 'ATON', 'ATON', 'ATON', 'TONS']),
#  ('Greenish blue', 'AQUA', ['TEAL', 'TEAL', 'CYAN', 'TEAL', 'TEAL']),
#  ('Most transparent', 'SHEEREST', ['GLASSINE']),
#  ('Help in rounding up', 'LARIAT', ['ASSIST', 'ASSIST', 'MAYDAY', 'ASSIST']),
#  ('Grp. concerned with hacking', 'NSA', ['ABA', 'ABA', 'NBA']),
#  ('Religion with public shrines', 'SHINTO', ['STUPAS', 'ABSORB']),
#  ('Write 2 + 7 = 10, e.g.', 'MISADD', ['ENFACE', 'INDITE', 'FORGET']),
#  ('More full of life', 'SPRYER', ['LCHAIM', 'CEREAL', 'SAYING']),
#  ("It's easy to swallow", 'PAP', ['EAT', 'VEG']),
#  ('Hockey skater, informally',
#   'ICER',
#   ['AXEL', 'VEEP', 'DEMO', 'MEGA', 'BUCK']),
#  ('Renoir\'s "The Blonde ___"', 'BATHER', ['ARTIST']),
#  ('Bathwear', 'TERRY', ['DRONE', 'UNDER', 'ATBAY', 'GEESE', 'ACCTS']),
#  ("Present home of the America's Cup",
#   'PERTH',
#   ['YACHT', 'YACHT', 'EWERS', 'YACHT', 'NONCE']),
#  ('Severe sales restriction, informally', 'ONEPER', []),
#  ("Driver's license requirement",
#   'EYEEXAM',
#   ['PHOTOID', 'FREEDOM', 'EMPOWER', 'LEGALID']),
#  ("Like a sweep's uniform", 'SOOTY', ['RANGE', 'SCOPE', 'EQUAL', 'ALIKE']),
#  ('Personnel concern for Santa?', 'ELFESTEEM', ['ATTRITION'])]

# %%
guess("bruins")
# Out:
# ['UCLA', 'UCLA', 'ORR', 'UCLA', 'UCLA']
