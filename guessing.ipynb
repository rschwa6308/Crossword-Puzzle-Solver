# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt

DATA_PATH = r"data\nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

sample = random.sample(puzzles_available, 10_000)

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)
clue_answer_pairs
# Out:
# [('Bang the keyboard', 'TYPE'),
#  ('Word with wet or white', 'WASH'),
#  ('Winter sound', 'SLOSH'),
#  ('Twenty quires', 'REAM'),
#  ('"To work ___ pray"', 'ISTO'),
#  ('South American prairie', 'PAMPA'),
#  ('Famed lawman', 'EARP'),
#  ('Held', 'MAINTAINED'),
#  ('Chinatown attraction', 'SHRIMPFRIEDRICE'),
#  ('Something to obey', 'RULE'),
#  ('___ salmon (sockeye)', 'RED'),
#  ('Narrow passage', 'DEFILE'),
#  ('Pub purchase', 'ALE'),
#  ("Sprat's no-no", 'FAT'),
#  ('Quickly', 'APACE'),
#  ('Where to see "La Maja Desnuda"', 'PRADO'),
#  ('___ du Diable', 'ILE'),
#  ('Chinatown attraction', 'LOBSTERCHOWMEIN'),
#  ('Top painter of birds', 'EDE'),
#  ('Moslem prince', 'AMEER'),
#  ('Norway, to a Norwegian', 'NORGE'),
#  ('Suffix with law or saw', 'YER'),
#  ("Popeye's Olive", 'OYL'),
#  ('Obliquely', 'ASLANT'),
#  ('Meet, as judges', 'SIT'),
#  ("Sleuth's need", 'CLUE'),
#  ('Chinatown attraction', 'CHICKENCHOPSUEY'),
#  ('Nobelist in Literature: 1934', 'PIRANDELLO'),
#  ("Tracy's bride", 'TESS'),
#  ('Word with said or thought', 'AFORE'),
#  ('Courts', 'WOOS'),
#  ('"Or ___!"', 'ELSE'),
#  ('Strengthen', 'SINEW'),
#  ('Graf ___', 'SPEE'),
#  ("Natty Bumppo's quarry", 'DEER'),
#  ('Uno, dos, ___', 'TRES'),
#  ('Relative of yep', 'YEAH'),
#  ('Young salmon', 'PARR'),
#  ('Persons relying on experience vis-à-vis theory', 'EMPIRICS'),
#  ('What some nuns will have none of', 'WIMPLE'),
#  ('"___ and Sane Fourth": Masson', 'ASAFE'),
#  ('Tend the pot', 'STIR'),
#  ('"___ soit . . . "', 'HONI'),
#  ('Spud', 'SPADE'),
#  ('One of the Scottish gentry', 'LAIRD'),
#  ('Arena in Atlanta', 'OMNI'),
#  ('Risk venture, for short', 'SPEC'),
#  ('Rock-fault angle', 'HADE'),
#  ('Shipworm', 'TEREDO'),
#  ("Matador's cloth on a stick", 'MULETA'),
#  ('Mayor who died in 1976', 'DALEY'),
#  ('Type of lyric poem', 'EPODE'),
#  ('Luther foe ("Hammer of Heretics")', 'FABER'),
#  ('Ray ___, famous manager of boxers', 'ARCEL'),
#  ('Comedian Bert: 1895–1967', 'LAHR'),
#  ('Fair, in Ferrara', 'FIERA'),
#  ('Set in a row', 'ALIGN'),
#  ('Principle', 'TENET'),
#  ('Frog, to a skunk', 'PREY'),
#  ('Confesses', 'OWNSUP'),
#  ('Hammed it up', 'EMOTED'),
#  ('Disturbed; annoyed', 'MOLESTED'),
#  ('"He fumbles up into ___ adieu": Shak.', 'ALOOSE'),
#  ('Word with head or crow', 'SCARE'),
#  ('"___ him when . . . "', 'IKNEW'),
#  ('Shepherdess of poetry', 'CHLOE'),
#  ('Accts.', 'CPAS'),
#  ('Stereo feature', 'HIFI'),
#  ('Niblick, e.g.', 'IRON'),
#  ("Seven o'clock event in N.Y.C.", 'NEWS'),
#  ('Street sound, once', 'CLOP'),
#  ('Ubangi feeder', 'UELE'),
#  ('Being', 'ESSE'),
#  ('River of France and Belgium', 'YSER'),
#  ('When doubled, a seafood entree', 'MAHI'),
#  ('Is visibly frightened', 'PALES'),
#  ("Off one's trolley", 'BATS'),
#  ('"Yeah, right!"', 'ASIF'),
#  ('Work ___', 'OFART'),
#  ("Pop's Brickell", 'EDIE'),
#  ('Gigantic instrument?', 'BIGFATLYRE'),
#  ('"Take ___!" (track coach\'s order)', 'ALAP'),
#  ('Holed up', 'HID'),
#  ('First name in horror', 'LON'),
#  ('Actress Sorvino', 'MIRA'),
#  ('Instrument made in the lab?', 'CHEMICALCYMBAL'),
#  ('Straits of ___', 'FLORIDA'),
#  ('Tee follower?', 'HEE'),
#  ('Crew need', 'OAR'),
#  ('Set alight', 'TORCH'),
#  ('Quattros, e.g.', 'AUDIS'),
#  ('Greet the day', 'RISE'),
#  ('Take your pick?', 'STRUM'),
#  ('Federico of the Clinton cabinet', 'PENA'),
#  ('Touch up', 'EMEND'),
#  ('Up', 'ATBAT'),
#  ('Early fifth-century year', 'CDI'),
#  ('Ridge of Homeland Security', 'TOM'),
#  ('Like some burgers', 'BROILED'),
#  ('Instrument found at the Super Bowl?', 'QUARTERBACKSAX'),
#  ('Donald, to Dewey', 'UNCA'),
#  ('Opposite of paleo-', 'NEO'),
#  ('Order of corn', 'EAR'),
#  ('"I\'ll be ___ of a gun!"', 'ASON'),
#  ('Missing instrument?', 'STOLENBASS'),
#  ('Ste. Jeanne ___', 'DARC'),
#  ('King of Thebes slain by Theseus', 'CREON'),
#  ('Inner: Prefix', 'ENTO'),
#  ('January 1 song word', 'SYNE'),
#  ('Surfer wannabe', 'HODAD'),
#  ('Mail: Abbr.', 'LTRS'),
#  ('Shelley queen', 'MAB'),
#  ('"___ recall ..."', 'ASI'),
#  ("Arrogant one's place", 'HIGHHORSE'),
#  ('More uncertain', 'IFFIER'),
#  ("Chips' place", 'POT'),
#  ('1955 merger grp.', 'AFL'),
#  ('Eric Clapton hit with a never-ending chorus', 'LAYLA'),
#  ('Flynn of "Captain Blood"', 'ERROL'),
#  ('Dumpster emanation', 'STENCH'),
#  ('Request to the Enterprise', 'BEAMMEUP'),
#  ('Seat-of-the-pants performance', 'ADLIB'),
#  ('Papal wear', 'TIARA'),
#  ('Calyx part', 'SEPAL'),
#  ('___ one', 'ADMIT'),
#  ("Miner's filing", 'CLAIM'),
#  ('Binding exchanges', 'IDOS'),
#  ('Magna ___', 'CARTA'),
#  ('Roll-call call', 'YEA'),
#  ('"Watch out!"', 'FORE'),
#  ('P.C. part', 'CRT'),
#  ('When repeated, a cry of approval', 'HUBBA'),
#  ('U.S. citizen-to-be', 'DECLARANT'),
#  ('The Dow, e.g.', 'INDEX'),
#  ('Port ___ (Suez Canal city)', 'SAID'),
#  ('Door', 'ENTRANCE'),
#  ('1991 Grammy winner Cohn', 'MARC'),
#  ('Point', 'DOT'),
#  ('Keepsake', 'TOKEN'),
#  ('Good guy', 'MENSCH'),
#  ('Sanford of "The Jeffersons"', 'ISABEL'),
#  ('Thigh muscles', 'QUADS'),
#  ('Take back', 'UNSAY'),
#  ("Squirrel's find", 'ACORN'),
#  ('Old, but new again', 'RETRO'),
#  ('Like unpopular umps', 'BOOED'),
#  ('Mauna ___', 'LOA'),
#  ('Omega', 'END'),
#  ('Orch. section', 'STR'),
#  ('Brillo rival', 'SOS'),
#  ('Cooler idea?', 'JAILBREAK'),
#  ('Home to the Great Mosque', 'MECCA'),
#  ('It included a moonwalk', 'APOLLOXII'),
#  ('Spirit of St. Petersburg?', 'STOLI'),
#  ('One stocking bars', 'CANDYSHOP'),
#  ('West African capital', 'DAKAR'),
#  ('Old sitcom sot', 'OTIS'),
#  ("Pimienta's partner", 'SAL'),
#  ('Many instant message recipients', 'AOLERS'),
#  ('"Sketches" pseudonym', 'BOZ'),
#  ('Bad-tempered', 'BILIOUS'),
#  ('Compress, as a file', 'ZIP'),
#  ('Turn the air blue', 'SWEAR'),
#  ('Where many games can be viewed', 'ESPN'),
#  ('Prefix with data', 'META'),
#  ('Motor problems', 'TICS'),
#  ('Fat-derived', 'STEARIC'),
#  ('Havana highball', 'MOJITO'),
#  ('Recite mechanically', 'INTONE'),
#  ('Swank', 'OPULENT'),
#  ('Word before red', 'BEET'),
#  ('Beech house?', 'NEST'),
#  ('Quarter of zwölf', 'DREI'),
#  ('Tables in western scenes', 'MESAS'),
#  ('Word after red', 'ANT'),
#  ('Like time, inexorably', 'GOINGBY'),
#  ('"___ I forsook the crowded solitude": Wordsworth', 'ERE'),
#  ('Walters portrayer on "S.N.L."', 'RADNER'),
#  ('Dance piece?', 'CHA'),
#  ('Thé addition', 'LAIT'),
#  ('Produce sentimental notes?', 'CROON'),
#  ('Big-name Web crawler', 'GOOGLEBOT'),
#  ('"The Asphalt Jungle" revolves around one', 'HEIST'),
#  ('Like Francisco Goya', 'ARAGONESE'),
#  ('"Breaking Away" director', 'YATES'),
#  ('She "made a fool of everyone," in song', 'SEXYSADIE'),
#  ('A. J. ___, author of the best seller "The Know-It-All: One Man\'s Humble Quest to Become the Smartest Person in the World"',
#   'JACOBS'),
#  ('Director of "The 40-Year-Old Virgin" and "This Is 40"', 'APATOW'),
#  ('Turn positive, say', 'IONIZE'),
#  ('Some Yale degs.', 'LLDS'),
#  ('Nellie who wrote "Ten Days in a Mad-House"', 'BLY'),
#  ('Martini accompanier?', 'ROSSI'),
#  ('Uses a drunkometer, e.g.', 'EXHALES'),
#  ('Provençal spreads', 'AIOLIS'),
#  ('100-at currency unit', 'KIP'),
#  ("It was run in the 1980s-'90s", 'MSDOS'),
#  ('Abbr. for the listless?', 'ETAL'),
#  ('Tab alternative', 'COKEZERO'),
#  ('Big name in allergy relief', 'CLARITIN'),
#  ("It's flown in", 'AIRSPACE'),
#  ("___ Anne's (pretzel maker)", 'AUNTIE'),
#  ('Ultra ___', 'BRITE'),
#  ('Quick missions?', 'OPS'),
#  ('Slightly biased?', 'ATILT'),
#  ('Like some finishes', 'MATTE'),
#  ('Hole in one on a par 5 hole', 'CONDOR'),
#  ('"No ___ is worse than bad advice": Sophocles', 'ENEMY'),
#  ('Bahrain, Bhutan or Brunei', 'MONARCHY'),
#  ('Clearing', 'OPENAREA'),
#  ('Popular line of footwear?', 'JUSTDOIT'),
#  ('Endurance race, briefly', 'TRI'),
#  ('Cardiff Giant, e.g.', 'BIGHOAX'),
#  ('Cry for another piece', 'ENCORE'),
#  ('Starfish setting', 'SEABED'),
#  ('Some opera passages', 'ARIOSI'),
#  ('Parlor piece', 'SETTEE'),
#  ('Word on a restroom door', 'GENTS'),
#  ('Loose', 'BAGGY'),
#  ('Thing twitched on "Bewitched"', 'NOSE'),
#  ('River known for the goldfields in its basin', 'LENA'),
#  ('Sign on an interstate', 'GAS'),
#  ('"___ Tarantos" (1963 film)', 'LOS'),
#  ('"Spin the Black Circle" Grammy winner of 1995', 'PEARLJAM'),
#  ('Sort who needs to button up', 'GASBAG'),
#  ('Buttoned up', 'ASQUIETASAMOUSE'),
#  ('Not have a hunch?', 'STANDUPSTRAIGHT'),
#  ('What shy people often have', 'DEBTS'),
#  ('Trendy tuna', 'AHI'),
#  ("With 22-Across, runner's woe", 'LEG'),
#  ('Prohibition, e.g.', 'ERA'),
#  ('See 20-Across', 'CRAMP'),
#  ('City near Pyramid Lake', 'RENO'),
#  ('Uglify', 'MAR'),
#  ('"Superman II" villainess', 'URSA'),
#  ('Atlas offerings', 'AUTOMOBILETIRES'),
#  ('Ivory tower setting', 'GROVESOFACADEME'),
#  ('Some expressions of false humility', 'UNDERSTATEMENTS'),
#  ('Large wire', 'ASSOCIATEDPRESS'),
#  ('"Boxing Helena" star Sherilyn', 'FENN'),
#  ('Squad leader?', 'ESS'),
#  ('Comic response, in Variety', 'LAFF'),
#  ('Greek restaurant menu subheading', 'GYROS'),
#  ('Realization vocalization', 'AHA'),
#  ("Plumber's union?", 'ELL'),
#  ('Catcher of the rye?', 'BIB'),
#  ('Dipsticks', 'ASSES'),
#  ('Part of the Ring of Fire', 'ALEUTIANISLANDS'),
#  ('Light alternative', 'FOURWAYSTOPSIGN'),
#  ('Modern resident of ancient Ebla', 'SYRIAN'),
#  ('Many gallerygoers', 'ESTHETES'),
#  ('___-Calais (French department)', 'PASDE'),
#  ('Imparter of fruity overtones', 'ESTER'),
#  ('Hub for Jordan Aviation', 'AQABA'),
#  ('Half-pint', 'RUNT'),
#  ('Eyeshades?', 'LIDS'),
#  ('Vingt-et-un, e.g.', 'JEU'),
#  ('How some instruments are sold', 'ATPAR'),
#  ('Gessen who wrote the 2012 Putin biography "The Man Without a Face"',
#   'MASHA'),
#  ('Bayou predator', 'GAR'),
#  ('Cold war grp.?', 'AMA'),
#  ('"___ gather"', 'SOI'),
#  ('Military brass', 'BUGLE'),
#  ('Horror-struck, apparently', 'ASHEN'),
#  ('First moment', 'GETGO'),
#  ('Goose', 'STIMULATE'),
#  ('Ferry ride, say', 'CROSSING'),
#  ('Ushers in', 'PRECEDES'),
#  ('Assault team', 'RAIDERS'),
#  ('Depart from', 'MOVEOFF'),
#  ('Punish by fine', 'AMERCE'),
#  ('They get stuck in corners', 'STAMPS'),
#  ("Arizona's ___ Fria River", 'AGUA'),
#  ("Some of a caterer's inventory", 'URNS'),
#  ('Upscale Italian shoe brand', 'TODS'),
#  ('Where Captain Cook landed in 1770', 'BOTANYBAY'),
#  ('"___ first ..."', 'IFAT'),
#  ('Conductor Leibowitz', 'RENE'),
#  ('Crew at a pileup', 'EMTS'),
#  ('Short term?', 'SESS'),
#  ('Toronto team, briefly', 'LEAFS'),
#  ('Dental gold, e.g.', 'ALLOY'),
#  ('Jacinthe or jonquille', 'FLEUR'),
#  ('Salon service', 'RINSE'),
#  ('Late notices?', 'OBITS'),
#  ('Peeved, after "in"', 'ASNIT'),
#  ('Play both sides, in a way', 'HEDGE'),
#  ('Pro grps.', 'ASSNS'),
#  ("Xanadu's river", 'ALPH'),
#  ('It may have a row of 28-Down, briefly', 'SASE'),
#  ('William Tell territory', 'URI'),
#  ('Old Eastern alternative', 'TWA'),
#  ('Rankin who created Inspector Rebus', 'IAN'),
#  ('Juice fiend', 'SOT'),
#  ('___ War (race horse)', 'MANO'),
#  ('Borders on', 'ABUTS'),
#  ('N.F.L. player', 'RAM'),
#  ('Chinaware items', 'EWERS'),
#  ('Actor Williams', 'ROBIN'),
#  ('Conductor de Waart', 'EDO'),
#  ('Boston transit run or rink divider', 'THEBLUELINE'),
#  ('Rummy game', 'GIN'),
#  ('Actor Linden', 'HAL'),
#  ('Part of A.D.', 'ANNO'),
#  ('Next-to-last syllable', 'PENULT'),
#  ('Western capital', 'OLYMPIA'),
#  ('Noel singer', 'CAROLER'),
#  ('Quit it!', 'DESIST'),
#  ('Heavy weight', 'TON'),
#  ('Superstar', 'NAME'),
#  ('Short-story writer', 'OHENRY'),
#  ('Sutherland role', 'NORMA'),
#  ('Accelerate', 'REV'),
#  ("Bruins' former coach", 'OREILLY'),
#  ('Gal of songdom', 'SAL'),
#  ('Vote in', 'ELECT'),
#  ('Koch and Flynn', 'MAYORS'),
#  ('Leaping car', 'LENA'),
#  ('Precinct worker', 'POL'),
#  ('Covering worn over a boot', 'GAITER'),
#  ('Programs for committees', 'AGENDAS'),
#  ('Candid; honest', 'SINCERE'),
#  ('More snappish', 'TARTER'),
#  ('Founder of Kievan Russia', 'OLEG'),
#  ('Blockhead, in Brest', 'ANE'),
#  ('___ jiffy', 'INA'),
#  ('Wales and Campbell, in hockey', 'CONFERENCES'),
#  ('Fall mo.', 'OCT'),
#  ('"What ___," 1939 film', 'ALIFE'),
#  ('Employ again', 'REUSE'),
#  ('Anne Lindbergh, ___ Morrow', 'NEE'),
#  ('Pause', 'LETUP'),
#  ('Makes a choice', 'OPTS'),
#  ('System', 'METHOD'),
#  ('Have ___ of a time (enjoy)', 'AWHALE'),
#  ("Bruins' Cam and family", 'NEELYS'),
#  ('Eye, in poesy', 'ORB'),
#  ('Place for a rink', 'ARENA'),
#  ('Machete', 'BOLO'),
#  ('___ supra (as above, in law)', 'UBI'),
#  ('___ Alley', 'TINPAN'),
#  ('Dirty look', 'SNEER'),
#  ('First team', 'REGULARS'),
#  ('Horns of ___', 'ADILEMMA'),
#  ('Les Canadiens', 'MONTREAL'),
#  ('Paul Newman film', 'SLAPSHOT'),
#  ("Parson's role", 'UNITER'),
#  ('Actress Clare ___', 'NONO'),
#  ('"O sole ___"', 'MIO'),
#  ('In a shy way', 'COYLY'),
#  ('Experiment', 'TRIAL'),
#  ('Remote telecasts', 'NEMOS'),
#  ('N.H.L. player', 'NYRANGER'),
#  ('Kinship', 'RELATION'),
#  ('Refinement', 'ELEGANCE'),
#  ('Worship', 'VENERATE'),
#  ('More sluggish', 'LOGIER'),
#  ('Argot', 'CANT'),
#  ('Set a dog on', 'SIC'),
#  ('Release, in a way', 'PAROLE'),
#  ('Kin of a demitasse', 'TEACUP'),
#  ('Hemingway or Lehman', 'ERNEST'),
#  ("Pee Wee's family", 'REESES'),
#  ('Paste-on', 'DECAL'),
#  ('Poet Wilbur\'s "Walking to ___"', 'SLEEP'),
#  ('"The Mask ___ Manchu," Karloff film', 'OFFU'),
#  ('Kind of picker', 'NIT'),
#  ('Modernist', 'NEO'),
#  ('Tater', 'SPUD'),
#  ('Start of a palindrome', 'MADAM'),
#  ('Figurehead site', 'PROW'),
#  ('Silent one', 'HARPO'),
#  ('Mata ___', 'HARI'),
#  ('Yankee Conference town', 'ORONO'),
#  ('Piquant', 'RACY'),
#  ('"Yond Cassius has ___ and hungry look": Julius Caesar', 'ALEAN'),
#  ("President's vision?", 'EISENHOWERSEYES'),
#  ('You can get a rise out of it', 'YEAST'),
#  ('High spots', 'PLATEAUS'),
#  ('Dances for Desi', 'RUMBAS'),
#  ('Mario Cuomo, e.g.', 'EXGOV'),
#  ('Fraternity letters', 'XIS'),
#  ('Lasting forever', 'EONIAN'),
#  ('Red ___', 'SEA'),
#  ("President's bird?", 'VANBURENSWREN'),
#  ('Spoiled child, perhaps', 'WHINER'),
#  ('Athletic type, supposedly', 'ARIES'),
#  ('Bones, in anatomy', 'OSSA'),
#  ('Architectural flute', 'STRIA'),
#  ('___-mo', 'SLO'),
#  ('Innocent, e.g.', 'POPE'),
#  ('Stable locks', 'MANE'),
#  ('Place to buy a pie', 'PIZZERIA'),
#  ('Prankster', 'IMP'),
#  ("President's injuries?", 'NIXONSNICKS'),
#  ('___-Unis', 'ETATS'),
#  ('Parts of a baseball schedule', 'DAYGAMES'),
#  ('Archenemies, maybe', 'NEMESES'),
#  ("Czar's reply to protesters", 'NYET'),
#  ('Broad sash', 'OBI'),
#  ("Flaubert's birthplace", 'ROUEN'),
#  ('___ Khan', 'AGA'),
#  ('Shot, e.g.', 'AMMO'),
#  ('They do the thinking', 'CEREBRA'),
#  ('Superiors', 'ABBESSES'),
#  ('Bar at night, perhaps', 'ROOST'),
#  ("President's testament?", 'WILSONSWILL'),
#  ('Annex', 'ELL'),
#  ('Banker types', 'MONEYMEN'),
#  ('London gallery', 'TATE'),
#  ('Spring time in Lisbon', 'MAIO'),
#  ("Boston's Bobby", 'ORR'),
#  ('___ Prayer', 'LORDS'),
#  ('Leave a mark on', 'SCAR'),
#  ('Big garden products brand', 'ORTHO'),
#  ('Look into again, as a case', 'REOPEN'),
#  ("President's takeover?", 'COOLIDGESCOUP'),
#  ('Misjudge', 'ERR'),
#  ('Fictional weaver', 'MARNER'),
#  ('Mouths', 'ORA'),
#  ('Does high-tech surgery, in a way', 'LASES'),
#  ('One of the Brady bunch', 'MARCIA'),
#  ("Baby's pastime", 'PEEKABOO'),
#  ('Protected bird', 'EGRET'),
#  ("President's weapon?", 'BUCHANANSCANNON'),
#  ('Rice-___', 'ARONI'),
#  ('"...___ saw Elba"', 'EREI'),
#  ('"Let ___ Cake"', 'EMEAT'),
#  ('Bewilder', 'DAZE'),
#  ("Part of a ship's bow", 'HAWSE'),
#  ('Reddish-brown gem', 'SARD'),
#  ('One-sided tilts', 'ROUTS'),
#  ('Victory, to Wagner', 'SIEG'),
#  ('Popular dog name', 'SHEP'),
#  ('Easter egg hunt sight', 'PAIL'),
#  ('Constellation animal', 'URSA'),
#  ('Plan to take off', 'DIET'),
#  ('Angora', 'MOHAIR'),
#  ('Sound reveille', 'AROUSE'),
#  ('Gives, old-style', 'DOWS'),
#  ('Chemical suffix', 'ANE'),
#  ('The mornings after', 'MORROWS'),
#  ('Early infant: Var.', 'PREMIE'),
#  ('Some shades', 'RAYBANS'),
#  ('Kind of liner', 'OCEAN'),
#  ('"Swiss Family Robinson" author Johann', 'WYSS'),
#  ("President's fog?", 'HAYESHAZE'),
#  ("Nikita's successor", 'ALEXEI'),
#  ("President's beam?", 'REAGANSRAY'),
#  ('El ___', 'PASO'),
#  ('Airing', 'ONTV'),
#  ('Link', 'NEXUS'),
#  ('Noted jazz bandleader', 'SUNRA'),
#  ('Nordrhein-Westfalen city', 'ESSEN'),
#  ('Hardly stimulating', 'VAPID'),
#  ('Bouquet', 'AROMA'),
#  ('Surprisingly cold', 'NIPPY'),
#  ('Busy one', 'BEE'),
#  ('Etiquette subjects', 'NONOS'),
#  ('Emerald City V.I.P., with "the"', 'WIZ'),
#  ('Bluebloods', 'ELITE'),
#  ('Get hot under the collar?', 'ROAST'),
#  ('Some rtes.', 'TPKS'),
#  ('Upswing', 'RISE'),
#  ('Ape', 'MIMIC'),
#  ('Pink-slip', 'AXE'),
#  ('Old-fashioned heating devices', 'ETNAS'),
#  ('Apprehend', 'NAB'),
#  ('Aloof ones', 'SNOBS'),
#  ('Prefix with modulator', 'NEURO'),
#  ("Stammerer's phrase", 'IMEAN'),
#  ('The 21st, e.g.: Abbr.', 'CEN'),
#  ('Dinner for the Cratchits', 'GOOSE'),
#  ('Mercury model', 'SABLE'),
#  ('Electrical unit', 'REL'),
#  ('Goop', 'GEL'),
#  ('Hardwear?', 'ARMOR'),
#  ('Often-recited Christmas poet', 'MOORE'),
#  ("President's line?", 'MONROESROW'),
#  ('Pitcher', 'EWER'),
#  ('Unwanted coat?', 'RIND'),
#  ('Honor', 'AWARD'),
#  ('Snippet', 'BIT'),
#  ('Alliance until 1977', 'SEATO'),
#  ('Root of diplomacy', 'ELIHU'),
#  ('Single-master', 'SLOOP'),
#  ("President's article of apparel?", 'TYLERSTIE'),
#  ('Flight path', 'STAIR'),
#  ('Fed. holiday, often', 'MON'),
#  ('"Happy Days" father, informally', 'MRC'),
#  ('Less available', 'SCARCER'),
#  ('Actress Braga', 'SONIA'),
#  ('Maid', 'CLEANER'),
#  ("Expo '70 site", 'OSAKA'),
#  ("Shows pride in one's appearance", 'PREENS'),
#  ('Corsage staple', 'ORCHID'),
#  ('Attacks', 'GOESAT'),
#  ('Founds', 'ERECTS'),
#  ('Spanish actress Carmen ___', 'MAURA'),
#  ('Mother of Judah', 'LEAH'),
#  ('Where Shah Jahan is entombed', 'AGRA'),
#  ('U.K. honors', 'MBES'),
#  ('French tire', 'PNEU'),
#  ('Common conjunctions', 'ANDS'),
#  ('Sons of, to a sabra', 'BNAI'),
#  ('Seep', 'OOZE'),
#  ('Standard force', 'ONEG'),
#  ('"Yo te ___"', 'AMO'),
#  ('Distorts', 'WARPS'),
#  ('Iranian ruler', 'SHAH'),
#  ('Fellow', 'CHAP'),
#  ('Rousseau classic', 'EMILE'),
#  ('Code word for K', 'KILO'),
#  ('Leg covering', 'HOSE'),
#  ('Carney, Linkletter, Buchwald and four more', 'SEVENLIVELYARTS'),
#  ('Put great value on', 'TREASURE'),
#  ('___ Horn, English breed of sheep', 'DORSET'),
#  ('Do a laundry job', 'SORT'),
#  ('Those with a coo or a moue', 'POUTERS'),
#  ('Tainted', 'IMPURE'),
#  ('Black suit', 'CLUBS'),
#  ('Coconut fiber', 'COIR'),
#  ("Johnny Bench's station", 'PLATE'),
#  ('Gab at length', 'JAW'),
#  ('Unlikely Hollywood rift', 'HOPEAGAINSTHOPE'),
#  ('U.S. Indian', 'UTE'),
#  ('Flicker', 'BLINK'),
#  ('Depression figure', 'OKIE'),
#  ('Move stealthily', 'SLINK'),
#  ('Sewing item', 'THREAD'),
#  ('Lot', 'FORTUNE'),
#  ('Field worker', 'HOER'),
#  ('Most frigid', 'ICIEST'),
#  ('How brats behave', 'TERRIBLY'),
#  ('Buttons, Pearl and Ben', 'REDWHITEANDBLUE'),
#  ('Trainbearer', 'PAGE'),
#  ('Have to have', 'NEED'),
#  ('Mezzo-soprano Obraztsova', 'ELENA'),
#  ('United', 'ONED'),
#  ('Like venison', 'GAMY'),
#  ('Exclude', 'DEBAR'),
#  ('Bridge seat', 'WEST'),
#  ('Part of N.A.', 'AMER'),
#  ('Cleave', 'RIVE'),
#  ("Hedonist's raison d'être", 'PLEASURE'),
#  ('Impulse conveyer', 'SENSOR'),
#  ('Avoid, as an issue', 'SKIRT'),
#  ('Apiary sight', 'HIVE'),
#  ('Stout', 'ALE'),
#  ('Nonsigners in spring', 'HOLDOUTS'),
#  ('Followers of eye and pie', 'CHARTS'),
#  ('Morgan or Suffolk', 'HORSE'),
#  ('Michaelmas daisy', 'ASTER'),
#  ('Aphids, ticks, etc.', 'PESTS'),
#  ("Troller's roller", 'LURE'),
#  ('"Sure thing!"', 'YOUBET'),
#  ('Part of a platform', 'PLANK'),
#  ('Valuable Andes grass', 'ICHU'),
#  ('Unresolved', 'MOOT'),
#  ('Calumet', 'PIPE'),
#  ('Hoosegow', 'CLINK'),
#  ("Robert Treat ___, patriot of '76", 'PAINE'),
#  ('Wisecrack', 'JOKE'),
#  ('Samoan port', 'APIA'),
#  ('Knawel or spurry', 'WEED'),
#  ('Embarrassed', 'ABLUSH'),
#  ('Asparkle', 'GLINTING'),
#  ('Ghastly', 'HORRIBLE'),
#  ('___ tomatoes', 'STEWED'),
#  ('Undecided', 'TORN'),
#  ('Came together, as elephants', 'HERDED'),
#  ('Heavyweight Luis', 'FIRPO'),
#  ('Indian, for one', 'OCEAN'),
#  ('Elevation between valleys', 'RIDGE'),
#  ('Intoxicating', 'HEADY'),
#  ('Rain cats and dogs', 'TEEM'),
#  ('Blister', 'BLEB'),
#  ('Moth or Park', 'LUNA'),
#  ('Part of I.G.Y.', 'YEAR'),
#  ('Oopak is one', 'TEA'),
#  ('Confectioneries, e.g.', 'SHOPS'),
#  ('Make a pinch', 'NAB'),
#  ('"Save ___ from his friends . . . ": Hazlitt', 'AMAN'),
#  ('Cute marsupial', 'KOALA'),
#  ('Lucid', 'SANE'),
#  ('Acronym born 4/4/49', 'NATO'),
#  ('Elia product', 'ESSAY'),
#  ('Staleness', 'MUST'),
#  ('Wife of Osiris', 'ISIS'),
#  ('Drinks', 'WETSONESWHISTLE'),
#  ("Kerry's county seat", 'TRALEE'),
#  ('Egg depositories', 'NESTS'),
#  ('Track of a cat', 'WAKE'),
#  ('Dazzled', 'GLARED'),
#  ('Accelerator of maturation', 'AGER'),
#  ('Like Socrates', 'ERUDITE'),
#  ('Mulligatawny vessels', 'TUREENS'),
#  ('He wrote "Jennie Gerhardt"', 'DREISER'),
#  ('Rock formation', 'TERRANE'),
#  ('Become a stool pigeon', 'SING'),
#  ('Preventer of many a strike', 'TENPIN'),
#  ('Part of A.D.', 'ANNO'),
#  ("Pyromaniac's offense", 'ARSON'),
#  ('Dogmata', 'TENETS'),
#  ('Begins', 'GETSONESFEETWET'),
#  ('Rimbaud\'s "his"', 'ALUI'),
#  ('Penny follower', 'ANTE'),
#  ('"A Guide to Confident Living" author', 'PEALE'),
#  ('Opportune', 'RIPE'),
#  ('Preserver of produce on a RR', 'ICER'),
#  ('Pyle of the Fourth Estate', 'ERNIE'),
#  ('Vestige', 'SCAR'),
#  ('Chemin de ___', 'FER'),
#  ('Ferrara rulers for several centuries', 'ESTES'),
#  ('Distort', 'SKEW'),
#  ('Plus-fours accompaniment', 'HOSE'),
#  ('Drier of a sort', 'OAST'),
#  ('Billboard worker', 'PLASTERER'),
#  ('" . . . solicitous what men will ___ think": Hale', 'SAYOR'),
#  ("Sartre's first novel", 'NAUSEA'),
#  ('Was liable, with "for"', 'ANSWERED'),
#  ('Playwright Henley', 'BETH'),
#  ('Licorice-flavored seed', 'ANISE'),
#  ('Spinnaker supports', 'MASTS'),
#  ("Like Pisa's oddity", 'ATILT'),
#  ('Pushes forward cautiously', 'NOSES'),
#  ('Odor', 'SMELL'),
#  ('Gee-gee', 'NAG'),
#  ('___ course (at the right time)', 'INDUE'),
#  ('Power unit', 'WATT'),
#  ('Chill', 'AGUE'),
#  ('Noted drama critic', 'KERR'),
#  ('Stray', 'ERR'),
#  ('Calamities', 'DISASTERS'),
#  ('"Love ___ the Air," 1978 tune', 'ISIN'),
#  ('Ky. neighbor', 'TENN'),
#  ('Hence, to Hadrian', 'ERGO'),
#  ('"His wife could ___ lean"', 'EATNO'),
#  ('Compass point', 'NNE'),
#  ('Life, e.g.', 'SENTENCE'),
#  ('Vex', 'PESTER'),
#  ('Deduce', 'INFER'),
#  ('Mata Hari, ___ Zelle', 'NEE'),
#  ('Food thickeners', 'AGARS'),
#  ('Keepsake', 'RELIC'),
#  ('Buddhist shrine', 'STUPA'),
#  ('Twig for basketry', 'OSIER'),
#  ('Conical structure', 'TEPEE'),
#  ('Credulous', 'NAIF'),
#  ('Desire', 'WANT'),
#  ('Composer Siegmeister', 'ELIE'),
#  ('Links items', 'TEES'),
#  ('Flexible, electrically', 'ACDC'),
#  ('Desert plants', 'CACTI'),
#  ('For fear that', 'LEST'),
#  ("Prisoner's knife", 'SHIV'),
#  ('Be ___ in the neck', 'APAIN'),
#  ('"Even ___ speak ..."', 'ASWE'),
#  ('Cab', 'TAXI'),
#  ('Window features', 'PANES'),
#  ('One at the computer', 'USER'),
#  ('Agent Gold of HBO\'s "Entourage"', 'ARI'),
#  ('Japanese sleuth Mr. ___', 'MOTO'),
#  ('Primp', 'PREEN'),
#  ('2000 De Niro/Stiller comedy', 'MEETTHEPARENTS'),
#  ('"Mighty" man who struck out', 'CASEY'),
#  ('Not written, as a test', 'ORAL'),
#  ('Makes mistakes', 'ERRS'),
#  ('Pleased', 'GLAD'),
#  ('"___ Pinafore"', 'HMS'),
#  ('Basic, as issues', 'MEATANDPOTATOES'),
#  ('Toddler', 'TOT'),
#  ('Land west of Vietnam', 'LAOS'),
#  ('Chooses', 'OPTS'),
#  ("West Germany's capital", 'BONN'),
#  ('Alternative to singles, in figure skating', 'PAIRS'),
#  ('What judges do in court', 'METEOUTJUSTICE'),
#  ('First name in W.W. II infamy', 'ADOLF'),
#  ("Commedia dell'___", 'ARTE'),
#  ('Gold, in Guadalajara', 'ORO'),
#  ('Color lightly', 'TINT'),
#  ('So yesterday', 'PASSE'),
#  ('Editing mark', 'STET'),
#  ('Suffix with kitchen', 'ETTE'),
#  ('Parisian love', 'AMOUR'),
#  ('No. on a bank statement', 'ACCT'),
#  ("Like show horses' feet", 'SHOD'),
#  ('Bedsheets, e.g.', 'LINEN'),
#  ('"___ be in England"', 'OHTO'),
#  ('"The Thin Man" dog', 'ASTA'),
#  ("The third time's said to be one", 'CHARM'),
#  ('Strom Thurmond follower of 1948', 'DIXIECRAT'),
#  ('106, to Trajan', 'CVI'),
#  ('Truman who wrote "Breakfast at Tiffany\'s"', 'CAPOTE'),
#  ('Lack of interest', 'APATHY'),
#  ('Something to paddle', 'CANOE'),
#  ('Even score', 'TIE'),
#  ('Ones who are elected', 'INS'),
#  ("Winner's wreath", 'LAUREL'),
#  ('German steel city', 'ESSEN'),
#  ('Bonbon, e.g.', 'SWEET'),
#  ('Shorebirds', 'TERNS'),
#  ('The Appalachians, e.g.: Abbr.', 'MTS'),
#  ('"The Devil Wears ___"', 'PRADA'),
#  ('Sunrise direction', 'EAST'),
#  ('Explorer Marco', 'POLO'),
#  ('"I smell ___"', 'ARAT'),
#  ('Ambulance worker, for short', 'EMT'),
#  ('___ Speed Wagon (old vehicle)', 'REO'),
#  ('Auto gizmo that talks, in brief', 'GPS'),
#  ('Sidewalk game with chalk', 'HOPSCOTCH'),
#  ('Big Apple museum, with "the"', 'MET'),
#  ('Sizzling sound', 'SSS'),
#  ('Standoffish', 'ALOOF'),
#  ("Half of Mork's goodbye", 'NANU'),
#  ('Advice regarding touching a hot stove', 'DONT'),
#  ('Actress Spelling', 'TORI'),
#  ('Sang loudly, with "out"', 'BELTED'),
#  ('Chase', 'PURSUE'),
#  ('To the rear, on a ship', 'ASTERN'),
#  ('Suffix with Israel or Manhattan', 'ITE'),
#  ('Spouses', 'MATES'),
#  ('Singer Piaf', 'EDITH'),
#  ("The Lone Ranger's faithful friend", 'TONTO'),
#  ('Bourne of "The Bourne Identity"', 'JASON'),
#  ('Build', 'ERECT'),
#  ("Sgt. Snorkel's four-legged friend", 'OTTO'),
#  ('Friend', 'PAL'),
#  ('French friend', 'AMI'),
#  ('___ Paulo, Brazil', 'SAO'),
#  ('It goes from stem to stern', 'KEEL'),
#  ('Ten Commandments word', 'SHALT'),
#  ('Companion of OIlie', 'FRAN'),
#  ('Dancer Pavlova', 'ANNA'),
#  ('Champing at the bit', 'EAGER'),
#  ('A billion years', 'AEON'),
#  ('Con game', 'SCAM'),
#  ('Vacant', 'INANE'),
#  ('Soap unit', 'CAKE'),
#  ("Stoves that don't work?", 'BOMBINGRANGES'),
#  ('"Diamonds _____ a girl\'s ..."', 'ARE'),
#  ('"Gidget" star', 'DEE'),
#  ('Perform perfectly', 'DOTOAT'),
#  ("Hagar the Horrible's honey", 'HELGA'),
#  ('It was banned in 1973', 'DDT'),
#  ('Beatniks beat it', 'BONGO'),
#  ('Interjections', 'OHS'),
#  ('_____ in apple', 'AAS'),
#  ('lamb and dactyl', 'FEET'),
#  ('Filming actors?', 'SHOOTINGSTARS'),
#  ('Pasture sounds', 'BAAS'),
#  ('Carl of baseball, informally', 'YAZ'),
#  ('Tic-toe bridge', 'TAC'),
#  ('Lady _____, founder of the Girl Guides', 'AGNES'),
#  ('Trouble in France', 'MAL'),
#  ('Frame', 'SETUP'),
#  ('Itch initiator', 'REDBUG'),
#  ('Partake of', 'EAT'),
#  ('Calendar abbr.', 'APR'),
#  ('Arson?', 'BURNINGDESIRE'),
#  ('West of Gotham City', 'ADAM'),
#  ('"I\'m _____ duck"', 'ADEAD'),
#  ('_____ hemp (fiber plant)', 'ALOE'),
#  ('"I Spy" star', 'CULP'),
#  ('List of candidates', 'SLATE'),
#  ('It may come with points', 'LOAN'),
#  ('Grown-up grigs', 'EELS'),
#  ('Biblical king with 10 wives', 'HEROD'),
#  ('Muffs', 'ERRS'),
#  ('North African fortress', 'KASBAH'),
#  ('Concert cry', 'ENCORE'),
#  ('Filling surrounder', 'ENAMEL'),
#  ('"Mrs. Battle\'s Opinions on Whist" writer', 'LAMB'),
#  ('Ile de la Cite site', 'SEINE'),
#  ('The _____ Man (tarot card)', 'HANGED'),
#  ('Actor John', 'AGAR'),
#  ('First name in supper club entertainment', 'LENA'),
#  ('Drift', 'TREND'),
#  ('Not at a distance', 'FACETOFACE'),
#  ('Logician', 'REASONER'),
#  ('Flight approval', 'AOK'),
#  ("22° 30'", 'NNE'),
#  ('Baking potato', 'IDAHO'),
#  ('Lump', 'GOB'),
#  ('"Rock of _____"', 'AGES'),
#  ("Young 'un", 'TOT'),
#  ('Thrilled response', 'GOOSEBUMPS'),
#  ('Tony of "Who\'s the Boss?"', 'DANZA'),
#  ('License', 'TAG'),
#  ('Pen', 'STY'),
#  ('Trans-Atlantic flier', 'SST'),
#  ('Emerson, The _____ of Concord', 'SAGE'),
#  ('Game originally called "fives"', 'HANDBALL'),
#  ('Descartes conclusion', 'IAM'),
#  ('Fashion', 'TASTE'),
#  ("Sot's spot", 'BAR'),
#  ('Big _____, Calif.', 'SUR'),
#  ('Not staccato', 'LEGATO'),
#  ('A sew-and-sew?', 'TAILOR'),
#  ('Hubbub', 'UPROAR'),
#  ('Is foppish', 'PREENS'),
#  ('Grind', 'GNASH'),
#  ('Kind of attraction', 'ADDED'),
#  ('Run in place', 'IDLE'),
#  ('About', 'NEAR'),
#  ('No_____ (register button)', 'SALE'),
#  ('Plane downer', 'ACE'),
#  ('Like threatening bills', 'DUE'),
#  ('Grateful?', 'ASHES'),
#  ('Way off', 'AFAR'),
#  ("Fitted at the smithy's", 'SHOD'),
#  ('Forestall, with "off"', 'STAVE'),
#  ('All-or-___', 'NONE'),
#  ('Hefty volume', 'TOME'),
#  ('Divided land', 'KOREA'),
#  ('Garden access', 'GATE'),
#  ('Havoc', 'RUIN'),
#  ('Carney and Garfunkel', 'PERFORMINGARTS'),
#  ('"___ takers?"', 'ANY'),
#  ('Not of the cloth', 'LAY'),
#  ('Blazing', 'AGLARE'),
#  ('Turn, as pancakes', 'FLIP'),
#  ('Bit of baloney', 'FIB'),
#  ('Man of Steel portrayer', 'REEVE'),
#  ('Tram loads', 'ORES'),
#  ('Enter only up to the ankles, say', 'WADE'),
#  ('Clinton and Bradley', 'GOVERNMENTBILLS'),
#  ('Lyric poetry', 'ODES'),
#  ('Vittles', 'EATS'),
#  ('Money in the bank, e.g.', 'ASSET'),
#  ('Fore site?', 'TEE'),
#  ('Zillions', 'TONS'),
#  ('Kennel club categories', 'BREEDS'),
#  ('Half a sawbuck', 'FIN'),
#  ("Sculler's need", 'OAR'),
#  ('Robinson and Thomas', 'BALLPARKFRANKS'),
#  ('Reed in a pit', 'OBOE'),
#  ("Drinker's spree", 'TOOT'),
#  ('Checkroom items', 'COATS'),
#  ('Microwave', 'NUKE'),
#  ('Up to it', 'ABLE'),
#  ("Nairobi's land", 'KENYA'),
#  ("Porter's regretful Miss", 'OTIS'),
#  ("Like Jack Sprat's diet", 'LEAN'),
#  ('Shuteye', 'SLEEP'),
#  ('"Don\'t ___" (comment after a bad day)', 'ASK'),
#  ('Station', 'STOP'),
#  ('Relative of a rabbit', 'HARE'),
#  ('Ending with "for" or "what"', 'EVER'),
#  ('Columbus, e.g.', 'SEAFARER'),
#  ('Ticked off', 'ANGRY'),
#  ('Brew topper', 'FOAM'),
#  ('Nay sayer', 'ANTI'),
#  ('Do another hitch', 'REENLIST'),
#  ('Leave the herd', 'STRAY'),
#  ('Lesson duration, often', 'HOUR'),
#  ('Pass over', 'OMIT'),
#  ("Bears' lairs", 'DENS'),
#  ('Fraction of a 46-Across', 'ONE'),
#  ('Popular clothing store, with "The"', 'GAP'),
#  ('Shoptalk', 'ARGOT'),
#  ('Crystal-lined rock', 'GEODE'),
#  ('Flood insurance of sorts', 'LEVEE'),
#  ("Class that's for the birds", 'AVES'),
#  ('Fingerboard ridges', 'FRETS'),
#  ('Monocle part', 'LENS'),
#  ('"F" on a quiz', 'FALSE'),
#  ('Puttered around', 'IDLED'),
#  ('Outdoes in competition', 'BESTS'),
#  ('Gulf sultanate', 'OMAN'),
#  ('Like Solomon', 'WISE'),
#  ('Just-born', 'NEONATAL'),
#  ("Recruit's home", 'BARRACKS'),
#  ('Bit of advice', 'TIP'),
#  ('Slot machine symbol', 'BAR'),
#  ('Hightails it', 'FLEES'),
#  ('"Come here ___?"', 'OFTEN'),
#  ("U2's frontman", 'BONO'),
#  ('Border on', 'ABUT'),
#  ('Evil Norse god', 'LOKI'),
#  ('Choir garb', 'ROBE'),
#  ('Caffeine source', 'KOLA'),
#  ('"Joyeux ___" (French greeting)', 'NOEL'),
#  ('Classic Welles role', 'KANE'),
#  ('Eyelid woe', 'STYE'),
#  ('Chucklehead', 'SAP'),
#  ('Rapscallions', 'IMPS'),
#  ('Kind of car', 'SQUAD'),
#  ('Squabble', 'SPAT'),
#  ('Society news', 'GALA'),
#  ('Weird', 'OUTRE'),
#  ('Slip (into)', 'EASE'),
#  ('Zing', 'ELAN'),
#  ('Instruction for murder?', 'DIALM'),
#  ('Part of the Walt Disney Co.', 'ESPN'),
#  ('Beginning of a quip', 'TACTISTHEUNSAID'),
#  ('Bean sprouts?', 'IDEAS'),
#  ('Sign of success', 'SRO'),
#  ('Some Harvard grads: Abbr.', 'DRS'),
#  ("Baseball's Cobb and others", 'TYS'),
#  ('Stumblebum', 'LOUT'),
#  ('Bread choice', 'WHEAT'),
#  ('Phrase on a party invitation', 'BETHERE'),
#  ('Part of A.D.', 'ANNO'),
#  ('More of the quip', 'PORTIONOFWHAT'),
#  ('French film', 'CINE'),
#  ('"Backroads" singer Ricky Van ___', 'SHELTON'),
#  ('Actress Tatum', 'ONEAL'),
#  ('Dry run', 'TEST'),
#  ('New Deal org.', 'WPA'),
#  ('Prime-time hrs.', 'PMS'),
#  ('One of the Gabors', 'EVA'),
#  ('Chalk-colored', 'ASHEN'),
#  ('End of the quip', 'YOUWERETHINKING'),
#  ('Actress Swenson', 'INGA'),
#  ('"The Silence of the Lambs" releaser', 'ORION'),
#  ('Brahms\'s "___ Rhapsody"', 'ALTO'),
#  ('Do a caulking job', 'SEAL'),
#  ('Seeing pink elephants', 'OILED'),
#  ('Shed item', 'TEAR'),
#  ('Phoenician trading center', 'TYRE'),
#  ('Paris underground', 'METRO'),
#  ('Old Icelandic literary work', 'EDDA'),
#  ('Words said with a nod', 'IGETIT'),
#  ('Food poisoning, e.g.', 'MALADY'),
#  ('Cry to actors on a set', 'PLACES'),
#  ('Man in a red-and-white suit', 'SANTA'),
#  ('Poor blokes', 'SODS'),
#  ('Throw in the towel', 'QUIT'),
#  ('Area code 801 locale', 'UTAH'),
#  ('City on the Rhone', 'ARLES'),
#  ('Take exception', 'DEMUR'),
#  ('Eyeballs', 'SEES'),
#  ('Place for a bowl', 'PASADENA'),
#  ('Wannabe', 'ASPIRANT'),
#  ('Takes care of', 'TENDSTO'),
#  ('Spot in the ocean', 'ISLET'),
#  ("Parent's order", 'NOW'),
#  ('Singer Redding', 'OTIS'),
#  ('"Oops..."', 'UHOH'),
#  ('Dogma', 'TENET'),
#  ('Chemistry Nobelist Otto', 'HAHN'),
#  ('La ___ tar pits', 'BREA'),
#  ('Rocky, for Stallone', 'ROLE'),
#  ('Newts', 'EFTS'),
#  ('Amount for film tickets and such', 'PINMONEY'),
#  ('Coffee order', 'ONESUGAR'),
#  ('Teutonic war god', 'WOTAN'),
#  ('Scribe', 'COPYIST'),
#  ('Sheltered side', 'LEE'),
#  ('Frittered (away)', 'WHILED'),
#  ('Half a decade', 'PENTAD'),
#  ('Wool type', 'ANGORA'),
#  ('Indy 500 sound', 'VROOM'),
#  ('Where to live the high life?', 'AERIE'),
#  ('Play for the Bruins, say', 'SKATE'),
#  ('Whip mark', 'WALE'),
#  ('Sudden game ending', 'TILT'),
#  ('One with ground strokes?', 'HOER'),
#  ('Prefix with European', 'INDO'),
#  ('NATO agreement, e.g.', 'PACT'),
#  ('Fred or Steve', 'ALLEN'),
#  ('Patty ___ Astin', 'DUKE'),
#  ('Wreath for Lancelot', 'ORLE'),
#  ("Rudy Vallee's alma mater", 'MAINE'),
#  ('In a snit', 'IRED'),
#  ('Secular', 'LAIC'),
#  ('Vinegary: Comb. form', 'ACETO'),
#  ('Toe the ___', 'LINE'),
#  ('Teemed', 'ABOUNDED'),
#  ('Charles ___ Reilly', 'NELSON'),
#  ('Happen upon', 'MEET'),
#  ('Swiss stream', 'AARE'),
#  ('He of the "lean and hungry look"', 'CASSIUS'),
#  ('___ Garter, famous London tavern', 'STARAND'),
#  ('City on the Somme', 'AMIENS'),
#  ('Competes', 'VIES'),
#  ('Ess follower', 'TEE'),
#  ("Chaucer's Wife of ___", 'BATH'),
#  ('Ovine sound', 'MAA'),
#  ("It won't buy much in Torino", 'LIRA'),
#  ('Gold, in Granada', 'ORO'),
#  ('Plant shoot', 'CION'),
#  ('Samuel ___ Coleridge', 'TAYLOR'),
#  ('Bicycles built for two', 'TANDEMS'),
#  ('Elegant', 'COURTLY'),
#  ("End of an O'Neill title", 'ELMS'),
#  ("Gudrun's spouse", 'ATLI'),
#  ('Slender and graceful', 'SVELTE'),
#  ('In an unimpaired state', 'INTACTLY'),
#  ('Part of N.B.', 'NOTA'),
#  ('John ___ Garner', 'NANCE'),
#  ('Handmaiden in a W.S. play', 'IRAS'),
#  ('Chester ___ Arthur', 'ALAN'),
#  ('Guitar of India', 'SITAR'),
#  ('Certain', 'SURE'),
#  ('Item to spend in Acapulco', 'PESO'),
#  ('Certain jackets', 'ETONS'),
#  ('Spree', 'TEAR'),
#  ('Actress Negri of silents', 'POLA'),
#  ('Fine horse', 'ARAB'),
#  ...]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (845399, 847)

# %%
# Vectorize Clues
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(strip_accents="unicode", stop_words="english")
X_train = vectorizer.fit_transform(np.array(clues_train))
X_train

# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)
# Out:
# <845399x76988 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1755848 stored elements in Compressed Sparse Row format>

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors().fit(X_train)
model
# Out:
# NearestNeighbors()

# %%
# Define a guesser function
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector = vectorizer.transform([clue])
    distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
    raw_guesses = [answers_train[i] for i in indices[0]]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue.lower()
        return o
    
    guesses = [g for g in raw_guesses if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
i = random.randint(0, len(clues_test))
test_clue, test_answer = clues_test[i], answers_test[i]
print("clue:", test_clue)
print("answer:", test_answer)

# distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# print("guesses:", [answers_train[i] for i in indices[0]])

guesses = guess(test_clue, slot_length=len(test_answer))
print("guesses:", guesses)
# Out:
# clue: Noted missile range site
# answer: WHITESANDS
# guesses: ['WHITESANDS']

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
    if i % 100 == 0: print(i)
    guesses = guess(clue, len(answer), max_guesses=5)
    if answer in guesses:
        correct_pairs.append((clue, answer, guesses))
    else:
        incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4348/2740350629.py in <module>
#       4 for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
#       5     if i % 100 == 0: print(i)
# ----> 6     guesses = guess(clue, len(answer), max_guesses=5)
#       7     if answer in guesses:
#       8         correct_pairs.append((clue, answer, guesses))
#
# ~\AppData\Local\Temp/ipykernel_4348/1894279841.py in guess(clue, slot_length, max_guesses, max_guesses_raw)
#       2 def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
#       3     clue_vector = vectorizer.transform([clue])
# ----> 4     distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
#       5     raw_guesses = [answers_train[i] for i in indices[0]]
#       6     # print([clues_train[i] for i in indices[0]])
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     747                 kwds = self.effective_metric_params_
#     748
# --> 749             chunked_results = list(
#     750                 pairwise_distances_chunked(
#     751                     X,
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1710         else:
#    1711             X_chunk = X[sl]
# -> 1712         D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1713         if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1714             metric, None
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1882         func = partial(distance.cdist, metric=metric, **kwds)
#    1883
# -> 1884     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1885
#    1886
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1423
#    1424     if effective_n_jobs(n_jobs) == 1:
# -> 1425         return func(X, Y, **kwds)
#    1426
#    1427     # enforce a threading backend to prevent data communication overhead
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     325             )
#     326
# --> 327     return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     328
#     329
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\metrics\pairwise.py in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     366     else:
#     367         # if dtype is already float64, no need to chunk and upcast
# --> 368         distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     369         distances += XX
#     370         distances += YY
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\base.py in __matmul__(self, other)
#     558             raise ValueError("Scalar operands are not allowed, "
#     559                              "use '*' instead")
# --> 560         return self.__mul__(other)
#     561
#     562     def __rmatmul__(self, other):
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     478             if self.shape[1] != other.shape[0]:
#     479                 raise ValueError('dimension mismatch')
# --> 480             return self._mul_sparse_matrix(other)
#     481
#     482         # If it's a list or whatever, treat it like a matrix
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\compressed.py in _mul_sparse_matrix(self, other)
#     499
#     500         major_axis = self._swap((M, N))[0]
# --> 501         other = self.__class__(other)  # convert to this format
#     502
#     503         idx_dtype = get_index_dtype((self.indptr, self.indices,
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      32                 arg1 = arg1.copy()
#      33             else:
# ---> 34                 arg1 = arg1.asformat(self.format)
#      35             self._set_self(arg1)
#      36
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\base.py in asformat(self, format, copy)
#     320             # Forward the copy kwarg, if it's accepted.
#     321             try:
# --> 322                 return convert_method(copy=copy)
#     323             except TypeError:
#     324                 return convert_method()
#
# e:\Misc\Crossword-Puzzle-Solver\env\lib\site-packages\scipy\sparse\csc.py in tocsr(self, copy)
#     139         data = np.empty(self.nnz, dtype=upcast(self.dtype))
#     140
# --> 141         csc_tocsr(M, N,
#     142                   self.indptr.astype(idx_dtype),
#     143                   self.indices.astype(idx_dtype),
#
# KeyboardInterrupt:

# %%
incorrect_pairs
# Out:
# [('Christmas décor item', 'MISTLETOE', ['WALLPAPER']),
#  ('Gives off fumes', 'REEKS', ['STEWS', 'VAPOR', 'STEWS', 'AREEK', 'RAGES']),
#  ('Vehicle in a spiritual', 'CHARIOT', ['ORECART']),
#  ('Unmanned aircraft', 'DRONES', ['ALBEIT', 'ENGINE']),
#  ('Dir. from Milan to Udine', 'ENE', ['SIG', 'TAB', 'EAT', 'OUR', 'PRO']),
#  ('Fishing spot for Scots', 'LOCH', ['PIER', 'PIER', 'PIER', 'AULD', 'COVE']),
#  ('Interrogate', 'GRILL', ['LEGIT', 'DENSE', 'AMPLE', 'ALIEN', 'ELITE']),
#  ('Nose part', 'ALARE', ['NARIS', 'SNOOP', 'SNOOT', 'NASAL', 'SMELL']),
#  ('Car part', 'TAILPIPE', ['RADIATOR']),
#  ("Gaby's spouse", 'MARI', ['MATE', 'MATE', 'MATE', 'MATE', 'MATE']),
#  ('Former Chinese monetary unit',
#   'TAEL',
#   ['ANNA', 'LIRA', 'LIRA', 'LIRA', 'LIRA']),
#  ('Off the leash', 'LOOSE', ['STRAP', 'TWIXT', 'UNION', 'FROWN', 'STILL']),
#  ('What a "midnight ride" horse earned', 'ESTEEMOFREVERE', []),
#  ('Put money into a sinking fund',
#   'AMORTIZE',
#   ['DONATETO', 'THEMAINE', 'INTANDEM']),
#  ('"Festina lente"', 'MAKEHASTESLOWLY', []),
#  ('With 12-Down, where the fault lies?',
#   'SAN',
#   ['TOO', 'RAP', 'NAG', 'ERR', 'ERR']),
#  ('Old Dashiell Hammett radio series, with "The"',
#   'FATMAN',
#   ['ETALIA', 'ATMOST', 'IMDONE', 'STATES', 'ENTAIL']),
#  ('Susan Sontag piece',
#   'ESSAY',
#   ['CAPED', 'ENDED', 'ARGUE', 'AXIOM', 'ARGOT']),
#  ('Story mapped out in this grid, from lower left to upper right',
#   'HANSELANDGRETEL',
#   ['IVENEVERTRIEDIT']),
#  ('Vinland pioneers', 'NORSE', ['PRIOR', 'TOTAL', 'TABOO']),
#  ('Got as a result', 'REAPED', ['EFFECT', 'UPSHOT', 'LEADTO', 'CREATE']),
#  ('Emulate Errol Flynn', 'SWASHBUCKLE', []),
#  ('Ready to receive visitors, say',
#   'DECENT',
#   ['SHOWIN', 'INCEPT', 'ACCEPT', 'GUESTS', 'GUESTS']),
#  ('Fissure filler', 'ORE', []),
#  ('Create a fuss', 'ACTUP', []),
#  ('Ciphers', 'NOUGHTS', ['APPOINT']),
#  ('Credo: Part IV', 'HASA', ['VIII', 'DRIP', 'TUBE']),
#  ('Legendary English outlaw', 'CLYMOFTHECLOUGH', []),
#  ('Classical name of Troy',
#   'ILION',
#   ['ILIUM', 'HELEN', 'OUNCE', 'PRIAM', 'PRIAM']),
#  ('"A Tree Grows in Brooklyn" woman ___ Nolan',
#   'KATIE',
#   ['ATREE', 'ATREE', 'ATREE', 'ATREE', 'ATREE']),
#  ('"I Enjoy Being ___" (Rodgers and Hammerstein tune)',
#   'AGIRL',
#   ['OTHER', 'ADOPE', 'ADEER', 'IOWAY', 'OSCAR']),
#  ('Criticized severely',
#   'BASHED',
#   ['SLATED', 'PANNED', 'PANNED', 'BLAMED', 'RAPPED']),
#  ('"Impossible" activity!',
#   'PROGRAMMINGAVCR',
#   ['TRISECTTHEANGLE',
#    'SQUARETHECIRCLE',
#    'SQUARETHECIRCLE',
#    'SQUARETHECIRCLE']),
#  ('1950 film "___ Very Own"', 'OUR', ['EVE', 'IKE', 'DOA', 'DOA', 'DOA']),
#  ('" . . . ___ still a moment": Poe', 'HEARTBE', ['SHORTLY']),
#  ('Properly lined up', 'INORDER', ['ALIGNED', 'STRIATE']),
#  ('Times, e.g.', 'FONT', ['ERAS', 'AFTS', 'EVER', 'ERAS', 'EVER']),
#  ('Obstruct', 'JAM', ['DAM', 'HHH', 'ILL']),
#  ('Indonesian Buddhist', 'LAO', ['ZEN', 'ZEN', 'ZEN', 'NUN', 'ZEN']),
#  ('Iron and tin sources', 'ORES', ['WARE']),
#  ('Low area of land', 'SWALE', ['MORON', 'MORON']),
#  ('P.G.A. stop', 'DORAL', ['DETER', 'FOCAL', 'CEASE', 'DEPOT', 'CEASE']),
#  ('Decorative neckline insert', 'VESTEE', ['ENTIRE']),
#  ('Solder, say', 'JOIN', ['WELD', 'TINS', 'BARE', 'ANEW', 'WEEP']),
#  ('Org. with dens', 'BSA', ['TOP']),
#  ('Jelly Belly flavor', 'PEAR', ['FAIL', 'FOLD', 'SALT']),
#  ('Miss alternative', 'MAAM', ['LASS', 'MAID', 'LASS', 'OMIT', 'LASS']),
#  ('18-wheeler', 'BIGRIG', ['GOCART']),
#  ('Hit song of 1954', 'TEACHMETONIGHT', ['CHRISTMASWALTZ']),
#  ('Establishes', 'SETS', ['ATOP', 'ALOT', 'AMER', 'UNIT', 'ALVA']),
#  ('Totally harmless', 'GENTLEASALAMB', []),
#  ('Founder of Lower Slobovia',
#   'CAPP',
#   ['ATAD', 'AMID', 'NEED', 'DELE', 'ATOP']),
#  ('Indian and Arctic', 'OCEANS', ['FRIGID']),
#  ('Shop, for one', 'CLASS', ['STORE', 'STORE', 'STORE', 'STORE', 'SWEAT']),
#  ('This-and-that recording for a friend or a party',
#   'MIXTAPE',
#   ['WIRETAP', 'RETAPED']),
#  ('Hymn of praise', 'ALLELUIA', ['CANTICLE', 'CANTICLE']),
#  ('Adjudged', 'RULED', ['ALIAS', 'STATS', 'ALIEN', 'MINUS', 'INKED']),
#  ("Committee's concern", 'AGENDA', ['SITSON']),
#  ('Ross and Coral', 'SEAS', ['ASEA', 'ASEA', 'ASEA', 'ASEA', 'ASEA']),
#  ("Kestrel's catcher", 'TALON', ['BENCH', 'SNARE', 'SNARE', 'SNARE', 'PLATE']),
#  ('Winter quarters', 'DEN', ['ONE', 'ONE', 'BRR', 'BRR']),
#  ('Salutes, in a way',
#   'TOASTS',
#   ['GREETS', 'SALVOS', 'BATTED', 'TACKLE', 'STARVE']),
#  ('___-specific', 'AGE', []),
#  ('Church-owned newsweekly, for short', 'THEMONITOR', []),
#  ('Plebiscites', 'VOTES', ['ALIAS', 'STATS', 'ALIEN', 'MINUS', 'INKED']),
#  ('Drops', 'EBBS', ['NAPS', 'NODS', 'RAIN', 'NODS', 'NAPS']),
#  ('Answer to "You wouldn\'t believe it"',
#   'TRYME',
#   ['TENET', 'CREED', 'AXIOM', 'TENET', 'CREDO']),
#  ("Helper in preparing the govt.'s legal case",
#   'ASSTDA',
#   ['FIXING', 'LENGTH', 'UNLESS']),
#  ('At any time', 'EVER', ['THEN', 'THEN', 'WHEN', 'ALOT', 'ONCE']),
#  ('Chump change', 'PEANUTS', ['CENTAVO', 'CENTAVO', 'REPLACE']),
#  ('"Can that be true?"', 'ITIS', ['FACT', 'REAL', 'AMEN', 'FACT', 'REAL']),
#  ('Sluggish creatures',
#   'SLOTHS',
#   ['BOVINE', 'TORPID', 'LEADEN', 'TORPID', 'LEADEN']),
#  ('_____ Lilas (Paris suburb)', 'LES', ['RYE', 'ICI']),
#  ('Incomplete', 'PARTIAL', ['NOTDONE', 'SKETCHY', 'MISRUNS']),
#  ('Irrelevant', 'BESIDETHEPOINT', []),
#  ('Woman with une nièce', 'TANTE', ['MIDST', 'ENDED', 'USURP', 'RISEN']),
#  ('Bling-bling?', 'HOODORNAMENTS', []),
#  ('"Never!"', 'WHENPIGSFLY', []),
#  ('City in N.H.', 'KEENE', ['OLEAN', 'SUCRE', 'URBAN', 'OLEAN', 'OLEAN']),
#  ('Notation on an envelope', 'PERSONAL', []),
#  ('Domingo asset', 'VOICE', ['TENOR', 'TENOR', 'TENOR', 'TENOR', 'TENOR']),
#  ('C-notes', 'IOOS', ['THOU', 'REMI', 'SEES', 'SOLS', 'REMI']),
#  ('Rock piles at the peak', 'TORS', ['NAPS', 'ATON', 'SORT', 'NAPS', 'ATON']),
#  ('He wrote "The Big Clock": 1946', 'FEARING', ['STAYPUT', 'THEDOTS']),
#  ('Submitting to control', 'MANAGEABLE', []),
#  ('Catechumen', 'TYRO', ['SENT', 'ERAT', 'EMIT', 'ERST', 'ACCS']),
#  ('Certain paintings', 'LANDSCAPES', ['STILLLIFES']),
#  ('Treats for horses',
#   'APPLES',
#   ['PACERS', 'TBONES', 'TBONES', 'HIPPOS', 'STABLE']),
#  ('Interjection of disinterest', 'MEH', ['BAH', 'FDR', 'OPT', 'NET', 'HER']),
#  ('1996 Olympic tennis gold medalist',
#   'AGASSI',
#   ['DEVERS', 'TESSAS', 'IM#ONE', 'ASHTON', 'JOYNER']),
#  ("Yellow's opposite", 'BOLD', ['ASEA', 'LESS']),
#  ('Causes dissolution of cells',
#   'LYSES',
#   ['LYSIS', 'SENDS', 'BRAVO', 'CIRCA', 'ENDED']),
#  ('Exploit, e.g.', 'ACT', ['USE', 'USE', 'USE', 'USE', 'USE']),
#  ('Quiet times', 'REPOSES', []),
#  ('___ blue', 'NAVY', ['NILE', 'CYAN', 'NYPD', 'YALE', 'NILE']),
#  ('Franklin with a cameo role in "The Blues Brothers"',
#   'ARETHA',
#   ['ELWOOD', 'WALKON', 'RELIVE']),
#  ('"Avalon" band', 'ROXYMUSIC', []),
#  ('Feminist Lucy', 'STONE', ['ILOVE', 'ILOVE', 'ILOVE', 'ILOVE', 'ILOVE']),
#  ('Genetics, e.g.: Abbr.', 'SCI', ['RNA', 'RNA', 'RNA', 'DIS']),
#  ('Upstate New York city', 'ELMIRA', ['OSWEGO', 'ONEIDA']),
#  ('"Politics ___ beanbag" (Mr. Dooley maxim)',
#   'AINT',
#   ['ERST', 'VOUS', 'ANEW', 'CEDE', 'EMIT']),
#  ('Tears down: Var.', 'RASES', ['HASAT', 'RENDS', 'RACES', 'RACES', 'RENTS']),
#  ('Gazelle, at times', 'LOPER', ['ARIEL', 'ARIEL', 'ARIEL', 'ARIEL', 'ARIEL']),
#  ('A question of possession', 'WHOSE', ['TITLE', 'BYFAR', 'DOUBT']),
#  ('Causes of street rumbles?', 'ELS', ['REP']),
#  ("Pirate's eye cover", 'PATCH', ['ALIAS', 'ALIAS', 'ALIAS', 'ALIAS']),
#  ('"___ no money"', 'SEND', ['ISNT', 'ARUN', 'ARUN', 'ISNT', 'ARUN']),
#  ("Columbia, S.C., newspaper's security department?",
#   'STATEPOLICE',
#   ['VOLUNTARILY']),
#  ('Takes pleasure (in)',
#   'BASKS',
#   ['ENJOY', 'ENJOY', 'REVEL', 'AREAL', 'ITWAS']),
#  ('Drop a dime, so to speak',
#   'PHONE',
#   ['NOVEL', 'MINIM', 'SLEEP', 'VISIT', 'ABATE']),
#  ('Brit. military sch.', 'RMA', ['DSO', 'DSO', 'DSO', 'DSO', 'DSO']),
#  ('"Couldn\'t agree more"', 'YEAH', ['AMEN', 'AMEN', 'JIBE', 'JIBE', 'JIBE']),
#  ('Spielberg film', 'SCHINDLERSLIST', []),
#  ('Cello feature', 'FHOLE', ['VIOLA', 'VIOLA', 'VIOLA', 'STAIR', 'MOVIE']),
#  ('Absolute', 'SHEER', ['UTTER', 'UTTER', 'UTTER', 'UTTER', 'UTTER']),
#  ('Uninspired', 'TRITE', ['LABOR', 'SHEER', 'ALIAS']),
#  ('It may have several scénes', 'ACTE', ['OLIO', 'SETS', 'MOBS', 'ACTS']),
#  ('Brought forth', 'BIRTHED', ['SPAWNED', 'EVINCED', 'INDUCED']),
#  ('Wings', 'ELLS', ['ALAE', 'ALAE', 'ALAE', 'ALAE', 'ALAE']),
#  ('Txts, e.g.', 'MSGS', ['SENT', 'ERAT', 'EMIT', 'ERST', 'ACCS']),
#  ("Winner's take, sometimes", 'ALL', ['HST', 'AHA', 'HST', 'DDE', 'DDE']),
#  ('Pale colors', 'ECRUS', ['TINTS', 'TONES', 'STAKE', 'ASHEN', 'ASHEN']),
#  ('Send a quick update, in a way',
#   'TEXT',
#   ['WIRE', 'WIRE', 'REDO', 'ALOT', 'EARN']),
#  ('Big shot', 'FATCAT', ['SOARED']),
#  ('Its alphabet starts with alif', 'ARABIC', ['RENEWS', 'ABCDEF', 'RESETS']),
#  ('Drunkenly reveling',
#   'ONATOOT',
#   ['TIPSILY', 'LARKERS', 'PROCEED', 'ONETIME']),
#  ('Relative of a kite', 'ERN', ['TOM', 'BOX', 'ASA', 'ASA', 'ASA']),
#  ('Gets a lift', 'RIDES', ['SKIER', 'STEAL', 'RAISE', 'HOPIN', 'HOIST']),
#  ('Buffer, in a way',
#   'SHAMMY',
#   ['LINEAR', 'ENTITY', 'INTHAT', 'SHAKES', 'INEVER']),
#  ('N.B.A. team', 'MAGIC', ['YOKED']),
#  ('Harass', 'GNAW', ['HAZE', 'RIDE', 'RIDE', 'RIDE', 'HAZE']),
#  ('Adoring one', 'DOTER', ['DOTES', 'GREEN', 'LEGIT', 'ALIEN', 'DENSE']),
#  ('Copy blocks set without a break',
#   'RUNONS',
#   ['DETERS', 'DETERS', 'ECTYPE', 'PARROT']),
#  ('Bank client', 'MORTGAGEE', []),
#  ('Relay rod', 'BATON', ['STAFF', 'STAFF', 'SPARE']),
#  ('Entitle', 'NAME', ['SENT', 'ERAT', 'EMIT', 'ERST', 'ACCS']),
#  ('"The Twilight ___"', 'ZONE', ['SAGA', 'SAGA', 'DUSK', 'GODS', 'TEEN']),
#  ('Months of dawn-to-dusk fasting', 'RAMADANS', ['HEADLINE']),
#  ('Land', 'REELIN', ['ASHORE', 'NOMANS', 'ASHORE', 'ARRIVE', 'ASHORE']),
#  ('Bike part: Abbr.', 'PED', ['HOG']),
#  ('James Bond et al.', 'AGENTS', ['ALIENS', 'ALIENS', 'MONTHS']),
#  ('What holders of a straight do', 'STANDPAT', []),
#  ("Gunnery officer's command", 'RELOAD', ['EXISTS', 'SUPINE']),
#  ('Spirit', 'SPUNK', ['HEART', 'MOXIE', 'ARDOR', 'ANIMA', 'GUSTO']),
#  ('King who had an audience with Pope Leo I', 'ATTILA', ['BAINES', 'LEGEND']),
#  ('Transferred, as sovereignty, by death',
#   'DEMISED',
#   ['SCEPTRE', 'ALIENOR', 'AFFRONT', 'RETRACT']),
#  ('Tees and ells',
#   'JOINTS',
#   ['SHIRTS', 'DRIVES', 'ANGERS', 'TOBOOT', 'NOSOAP']),
#  ('Corner', 'TRAP', ['TREE', 'TREE', 'JAIL', 'TREE', 'TREE']),
#  ('Bell sound', 'DING', ['PEAL', 'DONG', 'DONG', 'TING', 'TING']),
#  ('Lay', 'BALLAD', ['SUNNED', 'EXPEND']),
#  ("Riff's partner", 'RAFF', ['SCAT', 'ANEW', 'ANEW', 'SEAT', 'THIS']),
#  ('Heavy blow', 'GUST', ['GALE', 'SLUG', 'ONER', 'WHAM', 'TOOT']),
#  ('Deere products', 'PLOWS', ['MOWER', 'BALER']),
#  ('Diagram', 'GRID', ['PLAN', 'PLAN', 'VENN', 'TREE', 'TREE']),
#  ('Hebron grp.', 'PLO', ['EMS', 'AMA', 'AMA', 'USO', 'AMA']),
#  ('Regular dates', 'STEADIES', ['SPORADIC', 'PERIODIC']),
#  ('Yamani and Fahd', 'ARABS', ['SAUDI', 'SAUDI', 'ISLAM', 'TRIAD', 'SLASH']),
#  ('Capture', 'SEIZE', ['SNARE']),
#  ('Lump together', 'AGGREGATE', []),
#  ('Perennial government concern',
#   'DEFICIT',
#   ['REGIMEN', 'REGIMEN', 'BEGONIA', 'ALLDONE', 'ELECTED']),
#  ('1939 movie lawman',
#   'DESTRY',
#   ['ARNESS', 'ELAPSE', 'INTOTO', 'RATING', 'ACROSS']),
#  ("Analysts' concerns", 'EGOS', ['RTES', 'SSNS', 'RTES', 'STDS', 'AMID']),
#  ('Bandicoot', 'MOLERAT', ['PRECEDE']),
#  ('Dickens title character',
#   'DROOD',
#   ['ATALE', 'ATALE', 'ATALE', 'ATALE', 'ATALE']),
#  ('Chicago Outfit bigwig', 'CAPONE', ['ATTIRE', 'WEARER']),
#  ('Place to test aerodynamics', 'WINDTUNNEL', []),
#  ("Rabbi's co-worker",
#   'CANTOR',
#   ['HILLEL', 'SHOFAR', 'TALMUD', 'TALMUD', 'ESDRAS']),
#  ('Changes with the times',
#   'ADAPTS',
#   ['VARIES', 'ALTERS', 'ALTERS', 'RESAVE', 'ALTERS']),
#  ('A dwarf', 'DOPEY', ['GNOME', 'STUNT', 'GNOME', 'STUNT', 'GNOME']),
#  ('Onetime seat of the Este family', 'MODENA', ['ETERNO', 'ENBLOC', 'DOTELL']),
#  ('Franciscan abbr.', 'OSF', ['DIG', 'AHA']),
#  ('"It Had to Be You" composer ___ Jones',
#   'ISHAM',
#   ['CRAVE', 'COHAN', 'NORAH', 'ALLAN', 'ETTAS']),
#  ('Was she a real Copt?', 'CLEOPATRA', []),
#  ('Saharan sections', 'ERGS', ['ARID', 'SERE', 'SERE', 'ARID', 'ARID']),
#  ('Orchestra sect.', 'STR', ['SYM', 'PIT', 'PIT', 'TRI', 'APP']),
#  ('Mount Olympus chief', 'ZEUS', ['GODS', 'GODS', 'GODS', 'GODS', 'ARES']),
#  ('Playground, e.g.', 'AREA', ['WHEE', 'PARC']),
#  ("Soldier's shelter", 'PUPTENT', ['REHOUSE']),
#  ('One who was very successful with numbered balls',
#   'MINNESOTAFATS',
#   ['LOTTERYWINNER']),
#  ('Become attracted by', 'TAKETO', ['FREELY', 'THEEND', 'BAINES']),
#  ("Bull's antithesis", 'BEAR', ['FROM', 'LESS', 'LESS', 'TAKE', 'EVIL']),
#  ("Gretzky's stats", 'GOALS', ['OILER', 'OILER']),
#  ('Of a 14th-century Tuscan family', 'MEDICEAN', []),
#  ('Impenetrable', 'SOLID', ['DENSE', 'DENSE', 'UNITE']),
#  ('Shakes', 'EVADES', ['ELUDES']),
#  ('Nick', 'GRAZE', ['SANTA', 'SANTA', 'NOLTE', 'NOLTE', 'SANTA']),
#  ('Out of', 'FROM', ['SENT', 'ERAT', 'EMIT', 'ERST', 'ACCS']),
#  ('R.I. feathered group', 'REDS', ['BOAS', 'NEST', 'SAGO', 'DART', 'DART']),
#  ('"It Had to Be You" lyricist',
#   'KAHN',
#   ['HART', 'ANKA', 'ANKA', 'ANKA', 'ANKA']),
#  ('"Luncheon of the Boating Party" painter', 'RENOIR', ['TIFFIN', 'RETAIN']),
#  ('Pursue some e-mail chicanery',
#   'PHISH',
#   ['FRAUD', 'CHASE', 'CHASE', 'CHASE', 'CHASE']),
#  ('Repeated musical passages',
#   'DACAPOS',
#   ['ARIOSOS', 'PRESTOS', 'PRESTOS', 'ARIOSOS', 'DEFILES']),
#  ('Stepfather of Ull', 'THOR', ['SLAY', 'CODE', 'AXIS', 'DASH', 'AURA']),
#  ('Lebanese port', 'SIDON', ['CEDAR', 'CEDAR', 'BEKAA', 'SALAM', 'MALIK']),
#  ('Adjective once misapplied to the Earth',
#   'FLAT',
#   ['MARL', 'SOIL', 'SOWN', 'SOIL', 'SOIL']),
#  ('Reddish equines', 'ROANS', ['RUDDY', 'ARABS', 'CIRCA', 'AGAIN', 'ERECT']),
#  ('Step on the gas', 'REV', ['HIE', 'HIE', 'HIE']),
#  ('What tartans denote', 'CLANS', ['COLON', 'TOWIT', 'RELIT']),
#  ('Less watery', 'DRIER', ['HYDRO', 'MOIRE', 'SLOSH', 'MOIRE', 'OCEAN']),
#  ('Silt deposit', 'LOESS', ['RIFLE', 'ASTIR', 'LEAVE']),
#  ('Put in order', 'ALIGN', ['EDICT', 'ARRAY', 'AMISS', 'ALINE']),
#  ('Large amount', 'GOBS', ['SCAD', 'SLEW', 'MINT', 'SLEW', 'VAST']),
#  ("Procrastinator's promise",
#   'SOON',
#   ['WORD', 'WORD', 'OLEO', 'OLEO', 'OATH']),
#  ('Impale', 'SPEAR', ['SHEER', 'ALIAS', 'LABOR']),
#  ('12-Down is one', 'ADE', ['RAM', 'INN', 'IKE', 'DEC']),
#  ('Cook on TV', 'JULIACHILD', ['SHORTORDER']),
#  ('Derisive ones', 'SNORTERS', ['SNEERING']),
#  ('Future hunters',
#   'EAGLETS',
#   ['NIMRODS', 'LATERON', 'LATERON', 'SEALERS', 'SEALERS']),
#  ('Made a right turn', 'GEED', ['GEES', 'GEES', 'CEDE', 'DENY', 'SLUE']),
#  ('Little one', 'ELF', ['ANY', 'TOT', 'TAD', 'TOT', 'TOT']),
#  ('Garden flower', 'TEAROSE', ['ANEMONE', 'COROLLA']),
#  ('Cap', 'ACME', ['BRIM', 'APIE', 'LENS']),
#  ("Juan's sweetheart", 'AMIGA', ['FLAME', 'HONEY', 'HONEY', 'FLAME', 'DEARY']),
#  ('Giant reed of India', 'NAL', ['INK', 'LTD', 'INK', 'OTT', 'AOL']),
#  ('Before you know it', 'SOON', ['OHOH', 'UPON', 'UPON', 'UPON', 'ONTO']),
#  ('Entrancing', 'ORPHIC', ['ORELSE', 'PRONTO', 'EGRESS']),
#  ('Install in an office', 'ANOINT', ['AGENCY']),
#  ('Is unable to stand', 'DESPISES', ['DOMINATE']),
#  ('"To recap ..."', 'INSUMMARY', []),
#  ('A lot of thought goes into it', 'OBSESSION', []),
#  ('O.T. language', 'HEB', ['ENG', 'ESE', 'ESE', 'ESE', 'ESE']),
#  ('Knocked, in a way', 'JEERED', ['ONEPIN', 'BEANED', 'BEANED', 'RRATED']),
#  ('Youngest "Downton Abbey" daughter',
#   'SYBIL',
#   ['SINCE', 'ALTER', 'TEXAN', 'AVOID', 'REAMS']),
#  ('Middle Eastern dish',
#   'PILAU',
#   ['PILAF', 'PILAF', 'SADAT', 'AQABA', 'YEMEN']),
#  ('Forward', 'REMAIL', ['SHIEST', 'RESEND', 'BRASSY', 'RESHIP', 'RESEND']),
#  ('Admonishing Alexander', 'WARNINGBELL', []),
#  ('Go off-shore, maybe', 'WADE', ['PROP', 'PROP', 'ASEA', 'PROP', 'ERNE']),
#  ('U.S. painter: 1859–1940',
#   'POORE',
#   ['AGREE', 'UNDER', 'SANER', 'EIDER', 'UTTER']),
#  ('With shaking hands, perhaps', 'NERVOUSLY', []),
#  ("Basketball's path", 'ARC', ['WAY', 'WAY', 'RRS', 'WAR', 'ABA']),
#  ('Sour substances', 'ACIDS', ['ACERB', 'SPOIL', 'ACERB', 'ACERB', 'ACERB']),
#  ('Asked', 'QUERIED', ['INVITED', 'INVITED', 'INVITEE', 'QUIZZED', 'SENTFOR']),
#  ('Difficult task', 'TOUGHNUTTOCRACK', ['SHOULDERTHELOAD']),
#  ('___ years (elderly)', 'ONIN', ['AGED', 'AGED', 'AGED', 'AGED', 'AGED']),
#  ('Looks for food',
#   'FORAGES',
#   ['PERUSES', 'TENDSTO', 'ADMIRES', 'TENDSTO', 'ASPECTS']),
#  ('Lot', 'GOODDEAL', ['SODOMITE']),
#  ('Halloween color', 'ORANGE', ['SMUTTY']),
#  ('Bridge name', 'GOREN', []),
#  ('Cousins of margays', 'OCELOTS', ['ANALOGS', 'UMPIRES', 'ISOMERS']),
#  ("Bad feeling in the pit of one's stomach?",
#   'ULCER',
#   ['EATEN', 'ABHOR', 'EATEN', 'ABHOR', 'ABHOR']),
#  ('Attention-getter, in some rooms',
#   'OYEZ',
#   ['AHEM', 'PSST', 'PSST', 'AHEM', 'AHEM']),
#  ('Jazz setting', 'UTAH', ['ELLA', 'ELLA', 'HOKE', 'HOKE', 'ELLA']),
#  ('Campus site', 'HALL', ['DORM', 'DEAN', 'DEAN', 'DEAN', 'DEAN']),
#  ('See 13 Across', 'AER', ['WHY', 'JOB', 'DIG', 'OUT']),
#  ('Bodies making their closest approach in more than 50,000 years on August 27, 2003',
#   'THEEARTHANDMARS',
#   ['COSTAGAVRASFILM']),
#  ('Greenkeepers?', 'TERRARIA', ['SAMEBOAT', 'NUMEROUS']),
#  ('Maniacal', 'INSANE', ['TANDEM', 'APIECE']),
#  ('Go along', 'AGREE', ['ALIAS', 'STATS', 'ALIEN', 'MINUS', 'INKED']),
#  ('What "hemi-" means',
#   'HALFOF',
#   ['AGENCY', 'MANNER', 'AGENTS', 'AGENCY', 'AGENCY']),
#  ('"Two ___," 1951 revue', 'ONTHEAISLE', []),
#  ('Lightest known substance', 'HYDROGEN', []),
#  ("Soldier's gear", 'MESSKIT', ['REVERSE', 'CLOTHES']),
#  ('R.L.S. pirate', 'BONES', ['ASTRO', 'CHEST', 'BOOTY', 'MATEY']),
#  ('Tumult', 'MAYHEM', ['UNREST', 'UPROAR', 'UPROAR']),
#  ('Sound from a dungeon', 'MOAN', ['DANK', 'ROLE', 'PAST', 'SLAY', 'TABU']),
#  ('Wait-___ (thorny plant)', 'ABIT', ['ROSE', 'STEM', 'ASEC', 'ASEC', 'ASEC']),
#  ('Early film star Charles _____',
#   'OGLE',
#   ['WARS', 'DANA', 'CREW', 'NORA', 'CAPE']),
#  ('Bare: Comb. form', 'GYMNO', ['STARK', 'SCANT', 'STARK', 'NAKED', 'SCANT']),
#  ('Bill collector?', 'TIPJAR', ['DUNNER', 'CURIOS', 'DEBTOR']),
#  ("One with a print outside Grauman's Chinese Theatre",
#   'STAR',
#   ['SANS', 'ELSE', 'THUS', 'WHAT', 'ERST']),
#  ('Churned about', 'MOILED', ['MAIDEN', 'ATONED']),
#  ('Droughty', 'DRY', ['ILL', 'HEY', 'HHH', 'LED']),
#  ('December spinner', 'DREIDEL', ['ROTATOR', 'ROTATOR', 'YEAREND']),
#  ('Foster home since 1982', 'SHEA', ['REAR', 'REAR', 'REAR', 'REAR', 'REAR']),
#  ('A musical "B"', 'BRAHMS', ['SEPTET', 'SEPTET']),
#  ('"Liebestod" is one', 'ARIA', ['SLAY', 'CODE', 'AXIS', 'DASH', 'AURA']),
#  ("Caesar's well", 'BENE', ['SIDS', 'ESSE', 'ETTU', 'SIDS', 'ILLE']),
#  ('Hawkshaw', 'TEC', ['VIM', 'PER', 'OPT', 'NIN', 'AHA']),
#  ('Drink on board', 'GROG', ['LADE', 'ROOM', 'LADE', 'DIVE', 'LATH']),
#  ('Native', 'INBRED', ['AUSSIE']),
#  ("Native African's musical beat?", 'PYGMYRHYTHM', []),
#  ('One who dropped a pill on the floor?', 'TABLETHUNTER', ['GUNTHEENGINE']),
#  ('With 106-Across, phrase said with a sneer',
#   'BENEATH',
#   ['CURRENT', 'AGREETO', 'REAREND']),
#  ('1949-50 P.G.A. season money leader', 'SNEAD', ['ASTIR', 'IMSET']),
#  ('Ornamentational styles', 'ROCOCOS', ['FANGLES', 'LATESTS']),
#  ('Brief, catchy phrase', 'SOUNDBITE', ['SLOGANEER']),
#  ("Steakhouse chef's action", 'SEARING', ['SKYWARD', 'ALLOVER']),
#  ("Hiker's woe", 'CORN', ['PATH', 'MILE', 'ELEV', 'GORP', 'PATH']),
#  ('Wheelchair-accessible route',
#   'RAMP',
#   ['OPEN', 'OPEN', 'OPEN', 'OPEN', 'OPEN']),
#  ('Not in, in Inverness', 'OOT', ['NAE', 'TAM', 'ILL', 'HHH', 'HEY']),
#  ('Side-channel, in Canada', 'SNYE', ['DUCT', 'ASEA', 'LANE', 'ESSO']),
#  ('Kind of batting stance', 'OPEN', ['POSE', 'POSE', 'POSE', 'POSE', 'NEXT']),
#  ('One making waves', 'SPEEDBOAT', ['MILLYTARY', 'TRUESTORY']),
#  ("Syllogism's opener", 'MAJORPREMISE', []),
#  ('What you really saw?', 'METEORSHOWER', []),
#  ('A woman who has borne one child', 'UNIPARA', []),
#  ("Valley girl's filler", 'LIKE', ['ASIF', 'DALE', 'GLEN', 'GLEN', 'GLEN']),
#  ('Classroom projectile', 'PAPERAIRPLANE', []),
#  ('Words of recognition',
#   'OHITSYOU',
#   ['SHOUTOUT', 'TAKEABOW', 'CALLERID', 'WANNABET']),
#  ('Cleavage-revealing dress feature', 'SCOOPNECK', []),
#  ('Unappetizing', 'INSIPID', ['VERSION']),
#  ('Sailing race', 'REGATTA', ['PRIMARY']),
#  ('Station with a show',
#   'AIRER',
#   ['DEPOT', 'DEPOT', 'DEPOT', 'DEPOT', 'DEPOT']),
#  ('"Give it ___!"', 'AREST', ['NEVER', 'ROGER', 'ASIGN', 'AHOLD', 'LEAST']),
#  ('Views furtively', 'PEEKSAT', ['ASPECTS']),
#  ('Severly pan', 'TRASH', ['DEITY', 'ROAST', 'KNOCK', 'ROAST', 'ROAST']),
#  ('Party favorites?', 'ALIST', ['IDOLS', 'SEEDS', 'SIDED', 'MALTS', 'SEALS']),
#  ('"Phooey!"', 'DRAT', ['NUTS', 'NUTS', 'CRUD', 'RATS', 'RATS']),
#  ('Given away', 'UNKEPT', ['ASSUME', 'ENDING', 'LOANED', 'STORED', 'ABSENT']),
#  ("It's embarrassing to eat", 'HUMBLEPIE', []),
#  ('Show surprise', 'START', ['ABACK', 'HELLO', 'ABACK', 'OHWOW', 'IKNEW']),
#  ('Like the winner in a guessing contest', 'CLOSEST', ['HANGMAN', 'SMALLER']),
#  ('It borders the Atl.', 'AFR', ['EUR', 'DEL', 'FLA', 'EUR', 'STR']),
#  ("Order at Long John Silver's",
#   'FRIEDSHRIMP',
#   ['POCKETMONEY', 'MARGARETLEG']),
#  ('Tennis scores after deuce', 'ADINS', ['RESTS']),
#  ('Forward-looking man?', 'NOSTRADAMUS', []),
#  ('Wrestling surfaces', 'MATS', ['HOLD', 'NAPS', 'SUMO', 'SUMO', 'SUMO']),
#  ('Water carrier', 'PAIL', ['MAIN', 'HOSE', 'DUCT', 'MAIN', 'EWER']),
#  ("Favorite 60's song of 36-Across?",
#   'THISMAGICMOMENT',
#   ['BALTIMOREORIOLE', 'HOWLITTLEWEKNOW', 'WEKISSINASHADOW']),
#  ('Wisdom', 'SAPIENCE', []),
#  ('Dormitory annoyance', 'SNORER', ['HASSLE', 'SNAPAT', 'SERTAS', 'AVENGE']),
#  ('Gooey stuff', 'EPOXY', ['SLIME', 'GUNKY', 'SMORE', 'GRIST']),
#  ('Malta adopted it in 2008',
#   'EURO',
#   ['OVAL', 'SANE', 'DUET', 'NLER', 'DELE']),
#  ('Where to see Atlas', 'ROCKEFELLERCENTER', []),
#  ('Sick and tired', 'FEDUP', ['BORED', 'WEARY', 'STALE', 'SPENT', 'STALE']),
#  ('Pool', 'POT', []),
#  ('A Parisian Bank', 'LEFT', ['ETRE', 'AMOI', 'ACCT', 'SAVE', 'RELY']),
#  ("Orville Wright's birthplace", 'DAYTON', ['OHIOAN', 'OHIOAN', 'PRESTO']),
#  ('Barbecue blocks', 'COALS', ['STEMS', 'ROAST', 'BROIL', 'GRILL', 'ROAST']),
#  ('Philosophy of Epicurus', 'HEDONISM', ['BRASSHAT']),
#  ('Address part', 'STREET', ['SPEECH', 'TALKTO']),
#  ('Substitute', 'TEMP', ['SWAP', 'SWAP', 'ALFA']),
#  ("Student's cry", 'AHA', ['MID', 'GPA', 'MED', 'SDS']),
#  ('Describing a speedwalking duo', 'HEELANDTOE', []),
#  ("Heat in one's car", 'ROADRAGE', ['ESCALATE', 'HANDGUNS']),
#  ('2004 N.B.A. All-Star Michael',
#   'REDD',
#   ['TSAR', 'TSAR', 'DEPP', 'TERI', 'UNIT']),
#  ('Kind of note', 'GRACE', ['BFLAT']),
#  ('Stereotypically messy digs', 'DORMROOM', ['POTSHOTS', 'UNEARTHS']),
#  ('Read the riot act to',
#   'SCOLDED',
#   ['UPBRAID', 'READTHE', 'YELLSAT', 'PERUSED', 'PERUSED']),
#  ('How one must win in Ping-Pong', 'BY2', ['REC', 'REC', 'NET', 'NET', 'REC']),
#  ('Unimprovable situation', 'HEAVENONEARTH', []),
#  ('Counsel positively', 'URGE', ['HEED', 'WARN', 'SURE', 'AVER', 'AVER']),
#  ('Base break', 'LEAVE', ['ERUPT', 'PAUSE', 'ONEND', 'PARSE']),
#  ('Without effort', 'IDLY', ['DINT', 'STAB', 'DINT', 'STAB', 'DINT']),
#  ('Capital of Honduras', 'TEGUCIGALPA', []),
#  ('Garrison', 'FORT', ['POST', 'POST', 'NDAK', 'NOIR', 'SOON']),
#  ('Young women, to Aussies', 'SHEILAS', ['MINISKI']),
#  ('Black haws', 'SLOES', ['BRAYS', 'EBONY', 'EBONY']),
#  ('Pueblo tongue', 'ZUNI', ['DELI', 'MESA', 'HOPI', 'HOPI', 'HOPI']),
#  ('Watch features', 'DIALS', ['RESEE', 'VIGIL']),
#  ('Life preservers',
#   'MAEWESTS',
#   ['SENTENCE', 'BIOTICAL', 'VITALITY', 'SENTENCE']),
#  ('More uncertain', 'CHANCIER', []),
#  ("One of the S's in U.S.S.",
#   'SHIP',
#   ['SENT', 'ERAT', 'EMIT', 'ERST', 'ACCS']),
#  ('Enterprise officer', 'SPOCK', ['CADET', 'CADET', 'CADET', 'CADET']),
#  ('Palm product (4)', 'DATE', ['HEEL', 'HEEL', 'TREE', 'NIPA', 'ACAI']),
#  ('Errol Flynn portrayer in "The Aviator"', 'JUDELAW', ['FRESHEN', 'RETIREE']),
#  ('Ornamental case', 'ETWEE', ['FANCY']),
#  ('Richard Starkey', 'RINGO', ['ASTRO', 'SLASH', 'SPEND', 'PRIOR', 'BADLY']),
#  ('Holiday time', 'YULE', ['NOEL', 'REST', 'INNS', 'INNS', 'XMAS']),
#  ('Shoot for the stars', 'GOBIG', ['SPRIG', 'AIMAT', 'AIMAT']),
#  ('Football score abroad', 'GOL', ['EIN', 'CIE', 'NIE', 'UNE', 'SIE']),
#  ('Does in', 'ICES', ['DEER', 'DEER', 'ACTS', 'DEER', 'DEER']),
#  ("Golfer's org.", 'PGA', ['TEE', 'AMA', 'AMA', 'NRA', 'AMA']),
#  ('Strike violently', 'RAM', ['RAP', 'FAN', 'FAN', 'HIT', 'FAN']),
#  ('Electioneer', 'ORATE', ['SHEER', 'ALIAS', 'OWNED']),
#  ('From humble beginnings', 'LOWBORN', ['ORIGINS']),
#  ("Game for those who don't like to draw", 'STUDPOKER', ['AHARDTIME']),
#  ('Yaw relative, on an aircraft',
#   'ROLL',
#   ['VEER', 'AERO', 'AERO', 'AERO', 'AERO']),
#  ('Former', 'OLDEN', ['ALIAS', 'STATS', 'ALIEN', 'MINUS', 'INKED']),
#  ('"___ does not surpass nature, but only brings it to perfection": Cervantes',
#   'ART',
#   ['YAK', 'TIE']),
#  ('Three', 'QUARTEROFADOZEN', []),
#  ('Japanese tourist city on Kyushu',
#   'MIYAZAKI',
#   ['KUMAMOTO', 'TRAVELER', 'TRAVELER']),
#  ('Err', 'TRIP', ['SLIP', 'SLIP', 'ACOG', 'POPE', 'ASTO']),
#  ('Consumer Reports report', 'TEST', ['USER', 'USER', 'USES', 'USER', 'USER']),
#  ('One may be fair', 'MAIDEN', ['STORMY', 'MIDWAY']),
#  ('Shelley\'s "statesman\'s game"',
#   'WAR',
#   ['OER', 'EER', 'EER', 'ODE', 'ODE']),
#  ('"No ___ think is in my tree" ("Strawberry Fields Forever" lyric)',
#   'ONEI',
#   ['ASST', 'INRE', 'MOST', 'PUSH', 'THEN']),
#  ('Mining target', 'SEAM', ['LODE', 'COAL', 'ORSK', 'WIDE', 'GOAL']),
#  ('Daisy developed by Luther Burbank', 'SHASTA', []),
#  ("Pundit's piece", 'OPED', ['SAGE', 'SAGE', 'SAGE', 'SAGE', 'SAGE']),
#  ('Attica and Newgate', 'PRISONS', ['LOCKSUP', 'CONTEST', 'ENMASSE']),
#  ('Examine', 'GOOVER', ['SEARCH', 'RETEST', 'PERUSE', 'RETEST', 'PERUSE']),
#  ('Caesar and Luckman', 'SIDS', ['GAUL', 'ILLE', 'ESSE', 'ETTU', 'ETTU']),
#  ('Parts of stews', 'BROTHS', ['ONIONS', 'PIECES', 'CAMEOS']),
#  ('Old English dialect',
#   'SAXON',
#   ['ARGOT', 'ARGOT', 'ARGOT', 'NOHOW', 'IDIOM']),
#  ('It started in 2003 with the bombing of Baghdad',
#   'IRAQWAR',
#   ['UNFUNNY', 'HOWEVER', 'REPUTED']),
#  ('Forwarded', 'AIDED', ['LEGIT', 'BOARD']),
#  ('Item in a West Potomac Park memorial',
#   'CHAIR',
#   ['RIVER', 'LEAVE', 'PHONE', 'CIRCA']),
#  ('Cooks gently',
#   'SIMMERS',
#   ['HATCHES', 'BRAISES', 'BRAISES', 'EASESIN', 'EASESIN']),
#  ('Dressy clothing', 'FINERY', ['ROBING', 'ATTIRE', 'ATTIRE']),
#  ('Seat for Snerd', 'LAP', ['ORE']),
#  ('"We\'ve ___, an\' a debt . . . ": J.R. Lowell',
#   'AWAR',
#   ['IATE', 'UPTO', 'IATE', 'IATE', 'IATE']),
#  ('Fire insurance?', 'TENURE', ['LLOYDS', 'CLAIMS', 'AGENTS']),
#  ('Postcard sentiment', 'MISSYOU', ['GETWELL', 'THERAGE']),
#  ('Grunge rock hub', 'SEATTLE', ['ATANEND']),
#  ('Long green', 'DOREMI', ['UNRIPE', 'UNRIPE', 'UNRIPE', 'UNRIPE', 'UNRIPE']),
#  ('Exhortation from Horace\'s "Odes"', 'SEIZETHEDAY', []),
#  ("War's opposite", 'PEACE', ['BEEFY', 'LEAST']),
#  ('Comic book (1997)', 'BRAINDROPPINGS', []),
#  ("Can't not", 'HASTO', ['ALIAS', 'STATS', 'ALIEN', 'MINUS', 'INKED']),
#  ('Milt Gross\'s "Nize ___"',
#   'BABY',
#   ['YUCK', 'ICKY', 'RANK', 'GUCK', 'ICKY']),
#  ('Popular thesaurus', 'ROGETS', ['REDHOT', 'REDHOT'])]

# %%
guess("bruins")
# Out:
# ['UCLA', 'UCLA', 'UCLA', 'UCLA', 'ORR']

# %%
# serialize and save model
import pickle

TRAINED_MODEL_PATH = "trained_model.p"

pickle.dump((answers_train, vectorizer, model), open(TRAINED_MODEL_PATH, "wb"))
