# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt

DATA_PATH = r"data\nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

# sample = random.sample(puzzles_available, 10_000)

# sample puzzles from EVEN days
sample = [puzz for puzz in puzzles_available if puzz[-1]%2==0]

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)
clue_answer_pairs
# Out:
# [('Capital of Ghana', 'ACCRA'),
#  ('Shows wear, as a chair cushion', 'SAGS'),
#  ('Progeny of an old block', 'CHIP'),
#  ('Yugoslav native', 'CROAT'),
#  ("Guy Fawkes's forte", 'PLOT'),
#  ('Window part', 'PANE'),
#  ('Well-known drudge', 'CINDERELLA'),
#  ('Status quo ___ bellum', 'ANTE'),
#  ('Clocked', 'TIMED'),
#  ('Bedroom piece', 'DRESSER'),
#  ('Bull-rider of myth', 'EUROPA'),
#  ('Thus, to Caesar', 'ITA'),
#  ('Prior to', 'ERE'),
#  ('Roman 1501', 'MDI'),
#  ('Harvest goddess', 'OPS'),
#  ('Haul', 'LUG'),
#  ('Hallucinogen', 'LSD'),
#  ('Word with after or new', 'MATH'),
#  ('Condescended', 'STOOPED'),
#  ('Alaskan native', 'ALEUT'),
#  ('Common-Market initials', 'EEC'),
#  ('Kind of transit', 'RAPID'),
#  ('Custom-made in London', 'BESPOKE'),
#  ('___ chance (no way)', 'NOTA'),
#  ('Mil. man', 'SGT'),
#  ('Turntable abbr.', 'RPM'),
#  ('Holy day: Abbr.', 'SAB'),
#  ('Handed or headed', 'RED'),
#  ('Kind of text or cursor', 'PRE'),
#  ("Bill's partner", 'COO'),
#  ('Stomach: Prefix', 'GASTRO'),
#  ('Composer Victor', 'HERBERT'),
#  ('"Thar she ___!"', 'BLOWS'),
#  ('Heating vessel', 'ETNA'),
#  ('Victims of 8 Down', 'THREEBEARS'),
#  ('Estate or life', 'REAL'),
#  ('Poetic times', 'EENS'),
#  ('Good-by', 'ADIOS'),
#  ('She, in Paris', 'ELLE'),
#  ('Mild oath', 'DRAT'),
#  ('Moisten', 'BEDEW'),
#  ('Grammar case: Abbr.', 'ACC'),
#  ('Dernier ___', 'CRI'),
#  ('Penitent', 'CONTRITE'),
#  ("TV's brother", 'RADIO'),
#  ('Musical direction', 'ATEMPO'),
#  ('Rushed', 'SPED'),
#  ('Still and ___', 'ALL'),
#  ('Well-known intruder', 'GOLDILOCKS'),
#  ('Turn on, as an engine', 'STARTUP'),
#  ('Auditors: Abbr.', 'CPAS'),
#  ('Well-known oven user', 'HANSEL'),
#  ('Buries', 'INTERS'),
#  ('Looked closely', 'PEERED'),
#  ('Gathers', 'REAPS'),
#  ("Rarin' to go", 'EAGER'),
#  ('Anarchist Goldman', 'EMMA'),
#  ('System of land tenure', 'UDAL'),
#  ('Exploiter of 17 Across', 'STEPMOTHER'),
#  ('Center of activity', 'HUB'),
#  ('Fed. aid agency', 'OEO'),
#  ('Mr. Beard', 'DAN'),
#  ('Canonical hour', 'TERCE'),
#  ('Mideast city', 'PORTSAID'),
#  ('Passage, in anatomy', 'ITER'),
#  ('Pedestal part', 'DADO'),
#  ('Displayed', 'SPORTED'),
#  ('National emblem', 'EAGLE'),
#  ('Celestial music maker', 'SPHERE'),
#  ('Co-conspirator of 11 Down', 'GRETEL'),
#  ('Threefold', 'TERNAL'),
#  ('African tree', 'BAOBAB'),
#  ('Bergman, e.g.', 'SWEDE'),
#  ('Poetic misery', 'BALE'),
#  ('Overcome', 'BEST'),
#  ('Nucleic-acid initials', 'RNA'),
#  ('Small deer', 'ROE'),
#  ('Compass point', 'SSW'),
#  ('W. W. II org.', 'OPA'),
#  ('Synthetic', 'ERSATZ'),
#  ('Nicholas, e.g.', 'TSAR'),
#  ('Bridge mishap', 'SET'),
#  ('"___ Kapital"', 'DAS'),
#  ("Fresh-air fiend's advice", 'BREATHE'),
#  ('Go on about', 'RAVE'),
#  ('Imitate', 'APE'),
#  ('Feminine suffix', 'ESS'),
#  ('Threw off course', 'DERAILED'),
#  ('Thames landmark', 'ETON'),
#  ('Disencumber', 'RID'),
#  ('Become involved', 'STEPIN'),
#  ('Concrete strip', 'SLAB'),
#  ('F.D.R. program', 'NEWDEAL'),
#  ('Neighbor of Naples', 'SORRENTO'),
#  ('Rich fabric', 'SAMITE'),
#  ('Particle', 'ATOM'),
#  ('Type of well', 'ARTESIAN'),
#  ("Ethan Allen's conquest", 'TICONDEROGA'),
#  ('Dispatched', 'SENT'),
#  ('King of the old South', 'COTTON'),
#  ('Piddling salute', 'ONEGUN'),
#  ('Soft foods', 'PAPS'),
#  ('Please, in Bonn', 'GEFALLEN'),
#  ('Fountain specialties', 'SUNDAES'),
#  ('Month: Abbr.', 'OCT'),
#  ('Cable-making machine', 'STRANDER'),
#  ('Lively dance', 'HORA'),
#  ('Recording system', 'STEREO'),
#  ('Roman statesman', 'CATO'),
#  ('Undeveloped', 'RAW'),
#  ('French cleric', 'ABBE'),
#  ('Final confrontation', 'SURRENDEROFCORNWALLIS'),
#  ('Major poem', 'EPOS'),
#  ('Noun suffix', 'ERY'),
#  ('Mud, in France', 'BOUE'),
#  ('Zealous', 'ARDENT'),
#  ('Resorts', 'SPAS'),
#  ('Church musical rite', 'SUNGMASS'),
#  ('Long ___', 'AGO'),
#  ('Spotted cat', 'LEOPARD'),
#  ('Swiss town', 'WINDISCH'),
#  ('At the peak', 'ATOP'),
#  ('Fly', 'AVIATE'),
#  ('Sore', 'CANKER'),
#  ('Aunts, in Spain', 'TIAS'),
#  ('The low point', 'VALLEYFORGE'),
#  ('New Jersey battle', 'MONMOUTH'),
#  ('Stake', 'ANTE'),
#  ('Confine', 'INTERN'),
#  ('Site of U.S. base in Canada', 'ARGENTIA'),
#  ('Adirondack river', 'SARANAC'),
#  ('Times or tack', 'HARD'),
#  ('Wobble', 'TEETER'),
#  ('Packing unit: Abbr.', 'CTN'),
#  ('Batty', 'LOCO'),
#  ('___ contempt (accused in court)', 'CITEDFOR'),
#  ('Period', 'ERA'),
#  ('Korean soldier', 'ROK'),
#  ('Region: Abbr.', 'TERR'),
#  ('Offensive or defensive', 'PLATOON'),
#  ('British medical org.', 'RCS'),
#  ('Office holders', 'INS'),
#  ('Vehicle', 'SLED'),
#  ('Aver', 'ALLEGE'),
#  ('Its, in Paris', 'SES'),
#  ('Black Sea port', 'ODESSA'),
#  ('Pulpit occupant', 'PASTOR'),
#  ('Declare', 'ASSERT'),
#  ('Goof', 'ERR'),
#  ('Subject of Kant critique', 'REASON'),
#  ('Move easily', 'SAIL'),
#  ('Titan with a burden', 'ATLAS'),
#  ('Early confrontation', 'THEBATTLEOFBUNKERHILL'),
#  ('British letter', 'ZED'),
#  ("Hessians' Waterloo", 'TRENTON'),
#  ('Shiny fabric', 'SATEEN'),
#  ('Swear', 'AVOW'),
#  ('Tear', 'REND'),
#  ('Site of the turning point', 'SARATOGA'),
#  ('Postscript to a play', 'EPILOGUE'),
#  ('Kennedy', 'TED'),
#  ('Vermont battle', 'BENNINGTON'),
#  ('This: Ger.', 'DIESE'),
#  ('Journalism', 'PRESS'),
#  ('Like an otary', 'EARED'),
#  ('Spud', 'TATER'),
#  ('Clerical headwear', 'MITER'),
#  ('Religious picture', 'ICON'),
#  ("France's Le ___", 'MANS'),
#  ('Unsmiling', 'DOUR'),
#  ('Sicilian city', 'ENNA'),
#  ('Atlantic islands', 'CANARY'),
#  ('" . . . grow too ___ dream"', 'OLDTO'),
#  ('Nemesis of bad guys', 'POSSE'),
#  ('Misbehave', 'ACTUP'),
#  ('Feather: Prefix', 'PTERO'),
#  ('Sharp setbacks', 'FACERS'),
#  ('Disseminated', 'SOWN'),
#  ('Holy ___', 'SEE'),
#  ("Sultans' collections", 'HAREMS'),
#  ('B. &amp; O., etc.', 'RRS'),
#  ('Redden, in Paris', 'ROUGIR'),
#  ('City official: Abbr.', 'ALD'),
#  ("Goat's cry", 'BLEAT'),
#  ('Church fund-raiser', 'BINGO'),
#  ('Bar legally', 'ESTOP'),
#  ('___ Sea scrolls', 'DEAD'),
#  ("Vogue's Nast", 'CONDE'),
#  ('The C.I.C.', 'WASHINGTON'),
#  ('___ gratia artis', 'ARS'),
#  ('Glut', 'SATE'),
#  ('Victim', 'PREY'),
#  ('Scorch', 'SINGE'),
#  ('Expert on lines', 'ACTOR'),
#  ('Footing at Mauna Loa', 'LAVA'),
#  ("Northwestern's home", 'EVANSTON'),
#  ('Bayonne, N.J., sights', 'OILTANKS'),
#  ('More feeble', 'PALER'),
#  ('Kind of hog', 'WART'),
#  ('In unison', 'ASONE'),
#  ('Site of a widely-heard shot', 'CONCORD'),
#  ('Eastern ruler', 'AMEER'),
#  ('Small coach', 'FIACRE'),
#  ('Midday-sun sharer', 'MADDOG'),
#  ('Says', 'UTTERS'),
#  ('Wine measure', 'TIERCE'),
#  ('Worry', 'HARASS'),
#  ('Port of Brazil', 'NATAL'),
#  ('Heights: Abbr.', 'ALTS'),
#  ('Mr. Coward', 'NOEL'),
#  ('Network', 'RETE'),
#  ('Dernier ___', 'CRI'),
#  ('Auditor: Abbr.', 'CPA'),
#  ('Adversary', 'FOE'),
#  ('Bible book', 'ACTS'),
#  ('Seize', 'GRAB'),
#  ('Counterfeit', 'SHAM'),
#  ('Heart action', 'BEAT'),
#  ('Garbo', 'GRETA'),
#  ('Franchot', 'TONE'),
#  ('Canyon mouth', 'ABRA'),
#  ('"___, Macduff"', 'LAYON'),
#  ('Karenina', 'ANNA'),
#  ("Object of Thomas Paine's scorn", 'SUNSHINEPATRIOT'),
#  ('Crewmen', 'HANDS'),
#  ('Insect egg', 'NIT'),
#  ('Sal, e.g.', 'GAL'),
#  ('British-firm abbr.', 'LTD'),
#  ('"The Sleeping Beauty" et al.', 'BALLETS'),
#  ('Biographer of Henry James', 'EDEL'),
#  ('Koran chapter', 'SURA'),
#  ('Ipse ___', 'DIXIT'),
#  ('Fall field sight', 'SHEAF'),
#  ('Swindle', 'CON'),
#  ('Growing out', 'ENATE'),
#  ('Rich cake', 'TORTE'),
#  ("Mason's burdens", 'HODS'),
#  ('Stamp backing', 'GLUE'),
#  ('Rapture', 'ECSTASY'),
#  ('Asian sheep', 'SHA'),
#  ('Recipe abbr.', 'TSP'),
#  ('Id ___ (that is)', 'EST'),
#  ('Perfumes: Var.', 'ATARS'),
#  ('Joseph Conrad story', 'HEARTOFDARKNESS'),
#  ('Enthusiastic', 'AVID'),
#  ('Jail-door sound', 'CLANK'),
#  ('"___ virumque cano"', 'ARMA'),
#  ('Mother of Helen', 'LEDA'),
#  ('Sorts', 'KINDS'),
#  ('Mend', 'KNIT'),
#  ('Salver', 'TRAY'),
#  ('Health resorts', 'SPAS'),
#  ('Punta del ___', 'ESTE'),
#  ('Down with, in Paris', 'ABAS'),
#  ('Philippine island', 'CEBU'),
#  ('Mountain lake', 'TARN'),
#  ('Secrete', 'STASH'),
#  ('Luxembourg, e.g.', 'GRANDDUCHY'),
#  ('Kings, in Spain', 'REYES'),
#  ('On', 'ATOP'),
#  ('Basis of a certain split', 'BANANA'),
#  ('Causing surprise', 'STARTLING'),
#  ('"___ soit qui . . . "', 'HONI'),
#  ('___ Domini', 'ANNO'),
#  ('Essential part', 'MEAT'),
#  ('Flashes', 'GLINTS'),
#  ('Actor Holbrook', 'HAL'),
#  ('Diacritical mark', 'TILDE'),
#  ('Beau ___', 'GESTE'),
#  ('Kind of committee', 'ADHOC'),
#  ('Ogles', 'LEERS'),
#  ('Park fixtures', 'BANDSTANDS'),
#  ('Glorify', 'EXALT'),
#  ('Roman emperor', 'TITUS'),
#  ('Soak', 'STEEP'),
#  ('Like some saints', 'LATTERDAY'),
#  ('Marsupial, for short', 'ROO'),
#  ("Belshazzar's party", 'FEAST'),
#  ('Shovelheads', 'SHARKS'),
#  ('Big Board listings', 'STOCKS'),
#  ('Neighbor of Okla.', 'ARK'),
#  ('Turkish city', 'ADANA'),
#  ('Oil source of a sort', 'SNAKE'),
#  ('Crippled', 'HALT'),
#  ('For ___ and a day', 'EVER'),
#  ('Operatic heroine', 'AIDA'),
#  ('Impertinent', 'FLIP'),
#  ('Birds of prey', 'ERNS'),
#  ('Struck', 'SMIT'),
#  ('Cloy', 'SATE'),
#  ('African stockade', 'BOMA'),
#  ('Utmost degree', 'ACME'),
#  ('Feudal lord', 'LIEGE'),
#  ('Magnetites', 'ORES'),
#  ('Checkroom fixture', 'COATHANGER'),
#  ('Body english, in a way', 'WISHFULTHINKING'),
#  ('City-map unit', 'LOT'),
#  ('East, in Madrid', 'ESTE'),
#  ('Lets', 'LEASES'),
#  ('Kind of drum', 'SNARE'),
#  ('Bridge bid: Abbr.', 'DBL'),
#  ('Crimean river', 'ALMA'),
#  ('Pledges', 'ASSURES'),
#  ('Place for a token', 'SLOT'),
#  ('Port of Arabia', 'ADEN'),
#  ('Pointless', 'INANE'),
#  ("Gambler's dream", 'TOHITTHEJACKPOT'),
#  ('The vowels', 'AEIOU'),
#  ('Asteroid', 'EROS'),
#  ('"___ long, long way to . . . "', 'ITSA'),
#  ('Kind of general', 'TWOSTAR'),
#  ('Full extent', 'SPAN'),
#  ('Gardner of cartoons', 'REA'),
#  ('Golden calf et al.', 'IDOLS'),
#  ("Moat's protégé, in a way", 'CASTLE'),
#  ('Kettle or snare', 'DRUM'),
#  ('___ Testament', 'NEW'),
#  ('Kaufman-Hart play', 'ONCEINALIFETIME'),
#  ('Get out of the way', 'STANDASIDE'),
#  ('Cross', 'ROOD'),
#  ('Pastries', 'TARTS'),
#  ('Biblical priest', 'EBER'),
#  ('Miss Bancroft', 'ANNE'),
#  ('Rose, Cotton, etc.', 'BOWLS'),
#  ('Hunter of the sky', 'ORION'),
#  ('Hostess Perle', 'MESTA'),
#  ('Cinder', 'ASH'),
#  ('Needle, in old Rome', 'ACUS'),
#  ('Belmont entry', 'COLT'),
#  ('Matched', 'MATED'),
#  ('Ordinal suffix', 'ETH'),
#  ('Highway unit', 'LANE'),
#  ('"___ Dinka Doo"', 'INKA'),
#  ('Shield', 'EGIS'),
#  ('Hackman or Tierney', 'GENE'),
#  ('Work units', 'ERGS'),
#  ('Quirinal and Bunker, e.g.', 'HILLS'),
#  ('Sense', 'FEEL'),
#  ('Fractions', 'RATIOS'),
#  ('Minstrel-show instruments', 'BANJOS'),
#  ('Doorstep fixture', 'MAT'),
#  ('Cling to', 'ADHERE'),
#  ('"___ transit gloria . . . "', 'SIC'),
#  ('Harsh', 'UNKIND'),
#  ('Engrossed', 'RAPT'),
#  ("Seth's son", 'ENOS'),
#  ('Bristle', 'SETA'),
#  ('Photocopy', 'STAT'),
#  ('Movie-chain name', 'LOEW'),
#  ("Louisville's river", 'OHIO'),
#  ('Poetic word', 'EER'),
#  ('Mild rebuke', 'TUT'),
#  ('Viper', 'ASP'),
#  ('Sports place', 'ARENA'),
#  ('Love, in France', 'AIME'),
#  ('Improvise', 'ADLIB'),
#  ('Kind of ring', 'ONION'),
#  ('Kind of ade', 'LEMON'),
#  ('Bjorn Borg, e.g.', 'SWEDE'),
#  ('Expense', 'COST'),
#  ('Wall pier', 'ANTA'),
#  ('Unpleasant aftermath', 'SCAR'),
#  ("Omar's product", 'TENT'),
#  ('Covers', 'LIDS'),
#  ('___ out (endure)', 'RIDE'),
#  ('Shore, in Bonn', 'UFER'),
#  ('Enzyme suffix', 'ASE'),
#  ('___-la', 'TRA'),
#  ('Talks on and on', 'PRATES'),
#  ('Meal', 'REPAST'),
#  ('Kind of control', 'REMOTE'),
#  ('Springy', 'ELASTIC'),
#  ('Patriots of 1776', 'CONTINENTALARMY'),
#  ('Consumed', 'ATE'),
#  ('Giveaway-ad words', 'TAKEONE'),
#  ("Poet's word", 'EER'),
#  ("Parishioner's place", 'PEW'),
#  ('German article', 'EIN'),
#  ('___ the line', 'TOE'),
#  ('Nautical reading', 'ESE'),
#  ('Like some seals', 'EARLESS'),
#  ('Large cask', 'TUN'),
#  ('Meanders', 'STROLLS'),
#  ('Give orders', 'DICTATE'),
#  ('City way: Abbr.', 'AVE'),
#  ('Chinese leader', 'MAO'),
#  ('Have', 'POSSESS'),
#  ('Certain musician', 'HARPIST'),
#  ('Emmet', 'ANT'),
#  ('Protestant nonconformist', 'SECTARY'),
#  ('French sea', 'MER'),
#  ('Certain vote', 'YEA'),
#  ('Morsel', 'ORT'),
#  ('Be indebted', 'OWE'),
#  ('"___ in the stilly night"', 'OFT'),
#  ('___ pensée (hidden motive)', 'ARRIERE'),
#  ('Channel', 'GAT'),
#  ('Declaration signers', 'FOUNDINGFATHERS'),
#  ('Interdicted', 'FORBADE'),
#  ('Let go', 'UNHAND'),
#  ('Joined up with', 'TEAMED'),
#  ('Hosiery threads', 'LISLES'),
#  ('Dissent', 'PROTEST'),
#  ('Library user, at times', 'RENEWER'),
#  ('Quantity: Abbr.', 'AMT'),
#  ('Roof, in Paris', 'TOIT'),
#  ('Lab vessel', 'ETNA'),
#  ('Ones with a quest', 'SEEKERS'),
#  ('Modified colors again', 'RETONED'),
#  ('Spirit', 'ELAN'),
#  ('Lacking vigor', 'PALE'),
#  ('Blind ___ bat', 'ASA'),
#  ('Musical passage', 'STRETTA'),
#  ('Recess', 'TIMEOUT'),
#  ('Libyan resort', 'CYRENE'),
#  ("Matadors' needs", 'CAPES'),
#  ('Armstrong', 'NEIL'),
#  ('Little people', 'ELVES'),
#  ('Scabbard lining: Fr.', 'ALESE'),
#  ('Loose jacket', 'SIMAR'),
#  ('Frightening', 'SCARY'),
#  ('Western alliance', 'OAS'),
#  ('Spinner', 'TOP'),
#  ('Retribution', 'PAYOFF'),
#  ('Twelve inches', 'ONEFOOT'),
#  ('Importance', 'STATURE'),
#  ('" . . . like a woman ___"', 'SCORNED'),
#  ('Odious', 'HATEFUL'),
#  ('Miss Coca', 'IMOGENE'),
#  ('___ Folly (Alaska)', 'SEWARDS'),
#  ('Waste allowances', 'TRETS'),
#  ('Neat', 'TRIG'),
#  ('Genesis man', 'ADAM'),
#  ('Take for a ___', 'RIDE'),
#  ('Hindu queen', 'RANI'),
#  ('Anglo-Saxon letters', 'ETHS'),
#  ("Knicks' league: Abbr.", 'NBA'),
#  ('Prince ___', 'HAL'),
#  ("Skiers' lifts", 'TOWS'),
#  ('Midwest city', 'OMAHA'),
#  ('Bible book', 'ACTS'),
#  ('One of the five', 'ERIE'),
#  ('___ colony', 'PENAL'),
#  ('Hindu goddess of beauty', 'SHRI'),
#  ('Lofty words in an atlas', 'CANADIANROCKIES'),
#  ('Enlarges', 'ADDSONTO'),
#  ("MIG's and SST's", 'PLANES'),
#  ('Aviator Post', 'WILEY'),
#  ('Hashhouse', 'BEANERY'),
#  ('Like a knife', 'BLADED'),
#  ('Divides again', 'RECUTS'),
#  ('Ventilated', 'AIRED'),
#  ('Sensational', 'LURID'),
#  ('Compass point', 'ENE'),
#  ('Star in Cygnus', 'SADR'),
#  ('Buddhist writing', 'SUTRA'),
#  ('Prurient matter', 'SMUT'),
#  ('Silkworm', 'ERI'),
#  ('Shoddy', 'TATTY'),
#  ('Monotonous sound', 'CHANT'),
#  ('Obdurate: Var.', 'STONEY'),
#  ('Alternative', 'CHOICE'),
#  ('Plateaus', 'UPLANDS'),
#  ('Inexperienced', 'GREEN'),
#  ('Tricks', 'PRANKS'),
#  ("Referees' needs", 'WHISTLES'),
#  ('Narrow words in an atlas', 'SINGAPORESTRAIT'),
#  ('Taro root', 'EDDO'),
#  ('Miss Bordoni', 'IRENE'),
#  ('Nine: Prefix', 'ENNE'),
#  ('Hardy girl', 'TESS'),
#  ('Bivouac ingredients', 'TENTS'),
#  ('Paradise', 'EDEN'),
#  ('Mexican Indian', 'TECA'),
#  ('Toward the mouth', 'ORAD'),
#  ('Little words in a atlas', 'WINDWARDISLANDS'),
#  ('Coast dweller', 'SEASIDER'),
#  ('Thought', 'OPINED'),
#  ('Substantial', 'MEATY'),
#  ('___ Domini', 'ANNO'),
#  ('Cambridge university: Abbr.', 'HAR'),
#  ('Baldness', 'ALOPECIA'),
#  ('Obliquely', 'ASKANT'),
#  ('Big words in an atlas', 'CHINESEMAINLAND'),
#  ('Shoe-factory worker', 'TREER'),
#  ('Timid one', 'SISSY'),
#  ('Parceled out', 'DOLED'),
#  ("Man's name", 'CLAUD'),
#  ('Black, blue or straw', 'BERRY'),
#  ('Low', 'BASE'),
#  ('Prevaricator', 'LIAR'),
#  ('Like old roads', 'RUTTY'),
#  ('Musical instruments', 'LUTES'),
#  ('___ Dimittis', 'NUNC'),
#  ('Feminine ending', 'ETTE'),
#  ('Small point of land', 'SANDSPIT'),
#  ('Closet item', 'SHOETREE'),
#  ('Tropical bean', 'TONKA'),
#  ('Community ___', 'CHEST'),
#  ('Dances', 'TANGOS'),
#  ('Turning points', 'CRISES'),
#  ('In a dither', 'UPSET'),
#  ("Fall's precursor", 'PRIDE'),
#  ('Belgian city', 'GHENT'),
#  ('Songbird', 'WREN'),
#  ('German article', 'EINE'),
#  ('British gun', 'STEN'),
#  ('Smeltery material', 'ORE'),
#  ('Biblical mount', 'PISGAH'),
#  ('Musical introductions', 'PRELUDES'),
#  ('Prompt', 'ONTIME'),
#  ('Firmly determined', 'RESOLUTE'),
#  ('Roger Kahn novel', 'THEBOYSOFSUMMER'),
#  ('Axe, e.g.', 'HEWER'),
#  ('Curved moldings', 'OGEES'),
#  ('In favor of', 'PRO'),
#  ('Old English moneys', 'ORAS'),
#  ('Reporters: Abbr.', 'CORRS'),
#  ('Lairs', 'DENS'),
#  ('Celtic Neptune', 'LER'),
#  ('Siberian native', 'TATAR'),
#  ('___ mistake (erred)', 'MADEA'),
#  ('Minstrel-show performers', 'ENDMEN'),
#  ('Of the cheek', 'MALAR'),
#  ('French philosopher', 'STSIMON'),
#  ('Romantic demonstrations', 'LOVEINS'),
#  ('Asparagus unit', 'SPEAR'),
#  ('Failed to', 'DIDNOT'),
#  ('Make ___ (rendezvous)', 'ADATE'),
#  ('Affirmations', 'YESES'),
#  ('Moscow affiliate: Abbr.', 'SSR'),
#  ('Celsius units: Abbr.', 'DEGS'),
#  ('Nile dam site', 'ASWAN'),
#  ('Shower affection on', 'DOTE'),
#  ('Paddle', 'OAR'),
#  ('Done in', 'SLAIN'),
#  ('Soft drinks', 'COLAS'),
#  ('Subject of 17 Across', 'BROOKLYNDODGERS'),
#  ('Came from', 'EMANATED'),
#  ('Reveal', 'EVINCE'),
#  ('Ervin et al.', 'SENATORS'),
#  ('Fractions', 'NINTHS'),
#  ('Threats to auto axles', 'POTHOLES'),
#  ('Innate', 'INHERENT'),
#  ('Flight attendants', 'STEWARDS'),
#  ('Taunts', 'GIBES'),
#  ('Eros', 'AMOR'),
#  ('Attention-getter', 'HEY'),
#  ('Playbill', 'PROGRAM'),
#  ("Asterisk's function", 'REFERRAL'),
#  ('Letters', 'ESSES'),
#  ('Gehrig et al.', 'LOUS'),
#  ('Danube city', 'ULM'),
#  ('Unloaded', 'DUMPED'),
#  ('Everlasting, formerly', 'ETERNE'),
#  ('Insect membrane', 'SEROSA'),
#  ('Relative of fly ash', 'SOOT'),
#  ('Kayak', 'CANOE'),
#  ('Was adventurous', 'DARED'),
#  ('Phoenix suburb', 'TEMPE'),
#  ('Song thrush', 'MAVIS'),
#  ('Atomizer outputs', 'MISTS'),
#  ('Thick woolen cloth', 'LODEN'),
#  ('Contrary one', 'NAYSAYER'),
#  ('Disrespectful', 'INSOLENT'),
#  ('Collar-washing instruction', 'NOSTARCH'),
#  ('Emphasizes', 'STRESSES'),
#  ('Tape-recorder buttons', 'REWINDS'),
#  ('Earthen bricks', 'ADOBES'),
#  ('Alas!', 'DEARME'),
#  ('Let out ___ (show frustration)', 'AGROAN'),
#  ('Hourglass filler', 'SAND'),
#  ('___ the good', 'ALLTO'),
#  ('___ the manger', 'DOGIN'),
#  ('Card game', 'SKAT'),
#  ('Roman 406', 'CDVI'),
#  ('"Cat ___ Hot Tin Roof"', 'ONA'),
#  ('Wine: Prefix', 'OEN'),
#  ('Fix a hose hole', 'DARN'),
#  ("Strains, as one's brains", 'RACKS'),
#  ("Torero's wear", 'CAPA'),
#  ('Tropical oil tree', 'EBOE'),
#  ("Atlantic convoy's foe", 'UBOAT'),
#  ('Swan genus', 'OLOR'),
#  ('Certain sixth sense', 'WOMANSINTUITION'),
#  ('Allows', 'SUPPOSES'),
#  ('Pipe-bowl residue', 'DOTTLE'),
#  ('Prefix with fold or dent', 'TRI'),
#  ('"I ___ man with . . . "', 'META'),
#  ('City on the Arno', 'PISA'),
#  ('Like a friar', 'MONASTIC'),
#  ('Family members', 'MAIDENAUNTS'),
#  ('Mrs. Johnson', 'OSA'),
#  ('Early thrall', 'ESNE'),
#  ('Jet plane', 'SST'),
#  ('Hair coils', 'BUNS'),
#  ('Man of briefs: Abbr.', 'ATT'),
#  ('Worldly parent', 'MOTHEREARTH'),
#  ("Mother's order to child", 'DOASISAY'),
#  ('Cloth measures', 'ELLS'),
#  ('Shade givers', 'ELMS'),
#  ('Harden', 'GEL'),
#  ('Breastbone: Prefix', 'STERNO'),
#  ('___ the Mount', 'SERMONON'),
#  ('Fiancées, in a way', 'LADIESINWAITING'),
#  ('Helm direction', 'ALEE'),
#  ('Like some walls', 'IVIED'),
#  ('Work on copy', 'EDIT'),
#  ('___ wear', 'MENS'),
#  ('Cavalry piece', 'SABRE'),
#  ('Sleuths: Abbr.', 'DETS'),
#  ('Moistens', 'DEWS'),
#  ('Arabian father', 'ABOU'),
#  ('Cut a dido', 'ROMP'),
#  ('Ocean current', 'NEAPTIDE'),
#  ('Ballet or bank', 'RUSSIAN'),
#  ("Rose's Romeo", 'ABIE'),
#  ('Swindles', 'CONS'),
#  ('Arabian tea', 'KAT'),
#  ('Matriculant', 'STUDENT'),
#  ('Priestly surplices', 'COTTAS'),
#  ('Came down', 'ALIT'),
#  ('Relative of a cartel', 'POOL'),
#  ('British composer', 'ARNE'),
#  ('People of Bergen', 'NORSE'),
#  ('Small bits', 'IOTAS'),
#  ('Casino card game', 'MONTE'),
#  ('Ship of exploring fame', 'PINTA'),
#  ('Like an overripe melon', 'MUSHY'),
#  ("Cook's offerings", 'TOURS'),
#  ('"___ It Romantic?"', 'ISNT'),
#  ('Wherewithal', 'CASH'),
#  ('Lake or Margaret', 'MEAD'),
#  ('Concerning', 'ASTO'),
#  ('Movie dog et al.', 'ASTAS'),
#  ('Went to the polls', 'BALLOTED'),
#  ('A.A. ___', 'MILNE'),
#  ('Subtle absorption', 'OSMOSIS'),
#  ('Do a road job', 'REGRADE'),
#  ('Tropical resin', 'ELEMI'),
#  ('World ___', 'SERIES'),
#  ('Bridge bid', 'SLAM'),
#  ('Narrative', 'TALE'),
#  ('British P.M.', 'EDEN'),
#  ('Rebuff, Scottish style', 'SNIB'),
#  ('Pitcher', 'EWER'),
#  ('Brood of pheasants', 'NIDE'),
#  ('" . . . with a blue ribbon ___"', 'ONIT'),
#  ('Theater-ad abbr.', 'NGTS'),
#  ('Ragweed genus', 'IVA'),
#  ('"Uncle Vanya" author', 'CHEKHOV'),
#  ('Holy city', 'MECCA'),
#  ('Word with legs or cuffs', 'TROUSER'),
#  ('Dramatist of the absurd', 'IONESCO'),
#  ('One of a French trio', 'ATHOS'),
#  ('Great joy', 'RAPTURE'),
#  ('Potters', 'CLAYMEN'),
#  ('Hotel-desk postings', 'CHECKOUTTIMES'),
#  ('Intends', 'AIMS'),
#  ('Aardvark food', 'ANTS'),
#  ('Contents of certain books', 'CHECKS'),
#  ('Milk: Prefix', 'LACT'),
#  ('___ volente', 'DEO'),
#  ('Recent: Prefix', 'NEO'),
#  ('Bypass closely', 'SKIRT'),
#  ('Factions', 'SECTS'),
#  ('Irish cry', 'ARRA'),
#  ("Arthur's nephew", 'GAWAIN'),
#  ('Great Barrier Island', 'OTEA'),
#  ('Geste or Nash', 'BEAU'),
#  ('Sea flier', 'ERN'),
#  ('Sing loudly, with "out"', 'BELT'),
#  ('Palm leaf: Var.', 'OLA'),
#  ('English game pebble', 'CHECKSTONE'),
#  ('Makes inquiries', 'CHECKSUPON'),
#  ('Humperdinck boy', 'HANSEL'),
#  ('Base runner, at times', 'STEALER'),
#  ('Treatment', 'USAGE'),
#  ('Common abbr.', 'ETC'),
#  ('___ code', 'AREA'),
#  ('Ground defense: Abbr.', 'LAA'),
#  ('African native', 'SOMALI'),
#  ('Stopovers for game pieces', 'CHECKERBOARDSQUARES'),
#  ('Whistle stop', 'HAMLET'),
#  ('Gold tinctures', 'ORS'),
#  ('Plaster item', 'CAST'),
#  ("Rockefeller's oil: Abbr.", 'STD'),
#  ('Miss Adoree', 'RENEE'),
#  ("Contract's predecessor", 'AUCTION'),
#  ('Coin', 'SPECIE'),
#  ('Realists', 'ACTUALISTS'),
#  ('Full go-ahead', 'BLANKCHECK'),
#  ('Estes and Menlo: Abbr.', 'PKS'),
#  ('Bird plumage', 'RUFF'),
#  ('Owned', 'HAD'),
#  ("Creil's river", 'OISE'),
#  ('Elbe tributary', 'EGER'),
#  ('Object of perception', 'SENSUM'),
#  ('"What ___ God wrought!"', 'HATH'),
#  ('Samantha', 'EGGAR'),
#  ('Miss Kett et al.', 'ETTAS'),
#  ('Roman way', 'VIA'),
#  ('Relative: Abbr.', 'BRO'),
#  ('Skin', 'DERM'),
#  ('Sleigh puller', 'DASHER'),
#  ('Show surprise', 'GASP'),
#  ('Small herring', 'BRIT'),
#  ('Accurate one', 'DOUBLECHECKER'),
#  ('Most trim', 'TIDIEST'),
#  ("Harmonizers' girl", 'ADELINE'),
#  ('Type of song', 'THEME'),
#  ('Set apart', 'ISOLATE'),
#  ('Picks', 'SELECTS'),
#  ('As good ___', 'ASNEW'),
#  ('Early stringed instrument', 'CHEKKER'),
#  ('Large insect', 'CICADA'),
#  ('"___ than thou"', 'HOLIER'),
#  ('Charm', 'ENAMOR'),
#  ('Florida sights', 'KEYS'),
#  ('Royal initials', 'HSM'),
#  ('Kind of ography', 'OCEAN'),
#  ('Author Kurt', 'VONNEGUT'),
#  ('Raincoats, for short', 'MACS'),
#  ('Moral: Abbr.', 'ETH'),
#  ('Begin a hotel visit', 'CHECKIN'),
#  ('Chinese fowl', 'COCHIN'),
#  ('Suppliant', 'ASKER'),
#  ('Japanese bastion of W.W. II', 'TRUK'),
#  ('Zounds!', 'RATS'),
#  ('Decide', 'OPT'),
#  ('Practical', 'UTILE'),
#  ('Common field plant', 'SUMAC'),
#  ('Establish', 'ERECT'),
#  ('Shelters or hostels', 'RESTS'),
#  ('1905 manifesto', 'OCTOBER'),
#  ('___ tee', 'TOA'),
#  ('Hindu garment', 'SAREE'),
#  ('Japanese orange', 'SATSUMA'),
#  ('Fundamentals', 'ABCS'),
#  ('Traveled widely', 'WENTABOUT'),
#  ("Flatfoot's relative", 'TEC'),
#  ('Social-club member', 'ELK'),
#  ('Squeeze out', 'EKE'),
#  ('Abate, old style', 'ASLAKE'),
#  ('Give out iridescence', 'OPALESCE'),
#  ('Of a military science', 'LOGISTIC'),
#  ('Carbon: Suffix', 'ANE'),
#  ('Guevara', 'CHE'),
#  ('Kind of girl', 'HATCHECK'),
#  ('Delights', 'ENCHANTS'),
#  ('Dare: Fr.', 'OSER'),
#  ("Goodman's instr.", 'CLAR'),
#  ('Sniffles', 'HEADCOLDS'),
#  ('Asian grass', 'USAR'),
#  ('As ___ resort', 'ALAST'),
#  ('Soak', 'RET'),
#  ('Trafalgar and Times: Abbr.', 'SQS'),
#  ('Excel in the slalom', 'OUTSKI'),
#  ('Tall bird', 'EMEU'),
#  ('Less smoggy', 'CLEARER'),
#  ('Grampuses', 'ORCS'),
#  ('Arabian capital', 'SANA'),
#  ('Ten: Prefix', 'DEK'),
#  ('Door sound', 'RAP'),
#  ('___ as a daisy', 'ASFRESH'),
#  ('Borneo natives', 'IBANS'),
#  ('Portions: Abbr.', 'PCS'),
#  ('Querying sounds', 'EHEH'),
#  ('Haul', 'LUG'),
#  ('Bowstring hemp', 'IFE'),
#  ('Based on moral law', 'NOMISTIC'),
#  ('Listen carefully', 'HEARKEN'),
#  ('Crams, in Scotland', 'STECHS'),
#  ('Grape', 'UVA'),
#  ('Take ___ (rest)', 'ABREAK'),
#  ('Sad, in Dijon', 'TRISTE'),
#  ('More biting', 'HOTTER'),
#  ('Norse tales', 'EDDAS'),
#  ('Hollow stone', 'GEODE'),
#  ('Thin cereal', 'GRUEL'),
#  ('Stroll along', 'AMBLE'),
#  ('Greek letter', 'THETA'),
#  ('Clownlike', 'APISH'),
#  ('Parking-lot hazard', 'DENT'),
#  ('Honor cards', 'ACES'),
#  ('Expanded', 'GREW'),
#  ('Swindle', 'BILK'),
#  ('Auto plate: Abbr.', 'LIC'),
#  ('Uncle, in Perth', 'EME'),
#  ('Deer', 'DOE'),
#  ('___ ground (regress)', 'LOSE'),
#  ('Big success', 'SMASH'),
#  ('Blue or poker', 'CHIP'),
#  ('To ___', 'AMAN'),
#  ('Put aside', 'PIGEONHOLE'),
#  ('Proceeds steadily', 'HOLDSONESCOURSE'),
#  ('Seafood delicacy', 'ROE'),
#  ('Greek goddess', 'ERIS'),
#  ('Kind of tube', 'INNER'),
#  ('Barracudas', 'SPETS'),
#  ('___ out (spend)', 'FORK'),
#  ('Network', 'LACIS'),
#  ('"___ were the days"', 'THOSE'),
#  ('Greek letter', 'CHI'),
#  ('Key', 'ISLET'),
#  ('Fatha Hines', 'EARL'),
#  ('Hangar', 'SHED'),
#  ('In ___ (eventually)', 'THECOURSEOFTIME'),
#  ('Present', 'HERE'),
#  ('Jets', 'SSTS'),
#  ('Where strikes are appreciated', 'LANES'),
#  ('Arctic native: Abbr.', 'ESK'),
#  ('Influence', 'GETAT'),
#  ('Abounding in: Suffix', 'ULENT'),
#  ('Foot: Prefix', 'PEDO'),
#  ('Arctic sights', 'FLOES'),
#  ("Nora's creator", 'IBSEN'),
#  ('Tale-teller', 'LIAR'),
#  ('___ up (delight in)', 'EAT'),
#  ('Let things ___ (leave alone)', 'TAKETHEIRCOURSE'),
#  ('One shifted to a new post', 'TRANSFEREE'),
#  ('___-do-well', 'NEER'),
#  ("Stable-owner's purchase", 'OATS'),
#  ('Kind of conscious', 'CLASS'),
#  ('Cheese', 'EDAM'),
#  ('Memorable comic', 'LAHR'),
#  ('Melville creation', 'OMOO'),
#  ('Store employee', 'SALESCLERK'),
#  ('Result', 'END'),
#  ('Kind of shirt', 'SPORT'),
#  ('Cares for', 'MINISTERSTO'),
#  ('Stone et al.', 'AGES'),
#  ('His, in Le Mans', 'SES'),
#  ('Ad ___', 'HOC'),
#  ('Piece', 'CHUNK'),
#  ('___ in (interfere)', 'HORN'),
#  ("Girl's name in Bonn", 'ILSE'),
#  ('Titled one', 'PEER'),
#  ('Black, in France', 'NOIRE'),
#  ('Looks after', 'SEESTO'),
#  ('Word with work or meal', 'PIECE'),
#  ("Rangers' concerns", 'FORESTFIRES'),
#  ('European capital', 'OSLO'),
#  ('Supple', 'LITHE'),
#  ('Residue', 'ASHES'),
#  ('___ luego (good-by)', 'HASTA'),
#  ('Color', 'CHINESERED'),
#  ('Virile ones', 'HEMEN'),
#  ('Common Latin phrase', 'IDEST'),
#  ('Like some jokes', 'STALE'),
#  ('Put into practice', 'USED'),
#  ('Chemical prefix', 'FLUORO'),
#  ('Chaps', 'GENTS'),
#  ('Hammer parts', 'PEENS'),
#  ('Spikes the punch', 'LACES'),
#  ('"Tell ___ the Marines"', 'ITTO'),
#  ('Theda', 'BARA'),
#  ('Card game', 'SKAT'),
#  ('European money', 'LIRA'),
#  ('Bewildered', 'ASEA'),
#  ('Duration', 'TERM'),
#  ('Electrical abbr.', 'HFC'),
#  ('Slippery one', 'EEL'),
#  ('French article', 'UNE'),
#  ('Hemingway', 'PAPA'),
#  ('Bout', 'SETTO'),
#  ('Declines', 'EBBS'),
#  ('Final or midterm event', 'EXAM'),
#  ('Group character', 'ETHOS'),
#  ('Mrs. Nick Charles', 'NORA'),
#  ("Like Dali's watches", 'LIMP'),
#  ('Rec and living', 'ROOMS'),
#  ('Hamilton-Burr meet', 'DUEL'),
#  ('Recipe abbr.', 'TSP'),
#  ('"Je ___ beaucoup"', 'TAIME'),
#  ("Guy's friend", 'GAL'),
#  ('Furor', 'HOOPLA'),
#  ('Four score', 'EIGHTY'),
#  ('"We ___" (with 43 Across)', 'HOLDTHESETRUTHS'),
#  ('Garbo, e.g.', 'SWEDE'),
#  ('He had not yet begun to fight', 'JONES'),
#  ('Asian holiday', 'TET'),
#  ('Madison Square Garden, e.g.', 'ARENA'),
#  ('___ Jeanne', 'STE'),
#  ('Musical symbol', 'GCLEF'),
#  ('Turns up a card', 'FACES'),
#  ('See 28 Across', 'TOBESELFEVIDENT'),
#  ('Bryant and Loos', 'ANITAS'),
#  ('Ace, as part of a blackjack', 'ELEVEN'),
#  ('Knowledge', 'KEN'),
#  ('Derrick', 'CRANE'),
#  ('Also', 'AND'),
#  ('Catchall abbr.', 'ETAL'),
#  ('Affirm', 'POSIT'),
#  ('Canal', 'ERIE'),
#  ('Shredded', 'TORE'),
#  ('Unique', 'ALONE'),
#  ("___ days' wonder", 'NINE'),
#  ('Former movie czar Will', 'HAYS'),
#  ('Approached an end', 'WANED'),
#  ('Soft ___ (flattery)', 'SOAP'),
#  ('Hide', 'PELT'),
#  ('W. W. II losers', 'AXIS'),
#  ('"Common Sense," e.g.', 'PAMPHLET'),
#  ('Elec. unit', 'AMP'),
#  ('Angel', 'SERAPH'),
#  ("Paris's Place d' ___", 'ETOILE'),
#  ('Author of 28 Across', 'THOMASJEFFERSON'),
#  ('Scholarly volume', 'TOME'),
#  ('W. W. II agency', 'OSS'),
#  ('Wind up', 'END'),
#  ('Bribed, as a public official', 'BOUGHT'),
#  ('Slightest hint', 'BREATH'),
#  ('Kellerman and Rand', 'SALLYS'),
#  ('Carry', 'TOTE'),
#  ('___ man out', 'ODD'),
#  ('Volcano', 'ETNA'),
#  ('Choler', 'IRE'),
#  ('Astronaut Grissom', 'GUS'),
#  ('White House monogram', 'HST'),
#  ('Be in the red', 'OWE'),
#  ('Time period', 'EON'),
#  ('Beverages', 'ALES'),
#  ('Kind of pronoun: Abbr.', 'REL'),
#  ("Film-director's bible", 'SCENARIO'),
#  ('Sawbuck', 'TEN'),
#  ('Part of i.e.', 'EST'),
#  ('Fetch', 'GET'),
#  ("Lee's group: Abbr.", 'CSA'),
#  ('Fin', 'FIVE'),
#  ('Summer cooler', 'ADE'),
#  ('"And the Lord ___ away"', 'TAKETH'),
#  ('___ customer', 'ONETOA'),
#  ('Consisting of two', 'BINARY'),
#  ('Miss Stritch', 'ELAINE'),
#  ("Loosed, as one's fury", 'VENTED'),
#  ('Soft drink', 'COLA'),
#  ("Pinta's partner", 'NINA'),
#  ('Intense', 'DEEP'),
#  ('French article', 'LES'),
#  ('Handle roughly', 'PAW'),
#  ('Type measures', 'ENS'),
#  ('Pith helmet', 'TOPI'),
#  ('Halloween choice', 'TRICK'),
#  ('Church area', 'APSE'),
#  ('N.C. College', 'ELON'),
#  ('Tidal wave', 'EAGRE'),
#  ('Fish bait', 'CHUM'),
#  ('Obvious', 'SELFEXPLANATORY'),
#  ('Trifled', 'TOYED'),
#  ('Awkward boat', 'TUB'),
#  ('Water pots of India', 'LOTAS'),
#  ('___ and Thummim', 'URIM'),
#  ('Spanish painter', 'MIRO'),
#  ('Newspaper section: Abbr.', 'FIN'),
#  ('Asian palm', 'TALIPOT'),
#  ('Prod', 'JAB'),
#  ('Besides', 'ALSO'),
#  ('Wanderer', 'NOMAD'),
#  ('___ de force', 'TOUR'),
#  ('Coin of Iran', 'RIAL'),
#  ('Century plant', 'AGAVE'),
#  ('Rough', 'RUDE'),
#  ('Attractive', 'CUTE'),
#  ('Roman menswear', 'TOGAS'),
#  ('Silkworm', 'ERIA'),
#  ("Ostrich's relative", 'EMU'),
#  ('Takes umbrage', 'RESENTS'),
#  ('Land of ___', 'NOD'),
#  ('Dissolute one', 'ROUE'),
#  ('Mental discipline', 'YOGA'),
#  ('Freshwater fish', 'ROACH'),
#  ('Shinto temple', 'SHA'),
#  ("La Scala's locale", 'MILAN'),
#  ('Cannibal', 'ANTHROPOPHAGITE'),
#  ('Brain passage', 'ITER'),
#  ('Jewish festival', 'PURIM'),
#  ("One of Ibsen's homes", 'OSLO'),
#  ('Ore deposit', 'LODE'),
#  ('Indian coins', 'ANNAS'),
#  ('Feds', 'TMEN'),
#  ('Exam', 'TEST'),
#  ('Toast additive', 'OLEO'),
#  ('Like 2 Down', 'POLYUNSATURATED'),
#  ('Conclude', 'INFER'),
#  ('Ritter or Antoine', 'TEX'),
#  ('Transported', 'RAPT'),
#  ('Eskimo hut', 'IGLU'),
#  ('Curmudgeon', 'CRAB'),
#  ('Understanding', 'KEN'),
#  ('Performer', 'ACTOR'),
#  ('Special type of reporting', 'PHOTOJOURNALISM'),
#  ('Koran chapter', 'SURA'),
#  ('Tortoise genus', 'EMYS'),
#  ('Work on copy', 'EDIT'),
#  ('Landed', 'ALIT'),
#  ('Sea cow', 'MANATEE'),
#  ('Decorum', 'MODESTY'),
#  ("Molière's forte", 'FARCE'),
#  ('Troy, to Caesar', 'ILIUM'),
#  ...]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (602694, 604)

# %%
# Vectorize Clues
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(strip_accents="unicode", stop_words="english")
X_train = vectorizer.fit_transform(np.array(clues_train))
X_train

# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)
# Out:
# <602694x69152 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1250059 stored elements in Compressed Sparse Row format>

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors().fit(X_train)
model
# Out:
# NearestNeighbors()

# %%
# Define a guesser function (just for testing; real one defined in guesser.py)
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector = vectorizer.transform([clue])
    distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
    raw_guesses = [answers_train[i] for i in indices[0]]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue.lower()
        return o
    
    guesses = [(g, d) for g, d in zip(raw_guesses, distances[0]) if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
i = random.randint(0, len(clues_test))
test_clue, test_answer = clues_test[i], answers_test[i]
print("clue:", test_clue)
print("answer:", test_answer)

# distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# print("guesses:", [answers_train[i] for i in indices[0]])

guesses = guess(test_clue, slot_length=len(test_answer))
print("guesses:", guesses)
# Out:
# clue: Williams's "___ Real"
# answer: CAMINO
# guesses: ['CAMINO', 'ACTUAL', 'ACTUAL', 'INESSE', 'INESSE']

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
    if i % 100 == 0: print(i)
    guesses = guess(clue, len(answer), max_guesses=5)
    if answer in guesses:
        correct_pairs.append((clue, answer, guesses))
    else:
        incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# Accuracy: 50.993%

# %%
incorrect_pairs
# Out:
# [('Bargain model: Prefix',
#   'ECONO',
#   ['STEAL', 'IDEAL', 'IDEAL', 'POSER', 'IDEAL']),
#  ('One-fifth of CCLX', 'LII', ['AVE', 'AVE', 'LEO', 'SOL', 'AVE']),
#  ('Ready to be driven',
#   'TEEDUP',
#   ['INGEAR', 'HERDED', 'CATTLE', 'GEARUP', 'ALLSET']),
#  ('Within reason', 'SANE', ['ERGO', 'ERGO', 'SAKE', 'NEED']),
#  ('Do something', 'REACT', ['EVENS', 'AMONG', 'LOONY', 'VOWEL', 'AGREE']),
#  ('Had lingering effects', 'ECHOED', ['ABLAZE', 'BIGWIG']),
#  ('Equipment for Olympian Lindsey Vonn',
#   'SKIS',
#   ['EROS', 'HERA', 'ZEUS', 'EROS', 'VERB']),
#  ('Early Irish alphabet', 'OGUM', ['OGAM', 'OGAM', 'ERSE', 'ARRA', 'ARRA']),
#  ('Cancel', 'ABORT', ['ANNUL', 'SCRUB', 'ANNUL', 'SCRUB', 'ANNUL']),
#  ('Not yielding much', 'LEAN', ['SOFT', 'EBOE', 'EBOE', 'ALOE', 'HEMP']),
#  ('___ honorables (reparations)', 'AMENDES', ['BERNARD', 'STREAMS']),
#  ('Triggers', 'SETSOFF', ['ELAINES', 'ERECTED', 'REGRESS', 'ALITTLE']),
#  ('-', 'BRITISHALEHOUSE', []),
#  ('One way to smile', 'PRETTILY', []),
#  ("Jack's need", 'PLAY', ['AMMO', 'POOR', 'TIRE', 'ALLI', 'PAAR']),
#  ('Civil war, e.g.', 'OXYMORON', []),
#  ('"David," e.g.', 'NUDE', ['CAMP', 'CAMP', 'CAMP', 'CAMP', 'CAMP']),
#  ('He wrote "The Proper Bostonians"',
#   'AMORY',
#   ['REEVE', 'NOUNS', 'NOUNS', 'NOUNS', 'PRUDE']),
#  ("One of a multitude in a devil's-snuffbox",
#   'SPORE',
#   ['HORDE', 'HORDE', 'HORDE', 'HORDE', 'HORDE']),
#  ('Yak', 'GAS', ['GAB', 'GAB', 'GAB', 'GAB', 'GAB']),
#  ('Short camping trips', 'SLEEPOUTS', []),
#  ('"I cast ___ to earth": Tennyson',
#   'ASEED',
#   ['TOSEA', 'NOTOF', 'NOTOF', 'THREW', 'SLING']),
#  ('"My ___ Foot"', 'LEFT', ['INIT', 'TROD', 'ARCH', 'INCH', 'STEP']),
#  ('Mining samples', 'CORES', ['CLAYS', 'LEDGE', 'PICKS', 'ABIDE']),
#  ('On all ___ (crawling, say)',
#   'FOURS',
#   ['ISSUE', 'ELECT', 'DITTO', 'ELIOT', 'SATED']),
#  ('Foresail', 'JIB', ['WED', 'GEE', 'OHO', 'FRO', 'TOO']),
#  ('-like', 'ISH', ['ODD', 'INT', 'ODD', 'ODD', 'DIG']),
#  ('Send a quick update, in a way', 'TEXT', ['WIRE', 'ALVA', 'ARTS', 'CONE']),
#  ('Major: Mus.', 'DUR', ['NUS', 'NUS']),
#  ('Pop star', 'IDOL', ['NOVA', 'EACH', 'NEHI', 'SODA', 'SODA']),
#  ('Sister of Calliope', 'URANIA', ['THALIA', 'EILEEN', 'EILEEN', 'STOPIT']),
#  ('Elizabeth I or II', 'QUEEN', ['TIARA', 'OCEAN', 'NIECE', 'NIECE', 'ESSEX']),
#  ('Banquette item', 'CUSHION', ['ARTICLE', 'CATALOG']),
#  ('Two-time A.L. home run champ Tony',
#   'ARMAS',
#   ['KINER', 'KINER', 'AARON', 'OLIVA', 'MARIS']),
#  ('Do at the wrong moment', 'MISTIME', ['SHORTLY', 'THESPUR']),
#  ('Dessert made from a Brazilian export',
#   'TAPIOCA',
#   ['SPUMONE', 'SHERBET', 'CORRECT', 'ASSAULT']),
#  ('Stand up under use', 'WEAR', ['DEFY', 'RISE', 'FACE', 'MEAN', 'MEAN']),
#  ('Quote, part 3', 'GOTBY', ['IWILL', 'RUNTO']),
#  ("Comfort's partner", 'AID', []),
#  ('Not forthright', 'COY', ['DOI', 'GMS', 'FRO', 'TIL', 'TRE']),
#  ('Path, to Pu Yi', 'TAO', ['ION', 'HST', 'LOT']),
#  ('Signs up?', 'ZODIAC', ['ENROLS', 'ENROLS']),
#  ('"This can\'t be!"', 'OHNO', ['ESSE', 'BOTH', 'ERAT', 'ALOT', 'FLAT']),
#  ('I.R.A. increaser: Abbr.', 'INT', ['TAX', 'FAN', 'NUS', 'AND', 'TRY']),
#  ('Reliable', 'SOUND', ['TRUER', 'SOLID', 'TRIED', 'SURER', 'SOLID']),
#  ('Ran behind schedule',
#   'WASLATE',
#   ['RUNLATE', 'RANLATE', 'RESLATE', 'RESLATE', 'TAXFORM']),
#  ('French counts?', 'TETES', ['LEANS', 'RATES', 'PEERS', 'HOUSE', 'DIETS']),
#  ('Novel or essay', 'PROSE', ['WROTE', 'THEME', 'TRITE', 'ONMAN']),
#  ('Drive away', 'BANISH', ['DISPEL', 'PROPEL', 'COERCE', 'ALLUDE']),
#  ('"Move your butt"', 'SCOOT', ['SCRAM']),
#  ('Hammering block', 'ANVIL', ['DETER', 'ESTOP', 'EMBAR', 'DETER', 'DEBAR']),
#  ('Mrs. in the White House', 'FIRSTLADY', []),
#  ('Like emendated works',
#   'ALTERED',
#   ['FOMENTS', 'COMBATS', 'OEUVRES', 'REVISES']),
#  ('Watchful one', 'EYER', ['ASAP', 'TEMP', 'ROSE', 'CUBE', 'ANEW']),
#  ('Most insistent', 'PUSHIEST', ['THENWHAT', 'SECONDLY']),
#  ('Warm-up?', 'DETENTE', ['PRELUDE', 'AFFABLE', 'PREGAME']),
#  ('Compass point, in Cancun', 'NORTE', []),
#  ('Red entries', 'LOSSES', ['DEBITS', 'IDIOMS', 'ALERTS']),
#  ('She said "I do"', 'WIFE', ['AMEN', 'AMEN', 'AMEN', 'ORAL', 'AMEN']),
#  ('"___ I a woman?": Sojourner Truth', 'ARENT', ['SERUM', 'NOLIE']),
#  ('A.M. sorrow?', 'MORNINGMOURNING', []),
#  ('Home of the U.S. Army Airborne Forces', 'FTBRAGG', ['COERCES', 'ARMADAS']),
#  ('Cowardly bird?', 'YELLOWWARBLER', []),
#  ('Godard, to Truffaut, e.g.', 'AMI', ['PER', 'PMS', 'TOO', 'RID', 'FAD']),
#  ('Comic from Chicago', 'MULL', ['CUBS', 'CUBS', 'CUBS', 'CARD', 'OLIN']),
#  ('Authorized', 'OKD', ['LOS', 'PER', 'NIL', 'YET']),
#  ('Whiskey distillery supply', 'SOURMASH', ['ADEQUATE']),
#  ('"Grant your own damn wishes," e.g.?', 'GENIEJERKREACTION', []),
#  ('"Crackers"', 'NUTSO', ['LOONY', 'BATTY', 'SNACK', 'NUTSY', 'BATTY']),
#  ('Tap site', 'KEG', ['ALE']),
#  ('Auto club service', 'TOW', ['USO', 'USO', 'AAA', 'AAA', 'CAR']),
#  ('Second-in-command in a kitchen', 'SOUSCHEF', []),
#  ('Greek letters', 'PIS', ['XIS', 'MUS', 'XIS', 'NUS', 'NUS']),
#  ('Lady of the knight?', 'DAME', ['HERS', 'PEER', 'MAAM', 'MAAM', 'HERS']),
#  ('Lunch with a crunch', 'TACO', ['CAPN', 'CAPN', 'MEAL', 'DINE', 'EATS']),
#  ('Eur. is one', 'CONT', ['OSLO', 'AMST', 'AUST', 'USSR']),
#  ("They're lifesavers", 'FIREDEPARTMENTS', ['FOURSHUTTHEDOOR']),
#  ('Hisser', 'SNAKE', ['LEAVE', 'QUASI', 'GRAVE', 'SINCE', 'AGAIN']),
#  ('Farm mother', 'HEN', ['EWE', 'EWE', 'DAM', 'EWE', 'BAA']),
#  ('Office dupes, for short', 'CCS', ['HAS', 'EXT']),
#  ("Logomachist's trait", 'CONTENTIOUSNESS', ['GOODSENSEOFYUMA']),
#  ('Shelley Long role on TV',
#   'DIANE',
#   ['ODIST', 'ODIST', 'ODIST', 'CENCI', 'AGOGO']),
#  ('Groups of indigenous plants',
#   'FLORAS',
#   ['NATIVE', 'NATIVE', 'NATIVE', 'NATIVE', 'NATIVE']),
#  ('Musical symbols', 'CLEFS', ['RESTS', 'TYPES', 'RESTS', 'REVUE', 'REVUE']),
#  ('Sacred: Prefix', 'HAGI', ['HOLY', 'HOLY', 'HOLY', 'HOLY', 'HOLY']),
#  ('French possessive', 'SES', ['TES', 'TES', 'TES', 'TES', 'TES']),
#  ("It's trapped on laundry day",
#   'LINT',
#   ['ARAT', 'ARAT', 'WASH', 'WASH', 'WASH']),
#  ('One pointing, as a gun',
#   'AIMER',
#   ['THERE', 'RIFLE', 'OATER', 'ANNIE', 'SONOF']),
#  ('"___ mouse!"', 'EEKA', ['TOPO', 'NOUN']),
#  ('Byproduct of an exhausted dairy cow?', 'WHIPPEDBUTTER', []),
#  ('Service commemoration', 'VETERANSDAY', []),
#  ('"___ in the course . . . "',
#   'WHEN',
#   ['SETA', 'SOUP', 'PATH', 'VEER', 'PATH']),
#  ("Ideal match, it's said, for a Cabernet Sauvignon", 'RARESTEAK', []),
#  ('Menu item', 'DISH', ['ROTI', 'POIS', 'FARE', 'EDIT', 'EDIT']),
#  ('Actress Sanford et al.', 'ISABELS', []),
#  ("Cuisinier's specialty",
#   'SALADE',
#   ['POTAGE', 'TARTES', 'TRIAGE', 'METIER', 'ETALII']),
#  ('Nickname of a former D.C. team',
#   'NATS',
#   ['SHAQ', 'SHAQ', 'NETS', 'RAMS', 'NETS']),
#  ('Anatomical cap', 'PATELLA', []),
#  ('To ___ (somewhat)', 'ADEGREE', ['OFASORT']),
#  ('Fault', 'SIN', ['NAG', 'TOO', 'ERR', 'ITS', 'TOA']),
#  ('Wind direction', 'ESE', ['SSE', 'NNE', 'ENE', 'SSW', 'SSE']),
#  ('Suffix with fleur', 'ETTE', []),
#  ('1,000 boats', 'MARKS', ['CAIRO', 'PUNTS', 'STERE', 'YAWLS', 'PROAS']),
#  ('Like some eye surgery', 'CORNEAL', ['INUTERO']),
#  ('Nucleic acid initials', 'DNA', ['RNA', 'RNA', 'RNA', 'RNA', 'RNA']),
#  ('"Dunno"', 'SEARCHME', ['ISITTIME']),
#  ('Optimistic', 'SANGUINE', []),
#  ('Radiation shield material',
#   'LEAD',
#   ['EGIS', 'EGIS', 'EGIS', 'EGIS', 'EGIS']),
#  ('Gerbil cousin', 'HAMSTER', []),
#  ('Strong cast', 'HEAVE', ['THREW', 'THREW', 'THREW', 'THROW', 'SLUNG']),
#  ('Abbr. for 12 x 12', 'GRO', ['ADE', 'RAM']),
#  ('Rimmed', 'EDGED', ['DRIVE', 'AGAIN', 'SALUT', 'ROGER']),
#  ('Fill gaps, in a way', 'DARN', ['RISE', 'DEBT', 'AMID', 'PFCS', 'AMID']),
#  ('Kind of flint', 'SKIN', ['KNAP', 'ROLE', 'ELSE', 'SGTS', 'THOU']),
#  ('Secretary of the Treasury', 'REGAN', ['PURSE', 'PURSE', 'STORE', 'EBOND']),
#  ('Full of small talk', 'CHITCHATTY', []),
#  ('Holiday preceder', 'EVE', ['OFF', 'OFF', 'AIM', 'ANY', 'YES']),
#  ('Tonic ingredient', 'IRON', ['KOLA', 'COLA', 'MAYO', 'LIME', 'ALOE']),
#  ('Uses a scope', 'AIMS', ['ROOM', 'AREA', 'AREA', 'AREA', 'AREA']),
#  ("Wassailers' song", 'CAROL', ['YULES', 'UNDER', 'ENDED', 'BLEAT', 'IWISH']),
#  ('Like pearls on a necklace',
#   'STRUNG',
#   ['STRING', 'NACRES', 'NACRES', 'CHOKER', 'AMULET']),
#  ('Outcome', 'EFFECT', ['RESULT', 'RESULT', 'UPSHOT', 'RESULT', 'UPSHOT']),
#  ('Arctic newspaper?', 'HUSKYVOICE', ['BITTERCOLD']),
#  ('Holy City populace', 'MECCANS', ['NEPALIS', 'ROLLERS']),
#  ('Other', 'ELSE', ['ESSE', 'BOTH', 'ERAT', 'ALOT', 'FLAT']),
#  ('High-ranking noncom', 'SGTMAJ', ['ARISTO', 'BEGUMS', 'SENIOR']),
#  ('Exiled tyrant', 'AMIN', ['TSAR', 'OGRE', 'NERO', 'NERO', 'NERO']),
#  ('Loss by decay', 'WASTAGE', ['STYMIED']),
#  ('Salvador et al.', 'DALIS', ['ACADS', 'STATS', 'BACKS', 'ABBRS', 'GORES']),
#  ('Like some friends', 'FAST', ['KITH', 'ROSS', 'ROSS', 'SECT', 'ROSS']),
#  ('One with a beat', 'COP', ['RAN', 'RAP']),
#  ('Meaningless talk', 'JABBERWOCKY', ['ABRACADABRA']),
#  ('Site of numerous firings',
#   'KILN',
#   ['MANY', 'MANY', 'MANY', 'SEAL', 'HAVE']),
#  ('Spanish houses', 'CASAS', ['EAVED', 'EAVED', 'NESTS', 'NESTS', 'NESTS']),
#  ('Fedora-industry slogan?', 'MAKEYOURPRESENTSFELT', []),
#  ('Quote, part 2', 'FOOLISH', []),
#  ('Writer, slangily', 'INKSLINGER', []),
#  ('Ivory Coast group', 'TARA', ['GURO', 'SOAP', 'SOAP', 'ASEA', 'TUSK']),
#  ('Succeed', 'ARRIVE', ['ASCEND', 'MAKEIT', 'ABLEST']),
#  ('Diana with a record-setting swim around Manhattan in 1975',
#   'NYAD',
#   ['APOP', 'COST', 'ABUT', 'SCAM', 'STAR']),
#  ('Assent to relent', 'OKOK', ['EASE', 'AMEN', 'AMEN', 'AMEN', 'AMEN']),
#  ('Yule tree adornment', 'TINSEL', ['ANKLET', 'MANANA', 'UPDATE']),
#  ("With one's head in the clouds?",
#   'TALL',
#   ['LACY', 'SCUD', 'SCUD', 'SCUD', 'OMEN']),
#  ('Viewer on the Nautilus', 'PERISCOPE', ['AUNATUREL']),
#  ('Stomach woe', 'ULCER', ['BELLY', 'ABHOR', 'ABIDE', 'ABHOR', 'ACIDS']),
#  ('Ill. city', 'PERU', ['HATE', 'BILE', 'SICK', 'EASE', 'PANA']),
#  ('Lacking conviction', 'ALLEGED', ['WITHOUT']),
#  ('Catch', 'ENTRAP', ['RETRAP', 'SNOOZE', 'THROAT']),
#  ('TV show', 'RHODA', ['VIDEO', 'SONYS', 'SONYS', 'VIDEO', 'AUDIO']),
#  ('"Diner" co-star, 1982', 'KEVINBACON', []),
#  ('"Here\'s looking at you," e.g.',
#   'TOAST',
#   ['SUNNY', 'ATYOU', 'ATYOU', 'CUTER', 'YIPES']),
#  ('The best you can be, Freudian-style', 'EGOIDEAL', ['NEUROSIS', 'CHOICEST']),
#  ('Famed Civil War photographer',
#   'BRADY',
#   ['HORST', 'DAVIS', 'ASSAD', 'MEADE', 'MEADE']),
#  ('Perpetual-motion state', 'RESTLESSNESS', []),
#  ('Mightier than', 'ABOVE', ['PAINE', 'AGAIN', 'ABIDE', 'RATIO', 'ATALL']),
#  ('Symbol in the center of a Scrabble board',
#   'STAR',
#   ['IDEM', 'OVER', 'HEAP', 'ATOP', 'FLAP']),
#  ('Sorceress of myth', 'MEDEA', ['WITCH', 'LAMIA', 'LAMIA', 'LAMIA', 'CIRCE']),
#  ('Young female sponsors?', 'AUSPICEGIRLS', []),
#  ('Some notebook screens, for short',
#   'LCDS',
#   ['CRTS', 'ANTI', 'ONCE', 'ARTS', 'AMID']),
#  ('City NE of Rome', 'TERNI', ['NANCY', 'UDINE', 'UDINE', 'SALEM', 'UTICA']),
#  ('Drum part', 'RIM', ['EAR', 'EAR', 'EAR', 'EAR', 'EAR']),
#  ('___ sinister', 'BAR', ['HEH', 'ALL', 'ORE', 'HER']),
#  ('"You Turned ___ Around"', 'MYWORLD', ['GONEBAD', 'UPENDED', 'TOGGLED']),
#  ('Big bike', 'HOG', ['ATV']),
#  ('Haute couture icon with her own perfume',
#   'COCOCHANEL',
#   ['DINNERTIME', 'ONOCCASION']),
#  ('Like some boots',
#   'LACEUP',
#   ['EVICTS', 'EVICTS', 'EJECTS', 'PUSSIN', 'SCARED']),
#  ('Private ... or a hint to the words spelled by the circled letters',
#   'INNER',
#   ['GHOST', 'TABOO', 'JOTTO', 'PROBE', 'THOSE']),
#  ('Items hanging in cribs', 'MOBILES', ['ANSWERS', 'RELIANT', 'ITEMIZE']),
#  ('He wrote 7 Down', 'BERNE', ['NOTED', 'OATES', 'THATS', 'ISAAC', 'AESOP']),
#  ('Meadowsweet', 'SPIREA', ['LADIES', 'ODDMAN', 'DOTELL', 'APIECE']),
#  ('Appraises', 'EVALUATES', []),
#  ('Hut cover', 'THATCH', ['NISSEN', 'ATEASE', 'NISSEN', 'REWRAP']),
#  ('Out', 'AWAY', ['ESSE', 'BOTH', 'ERAT', 'ALOT', 'FLAT']),
#  ('Neb. aborigine', 'OTO', ['KAN', 'KAN', 'KAN']),
#  ('Recycled retirees', 'RETREADS', ['ONPAROLE', 'ADEQUATE']),
#  ('Links features', 'GREENS', ['TIESTO', 'TIEINS', 'UNITES', 'MODELS']),
#  ('"___ to Simplicity": Collins', 'ODE', ['ABC', 'ABC']),
#  ('*Imaginary overthrow of the government?', 'PSEUDOCOUP', []),
#  ('Monastery manuscript',
#   'CODEX',
#   ['ABBOT', 'ABBEY', 'ABBEY', 'ABBOT', 'ABBOT']),
#  ('Henhouse threat', 'FOX', ['ONE']),
#  ("Drug-culture leader in the 60's",
#   'LEARY',
#   ['EARTH', 'PRATE', 'PRATE', 'SANER', 'UBOAT']),
#  ('Show slight relief, maybe', 'EXHALE', ['IGNORE', 'MEASLY']),
#  ('Cheevy of Edwin Arlington Robinson verse',
#   'MINIVER',
#   ['WILLYOU', 'USUALLY', 'ELAINES', 'STUFFED', 'ALLDONE']),
#  ('Reached the plucking point', 'RIPENED', ['INSPOTS']),
#  ('Just average', 'FAIRTOMIDDLING', []),
#  ('Hiatus', 'LULL', ['PROV', 'ANTI', 'ISAY', 'MBAS', 'REST']),
#  ('Blintzes, e.g.', 'ROLLUPS', ['INTOTAL']),
#  ('"That\'s amazing!"', 'GEE', ['WOW', 'OOH', 'CBS', 'MAP', 'OWN']),
#  ('"N.Y.P.D. Blue" title: Abbr.', 'DET', ['DEM', 'DEM', 'LOW', 'LOW', 'SAD']),
#  ('Give birth, as a whale',
#   'CALVE',
#   ['ORCAS', 'NATAL', 'NATAL', 'NATAL', 'NATAL']),
#  ("'13 or '14, now", 'GRAD', ['TIKI', 'MENU', 'ALTO', 'EAST']),
#  ('Bombay bigwigs', 'SIRDARS', []),
#  ('Hot actress of yore?', 'SARAHBURNHARDT', []),
#  ('Greek diner order', 'GYRO', ['HASH', 'SOAS', 'BOSS', 'SORT']),
#  ('North Sea port', 'EMDEN', ['WESER', 'WESER']),
#  ('He has a colorful job', 'DYER', ['TASK', 'ABLE', 'PEEL', 'PEEL', 'TASK']),
#  ('Vespiaries', 'NESTS', ['EVENS', 'AMONG', 'LOONY', 'VOWEL', 'AGREE']),
#  ('2 mg, say', 'DOSE', ['APOP', 'AMER', 'ERAT', 'ANNO', 'ALSO']),
#  ('A son of Priam', 'PARIS', ['TROIC', 'LEGIT', 'ERECT']),
#  ('Event won five straight times by Roger Federer',
#   'USOPEN',
#   ['ABSENT', 'NIGHON', 'LIBATE', 'DOABLE', 'UNTRUE']),
#  ("Fish that's split for cooking",
#   'SCROD',
#   ['ABOIL', 'LEAVE', 'LEAVE', 'RIVED']),
#  ("Next year's sophs", 'FROSH', ['PASSE', 'PASSE', 'CIRCA', 'SOLAR', 'SNARE']),
#  ('Geared down, perhaps', 'SHIFTED', ['INTOTAL']),
#  ('Security system component',
#   'SENSOR',
#   ['PLEDGE', 'TENURE', 'BRINKS', 'TENURE', 'TENURE']),
#  ('Deli request',
#   'TAKEA#',
#   ['ASKFOR', 'ASKFOR', 'ASKFOR', 'ASKFOR', 'INSIST']),
#  ('Lake', 'MERE', ['ERIE', 'ARAL', 'ERIE', 'ARAL', 'ERIE']),
#  ("Smucker's flavor", 'GRAPE', ['TASTE', 'BLAND', 'TASTE', 'SAPOR', 'SAPOR']),
#  ('Angers', 'SPLEENS', []),
#  ('Presumed facts', 'GIVENS', ['SKINNY', 'CHICHI']),
#  ('Long sandwich', 'SUB', ['BLT']),
#  ('Fiber-rich food', 'BRAN', ['EGGY', 'FIGS', 'TOFU', 'HAVE', 'HAHA']),
#  ('Huge success', 'SOCKEROO', ['SMASHHIT', 'COLOSSAL']),
#  ('Site of Celtic uprising?', 'BASKETBALLCOURT', []),
#  ('Act of burning', 'COMBUSTION', []),
#  ('Alphabetical order?', 'BLT', ['CDE', 'RST', 'MNO', 'EFG', 'CDE']),
#  ('Luminaries', 'STARS', ['AGAIN', 'SALUT', 'PEASE', 'DRIVE']),
#  ("Archer's favorite tree", 'YEW', ['PET', 'PET', 'PET', 'PET', 'PET']),
#  ('Lincoln and Ribicoff', 'ABRAHAMS', ['UNIONIST', 'ATNOTIME']),
#  ('Record holder', 'HIFI', ['IPOD', 'DISC', 'DISC', 'TAPE', 'SIDE']),
#  ('Lop off, to Burns', 'SNED', ['IRES', 'NANE', 'IRES', 'SYNE', 'SCOT']),
#  ('Startled cries', 'HEYS', ['EASY', 'ASKS', 'SOBS', 'RICO', 'ESSE']),
#  ('Illusions, spelled out in detail?', 'FACCEDILLAADES', []),
#  ('Title akin to Rev.', 'VEN', ['GUN', 'AMP', 'OPP', 'GUN', 'SER']),
#  ('Flower features',
#   'SEPALS',
#   ['PETALS', 'MODELS', 'ABLOOM', 'STAMEN', 'STAMEN']),
#  ('Capitol-___ (music company)', 'EMI', ['NAY', 'SEN', 'POL', 'ETS']),
#  ('Grant\'s "Walk, Don\'t Run" co-star',
#   'EGGAR',
#   ['CAMEO', 'POEMS', 'PHONE', 'BURNT', 'ANENT']),
#  ('Brew fancier in "Cheers"',
#   'NORM',
#   ['PYRO', 'BEER', 'ABIE', 'ABIE', 'YAYS']),
#  ('Flavor enhancer', 'SPICE', ['CLOVE', 'SAPOR', 'SAPOR', 'SAPOR', 'TASTE']),
#  ('Deli-cacy', 'REUBEN', ['SALAMI', 'SLICER', 'HOAGIE']),
#  ('Free', 'RELEASE', ['UNLOOSE', 'ATLARGE', 'PROBONO']),
#  ('Suffix with winning', 'EST', ['LED', 'IER', 'OSE', 'OSE', 'FER']),
#  ('Where to find aces and deuces', 'TENNIS', ['ADEPTS', 'TIPTOP', 'ADEPTS']),
#  ('On the Caribbean', 'ASEA', ['ISLE', 'SEAS', 'SEAS']),
#  ('Grandson of Catherine the Great, informally',
#   'ALEXI',
#   ['PETER', 'AREAR', 'POWER']),
#  ('Girl for whom a strait was named',
#   'HELLE',
#   ['ALIAS', 'OTHER', 'MISSY', 'CARLA', 'KATHY']),
#  ("25-Across's perch, perhaps", 'WIRE', ['ALIT', 'FISH', 'BALL', 'STEP']),
#  ('Bo-o-ring', 'HOHUM', ['DEREK', 'DEREK', 'DEREK', 'DEREK', 'DEREK']),
#  ('French interjection',
#   'ALORS',
#   ['TIENS', 'ARRAH', 'MERCI', 'SELAH', 'SELAH']),
#  ('What online shoppers may spend',
#   'ECASH',
#   ['KMART', 'USEUP', 'LOGIN', 'LOGIN', 'ENDED']),
#  ('*Be repetitive ... or what parts of the answers to the starred clues do?',
#   'GOINCIRCLES',
#   ['HLMFFWVDMRV']),
#  ('Fer-___, pit viper', 'DELANCE', []),
#  ('Words before "TV" or "each other"',
#   'MADEFOR',
#   ['SOTOSAY', 'UTTERED', 'PHRASED', 'WRANGLE', 'TACITLY']),
#  ('First Bond flick', 'DRNO', ['GLUE', 'LINK', 'GLUE', 'GLUE', 'GLUE']),
#  ('Singer Newton-John', 'OLIVIA', ['ELTONS']),
#  ('Shirley Verrett, for one',
#   'DIVA',
#   ['IRMA', 'EDER', 'ARIA', 'IRMA', 'ANNS']),
#  ('Grammy-winning James', 'ETTA', ['NANA', 'CARA', 'CECE', 'AGEE', 'AGEE']),
#  ('Blackjack choice', 'STAY', ['FINE', 'AONE', 'RARE', 'RARE']),
#  ('"You\'re glumping the pond where the Humming-Fish hummed!"',
#   'THELORAX',
#   ['EMOTICON', 'TENSCORE', 'LETALONE']),
#  ('Small porker', 'PIGLET', ['PETITE']),
#  ('Option: Abbr.', 'ALT', ['ESC', 'NOT', 'IRA', 'REC', 'IRA']),
#  ('Measures the circumference',
#   'GIRTS',
#   ['GIRTH', 'AMBIT', 'GIRTH', 'AMBIT', 'RESTS']),
#  ('Scene 1 setting in "La Bohème"', 'GARRET', []),
#  ('Music, drama, etc.', 'ARTS', ['ADUE', 'ADUE', 'ADUE', 'SOLO', 'ADUE']),
#  ('With 24-Across, "Uh-uh!"', 'IWOULDNT', ['DONTDOIT']),
#  ('Certain graph shape', 'PIE', ['FIT', 'FIT', 'GEL']),
#  ('Ancestral line',
#   'STRAIN',
#   ['QUAGGA', 'AMOUNT', 'RISKED', 'ISOBAR', 'NEXTUP']),
#  ("Certain '60s teens", 'MODS', ['ACNE', 'PROM', 'ELSE', 'ANNO', 'ATAD']),
#  ('Lord of the sands', 'SHEIK', ['DIANA', 'OTERO', 'SAITH', 'ISITI']),
#  ('One of the Huxleys', 'ALDOUS', ['BOWMAN']),
#  ('Some football linemen', 'GUARDS', ['WIRERS', 'REKICK', 'SOCCER']),
#  ('Out on ___', 'ALIMB', ['ARENT', 'AWRAP', 'RARIN', 'ARIDE', 'ADRAG']),
#  ('Peters out', 'ENDS', ['YEAS', 'OHSO', 'EMIT', 'ERGO', 'DELE']),
#  ('Soul-searching sessions?', 'SEANCES', ['SLEEPER']),
#  ('They go around on reservations', 'PEACEPIPES', ['LOVINGCARE']),
#  ('Key in again', 'RETYPE', ['ATONAL', 'OPENER']),
#  ("Veteran, on Veteran's Day", 'HONOREE', ['OLDHAND', 'TROUPER', 'OLDSALT']),
#  ('Bridge tower', 'PYLON', ['DWARF', 'DWARF', 'DWARF', 'SPIRE', 'SEARS']),
#  ('"How\'s it ___?"', 'GOIN', ['AMAN', 'SEEM', 'ELSE', 'PLAN', 'ISIT']),
#  ('Words before a chivalrous act',
#   'ALLOWME',
#   ['GALLANT', 'INSPIRE', 'OPERATE']),
#  ('"___ is bunk": Henry Ford', 'HISTORY', ['HOGWASH', 'SENATOR', 'SENATOR']),
#  ('Survival group', 'FITTEST', ['ARRIVAL']),
#  ('Dries, in a way', 'BLOTS', ['ENDED', 'RERAN']),
#  ('Coats', 'LAMINATES', ['TINPLATES']),
#  ('Lean', 'SLENDER', ['SPAREST']),
#  ('Hindu having gurus', 'SIKH', ['SRIS', 'ETAS', 'ERAT', 'CLEF', 'SOLE']),
#  ('Tollbooth location', 'PLAZA', ['SITUS', 'ASTIR']),
#  ('Parol', 'ORAL', ['SCAT', 'ANTI', 'APOP', 'MBAS', 'STIR']),
#  ('"Enough!"', 'CANIT', ['EVENS', 'AMONG', 'LOONY', 'VOWEL', 'AGREE']),
#  ('Gustos', 'ZESTS', ['EVENS', 'AMONG', 'LOONY', 'VOWEL', 'AGREE']),
#  ('Nessus, for one', 'CENTAUR', ['ELAINES', 'ERECTED', 'REGRESS', 'ALITTLE']),
#  ('Accessory for many a game', 'EGGTIMER', ['LETSDOIT', 'ALLRIGHT']),
#  ('Expo', 'TRADESHOW', []),
#  ('"___ roasting on an open fire"', 'CHESTNUTS', []),
#  ('NASA launch concern',
#   'WEATHER',
#   ['ORBITER', 'REENTRY', 'GALILEO', 'ACRONYM']),
#  ('Jinn', 'GENIE', ['EVENS', 'AMONG', 'LOONY', 'VOWEL', 'AGREE']),
#  ('Yo-yo', 'IDIOT', ['SANER', 'CELLO', 'SENSE', 'CELLO', 'CELLO']),
#  ('Slapping sounds', 'SPLATS', ['NOISES', 'NOISES', 'SPEAKS', 'OPINES']),
#  ('Will of "The Waltons"', 'GEER', ['PAPA', 'ERIN', 'ERIN', 'ERIN', 'ERIN']),
#  ('Chance', 'ACCIDENT', []),
#  ('Disorder', 'MESS', ['ACNE', 'RIOT', 'RIOT', 'RIOT', 'RIOT']),
#  ('Icy area', 'RINK', ['FLOE', 'AFAR', 'ZONE']),
#  ('Gen., adm.et. al.', 'LDRS', ['ALII', 'SPTS', 'IKES', 'ALII', 'ALIA']),
#  ('Earl ___ tea', 'GREY', ['PEER', 'ICED', 'ICED', 'MEAL', 'AVON']),
#  ('Millennium Falcon pilot in "Star Wars"',
#   'HANSOLO',
#   ['AVERAGE', 'MONEYED', 'SUBJECT']),
#  ('On this side: Prefix', 'CIS', ['SYN', 'ESO', 'SYN', 'NEO', 'UNI']),
#  ('Like a cube', 'SIDED', ['SIDES', 'RUBIK', 'RUBIK', 'EDGES', 'EDGES'])]

# %%
guess("opposite of NNE")
# Out:
# [('SSW', 0.0),
#  ('SSW', 0.0),
#  ('SSW', 0.0),
#  ('LILLE', 0.8641626488446986),
#  ('LILLE', 0.8641626488446986)]

# %%
# # serialize and save model
# import pickle

# TRAINED_MODEL_PATH = "trained_model.p"

# pickle.dump((answers_train, vectorizer, model), open(TRAINED_MODEL_PATH, "wb"))
