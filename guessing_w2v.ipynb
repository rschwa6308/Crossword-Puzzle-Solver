# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt


DATA_PATH = r"data\nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

# sample = random.sample(puzzles_available, 10_000)

# sample puzzles from EVEN days
sample = [puzz for puzz in puzzles_available if puzz[-1]%2==0]

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (602694, 604)

# %%
# Prepare data
new_clues_train = []
for clue in clues_train:
    clue = clue.replace('\'', '')
    clue = clue.replace('"', '')
    new_clues_train.append([w.lower() for w in clue.split(' ')])

new_clues_test = []
for clue in clues_test:
    clue = clue.replace('\'', '')
    clue = clue.replace('"', '')
    new_clues_test.append([w.lower() for w in clue.split(' ')])

# %%
import gensim.downloader
import gensim.models
from gensim.test.utils import common_texts

# load word2vec
w2v_model = gensim.downloader.load('glove-wiki-gigaword-300')
# build word2vec
#gensim_vectors.save('model.bin')
#w2v_model = gensim.models.word2vec.Word2Vec(new_clues_train, vector_size=300, min_count=1)
#saving the model persistence
w2v_model.save('w2v_model.bin')
# loading the model(decode error)
#model = gensim.models.KeyedVectors.load_word2vec_format('model.bin') 

# model.wv acts as gensim_vectors

# %%
# function average word2vec vector
def avg_feature_vector(words, model, num_features, ind2key_set):
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_words = 0
    for word in words:
        if word in ind2key_set:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %%
# DAN model
import torch
import torch.nn as nn

class DanModel(nn.Module):
    def __init__(self, n_classes, vocab_size, emb_dim=500,n_hidden_units=500, nn_dropout=.5):
        super(DanModel, self).__init__()
        self.n_classes = n_classes
        self.vocab_size = vocab_size
        self.emb_dim = emb_dim
        self.n_hidden_units = n_hidden_units
        self.nn_dropout = nn_dropout
        self.embeddings = nn.Embedding(self.vocab_size, self.emb_dim, padding_idx=0)
        self.linear1 = nn.Linear(emb_dim, n_hidden_units)
        self.linear2 = nn.Linear(n_hidden_units, n_classes)
        self.classifier = nn.Sequential(self.linear1,nn.ReLU(),nn.Dropout(nn_dropout),self.linear2)
        self._softmax = nn.Softmax()

    def average(self, text_embeddings, text_len):
        #average = []
        #vec = np.zeros((num_features, ), dtype='float32')
        #for qq in  text_embeddings:
        #     vec = np.add(vec,qq)
        #vec = np.divide(vec, text_len)
        #average = torch.tensor(average)
        #return average

        average = []
        for i in range(0,text_len):
            average.append((text_embeddings[i].sum(0)/text_len).tolist())
        average = torch.tensor(average)
        return average

        
    def forward(self,input_text,text_len, is_prob=False):

        logits = torch.LongTensor([0.0] * self.n_classes)

        # Complete the forward funtion.  First look up the word embeddings.
        # Then average them 
        #text_embed = self.embeddings(input_text)
        text_embed = self.embeddings(torch.LongTensor(input_text))
        text_embed = self.average(text_embed, text_len)
        # Before feeding them through the network
        logits = self.classifier(text_embed)

        if is_prob:
            logits = self._softmax(logits)

        return logits

# %%
def train(model, train_data_loader, train_data_answer, w2v_model,num_features):
    model.train()
    optimizer = torch.optim.Adamax(model.parameters())
    criterion = nn.CrossEntropyLoss()
    
    for idx, text in enumerate(train_data_loader):
        question_text = [abs(w2v_model[word]) for word in text]
        question_len = len(question_text)
        label = train_data_answer[idx].lower()
        if label in set(w2v_model.index_to_key):
            labels = w2v_model[label]
        else:
            vec = np.zeros((num_features, ), dtype='float32')
            for qq in question_text:
                vec = np.add(vec,qq)
            vec = np.divide(vec, question_len)
            w2v_model.add_vectors(label, vec)
            labels = w2v_model[label]
            
        optimizer.zero_grad()
        preds = model.forward(question_text,question_len)
        loss = criterion(preds,labels)
        loss.backward()
        optimizer.step()

# %%
dan_model = DanModel(len(set(answers_train)),300,emb_dim=500,n_hidden_units=500)
for epoch in range(50):
    
    train(dan_model, new_clues_train, answers_train,w2v_model,300)
# Out:
# C:\Users\mtchq\AppData\Local\Temp/ipykernel_16516/3225565465.py:37: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   logits = torch.LongTensor([0.0] * self.n_classes)
# C:\Users\mtchq\AppData\Local\Temp/ipykernel_16516/3225565465.py:42: DeprecationWarning: an integer is required (got type numpy.float32).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   text_embed = self.embeddings(torch.LongTensor(input_text))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16516/768604256.py in <module>
#       2 for epoch in range(50):
#       3
# ----> 4     train(dan_model, new_clues_train, answers_train,w2v_model,300)
#
# ~\AppData\Local\Temp/ipykernel_16516/3695667224.py in train(model, train_data_loader, train_data_answer, w2v_model, num_features)
#      20         optimizer.zero_grad()
#      21         preds = model.forward(question_text,question_len)
# ---> 22         loss = criterion(preds,model.classifier(torch.tensor(labels)))
#      23         loss.backward()
#      24         optimizer.step()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x300 and 500x500)

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

corpus = api.load("wiki-english-20171001") # download the corpus and return it opened as an iterable
model = Word2Vec(corpus)
model.train(new_clues_train, total_examples=len(new_clues_train), epochs=5)
# Out:
#  Part 1/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 2/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 3/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 4/4 [==================================================] 100.0% 364.2/364.2MB downloaded
# (434, 8380390)

# %%
from scipy import spatial
# define cosine similarity score
def sim_score(v1,v2):
    return 1 - spatial.distance.cosine(v1, v2)

# %%
# define vectorizer
def word2vec_vectorizer(data, model,num_features,ind2key_set):
    vec_data = []
    for sentence in data:
        sentence = [word for word in sentence if len(word)>1]
        vec_data.append(avg_feature_vector(sentence,model,num_features,ind2key_set))
    
    return vec_data

# %%
# Vectorize Clues
X_train = word2vec_vectorizer(new_clues_train,model.wv,100,set(model.wv.index_to_key))


# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

nn_model = NearestNeighbors().fit(X_train)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Define a guesser function
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector =  word2vec_vectorizer([clue],model.wv,100,set(model.wv.index_to_key))
    result = cosine_similarity(clue_vector, X_train)[0]
    indices = np.argsort(result)[::-1][:max_guesses_raw]
    raw_guesses = [answers_train[i] for i in indices]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue
        return o
    
    guesses = [g for g in raw_guesses if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
i = random.randint(0, len(new_clues_test))
test_clue, test_answer = new_clues_test[i], answers_test[i]
print("clue:", test_clue)
print("answer:", test_answer)

# distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# print("guesses:", [answers_train[i] for i in indices[0]])

guesses = guess(test_clue, slot_length=len(test_answer))
print("guesses:", guesses)
# Out:
# clue: ['refrain', 'syllables']
# answer: TRALA
# guesses: ['TRALA', 'LALAS', 'TRALA', 'EIEIO', 'TRALA']

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(new_clues_test, answers_test)):
    if i % 250 == 0: 
        guesses = guess(clue, len(answer), max_guesses=5)
        if answer in guesses:
            correct_pairs.append((clue, answer, guesses))
        else:
            incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(new_clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# Accuracy: 0.142%

# %%
incorrect_pairs
# Out:
# [('Making public', 'BARING', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Ball girl', 'DEB', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Classmates, e.g.', 'PEERS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Home wrecker?', 'SLOB', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Unusually small', 'DWARF', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Classmate, e.g.', 'PEER', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Priest's garb", 'ALB', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Confined', 'SHUTIN', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Derisive', 'SNEERY', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Primeval plot', 'EDEN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Finish of the 50's", 'CHROME', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('"___ and evening star": Tennyson',
#   'SUNSET',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Capek play', 'RUR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('___ in the right direction',
#   'ASTEP',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('English royal house', 'YORK', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Declare', 'ASSERT', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Deli offering', 'SAUSAGE', ['SILENTL', 'SEABEDS']),
#  ('Kind of trap', 'SAND', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Up to it', 'ABLE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('An Andrews', 'DANA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sportscaster Musberger',
#   'BRENT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Gershwin heroine', 'BESS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Like Shostakovich's Symphony No. 2",
#   'INB',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"My bad!"', 'OOPS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Exempt a coach?', 'FRANKLEAHY', []),
#  ('Mo. clock setting', 'CST', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('West Bank city', 'RAMALLAH', ['TOEDANCE']),
#  ('An 1898 discovery', 'NEON', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Meteors', 'SHOOTINGSTARS', []),
#  ('Community spirit', 'ETHOS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Oyster bed diver', 'PEARLER', ['SILENTL', 'SEABEDS']),
#  ('Start of a typing exercise', 'NOWISTHETIMEFOR', []),
#  ('Sharp', 'ACUTE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Mountain gazelles', 'ARIELS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Emulate Cicero', 'ORATE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Non-oil painting method', 'WATERCOLOR', []),
#  ("Spanish city that's home to the country's oldest university",
#   'SALAMANCA',
#   []),
#  ("Friend's address", 'THOU', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('1924 co-defendant', 'LOEB', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Less civil', 'RUDER', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('PT boat crewman: Abbr.', 'ENS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Palanquin', 'LITTER', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Trumpeted', 'BLEW', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Singers', 'CANARIES', ['TOEDANCE']),
#  ('Hole', 'CAVITY', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Spirit lamps', 'ETNAS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Literature', 'LETTERS', ['SILENTL', 'SEABEDS']),
#  ('Parisian seasons', 'ETES', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Tennessee ___ Ford',
#   'ERNIE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Former Ford', 'LTD', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Frank conversations', 'HEARTTOHEARTTALKS', []),
#  ('The Red Baron flew one', 'TRIPLANE', ['TOEDANCE']),
#  ('Emasculate', 'UNMAN', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Archbishop of Canterbury: 1928–42',
#   'LANG',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Carey leaves shore while ...', 'MARYLANDS', []),
#  ('Parenthetical remark',
#   'ASIDE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('List keeper Schindler et al.',
#   'OSKARS',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Air', 'MIEN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Any old time', 'ATTHEDROPOFAHAT', []),
#  ('Twilled fabric', 'SURAH', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('High point', 'ACME', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Newspaper notice', 'OBIT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Greek hero', 'AJAX', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"Little Miss Sunshine" vehicle',
#   'VWBUS',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Footlike part', 'PES', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Icon', 'IMAGE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Court call', 'LET', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Chester ___ Arthur', 'ALAN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Unlike a bucking bronco', 'RIDABLE', ['SILENTL', 'SEABEDS']),
#  ('Noes', 'REFUSALS', ['TOEDANCE']),
#  ('Kiln', 'OST', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ("Yang's opposite", 'YIN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('When repeated, eager', 'RAH', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Might-have-been Midwest team', 'STLOUISORDINALS', []),
#  ('Emulate Fadiman', 'EDIT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Unloyal', 'FALSE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Robinson and Thomas', 'BALLPARKFRANKS', []),
#  ('"Black gold"', 'OIL', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Situation for Pauline',
#   'PERIL',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Nintendo console with a remote',
#   'WII',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Like a river bottom',
#   'SILTY',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("LX years after Columbus's first voyage",
#   'MDLII',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Calms down', 'SEDATES', ['SILENTL', 'SEABEDS']),
#  ('Mob money units', 'GEES', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Brief time?', 'PRESSCONFERENCE', []),
#  ('Facing the pitcher',
#   'ATBAT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Beaver State', 'OREGON', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Old wine flask', 'OLPE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("King Arthur's father",
#   'UTHER',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Pilsener kin', 'ALE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"___ law," in electricity',
#   'OHMS',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Nothing', 'NIL', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('He fought Basil in "Robin Hood"',
#   'ERROL',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Love, to Dali', 'AMOR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Gold-mining province of Ecuador',
#   'ELORO',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Unwritten', 'ORAL', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("British thank-you's", 'TAS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Inhibit', 'DETER', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('See 14-Across', 'FOREMAN', ['SILENTL', 'SEABEDS']),
#  ('Neither Rep. nor Dem.', 'IND', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('She offered Excalibur to the future King Arthur', 'LADYOFTHELAKE', []),
#  ('Minnelli of "Arthur"', 'LIZA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Bundle', 'SHEAF', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Bye Bye Bye" band',
#   'NSYNC',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('City on the Meuse', 'SEDAN', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Scot\'s "own"', 'HAE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"A ___ very palpable . . . ": Shak.',
#   'HITA',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Formalist in teaching', 'PEDANT', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Food mixture in a small mold', 'TIMBALE', ['SILENTL', 'SEABEDS']),
#  ('Arctic ___', 'TERN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Allen and Ott', 'MELS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Frangipani, e.g.', 'ODOR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Hit song by Bart Howard', 'FLYMETOTHEMOON', []),
#  ('Eggs, in labs', 'OVA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Strong point', 'FORTE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Fräulein Braun', 'EVA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"_____ Misérables"', 'LES', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Bull: Prefix', 'TAUR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Discusses', 'TALKSOVER', []),
#  ('Legal claim', 'LIEN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Like the Congo's Mobutu Sese Seko", 'INEXILE', ['SILENTL', 'SEABEDS']),
#  ('Sound from a meadowland', 'MOO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Boring tool', 'GIMLET', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Make in a cauldron', 'BREW', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Head-turning attire', 'SEETHROUGHDRESS', []),
#  ('"___ loves me ?"', 'SHE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Fictional captain who said "Thou damned whale!"',
#   'AHAB',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('The "17" in NC-17', 'AGE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Ranch guests', 'DUDES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Story installments*', 'CEREALS', ['SILENTL', 'SEABEDS']),
#  ("Monroe's ___ of Good Feeling", 'ERA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Roof overhang', 'EAVE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"Hail ___, blithe spirit!": Shelley',
#   'TOTHEE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Rock in ___ (major music festival)',
#   'RIO',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Sch. course', 'ENG', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"M*A*S*H" extra', 'ROK', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Overexposed to the sun',
#   'FRIED',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Legislative branch', 'LOWERHOUSE', []),
#  ('A Madison V.P.', 'GERRY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"They escaped," said the pig man ___', 'PENSIVELY', []),
#  ("Practice that can't be wrong?",
#   'RITE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Pine product', 'RESIN', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"The Bartered Bride" composer', 'SMETANA', ['SILENTL', 'SEABEDS']),
#  ('Beatty film', 'REDS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Doctor's orders", 'SCANS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Chide', 'REPROVE', ['SILENTL', 'SEABEDS']),
#  ('___-the-wisp', 'WILLO', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Hotshots', 'ACES', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Tragicomic play of 1952', 'WAITINGFORGODOT', []),
#  ('"Drake" poet', 'NOYES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('En ___ (on tiptoe)', 'POINTE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Ancient Persian province', 'SATRAPY', ['SILENTL', 'SEABEDS']),
#  ("Cops' cry at the door", 'OPENUP', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Tearjerkers, sometimes',
#   'SOAPS',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Half of a hip-hop duo', 'DJJAZZYJEFF', []),
#  ('Large supply', 'TON', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Newspaper', 'GAZETTE', ['SILENTL', 'SEABEDS']),
#  ('Met pitcher', 'DOCGOODEN', []),
#  ('Made binding', 'SEALED', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Heliolater', 'SUNLOVER', ['TOEDANCE']),
#  ('An egg develops from it',
#   'OOCYTE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Type of type', 'CANON', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Tax of a sort', 'TITHE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Mona Lisa," e.g.', 'OIL', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Sikorsky', 'IGOR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Shakespearean words following "Speak, hands, for me!"',
#   'ETTU',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('The north wind, personified',
#   'BOREAS',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Before, in poetry', 'ERE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Spine-tingling', 'SCARY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Pull dandelions, e.g.', 'WEED', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Kvass's cousin", 'ALE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Billiard contact', 'KISS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Dark wines', 'REDS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Spirits', 'WINE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Number system with only 0's and 1's", 'BASETWO', ['SILENTL', 'SEABEDS']),
#  ('Conflict', 'WAR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ("Curmudgeon's word", 'BAH', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Leatherneck', 'JARHEAD', ['SILENTL', 'SEABEDS']),
#  ('Gazelle of N Africa', 'ADMI', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Favorites', 'PETS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Heads' opposite", 'TAILS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Vatican's locale", 'ROME', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Role in "Young Frankenstein"',
#   'IGOR',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Milne's Baby ____", 'ROO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Cooperative witness, maybe',
#   'NAMER',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Standard', 'NORM', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Where one might get one's first pair of overalls",
#   'BABYGAP',
#   ['SILENTL', 'SEABEDS']),
#  ('Sort', 'TYPE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Amphibians', 'EFTS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Unadulterated', 'PURE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Valley near the Dead Sea',
#   'ARABA',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"___ When I Laugh," 1981 film',
#   'ONLY',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Job follower', 'PSALMS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Prerequisites for some overseas travel', 'VACCINES', ['TOEDANCE']),
#  ('The Black Pearl of soccer',
#   'PELE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Wild talk', 'RANT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Seven, in Siena', 'SETTE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Humdinger', 'LULU', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Lotion ingredient', 'ALOE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Emma of "Dynasty"', 'SAMMS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('North Sea feeder', 'EMS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"...some kind of ___?"', 'ANUT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Manicurist's bottle", 'REMOVER', ['SILENTL', 'SEABEDS']),
#  ('___ Style Awards', 'ELLE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Bestial', 'BARBARIC', ['TOEDANCE']),
#  ('Six-foot avians', 'EMUS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Emit, as a big sigh',
#   'HEAVE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Sushi supplies', 'EELS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Politico Alexander',
#   'LAMAR',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Mentor', 'GURU', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Actor Marvin', 'LEE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Electric battery inventor',
#   'VOLTA',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Wisdom', 'SAPIENCE', ['TOEDANCE']),
#  ('Helpers: Abbr.', 'ASSTS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Long Asian river', 'AMUR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sneaker brand', 'PUMA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Type in', 'ENTER', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Hamburger refusal?', 'NEIN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Lily-livered', 'CRAVEN', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Mars Pathfinder, for one',
#   'ROVER',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Box elder', 'MAPLE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Abounds', 'TEEMS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Portuguese islands', 'AZORES', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Levy', 'IMPOSE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Make-or-break spot', 'POINTOFNORETURN', []),
#  ('"Tell it ___ Gath"',
#   'NOTIN',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Pitchers', 'EWERS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('CD follower', 'ROM', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('It may be full of bugs', 'BETA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Driver's helper", 'TEE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Trippet', 'CAM', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Jai ___', 'ALAI', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Eng. course', 'LIT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Stay out of sight', 'LIELOW', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Settle', 'REPAY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Pointed arch', 'OGEE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Source of political support', 'POWERBASE', []),
#  ("Attorney's concern", 'CASE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('<em>Ball</em>', 'TVCOMEDIENNE', []),
#  ('"How now! ___?": Hamlet', 'ARAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Stop by unannounced',
#   'POPIN',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Kind of rug', 'RYA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Queens place', 'SHEASTADIUM', []),
#  ('Induce a state of reverie',
#   'BEMUSE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('German spouse', 'FRAU', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Third anniversaries', 'TRIENNIALS', []),
#  ('The Belvedere ___ (Vatican sculpture)',
#   'TORSO',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Airborne unit?', 'KITE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Pro _____', 'RATA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Reindeer herdsmen of the North',
#   'LAPPS',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Pulitzer winner for "The Optimist\'s Daughter"',
#   'WELTY',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"___ the ramparts . . . "', 'OER', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('"The Great Gatsby" setting', 'JAZZAGE', ['SILENTL', 'SEABEDS']),
#  ('Seaweeds', 'ALGAE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Free from fat', 'LEAN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Prof's place: Abbr.", 'UNIV', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Nabokov novel', 'PNIN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('<em>Slow pacifist?</em>', 'TURTLEDOVE', []),
#  ('Young seal', 'PUP', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('___ Raymond Cobb', 'TYRUS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Stravinsky and others',
#   'IGORS',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Husky's home ground", 'SIBERIA', ['SILENTL', 'SEABEDS']),
#  ('Prefix with plunk or plop', 'KER', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Coffee brewer', 'URN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Mitigates', 'EASES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Preside over', 'CHAIR', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Halite', 'SALT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Pricing word', 'APIECE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Slow movement', 'LARGO', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Death Be Not Proud" poet John',
#   'DONNE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Moon man #2', 'ALDRIN', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Color for baby girls, traditionally',
#   'PINK',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Smug expression', 'SMIRK', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Roadie's ride", 'TOURBUS', ['SILENTL', 'SEABEDS']),
#  ('Grandfather-grandson U.S. Presidents', 'HARRISONS', []),
#  ('Speak well of', 'LAUD', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Row', 'TIER', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('High boot', 'BUSKIN', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('"I tawt I taw a puddy tat!" speaker', 'TWEETYBIRD', []),
#  ('Type of pansy', 'VIOLA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Game finder', 'SETTER', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Artist Bonheur', 'ROSA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('___ Vecchio, at Firenze',
#   'PONTE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Cuban tangolike dances', 'HABANERAS', []),
#  ('Deified', 'ADORED', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Mount for Abraham', 'ASS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Supposition', 'IDEA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Horoscope related', 'NATAL', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Part of v.v.', 'VERSA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Deli order', 'HAMONRYE', ['TOEDANCE']),
#  ("Ochlophobist's dread", 'THEMADDINGCROWD', []),
#  ('Petrol units', 'LITERS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Decibel measures', 'SONES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Gabor', 'EVA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Inimical', 'HOSTILE', ['SILENTL', 'SEABEDS']),
#  ('Starers', 'GAZERS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Corrigenda', 'ERRATA', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Funnies printed on packing materials?', 'CARDBOARDCARTOONS', []),
#  ('Product that puts waves in the hair', 'SALTSPRAY', []),
#  ("Like Haydn's Symphony No. 12 or 29",
#   'INE',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Speak raucously', 'BLAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('N.Y.C. subway', 'IND', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Dictionary, often', 'TOME', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Biological group', 'GENUS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Earth's crust", 'SIAL', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Protein for Pliny', 'OVA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Officially listed: Abbr.',
#   'REGD',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"My man"', 'BRO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Commence', 'START', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Reverberate', 'ECHO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Progress', 'RISE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Mineralogical suffix', 'ITE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Sen. Kennedy', 'TED', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Med. school subj.', 'ANAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Coward\'s "To Step ___"',
#   'ASIDE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Carte listing', 'VIN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Federal Reserve, e.g.: Abbr.', 'SYS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Certain aerophone', 'OBOE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Caner's material", 'RATTAN', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('End of 20 Across', 'HEDONEHERWRONG', []),
#  ('Chaperon', 'DUENNA', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Box office hit, slangily',
#   'BOFF',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Essential oil', 'ATTAR', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Jazz style', 'SCAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Old coin of Europe',
#   'DUCAT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Nine-day-old" veggies',
#   'PEASE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Like some books', 'USED', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('___ Benedict', 'EGGS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Art cult', 'DADA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Brought to bay', 'CORNERED', ['TOEDANCE']),
#  ('"Pardon me, are you from the Caribbean? Because ..."',
#   'JAMAICANMECRAZY',
#   []),
#  ('Bridge unit', 'TRICK', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Scupper, e.g.', 'HOLE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Parted company with a horse',
#   'ALIT',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Knock-down-drag-out', 'BATTLE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('___ football (indoor game)',
#   'ARENA',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Possesses', 'HAS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('D.M.V. part', 'MOTOR', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('+: Abbr.', 'POS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ("Tot's ammo", 'BBS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('At any point', 'EVER', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Like some suits', 'TAILORMADE', []),
#  ('Prefix with metric', 'ISO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Well-known maze traveler',
#   'PACMAN',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Egyptian Christian', 'COPT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Ruffle', 'ABASH', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Norwegian king', 'OLAF', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Shoe width for Bigfoot', 'EEE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Swiss river', 'AARE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Generator: Abbr.', 'DYN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ("Philosopher's study", 'SOUL', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Racketeer's org.?", 'USTA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Fortitude', 'STRENGTH', ['TOEDANCE']),
#  ('Plantation employee', 'PICKER', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Flings', 'TOSSES', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ("Quentin Tarantino paperback about a minister's stories?",
#   'PULPITFICTION',
#   []),
#  ('City of Spain', 'OVIEDO', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Nonsense', 'FIDDLEDEDEE', []),
#  ('Inexperienced', 'AMATEUR', ['SILENTL', 'SEABEDS']),
#  ('Rearward, at sea', 'AFT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Starts off', 'OPENS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Vice President Agnew',
#   'SPIRO',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('How birthday cake may be served', 'ALAMODE', ['SILENTL', 'SEABEDS']),
#  ('Little chief ___ (the pika)',
#   'HARE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Rubbish', 'TRASH', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Liturgical forms', 'RITES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Inner personalities, in psychology',
#   'ANIMAS',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Capital of Guam', 'AGANA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Simpson case judge', 'ITO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Canadian Indian', 'CREE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Clayey building material',
#   'PISE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Where to find missing links?', 'CHAINSTORES', []),
#  ('Fake jewels', 'PASTE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('See 42 Down', 'POOL', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('International trade place', 'OPENPORT', ['TOEDANCE']),
#  ('Upset stomach [consume]',
#   'NAUSEA',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('See 54-Down', 'BAR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Mil. craft', 'LST', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Writing on the biblical wall',
#   'MENE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Ed Kranepool was one', 'MET', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Murders, slangily', 'OFFS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Fam. members', 'SIBS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Trifles', 'FIGS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Ullmann', 'LIV', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Inspiration for a "Jackass" stunt, maybe',
#   'DARE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Grain sorghum', 'KAFIR', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Seed used medicinally',
#   'ANISE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Spot on a tie, perhaps', 'POLKADOT', ['TOEDANCE']),
#  ('Like virgin land', 'UNPLOTTED', []),
#  ('Making no progress', 'INARUT', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Laurence who wrote "Tristram Shandy"',
#   'STERNE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Acting through the skin', 'ENDERMIC', ['TOEDANCE']),
#  ('Aviation hazards', 'SHEARS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Bar and bas mitzvah',
#   'RITES',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Colossal, filmwise', 'EPIC', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Law: Abbr.', 'STAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Itty-bitty', 'TEENY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('___ 400 (Pennsylvania Nascar event)',
#   'POCONO',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Famed Rio beach', 'IPANEMA', ['SILENTL', 'SEABEDS']),
#  ('Auction unit', 'LOT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Wrestling maneuvers',
#   'HOLDS',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Director Truffaut film: 1972', 'TWOENGLISHGIRLS', []),
#  ('"Vous êtes ___" (label on a French map)',
#   'ICI',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('What Circe cast', 'SPELL', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Ornament a metal surface',
#   'CHASE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Make laugh', 'TICKLE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Fell for a come-on, say', 'BIT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ("Tendency to throw one's club after sinking a short stroke?",
#   'THEPUTTERFLYEFFECT',
#   []),
#  ("Squid's camouflage", 'INK', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Go out together', 'DATE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Gaelic', 'ERSE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Fake illness', 'MALINGER', ['TOEDANCE']),
#  ('Off the cuff', 'IMPROMPTU', []),
#  ('Agent, French style', 'HOMMEDAFFAIRES', []),
#  ('Retreat in fear', 'RUNSCARED', []),
#  ('Friend of Francesco',
#   'AMICO',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Like tigers and yaks',
#   'ASIAN',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Relented', 'GIVENIN', ['SILENTL', 'SEABEDS']),
#  ('Goals for duffers', 'PARS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Produced', 'TURNEDOUT', []),
#  ('"For shame!"', 'FIE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Poitier film, with "A"', 'RAISININTHESUN', []),
#  ('Yahoo! alternative', 'MSN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Come to the fore', 'EMERGE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Ice sheets', 'FLOES', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Lend ___ (listen)', 'ANEAR', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Letter', 'ESS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Bright', 'SHINY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Guitar ridge', 'FRET', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Kind of horse or man', 'POST', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Freedom', 'LATITUDE', ['TOEDANCE']),
#  ('Elec. units', 'AMPS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('All right', 'FINE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Aussie gal', 'SHEILA', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Word with hat or shoe', 'TREE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Whodunit feature', 'ALIBI', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Golden Horde member',
#   'TATAR',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Dominate', 'OWN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Goddess of peace', 'IRENE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Trattoria order', 'VINO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"Thirteen" actress ___ Rachel Wood',
#   'EVAN',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Tibetan priest', 'LAMA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Stuck in Pamplona?',
#   'GORED',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Norse god', 'ODIN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Northern tribesmen',
#   'ERIES',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Shoelace problem', 'KNOT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Iniquity', 'EVIL', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("''Whip It'' group", 'DEVO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('With 30 Down, Sixth Sister',
#   'BRYN',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Some old colonists', 'LEPERS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Local, e.g.', 'PUB', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Salmon or steeple', 'CHASE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Nicks producing cuts?', 'STEVIE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Dairy device', 'MILKER', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Jabber, jabber, jabber', 'TALKABLUESTREAK', []),
#  ('"No sun—___": T. Hood', 'NOMOON', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Facing', 'TOWARD', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Ache', 'BESORE', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Like', 'ALA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Rolls for dinner', 'SUSHI', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Tumor: Suffix', 'OMA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Member of the arum family',
#   'CALLA',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Tire', 'JADE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"___ Caesar shalt thou go"',
#   'UNTO',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sarah ___ Jewett, U.S. author: 1849–1909',
#   'ORNE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Bunny man, for short', 'HEF', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('McCartney title', 'SIR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Run ___ (encounter)', 'INTO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sufficient', 'AMPLE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Get out of the way', 'STANDASIDE', []),
#  ('See 21-Across', 'FOR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Dorm overseers, for short', 'RAS', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Saw', 'NOTICED', ['SILENTL', 'SEABEDS']),
#  ('Brisk', 'NIPPY', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Transit patron', 'USER', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Scot's sporran", 'PURSE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Aussie outlaw Kelly', 'NED', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Part of a saying re spendthrifts',
#   'EASYGO',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Wrap around a sandwich',
#   'SARAN',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('In medias ___', 'RES', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Enterprise crewman', 'SULU', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('"____ son salita" (Puccini aria)',
#   'IERI',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Shopping center', 'MART', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Stevens of Met fame', 'RISE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Germs', 'SEEDS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Colorado town or tree',
#   'ASPEN',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Quo vadis?" speaker',
#   'PETER',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Prefix with scope', 'STETHO', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Dissed, in a way', 'SASSED', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('1963 role for Liz', 'CLEO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Prefix with corn or form', 'UNI', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Bogeyman', 'SCARER', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('A grandson of Jacob', 'AROD', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Comforter's activity", 'CONSOLING', []),
#  ('Exemplars of firm friendship', 'DAMONANDPYTHIAS', []),
#  ('Army unit', 'TROOP', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Beaten (out)', 'EDGED', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Saline drop', 'TEAR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Road blocker after a winter storm', 'SNOWDRIFT', []),
#  ('Lacquer', 'JAPAN', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Others, to Ovid', 'ALIA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("A. A. Fair's real first name",
#   'ERLE',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sack cloth', 'BURLAP', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Train making all stops',
#   'LOCAL',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Sidestepped', 'AVERTED', ['SILENTL', 'SEABEDS']),
#  ('___ de León', 'PONCE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Sketches by ___": 1836', 'BOZ', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('A good thing to steal', 'THESHOW', ['SILENTL', 'SEABEDS']),
#  ('Nonalcoholic brew brand',
#   'ODOULS',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('One of the Bahamas',
#   'ABACO',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Building material for Solomon's Temple",
#   'CEDARS',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Happened to', 'BEFELL', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ("Lady Bird's middle name", 'ALTA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Home of more than 43 million',
#   'EGYPT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Put through a furnace',
#   'SMELT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Sliced food', 'PIZZA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Become fatigued', 'TIRE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Jots', 'IOTAS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Ralph of "The Waltons"',
#   'WAITE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Before, to the Bard', 'ERE', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Author of "The Nazarene"',
#   'ASCH',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Completed, in Caen', 'FINI', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Kids' book set in the jungle of Nool", 'HORTONHEARSAWHO', []),
#  ('"Dadgummit!"', 'DRAT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Prepares to dice chicken', 'DEBONES', ['SILENTL', 'SEABEDS']),
#  ('"Almanack" figure', 'RICHARD', ['SILENTL', 'SEABEDS']),
#  ('"Let me help with the dishes"',
#   'ILLDRY',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Guns', 'REVS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Rent', 'LET', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Star in Draco', 'ADIB', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ("Men's formalwear feature", 'COATTAIL', ['TOEDANCE']),
#  ('Convened', 'SAT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Course for a future g.p.',
#   'PREMED',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Deface', 'MAR', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('___-jongg', 'MAH', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Foofaraw', 'ADO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Landed', 'ALIT', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Charity', 'ALMS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Mountains', 'SLEWS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Of Erie, Huron, etc.', 'LACUSTRINE', []),
#  ('Causes sharp pain', 'SMARTS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Boundless', 'VAST', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Heavy knives', 'MACHETES', ['TOEDANCE']),
#  ('Apr. computers', 'CPAS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Ultrasecret org.', 'NSA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Decathlete Johnson',
#   'RAFER',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Indian name starter', 'SRI', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Registered', 'ENTERED', ['SILENTL', 'SEABEDS']),
#  ('Crystal ___', 'METH', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Lowly soldiers', 'GRUNTS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Dolt in "Of Mice and Men"',
#   'LENNIE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Japanese sect', 'ZEN', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Phi Beta ___', 'KAPPA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Man who's taken a vow", 'FRA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Sidestep', 'EVADE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('"Ain\'t She Sweet?" composer',
#   'AGER',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('With 33-Across, remitted',
#   'SENT',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Indian prince', 'RANA', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('QE2 milieu', 'OCEAN', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Have quite enough for', 'SATIATE', ['SILENTL', 'SEABEDS']),
#  ('Tarbell', 'IDA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Brilliant', 'STELLAR', ['SILENTL', 'SEABEDS']),
#  ('Brownstone features', 'STOOPS', ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Mislay', 'LOSE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Come after', 'ENSUE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Big bird', 'EMU', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Squirmy', 'WIGGLING', ['TOEDANCE']),
#  ('Cans', 'TINS', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Sidekick', 'PAL', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Wicker basket', 'PANNIER', ['SILENTL', 'SEABEDS']),
#  ('English cloth measure, once used for tax purposes',
#   'ALNAGE',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('Verbal contraction',
#   'ARENT',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Third-class', 'POOR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Big beast', 'BEHEMOTH', ['TOEDANCE']),
#  ('Sitcom with the theme song "I\'m a Survivor"',
#   'REBA',
#   ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('With enthusiasm', 'EAGERLY', ['SILENTL', 'SEABEDS']),
#  ('It helps you watch your balance: Abbr.',
#   'ATM',
#   ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Not a local: Abbr.', 'EXP', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Portly', 'OBESE', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Of two minds', 'TORN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Of sound', 'ACOUSTIC', ['TOEDANCE']),
#  ('Acted like Lear', 'RAGED', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ("Heffalump's creator",
#   'MILNE',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Oast', 'OVEN', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Actress Barbara Bel___',
#   'GEDDES',
#   ['DONORS', 'TEUTON', 'BRAKES', 'PRAWNS']),
#  ('"Tea for _____" (1925 hit)', 'TWO', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Frank Zappa or Dizzy Gillespie feature', 'SOULPATCH', []),
#  ("Bank depositor's div.", 'INT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Old or young follower', 'STER', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Best-selling novelist whom Time called "Bard of the Litigious Age"',
#   'SCOTTTUROW',
#   []),
#  ('Bug chaser?', 'ABOO', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Obsolescent communication',
#   'TELEX',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Kind of theater', 'ARENA', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Tart', 'SOUR', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Gilbert and Sullivan princess', 'IDA', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('Flower holder', 'VASE', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('One often seen at the door', 'MAT', ['GIL', 'TUT', 'NAG', 'OTT', 'AMT']),
#  ('W.W. II guns', 'STENS', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Top group', 'CREAM', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('God of war', 'ARES', ['ARAL', 'AMSO', 'NERO', 'ISEE', 'THAI']),
#  ('Gave out bit by bit',
#   'DOLED',
#   ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON']),
#  ('Propounded', 'POSED', ['GENOA', 'MARIO', 'ADAGE', 'PEELS', 'TALON'])]

# %%
guess("bruins")
# Out:
# ['DONORS', 'GENOA', 'ARAL', 'AMSO', 'MARIO']

# %%
# serialize and save model
import pickle

TRAINED_MODEL_PATH = "trained_model.p"

pickle.dump((answers_train, vectorizer, model), open(TRAINED_MODEL_PATH, "wb"))
