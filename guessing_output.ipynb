# %%
import os
import json
from pprint import pprint
import random
import numpy as np
from matplotlib import pyplot as plt

DATA_PATH = r"data\nyt_crosswords-cleaned"

# %%
puzzles_available = []

for year in os.listdir(DATA_PATH):
    if not year.isdecimal(): continue       # skip README.md
    for month in os.listdir(os.path.join(DATA_PATH, year)):
        for day in os.listdir(os.path.join(DATA_PATH, year, month)):
            puzzles_available.append((int(year), int(month), int(day.split(".")[0])))

print("Puzzles Available:", len(puzzles_available))
# Out:
# Puzzles Available: 14545

# %%
# Read a random sample of puzzles

# sample = random.sample(puzzles_available, 10_000)

# sample puzzles from EVEN days
sample = [puzz for puzz in puzzles_available if puzz[-1]%2==0]

clue_answer_pairs = []

for year, month, day in sample:
    path = os.path.join(DATA_PATH, f"{year}", f"{month:02d}", f"{day:02d}.json")
    with open(path, encoding="utf-8") as f:
        puzzle = json.load(f)
        for c, a in zip(
            puzzle["clues"]["across"] + puzzle["clues"]["down"],
            puzzle["answers"]["across"] + puzzle["answers"]["down"]
        ):
            clue = c[c.index(".")+2:]
            clue_answer_pairs.append((clue, a))

clues, answers = zip(*clue_answer_pairs)
clue_answer_pairs
# Out:
# [('Capital of Ghana', 'ACCRA'),
#  ('Shows wear, as a chair cushion', 'SAGS'),
#  ('Progeny of an old block', 'CHIP'),
#  ('Yugoslav native', 'CROAT'),
#  ("Guy Fawkes's forte", 'PLOT'),
#  ('Window part', 'PANE'),
#  ('Well-known drudge', 'CINDERELLA'),
#  ('Status quo ___ bellum', 'ANTE'),
#  ('Clocked', 'TIMED'),
#  ('Bedroom piece', 'DRESSER'),
#  ('Bull-rider of myth', 'EUROPA'),
#  ('Thus, to Caesar', 'ITA'),
#  ('Prior to', 'ERE'),
#  ('Roman 1501', 'MDI'),
#  ('Harvest goddess', 'OPS'),
#  ('Haul', 'LUG'),
#  ('Hallucinogen', 'LSD'),
#  ('Word with after or new', 'MATH'),
#  ('Condescended', 'STOOPED'),
#  ('Alaskan native', 'ALEUT'),
#  ('Common-Market initials', 'EEC'),
#  ('Kind of transit', 'RAPID'),
#  ('Custom-made in London', 'BESPOKE'),
#  ('___ chance (no way)', 'NOTA'),
#  ('Mil. man', 'SGT'),
#  ('Turntable abbr.', 'RPM'),
#  ('Holy day: Abbr.', 'SAB'),
#  ('Handed or headed', 'RED'),
#  ('Kind of text or cursor', 'PRE'),
#  ("Bill's partner", 'COO'),
#  ('Stomach: Prefix', 'GASTRO'),
#  ('Composer Victor', 'HERBERT'),
#  ('"Thar she ___!"', 'BLOWS'),
#  ('Heating vessel', 'ETNA'),
#  ('Victims of 8 Down', 'THREEBEARS'),
#  ('Estate or life', 'REAL'),
#  ('Poetic times', 'EENS'),
#  ('Good-by', 'ADIOS'),
#  ('She, in Paris', 'ELLE'),
#  ('Mild oath', 'DRAT'),
#  ('Moisten', 'BEDEW'),
#  ('Grammar case: Abbr.', 'ACC'),
#  ('Dernier ___', 'CRI'),
#  ('Penitent', 'CONTRITE'),
#  ("TV's brother", 'RADIO'),
#  ('Musical direction', 'ATEMPO'),
#  ('Rushed', 'SPED'),
#  ('Still and ___', 'ALL'),
#  ('Well-known intruder', 'GOLDILOCKS'),
#  ('Turn on, as an engine', 'STARTUP'),
#  ('Auditors: Abbr.', 'CPAS'),
#  ('Well-known oven user', 'HANSEL'),
#  ('Buries', 'INTERS'),
#  ('Looked closely', 'PEERED'),
#  ('Gathers', 'REAPS'),
#  ("Rarin' to go", 'EAGER'),
#  ('Anarchist Goldman', 'EMMA'),
#  ('System of land tenure', 'UDAL'),
#  ('Exploiter of 17 Across', 'STEPMOTHER'),
#  ('Center of activity', 'HUB'),
#  ('Fed. aid agency', 'OEO'),
#  ('Mr. Beard', 'DAN'),
#  ('Canonical hour', 'TERCE'),
#  ('Mideast city', 'PORTSAID'),
#  ('Passage, in anatomy', 'ITER'),
#  ('Pedestal part', 'DADO'),
#  ('Displayed', 'SPORTED'),
#  ('National emblem', 'EAGLE'),
#  ('Celestial music maker', 'SPHERE'),
#  ('Co-conspirator of 11 Down', 'GRETEL'),
#  ('Threefold', 'TERNAL'),
#  ('African tree', 'BAOBAB'),
#  ('Bergman, e.g.', 'SWEDE'),
#  ('Poetic misery', 'BALE'),
#  ('Overcome', 'BEST'),
#  ('Nucleic-acid initials', 'RNA'),
#  ('Small deer', 'ROE'),
#  ('Compass point', 'SSW'),
#  ('W. W. II org.', 'OPA'),
#  ('Synthetic', 'ERSATZ'),
#  ('Nicholas, e.g.', 'TSAR'),
#  ('Bridge mishap', 'SET'),
#  ('"___ Kapital"', 'DAS'),
#  ("Fresh-air fiend's advice", 'BREATHE'),
#  ('Go on about', 'RAVE'),
#  ('Imitate', 'APE'),
#  ('Feminine suffix', 'ESS'),
#  ('Threw off course', 'DERAILED'),
#  ('Thames landmark', 'ETON'),
#  ('Disencumber', 'RID'),
#  ('Become involved', 'STEPIN'),
#  ('Concrete strip', 'SLAB'),
#  ('F.D.R. program', 'NEWDEAL'),
#  ('Neighbor of Naples', 'SORRENTO'),
#  ('Rich fabric', 'SAMITE'),
#  ('Particle', 'ATOM'),
#  ('Type of well', 'ARTESIAN'),
#  ("Ethan Allen's conquest", 'TICONDEROGA'),
#  ('Dispatched', 'SENT'),
#  ('King of the old South', 'COTTON'),
#  ('Piddling salute', 'ONEGUN'),
#  ('Soft foods', 'PAPS'),
#  ('Please, in Bonn', 'GEFALLEN'),
#  ('Fountain specialties', 'SUNDAES'),
#  ('Month: Abbr.', 'OCT'),
#  ('Cable-making machine', 'STRANDER'),
#  ('Lively dance', 'HORA'),
#  ('Recording system', 'STEREO'),
#  ('Roman statesman', 'CATO'),
#  ('Undeveloped', 'RAW'),
#  ('French cleric', 'ABBE'),
#  ('Final confrontation', 'SURRENDEROFCORNWALLIS'),
#  ('Major poem', 'EPOS'),
#  ('Noun suffix', 'ERY'),
#  ('Mud, in France', 'BOUE'),
#  ('Zealous', 'ARDENT'),
#  ('Resorts', 'SPAS'),
#  ('Church musical rite', 'SUNGMASS'),
#  ('Long ___', 'AGO'),
#  ('Spotted cat', 'LEOPARD'),
#  ('Swiss town', 'WINDISCH'),
#  ('At the peak', 'ATOP'),
#  ('Fly', 'AVIATE'),
#  ('Sore', 'CANKER'),
#  ('Aunts, in Spain', 'TIAS'),
#  ('The low point', 'VALLEYFORGE'),
#  ('New Jersey battle', 'MONMOUTH'),
#  ('Stake', 'ANTE'),
#  ('Confine', 'INTERN'),
#  ('Site of U.S. base in Canada', 'ARGENTIA'),
#  ('Adirondack river', 'SARANAC'),
#  ('Times or tack', 'HARD'),
#  ('Wobble', 'TEETER'),
#  ('Packing unit: Abbr.', 'CTN'),
#  ('Batty', 'LOCO'),
#  ('___ contempt (accused in court)', 'CITEDFOR'),
#  ('Period', 'ERA'),
#  ('Korean soldier', 'ROK'),
#  ('Region: Abbr.', 'TERR'),
#  ('Offensive or defensive', 'PLATOON'),
#  ('British medical org.', 'RCS'),
#  ('Office holders', 'INS'),
#  ('Vehicle', 'SLED'),
#  ('Aver', 'ALLEGE'),
#  ('Its, in Paris', 'SES'),
#  ('Black Sea port', 'ODESSA'),
#  ('Pulpit occupant', 'PASTOR'),
#  ('Declare', 'ASSERT'),
#  ('Goof', 'ERR'),
#  ('Subject of Kant critique', 'REASON'),
#  ('Move easily', 'SAIL'),
#  ('Titan with a burden', 'ATLAS'),
#  ('Early confrontation', 'THEBATTLEOFBUNKERHILL'),
#  ('British letter', 'ZED'),
#  ("Hessians' Waterloo", 'TRENTON'),
#  ('Shiny fabric', 'SATEEN'),
#  ('Swear', 'AVOW'),
#  ('Tear', 'REND'),
#  ('Site of the turning point', 'SARATOGA'),
#  ('Postscript to a play', 'EPILOGUE'),
#  ('Kennedy', 'TED'),
#  ('Vermont battle', 'BENNINGTON'),
#  ('This: Ger.', 'DIESE'),
#  ('Journalism', 'PRESS'),
#  ('Like an otary', 'EARED'),
#  ('Spud', 'TATER'),
#  ('Clerical headwear', 'MITER'),
#  ('Religious picture', 'ICON'),
#  ("France's Le ___", 'MANS'),
#  ('Unsmiling', 'DOUR'),
#  ('Sicilian city', 'ENNA'),
#  ('Atlantic islands', 'CANARY'),
#  ('" . . . grow too ___ dream"', 'OLDTO'),
#  ('Nemesis of bad guys', 'POSSE'),
#  ('Misbehave', 'ACTUP'),
#  ('Feather: Prefix', 'PTERO'),
#  ('Sharp setbacks', 'FACERS'),
#  ('Disseminated', 'SOWN'),
#  ('Holy ___', 'SEE'),
#  ("Sultans' collections", 'HAREMS'),
#  ('B. &amp; O., etc.', 'RRS'),
#  ('Redden, in Paris', 'ROUGIR'),
#  ('City official: Abbr.', 'ALD'),
#  ("Goat's cry", 'BLEAT'),
#  ('Church fund-raiser', 'BINGO'),
#  ('Bar legally', 'ESTOP'),
#  ('___ Sea scrolls', 'DEAD'),
#  ("Vogue's Nast", 'CONDE'),
#  ('The C.I.C.', 'WASHINGTON'),
#  ('___ gratia artis', 'ARS'),
#  ('Glut', 'SATE'),
#  ('Victim', 'PREY'),
#  ('Scorch', 'SINGE'),
#  ('Expert on lines', 'ACTOR'),
#  ('Footing at Mauna Loa', 'LAVA'),
#  ("Northwestern's home", 'EVANSTON'),
#  ('Bayonne, N.J., sights', 'OILTANKS'),
#  ('More feeble', 'PALER'),
#  ('Kind of hog', 'WART'),
#  ('In unison', 'ASONE'),
#  ('Site of a widely-heard shot', 'CONCORD'),
#  ('Eastern ruler', 'AMEER'),
#  ('Small coach', 'FIACRE'),
#  ('Midday-sun sharer', 'MADDOG'),
#  ('Says', 'UTTERS'),
#  ('Wine measure', 'TIERCE'),
#  ('Worry', 'HARASS'),
#  ('Port of Brazil', 'NATAL'),
#  ('Heights: Abbr.', 'ALTS'),
#  ('Mr. Coward', 'NOEL'),
#  ('Network', 'RETE'),
#  ('Dernier ___', 'CRI'),
#  ('Auditor: Abbr.', 'CPA'),
#  ('Adversary', 'FOE'),
#  ('Bible book', 'ACTS'),
#  ('Seize', 'GRAB'),
#  ('Counterfeit', 'SHAM'),
#  ('Heart action', 'BEAT'),
#  ('Garbo', 'GRETA'),
#  ('Franchot', 'TONE'),
#  ('Canyon mouth', 'ABRA'),
#  ('"___, Macduff"', 'LAYON'),
#  ('Karenina', 'ANNA'),
#  ("Object of Thomas Paine's scorn", 'SUNSHINEPATRIOT'),
#  ('Crewmen', 'HANDS'),
#  ('Insect egg', 'NIT'),
#  ('Sal, e.g.', 'GAL'),
#  ('British-firm abbr.', 'LTD'),
#  ('"The Sleeping Beauty" et al.', 'BALLETS'),
#  ('Biographer of Henry James', 'EDEL'),
#  ('Koran chapter', 'SURA'),
#  ('Ipse ___', 'DIXIT'),
#  ('Fall field sight', 'SHEAF'),
#  ('Swindle', 'CON'),
#  ('Growing out', 'ENATE'),
#  ('Rich cake', 'TORTE'),
#  ("Mason's burdens", 'HODS'),
#  ('Stamp backing', 'GLUE'),
#  ('Rapture', 'ECSTASY'),
#  ('Asian sheep', 'SHA'),
#  ('Recipe abbr.', 'TSP'),
#  ('Id ___ (that is)', 'EST'),
#  ('Perfumes: Var.', 'ATARS'),
#  ('Joseph Conrad story', 'HEARTOFDARKNESS'),
#  ('Enthusiastic', 'AVID'),
#  ('Jail-door sound', 'CLANK'),
#  ('"___ virumque cano"', 'ARMA'),
#  ('Mother of Helen', 'LEDA'),
#  ('Sorts', 'KINDS'),
#  ('Mend', 'KNIT'),
#  ('Salver', 'TRAY'),
#  ('Health resorts', 'SPAS'),
#  ('Punta del ___', 'ESTE'),
#  ('Down with, in Paris', 'ABAS'),
#  ('Philippine island', 'CEBU'),
#  ('Mountain lake', 'TARN'),
#  ('Secrete', 'STASH'),
#  ('Luxembourg, e.g.', 'GRANDDUCHY'),
#  ('Kings, in Spain', 'REYES'),
#  ('On', 'ATOP'),
#  ('Basis of a certain split', 'BANANA'),
#  ('Causing surprise', 'STARTLING'),
#  ('"___ soit qui . . . "', 'HONI'),
#  ('___ Domini', 'ANNO'),
#  ('Essential part', 'MEAT'),
#  ('Flashes', 'GLINTS'),
#  ('Actor Holbrook', 'HAL'),
#  ('Diacritical mark', 'TILDE'),
#  ('Beau ___', 'GESTE'),
#  ('Kind of committee', 'ADHOC'),
#  ('Ogles', 'LEERS'),
#  ('Park fixtures', 'BANDSTANDS'),
#  ('Glorify', 'EXALT'),
#  ('Roman emperor', 'TITUS'),
#  ('Soak', 'STEEP'),
#  ('Like some saints', 'LATTERDAY'),
#  ('Marsupial, for short', 'ROO'),
#  ("Belshazzar's party", 'FEAST'),
#  ('Shovelheads', 'SHARKS'),
#  ('Big Board listings', 'STOCKS'),
#  ('Neighbor of Okla.', 'ARK'),
#  ('Turkish city', 'ADANA'),
#  ('Oil source of a sort', 'SNAKE'),
#  ('Crippled', 'HALT'),
#  ('For ___ and a day', 'EVER'),
#  ('Operatic heroine', 'AIDA'),
#  ('Impertinent', 'FLIP'),
#  ('Birds of prey', 'ERNS'),
#  ('Struck', 'SMIT'),
#  ('Cloy', 'SATE'),
#  ('African stockade', 'BOMA'),
#  ('Utmost degree', 'ACME'),
#  ('Feudal lord', 'LIEGE'),
#  ('Magnetites', 'ORES'),
#  ('Checkroom fixture', 'COATHANGER'),
#  ('Body english, in a way', 'WISHFULTHINKING'),
#  ('City-map unit', 'LOT'),
#  ('East, in Madrid', 'ESTE'),
#  ('Lets', 'LEASES'),
#  ('Kind of drum', 'SNARE'),
#  ('Bridge bid: Abbr.', 'DBL'),
#  ('Crimean river', 'ALMA'),
#  ('Pledges', 'ASSURES'),
#  ('Place for a token', 'SLOT'),
#  ('Port of Arabia', 'ADEN'),
#  ('Pointless', 'INANE'),
#  ("Gambler's dream", 'TOHITTHEJACKPOT'),
#  ('The vowels', 'AEIOU'),
#  ('Asteroid', 'EROS'),
#  ('"___ long, long way to . . . "', 'ITSA'),
#  ('Kind of general', 'TWOSTAR'),
#  ('Full extent', 'SPAN'),
#  ('Gardner of cartoons', 'REA'),
#  ('Golden calf et al.', 'IDOLS'),
#  ("Moat's protégé, in a way", 'CASTLE'),
#  ('Kettle or snare', 'DRUM'),
#  ('___ Testament', 'NEW'),
#  ('Kaufman-Hart play', 'ONCEINALIFETIME'),
#  ('Get out of the way', 'STANDASIDE'),
#  ('Cross', 'ROOD'),
#  ('Pastries', 'TARTS'),
#  ('Biblical priest', 'EBER'),
#  ('Miss Bancroft', 'ANNE'),
#  ('Rose, Cotton, etc.', 'BOWLS'),
#  ('Hunter of the sky', 'ORION'),
#  ('Hostess Perle', 'MESTA'),
#  ('Cinder', 'ASH'),
#  ('Needle, in old Rome', 'ACUS'),
#  ('Belmont entry', 'COLT'),
#  ('Matched', 'MATED'),
#  ('Ordinal suffix', 'ETH'),
#  ('Highway unit', 'LANE'),
#  ('"___ Dinka Doo"', 'INKA'),
#  ('Shield', 'EGIS'),
#  ('Hackman or Tierney', 'GENE'),
#  ('Work units', 'ERGS'),
#  ('Quirinal and Bunker, e.g.', 'HILLS'),
#  ('Sense', 'FEEL'),
#  ('Fractions', 'RATIOS'),
#  ('Minstrel-show instruments', 'BANJOS'),
#  ('Doorstep fixture', 'MAT'),
#  ('Cling to', 'ADHERE'),
#  ('"___ transit gloria . . . "', 'SIC'),
#  ('Harsh', 'UNKIND'),
#  ('Engrossed', 'RAPT'),
#  ("Seth's son", 'ENOS'),
#  ('Bristle', 'SETA'),
#  ('Photocopy', 'STAT'),
#  ('Movie-chain name', 'LOEW'),
#  ("Louisville's river", 'OHIO'),
#  ('Poetic word', 'EER'),
#  ('Mild rebuke', 'TUT'),
#  ('Viper', 'ASP'),
#  ('Sports place', 'ARENA'),
#  ('Love, in France', 'AIME'),
#  ('Improvise', 'ADLIB'),
#  ('Kind of ring', 'ONION'),
#  ('Kind of ade', 'LEMON'),
#  ('Bjorn Borg, e.g.', 'SWEDE'),
#  ('Expense', 'COST'),
#  ('Wall pier', 'ANTA'),
#  ('Unpleasant aftermath', 'SCAR'),
#  ("Omar's product", 'TENT'),
#  ('Covers', 'LIDS'),
#  ('___ out (endure)', 'RIDE'),
#  ('Shore, in Bonn', 'UFER'),
#  ('Enzyme suffix', 'ASE'),
#  ('___-la', 'TRA'),
#  ('Talks on and on', 'PRATES'),
#  ('Meal', 'REPAST'),
#  ('Kind of control', 'REMOTE'),
#  ('Springy', 'ELASTIC'),
#  ('Patriots of 1776', 'CONTINENTALARMY'),
#  ('Consumed', 'ATE'),
#  ('Giveaway-ad words', 'TAKEONE'),
#  ("Poet's word", 'EER'),
#  ("Parishioner's place", 'PEW'),
#  ('German article', 'EIN'),
#  ('___ the line', 'TOE'),
#  ('Nautical reading', 'ESE'),
#  ('Like some seals', 'EARLESS'),
#  ('Large cask', 'TUN'),
#  ('Meanders', 'STROLLS'),
#  ('Give orders', 'DICTATE'),
#  ('City way: Abbr.', 'AVE'),
#  ('Chinese leader', 'MAO'),
#  ('Have', 'POSSESS'),
#  ('Certain musician', 'HARPIST'),
#  ('Emmet', 'ANT'),
#  ('Protestant nonconformist', 'SECTARY'),
#  ('French sea', 'MER'),
#  ('Certain vote', 'YEA'),
#  ('Morsel', 'ORT'),
#  ('Be indebted', 'OWE'),
#  ('"___ in the stilly night"', 'OFT'),
#  ('___ pensée (hidden motive)', 'ARRIERE'),
#  ('Channel', 'GAT'),
#  ('Declaration signers', 'FOUNDINGFATHERS'),
#  ('Interdicted', 'FORBADE'),
#  ('Let go', 'UNHAND'),
#  ('Joined up with', 'TEAMED'),
#  ('Hosiery threads', 'LISLES'),
#  ('Dissent', 'PROTEST'),
#  ('Library user, at times', 'RENEWER'),
#  ('Quantity: Abbr.', 'AMT'),
#  ('Roof, in Paris', 'TOIT'),
#  ('Lab vessel', 'ETNA'),
#  ('Ones with a quest', 'SEEKERS'),
#  ('Modified colors again', 'RETONED'),
#  ('Spirit', 'ELAN'),
#  ('Lacking vigor', 'PALE'),
#  ('Blind ___ bat', 'ASA'),
#  ('Musical passage', 'STRETTA'),
#  ('Recess', 'TIMEOUT'),
#  ('Libyan resort', 'CYRENE'),
#  ("Matadors' needs", 'CAPES'),
#  ('Armstrong', 'NEIL'),
#  ('Little people', 'ELVES'),
#  ('Scabbard lining: Fr.', 'ALESE'),
#  ('Loose jacket', 'SIMAR'),
#  ('Frightening', 'SCARY'),
#  ('Western alliance', 'OAS'),
#  ('Spinner', 'TOP'),
#  ('Retribution', 'PAYOFF'),
#  ('Twelve inches', 'ONEFOOT'),
#  ('Importance', 'STATURE'),
#  ('" . . . like a woman ___"', 'SCORNED'),
#  ('Odious', 'HATEFUL'),
#  ('Miss Coca', 'IMOGENE'),
#  ('___ Folly (Alaska)', 'SEWARDS'),
#  ('Waste allowances', 'TRETS'),
#  ('Neat', 'TRIG'),
#  ('Genesis man', 'ADAM'),
#  ('Take for a ___', 'RIDE'),
#  ('Hindu queen', 'RANI'),
#  ('Anglo-Saxon letters', 'ETHS'),
#  ("Knicks' league: Abbr.", 'NBA'),
#  ('Prince ___', 'HAL'),
#  ("Skiers' lifts", 'TOWS'),
#  ('Midwest city', 'OMAHA'),
#  ('Bible book', 'ACTS'),
#  ('One of the five', 'ERIE'),
#  ('___ colony', 'PENAL'),
#  ('Hindu goddess of beauty', 'SHRI'),
#  ('Lofty words in an atlas', 'CANADIANROCKIES'),
#  ('Enlarges', 'ADDSONTO'),
#  ("MIG's and SST's", 'PLANES'),
#  ('Aviator Post', 'WILEY'),
#  ('Hashhouse', 'BEANERY'),
#  ('Like a knife', 'BLADED'),
#  ('Divides again', 'RECUTS'),
#  ('Ventilated', 'AIRED'),
#  ('Sensational', 'LURID'),
#  ('Compass point', 'ENE'),
#  ('Star in Cygnus', 'SADR'),
#  ('Buddhist writing', 'SUTRA'),
#  ('Prurient matter', 'SMUT'),
#  ('Silkworm', 'ERI'),
#  ('Shoddy', 'TATTY'),
#  ('Monotonous sound', 'CHANT'),
#  ('Obdurate: Var.', 'STONEY'),
#  ('Alternative', 'CHOICE'),
#  ('Plateaus', 'UPLANDS'),
#  ('Inexperienced', 'GREEN'),
#  ('Tricks', 'PRANKS'),
#  ("Referees' needs", 'WHISTLES'),
#  ('Narrow words in an atlas', 'SINGAPORESTRAIT'),
#  ('Taro root', 'EDDO'),
#  ('Miss Bordoni', 'IRENE'),
#  ('Nine: Prefix', 'ENNE'),
#  ('Hardy girl', 'TESS'),
#  ('Bivouac ingredients', 'TENTS'),
#  ('Paradise', 'EDEN'),
#  ('Mexican Indian', 'TECA'),
#  ('Toward the mouth', 'ORAD'),
#  ('Little words in a atlas', 'WINDWARDISLANDS'),
#  ('Coast dweller', 'SEASIDER'),
#  ('Thought', 'OPINED'),
#  ('Substantial', 'MEATY'),
#  ('___ Domini', 'ANNO'),
#  ('Cambridge university: Abbr.', 'HAR'),
#  ('Baldness', 'ALOPECIA'),
#  ('Obliquely', 'ASKANT'),
#  ('Big words in an atlas', 'CHINESEMAINLAND'),
#  ('Shoe-factory worker', 'TREER'),
#  ('Timid one', 'SISSY'),
#  ('Parceled out', 'DOLED'),
#  ("Man's name", 'CLAUD'),
#  ('Black, blue or straw', 'BERRY'),
#  ('Low', 'BASE'),
#  ('Prevaricator', 'LIAR'),
#  ('Like old roads', 'RUTTY'),
#  ('Musical instruments', 'LUTES'),
#  ('___ Dimittis', 'NUNC'),
#  ('Feminine ending', 'ETTE'),
#  ('Small point of land', 'SANDSPIT'),
#  ('Closet item', 'SHOETREE'),
#  ('Tropical bean', 'TONKA'),
#  ('Community ___', 'CHEST'),
#  ('Dances', 'TANGOS'),
#  ('Turning points', 'CRISES'),
#  ('In a dither', 'UPSET'),
#  ("Fall's precursor", 'PRIDE'),
#  ('Belgian city', 'GHENT'),
#  ('Songbird', 'WREN'),
#  ('German article', 'EINE'),
#  ('British gun', 'STEN'),
#  ('Smeltery material', 'ORE'),
#  ('Biblical mount', 'PISGAH'),
#  ('Musical introductions', 'PRELUDES'),
#  ('Prompt', 'ONTIME'),
#  ('Firmly determined', 'RESOLUTE'),
#  ('Roger Kahn novel', 'THEBOYSOFSUMMER'),
#  ('Axe, e.g.', 'HEWER'),
#  ('Curved moldings', 'OGEES'),
#  ('In favor of', 'PRO'),
#  ('Old English moneys', 'ORAS'),
#  ('Reporters: Abbr.', 'CORRS'),
#  ('Lairs', 'DENS'),
#  ('Celtic Neptune', 'LER'),
#  ('Siberian native', 'TATAR'),
#  ('___ mistake (erred)', 'MADEA'),
#  ('Minstrel-show performers', 'ENDMEN'),
#  ('Of the cheek', 'MALAR'),
#  ('French philosopher', 'STSIMON'),
#  ('Romantic demonstrations', 'LOVEINS'),
#  ('Asparagus unit', 'SPEAR'),
#  ('Failed to', 'DIDNOT'),
#  ('Make ___ (rendezvous)', 'ADATE'),
#  ('Affirmations', 'YESES'),
#  ('Moscow affiliate: Abbr.', 'SSR'),
#  ('Celsius units: Abbr.', 'DEGS'),
#  ('Nile dam site', 'ASWAN'),
#  ('Shower affection on', 'DOTE'),
#  ('Paddle', 'OAR'),
#  ('Done in', 'SLAIN'),
#  ('Soft drinks', 'COLAS'),
#  ('Subject of 17 Across', 'BROOKLYNDODGERS'),
#  ('Came from', 'EMANATED'),
#  ('Reveal', 'EVINCE'),
#  ('Ervin et al.', 'SENATORS'),
#  ('Fractions', 'NINTHS'),
#  ('Threats to auto axles', 'POTHOLES'),
#  ('Innate', 'INHERENT'),
#  ('Flight attendants', 'STEWARDS'),
#  ('Taunts', 'GIBES'),
#  ('Eros', 'AMOR'),
#  ('Attention-getter', 'HEY'),
#  ('Playbill', 'PROGRAM'),
#  ("Asterisk's function", 'REFERRAL'),
#  ('Letters', 'ESSES'),
#  ('Gehrig et al.', 'LOUS'),
#  ('Danube city', 'ULM'),
#  ('Unloaded', 'DUMPED'),
#  ('Everlasting, formerly', 'ETERNE'),
#  ('Insect membrane', 'SEROSA'),
#  ('Relative of fly ash', 'SOOT'),
#  ('Kayak', 'CANOE'),
#  ('Was adventurous', 'DARED'),
#  ('Phoenix suburb', 'TEMPE'),
#  ('Song thrush', 'MAVIS'),
#  ('Atomizer outputs', 'MISTS'),
#  ('Thick woolen cloth', 'LODEN'),
#  ('Contrary one', 'NAYSAYER'),
#  ('Disrespectful', 'INSOLENT'),
#  ('Collar-washing instruction', 'NOSTARCH'),
#  ('Emphasizes', 'STRESSES'),
#  ('Tape-recorder buttons', 'REWINDS'),
#  ('Earthen bricks', 'ADOBES'),
#  ('Alas!', 'DEARME'),
#  ('Let out ___ (show frustration)', 'AGROAN'),
#  ('Hourglass filler', 'SAND'),
#  ('___ the good', 'ALLTO'),
#  ('___ the manger', 'DOGIN'),
#  ('Card game', 'SKAT'),
#  ('Roman 406', 'CDVI'),
#  ('"Cat ___ Hot Tin Roof"', 'ONA'),
#  ('Wine: Prefix', 'OEN'),
#  ('Fix a hose hole', 'DARN'),
#  ("Strains, as one's brains", 'RACKS'),
#  ("Torero's wear", 'CAPA'),
#  ('Tropical oil tree', 'EBOE'),
#  ("Atlantic convoy's foe", 'UBOAT'),
#  ('Swan genus', 'OLOR'),
#  ('Certain sixth sense', 'WOMANSINTUITION'),
#  ('Allows', 'SUPPOSES'),
#  ('Pipe-bowl residue', 'DOTTLE'),
#  ('Prefix with fold or dent', 'TRI'),
#  ('"I ___ man with . . . "', 'META'),
#  ('City on the Arno', 'PISA'),
#  ('Like a friar', 'MONASTIC'),
#  ('Family members', 'MAIDENAUNTS'),
#  ('Mrs. Johnson', 'OSA'),
#  ('Early thrall', 'ESNE'),
#  ('Jet plane', 'SST'),
#  ('Hair coils', 'BUNS'),
#  ('Man of briefs: Abbr.', 'ATT'),
#  ('Worldly parent', 'MOTHEREARTH'),
#  ("Mother's order to child", 'DOASISAY'),
#  ('Cloth measures', 'ELLS'),
#  ('Shade givers', 'ELMS'),
#  ('Harden', 'GEL'),
#  ('Breastbone: Prefix', 'STERNO'),
#  ('___ the Mount', 'SERMONON'),
#  ('Fiancées, in a way', 'LADIESINWAITING'),
#  ('Helm direction', 'ALEE'),
#  ('Like some walls', 'IVIED'),
#  ('Work on copy', 'EDIT'),
#  ('___ wear', 'MENS'),
#  ('Cavalry piece', 'SABRE'),
#  ('Sleuths: Abbr.', 'DETS'),
#  ('Moistens', 'DEWS'),
#  ('Arabian father', 'ABOU'),
#  ('Cut a dido', 'ROMP'),
#  ('Ocean current', 'NEAPTIDE'),
#  ('Ballet or bank', 'RUSSIAN'),
#  ("Rose's Romeo", 'ABIE'),
#  ('Swindles', 'CONS'),
#  ('Arabian tea', 'KAT'),
#  ('Matriculant', 'STUDENT'),
#  ('Priestly surplices', 'COTTAS'),
#  ('Came down', 'ALIT'),
#  ('Relative of a cartel', 'POOL'),
#  ('British composer', 'ARNE'),
#  ('People of Bergen', 'NORSE'),
#  ('Small bits', 'IOTAS'),
#  ('Casino card game', 'MONTE'),
#  ('Ship of exploring fame', 'PINTA'),
#  ('Like an overripe melon', 'MUSHY'),
#  ("Cook's offerings", 'TOURS'),
#  ('"___ It Romantic?"', 'ISNT'),
#  ('Wherewithal', 'CASH'),
#  ('Lake or Margaret', 'MEAD'),
#  ('Concerning', 'ASTO'),
#  ('Movie dog et al.', 'ASTAS'),
#  ('Went to the polls', 'BALLOTED'),
#  ('A.A. ___', 'MILNE'),
#  ('Subtle absorption', 'OSMOSIS'),
#  ('Do a road job', 'REGRADE'),
#  ('Tropical resin', 'ELEMI'),
#  ('World ___', 'SERIES'),
#  ('Bridge bid', 'SLAM'),
#  ('Narrative', 'TALE'),
#  ('British P.M.', 'EDEN'),
#  ('Rebuff, Scottish style', 'SNIB'),
#  ('Pitcher', 'EWER'),
#  ('Brood of pheasants', 'NIDE'),
#  ('" . . . with a blue ribbon ___"', 'ONIT'),
#  ('Theater-ad abbr.', 'NGTS'),
#  ('Ragweed genus', 'IVA'),
#  ('"Uncle Vanya" author', 'CHEKHOV'),
#  ('Holy city', 'MECCA'),
#  ('Word with legs or cuffs', 'TROUSER'),
#  ('Dramatist of the absurd', 'IONESCO'),
#  ('One of a French trio', 'ATHOS'),
#  ('Great joy', 'RAPTURE'),
#  ('Potters', 'CLAYMEN'),
#  ('Hotel-desk postings', 'CHECKOUTTIMES'),
#  ('Intends', 'AIMS'),
#  ('Aardvark food', 'ANTS'),
#  ('Contents of certain books', 'CHECKS'),
#  ('Milk: Prefix', 'LACT'),
#  ('___ volente', 'DEO'),
#  ('Recent: Prefix', 'NEO'),
#  ('Bypass closely', 'SKIRT'),
#  ('Factions', 'SECTS'),
#  ('Irish cry', 'ARRA'),
#  ("Arthur's nephew", 'GAWAIN'),
#  ('Great Barrier Island', 'OTEA'),
#  ('Geste or Nash', 'BEAU'),
#  ('Sea flier', 'ERN'),
#  ('Sing loudly, with "out"', 'BELT'),
#  ('Palm leaf: Var.', 'OLA'),
#  ('English game pebble', 'CHECKSTONE'),
#  ('Makes inquiries', 'CHECKSUPON'),
#  ('Humperdinck boy', 'HANSEL'),
#  ('Base runner, at times', 'STEALER'),
#  ('Treatment', 'USAGE'),
#  ('Common abbr.', 'ETC'),
#  ('___ code', 'AREA'),
#  ('Ground defense: Abbr.', 'LAA'),
#  ('African native', 'SOMALI'),
#  ('Stopovers for game pieces', 'CHECKERBOARDSQUARES'),
#  ('Whistle stop', 'HAMLET'),
#  ('Gold tinctures', 'ORS'),
#  ('Plaster item', 'CAST'),
#  ("Rockefeller's oil: Abbr.", 'STD'),
#  ('Miss Adoree', 'RENEE'),
#  ("Contract's predecessor", 'AUCTION'),
#  ('Coin', 'SPECIE'),
#  ('Realists', 'ACTUALISTS'),
#  ('Full go-ahead', 'BLANKCHECK'),
#  ('Estes and Menlo: Abbr.', 'PKS'),
#  ('Bird plumage', 'RUFF'),
#  ('Owned', 'HAD'),
#  ("Creil's river", 'OISE'),
#  ('Elbe tributary', 'EGER'),
#  ('Object of perception', 'SENSUM'),
#  ('"What ___ God wrought!"', 'HATH'),
#  ('Samantha', 'EGGAR'),
#  ('Miss Kett et al.', 'ETTAS'),
#  ('Roman way', 'VIA'),
#  ('Relative: Abbr.', 'BRO'),
#  ('Skin', 'DERM'),
#  ('Sleigh puller', 'DASHER'),
#  ('Show surprise', 'GASP'),
#  ('Small herring', 'BRIT'),
#  ('Accurate one', 'DOUBLECHECKER'),
#  ('Most trim', 'TIDIEST'),
#  ("Harmonizers' girl", 'ADELINE'),
#  ('Type of song', 'THEME'),
#  ('Set apart', 'ISOLATE'),
#  ('Picks', 'SELECTS'),
#  ('As good ___', 'ASNEW'),
#  ('Early stringed instrument', 'CHEKKER'),
#  ('Large insect', 'CICADA'),
#  ('"___ than thou"', 'HOLIER'),
#  ('Charm', 'ENAMOR'),
#  ('Florida sights', 'KEYS'),
#  ('Royal initials', 'HSM'),
#  ('Kind of ography', 'OCEAN'),
#  ('Author Kurt', 'VONNEGUT'),
#  ('Raincoats, for short', 'MACS'),
#  ('Moral: Abbr.', 'ETH'),
#  ('Begin a hotel visit', 'CHECKIN'),
#  ('Chinese fowl', 'COCHIN'),
#  ('Suppliant', 'ASKER'),
#  ('Japanese bastion of W.W. II', 'TRUK'),
#  ('Zounds!', 'RATS'),
#  ('Decide', 'OPT'),
#  ('Practical', 'UTILE'),
#  ('Common field plant', 'SUMAC'),
#  ('Establish', 'ERECT'),
#  ('Shelters or hostels', 'RESTS'),
#  ('1905 manifesto', 'OCTOBER'),
#  ('___ tee', 'TOA'),
#  ('Hindu garment', 'SAREE'),
#  ('Japanese orange', 'SATSUMA'),
#  ('Fundamentals', 'ABCS'),
#  ('Traveled widely', 'WENTABOUT'),
#  ("Flatfoot's relative", 'TEC'),
#  ('Social-club member', 'ELK'),
#  ('Squeeze out', 'EKE'),
#  ('Abate, old style', 'ASLAKE'),
#  ('Give out iridescence', 'OPALESCE'),
#  ('Of a military science', 'LOGISTIC'),
#  ('Carbon: Suffix', 'ANE'),
#  ('Guevara', 'CHE'),
#  ('Kind of girl', 'HATCHECK'),
#  ('Delights', 'ENCHANTS'),
#  ('Dare: Fr.', 'OSER'),
#  ("Goodman's instr.", 'CLAR'),
#  ('Sniffles', 'HEADCOLDS'),
#  ('Asian grass', 'USAR'),
#  ('As ___ resort', 'ALAST'),
#  ('Soak', 'RET'),
#  ('Trafalgar and Times: Abbr.', 'SQS'),
#  ('Excel in the slalom', 'OUTSKI'),
#  ('Tall bird', 'EMEU'),
#  ('Less smoggy', 'CLEARER'),
#  ('Grampuses', 'ORCS'),
#  ('Arabian capital', 'SANA'),
#  ('Ten: Prefix', 'DEK'),
#  ('Door sound', 'RAP'),
#  ('___ as a daisy', 'ASFRESH'),
#  ('Borneo natives', 'IBANS'),
#  ('Portions: Abbr.', 'PCS'),
#  ('Querying sounds', 'EHEH'),
#  ('Haul', 'LUG'),
#  ('Bowstring hemp', 'IFE'),
#  ('Based on moral law', 'NOMISTIC'),
#  ('Listen carefully', 'HEARKEN'),
#  ('Crams, in Scotland', 'STECHS'),
#  ('Grape', 'UVA'),
#  ('Take ___ (rest)', 'ABREAK'),
#  ('Sad, in Dijon', 'TRISTE'),
#  ('More biting', 'HOTTER'),
#  ('Norse tales', 'EDDAS'),
#  ('Hollow stone', 'GEODE'),
#  ('Thin cereal', 'GRUEL'),
#  ('Stroll along', 'AMBLE'),
#  ('Greek letter', 'THETA'),
#  ('Clownlike', 'APISH'),
#  ('Parking-lot hazard', 'DENT'),
#  ('Honor cards', 'ACES'),
#  ('Expanded', 'GREW'),
#  ('Swindle', 'BILK'),
#  ('Auto plate: Abbr.', 'LIC'),
#  ('Uncle, in Perth', 'EME'),
#  ('Deer', 'DOE'),
#  ('___ ground (regress)', 'LOSE'),
#  ('Big success', 'SMASH'),
#  ('Blue or poker', 'CHIP'),
#  ('To ___', 'AMAN'),
#  ('Put aside', 'PIGEONHOLE'),
#  ('Proceeds steadily', 'HOLDSONESCOURSE'),
#  ('Seafood delicacy', 'ROE'),
#  ('Greek goddess', 'ERIS'),
#  ('Kind of tube', 'INNER'),
#  ('Barracudas', 'SPETS'),
#  ('___ out (spend)', 'FORK'),
#  ('Network', 'LACIS'),
#  ('"___ were the days"', 'THOSE'),
#  ('Greek letter', 'CHI'),
#  ('Key', 'ISLET'),
#  ('Fatha Hines', 'EARL'),
#  ('Hangar', 'SHED'),
#  ('In ___ (eventually)', 'THECOURSEOFTIME'),
#  ('Present', 'HERE'),
#  ('Jets', 'SSTS'),
#  ('Where strikes are appreciated', 'LANES'),
#  ('Arctic native: Abbr.', 'ESK'),
#  ('Influence', 'GETAT'),
#  ('Abounding in: Suffix', 'ULENT'),
#  ('Foot: Prefix', 'PEDO'),
#  ('Arctic sights', 'FLOES'),
#  ("Nora's creator", 'IBSEN'),
#  ('Tale-teller', 'LIAR'),
#  ('___ up (delight in)', 'EAT'),
#  ('Let things ___ (leave alone)', 'TAKETHEIRCOURSE'),
#  ('One shifted to a new post', 'TRANSFEREE'),
#  ('___-do-well', 'NEER'),
#  ("Stable-owner's purchase", 'OATS'),
#  ('Kind of conscious', 'CLASS'),
#  ('Cheese', 'EDAM'),
#  ('Memorable comic', 'LAHR'),
#  ('Melville creation', 'OMOO'),
#  ('Store employee', 'SALESCLERK'),
#  ('Result', 'END'),
#  ('Kind of shirt', 'SPORT'),
#  ('Cares for', 'MINISTERSTO'),
#  ('Stone et al.', 'AGES'),
#  ('His, in Le Mans', 'SES'),
#  ('Ad ___', 'HOC'),
#  ('Piece', 'CHUNK'),
#  ('___ in (interfere)', 'HORN'),
#  ("Girl's name in Bonn", 'ILSE'),
#  ('Titled one', 'PEER'),
#  ('Black, in France', 'NOIRE'),
#  ('Looks after', 'SEESTO'),
#  ('Word with work or meal', 'PIECE'),
#  ("Rangers' concerns", 'FORESTFIRES'),
#  ('European capital', 'OSLO'),
#  ('Supple', 'LITHE'),
#  ('Residue', 'ASHES'),
#  ('___ luego (good-by)', 'HASTA'),
#  ('Color', 'CHINESERED'),
#  ('Virile ones', 'HEMEN'),
#  ('Common Latin phrase', 'IDEST'),
#  ('Like some jokes', 'STALE'),
#  ('Put into practice', 'USED'),
#  ('Chemical prefix', 'FLUORO'),
#  ('Chaps', 'GENTS'),
#  ('Hammer parts', 'PEENS'),
#  ('Spikes the punch', 'LACES'),
#  ('"Tell ___ the Marines"', 'ITTO'),
#  ('Theda', 'BARA'),
#  ('Card game', 'SKAT'),
#  ('European money', 'LIRA'),
#  ('Bewildered', 'ASEA'),
#  ('Duration', 'TERM'),
#  ('Electrical abbr.', 'HFC'),
#  ('Slippery one', 'EEL'),
#  ('French article', 'UNE'),
#  ('Hemingway', 'PAPA'),
#  ('Bout', 'SETTO'),
#  ('Declines', 'EBBS'),
#  ('Final or midterm event', 'EXAM'),
#  ('Group character', 'ETHOS'),
#  ('Mrs. Nick Charles', 'NORA'),
#  ("Like Dali's watches", 'LIMP'),
#  ('Rec and living', 'ROOMS'),
#  ('Hamilton-Burr meet', 'DUEL'),
#  ('Recipe abbr.', 'TSP'),
#  ('"Je ___ beaucoup"', 'TAIME'),
#  ("Guy's friend", 'GAL'),
#  ('Furor', 'HOOPLA'),
#  ('Four score', 'EIGHTY'),
#  ('"We ___" (with 43 Across)', 'HOLDTHESETRUTHS'),
#  ('Garbo, e.g.', 'SWEDE'),
#  ('He had not yet begun to fight', 'JONES'),
#  ('Asian holiday', 'TET'),
#  ('Madison Square Garden, e.g.', 'ARENA'),
#  ('___ Jeanne', 'STE'),
#  ('Musical symbol', 'GCLEF'),
#  ('Turns up a card', 'FACES'),
#  ('See 28 Across', 'TOBESELFEVIDENT'),
#  ('Bryant and Loos', 'ANITAS'),
#  ('Ace, as part of a blackjack', 'ELEVEN'),
#  ('Knowledge', 'KEN'),
#  ('Derrick', 'CRANE'),
#  ('Also', 'AND'),
#  ('Catchall abbr.', 'ETAL'),
#  ('Affirm', 'POSIT'),
#  ('Canal', 'ERIE'),
#  ('Shredded', 'TORE'),
#  ('Unique', 'ALONE'),
#  ("___ days' wonder", 'NINE'),
#  ('Former movie czar Will', 'HAYS'),
#  ('Approached an end', 'WANED'),
#  ('Soft ___ (flattery)', 'SOAP'),
#  ('Hide', 'PELT'),
#  ('W. W. II losers', 'AXIS'),
#  ('"Common Sense," e.g.', 'PAMPHLET'),
#  ('Elec. unit', 'AMP'),
#  ('Angel', 'SERAPH'),
#  ("Paris's Place d' ___", 'ETOILE'),
#  ('Author of 28 Across', 'THOMASJEFFERSON'),
#  ('Scholarly volume', 'TOME'),
#  ('W. W. II agency', 'OSS'),
#  ('Wind up', 'END'),
#  ('Bribed, as a public official', 'BOUGHT'),
#  ('Slightest hint', 'BREATH'),
#  ('Kellerman and Rand', 'SALLYS'),
#  ('Carry', 'TOTE'),
#  ('___ man out', 'ODD'),
#  ('Volcano', 'ETNA'),
#  ('Choler', 'IRE'),
#  ('Astronaut Grissom', 'GUS'),
#  ('White House monogram', 'HST'),
#  ('Be in the red', 'OWE'),
#  ('Time period', 'EON'),
#  ('Beverages', 'ALES'),
#  ('Kind of pronoun: Abbr.', 'REL'),
#  ("Film-director's bible", 'SCENARIO'),
#  ('Sawbuck', 'TEN'),
#  ('Part of i.e.', 'EST'),
#  ('Fetch', 'GET'),
#  ("Lee's group: Abbr.", 'CSA'),
#  ('Fin', 'FIVE'),
#  ('Summer cooler', 'ADE'),
#  ('"And the Lord ___ away"', 'TAKETH'),
#  ('___ customer', 'ONETOA'),
#  ('Consisting of two', 'BINARY'),
#  ('Miss Stritch', 'ELAINE'),
#  ("Loosed, as one's fury", 'VENTED'),
#  ('Soft drink', 'COLA'),
#  ("Pinta's partner", 'NINA'),
#  ('Intense', 'DEEP'),
#  ('French article', 'LES'),
#  ('Handle roughly', 'PAW'),
#  ('Type measures', 'ENS'),
#  ('Pith helmet', 'TOPI'),
#  ('Halloween choice', 'TRICK'),
#  ('Church area', 'APSE'),
#  ('N.C. College', 'ELON'),
#  ('Tidal wave', 'EAGRE'),
#  ('Fish bait', 'CHUM'),
#  ('Obvious', 'SELFEXPLANATORY'),
#  ('Trifled', 'TOYED'),
#  ('Awkward boat', 'TUB'),
#  ('Water pots of India', 'LOTAS'),
#  ('___ and Thummim', 'URIM'),
#  ('Spanish painter', 'MIRO'),
#  ('Newspaper section: Abbr.', 'FIN'),
#  ('Asian palm', 'TALIPOT'),
#  ('Prod', 'JAB'),
#  ('Besides', 'ALSO'),
#  ('Wanderer', 'NOMAD'),
#  ('___ de force', 'TOUR'),
#  ('Coin of Iran', 'RIAL'),
#  ('Century plant', 'AGAVE'),
#  ('Rough', 'RUDE'),
#  ('Attractive', 'CUTE'),
#  ('Roman menswear', 'TOGAS'),
#  ('Silkworm', 'ERIA'),
#  ("Ostrich's relative", 'EMU'),
#  ('Takes umbrage', 'RESENTS'),
#  ('Land of ___', 'NOD'),
#  ('Dissolute one', 'ROUE'),
#  ('Mental discipline', 'YOGA'),
#  ('Freshwater fish', 'ROACH'),
#  ('Shinto temple', 'SHA'),
#  ("La Scala's locale", 'MILAN'),
#  ('Cannibal', 'ANTHROPOPHAGITE'),
#  ('Brain passage', 'ITER'),
#  ('Jewish festival', 'PURIM'),
#  ("One of Ibsen's homes", 'OSLO'),
#  ('Ore deposit', 'LODE'),
#  ('Indian coins', 'ANNAS'),
#  ('Feds', 'TMEN'),
#  ('Exam', 'TEST'),
#  ('Toast additive', 'OLEO'),
#  ('Like 2 Down', 'POLYUNSATURATED'),
#  ('Conclude', 'INFER'),
#  ('Ritter or Antoine', 'TEX'),
#  ('Transported', 'RAPT'),
#  ('Eskimo hut', 'IGLU'),
#  ('Curmudgeon', 'CRAB'),
#  ('Understanding', 'KEN'),
#  ('Performer', 'ACTOR'),
#  ('Special type of reporting', 'PHOTOJOURNALISM'),
#  ('Koran chapter', 'SURA'),
#  ('Tortoise genus', 'EMYS'),
#  ('Work on copy', 'EDIT'),
#  ('Landed', 'ALIT'),
#  ('Sea cow', 'MANATEE'),
#  ('Decorum', 'MODESTY'),
#  ("Molière's forte", 'FARCE'),
#  ('Troy, to Caesar', 'ILIUM'),
#  ...]

# %%
# Split data into train and test
from sklearn.model_selection import train_test_split

clues_train, clues_test, answers_train, answers_test = train_test_split(
    clues, answers,
    test_size=0.001, shuffle=True
)

len(clues_train), len(clues_test)
# Out:
# (602694, 604)

# %%
# Vectorize Clues
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(strip_accents="unicode", stop_words="english")
X_train = vectorizer.fit_transform(np.array(clues_train))
X_train

# Feature Engineering Ideas
# - clue is a pun (ends in "?")
# - clue is a proper noun (words are capitalized)
# Out:
# <602694x69145 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1250052 stored elements in Compressed Sparse Row format>

# %%
# Build a Nearest Neighbors Model
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors().fit(X_train)
model
# Out:
# NearestNeighbors()

# %%
# Define a guesser function (just for testing; real one defined in guesser.py)
def guess(clue, slot_length=None, max_guesses=5, max_guesses_raw=30):
    clue_vector = vectorizer.transform([clue])
    distances, indices = model.kneighbors(clue_vector, n_neighbors=max_guesses_raw)
    raw_guesses = [answers_train[i] for i in indices[0]]
    # print([clues_train[i] for i in indices[0]])

    def valid(g):
        o = True
        if slot_length:
            o &= len(g) == slot_length
        o &= g.lower() not in clue.lower()
        return o
    
    guesses = [(g, d) for g, d in zip(raw_guesses, distances[0]) if valid(g)]
    return guesses[:max_guesses]

    # TODO:
    # - include a confidence with each guess
    # - use repeated guesses and distances to determine confidence

# %%
# i = random.randint(0, len(clues_test))
# test_clue, test_answer = clues_test[i], answers_test[i]
# print("clue:", test_clue)
# print("answer:", test_answer)

# # distances, indices = model.kneighbors(vectorizer.transform([test_clue]), n_neighbors=10)
# # print("guesses:", [answers_train[i] for i in indices[0]])

# guesses = guess(test_clue, slot_length=len(test_answer))
# print("guesses:", guesses)

for i in range(0, len(clues_test)):
    print("----------------------------------------------")
    test_clue, test_answer = clues_test[i], answers_test[i]
    print("clue:", test_clue)
    print("answer:", test_answer)

    guesses = guess(test_clue, slot_length=len(test_answer))
    print("guesses:", guesses)
# Out:
# ----------------------------------------------
# clue: Chow down
# answer: EAT
# guesses: [('EAT', 0.0), ('EAT', 0.0), ('EAT', 0.0), ('EAT', 0.0)]
# ----------------------------------------------
# clue: Squabbling
# answer: ATODDS
# guesses: [('BENICE', 0.6572432574979622), ('INTOTO', 1.0), ('PATENT', 1.0)]
# ----------------------------------------------
# clue: Wild way to go
# answer: APE
# guesses: [('MAD', 0.6455905747691044)]
# ----------------------------------------------
# clue: One Fodor's guide
# answer: EUROPE
# guesses: [('MENTOR', 0.9178033945624456), ('SHERPA', 0.9178033945624456), ('ADVISE', 0.9178033945624456), ('MENTOR', 0.9178033945624456), ('KIMONO', 1.0)]
# ----------------------------------------------
# clue: Takes it easy
# answer: LOLLS
# guesses: [('LOLLS', 0.0), ('IDLES', 0.0), ('RESTS', 0.0), ('LOLLS', 0.0), ('IDLES', 0.5661845079580057)]
# ----------------------------------------------
# clue: Caught some Z's
# answer: TOOKANAP
# guesses: [('ENTANGLE', 0.0), ('ENSNARED', 0.0), ('OVERTOOK', 0.0), ('INTHEACT', 0.0), ('ENSNARED', 0.0)]
# ----------------------------------------------
# clue: ___ bean
# answer: MUNG
# guesses: [('MUNG', 0.0), ('CURD', 0.0), ('CURD', 0.0), ('MUNG', 0.0), ('SOYA', 0.0)]
# ----------------------------------------------
# clue: Commotion
# answer: TODO
# guesses: [('STIR', 0.0), ('STIR', 0.0), ('TODO', 0.0), ('TODO', 0.0), ('TODO', 0.0)]
# ----------------------------------------------
# clue: Each
# answer: APOP
# guesses: [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]
# ----------------------------------------------
# clue: Is unwell
# answer: AILS
# guesses: [('AILS', 0.0), ('AILS', 0.0), ('AILS', 0.0), ('ABED', 0.0), ('AILS', 0.0)]
# ----------------------------------------------
# clue: Sack
# answer: LOOT
# guesses: [('LOOT', 0.0), ('LOOT', 0.0), ('ABED', 0.0), ('ABED', 0.0), ('LOOT', 0.0)]
# ----------------------------------------------
# clue: Airport woes, as due to bad weather
# answer: DELAYS
# guesses: [('DELAYS', 0.6970211181570761), ('GRIEFS', 0.9103099980664744), ('SQUALL', 0.9895202384579534), ('ETALII', 0.9999999999999999), ('QUEENS', 0.9999999999999999)]
# ----------------------------------------------
# clue: Gaze dreamily
# answer: MOON
# guesses: [('MOON', 0.0), ('MOON', 0.0), ('PEER', 0.8281459341378639), ('MUSE', 0.9316012626317816), ('SLIM', 1.0)]
# ----------------------------------------------
# clue: Derived from apples
# answer: MALIC
# guesses: [('ROMES', 0.7851459859556044), ('MALIC', 0.7851459859556044), ('IMACS', 0.7851459859556044), ('IMACS', 0.7851459859556044), ('ROMES', 0.7851459859556044)]
# ----------------------------------------------
# clue: Aquatic mammal
# answer: OTTER
# guesses: [('OTTER', 0.0), ('OTTER', 0.0), ('OTTER', 0.0), ('OTTER', 0.0), ('OTTER', 0.0)]
# ----------------------------------------------
# clue: Denver's ___ Gardens amusement park
# answer: ELITCH
# guesses: [('OMELET', 0.9508302750990995), ('ALLDAY', 0.9973828152624047)]
# ----------------------------------------------
# clue: Uses again, as Tupperware
# answer: RESEALS
# guesses: [('ALLOVER', 1.0), ('NOTONCE', 1.0)]
# ----------------------------------------------
# clue: Stigma
# answer: ODIUM
# guesses: [('BRAND', 0.0), ('STAIN', 0.0), ('BRAND', 0.0), ('STAIN', 0.0), ('BRAND', 0.0)]
# ----------------------------------------------
# clue: Causing to rust
# answer: EROSIVE
# guesses: [('OXIDATE', 0.7440860736608327), ('OXIDATE', 0.7440860736608327), ('EROSIVE', 0.9490233337254373), ('OXIDIZE', 0.9546744149310611)]
# ----------------------------------------------
# clue: New Harmony, Ind., founder
# answer: OWEN
# guesses: [('AJAR', 0.9558203004743219), ('AJAR', 0.9558203004743219), ('AJAR', 0.9558203004743219), ('JIBE', 0.9558203004743219), ('AJAR', 0.9558203004743219)]
# ----------------------------------------------
# clue: Partner of bother
# answer: FUSS
# guesses: [('PAIN', 0.6174626515746531), ('PEST', 0.6174626515746531), ('PEST', 0.6174626515746531), ('PEST', 0.6174626515746531), ('GNAW', 0.6174626515746531)]
# ----------------------------------------------
# clue: Hang around
# answer: LOITER
# guesses: [('ADHERE', 0.0), ('REMAIN', 0.0), ('ONESEC', 0.0), ('RETIRE', 0.0), ('RETAIN', 0.0)]
# ----------------------------------------------
# clue: Aptitude
# answer: KNACK
# guesses: [('FLAIR', 0.0), ('SKILL', 0.0), ('FLAIR', 0.0), ('FLAIR', 0.0), ('RENEW', 1.0)]
# ----------------------------------------------
# clue: Key periods
# answer: ERAS
# guesses: [('AGES', 0.7106018952503763), ('AFTS', 0.7106018952503763), ('AFTS', 0.7106018952503763), ('AFTS', 0.7106018952503763), ('ERAS', 0.7106018952503763)]
# ----------------------------------------------
# clue: Mideast mogul
# answer: AMEER
# guesses: [('NABOB', 0.6644062833913065), ('NABOB', 0.6644062833913065), ('MAYER', 0.8551867014803649), ('YASIR', 0.8640911634095398), ('EMEER', 0.8640911634095398)]
# ----------------------------------------------
# clue: Worries
# answer: CARES
# guesses: [('STEWS', 0.0), ('STEWS', 0.0), ('STEWS', 0.0), ('FRETS', 0.0), ('FRETS', 0.0)]
# ----------------------------------------------
# clue: ___ Rud, river on Afghanistan's boundary
# answer: HARI
# guesses: [('ABCS', 1.0), ('ATOP', 1.0), ('POOR', 1.0), ('INST', 1.0), ('ANTI', 1.0)]
# ----------------------------------------------
# clue: Blue
# answer: DEJECTED
# guesses: [('CERULEAN', 0.0), ('EROTICAL', 0.0), ('HOSPITAL', 0.0)]
# ----------------------------------------------
# clue: "___ Three Lives": Philbrick
# answer: ILED
# guesses: [('ILED', 0.0), ('ILED', 0.0), ('ILED', 0.0), ('ILED', 0.0), ('ILED', 0.8542804508958204)]
# ----------------------------------------------
# clue: This point forward
# answer: HEREON
# guesses: [('ASSERT', 0.6551466118201497), ('REMAIL', 0.6551466118201497), ('ASSERT', 0.6551466118201497), ('SHIEST', 0.6551466118201497), ('RESEND', 0.6551466118201497)]
# ----------------------------------------------
# clue: Hitlerite
# answer: NAZI
# guesses: [('NAZI', 0.0), ('NAZI', 0.0), ('NAZI', 0.0), ('AMID', 1.0), ('LETS', 1.0)]
# ----------------------------------------------
# clue: Trip segment
# answer: LEG
# guesses: [('LEG', 0.0), ('ARC', 0.7440342737476092), ('ERR', 0.7865979218117033), ('LEG', 0.7865979218117033), ('LEG', 0.7865979218117033)]
# ----------------------------------------------
# clue: Newspaper opinion piece
# answer: OPED
# guesses: [('OPED', 0.0), ('OPED', 0.70236495706747), ('OPED', 0.70236495706747), ('OPED', 0.70236495706747), ('VIEW', 0.8274910856829651)]
# ----------------------------------------------
# clue: Prod
# answer: URGE
# guesses: [('URGE', 0.0), ('GOAD', 0.0), ('GOAD', 0.0), ('URGE', 0.0), ('URGE', 0.0)]
# ----------------------------------------------
# clue: It has a wheel on its heel
# answer: SKATE
# guesses: [('SEEDY', 0.6785886120720569), ('SEEDY', 0.6785886120720569), ('CUBAN', 0.8072478973768044), ('SPOKE', 0.8504881891078403), ('SPOKE', 0.8504881891078403)]
# ----------------------------------------------
# clue: Buttonhole, for example
# answer: SLIT
# guesses: [('SLIT', 0.6305641463458872), ('SLIT', 0.6305641463458872), ('VERB', 0.8962096661089525), ('CITE', 0.8962096661089525), ('AUTO', 0.8962096661089525)]
# ----------------------------------------------
# clue: Aristotelian element
# answer: EARTH
# guesses: [('LOGIC', 0.7474402947784039), ('CERIC', 0.9341542772710347), ('BORON', 0.9341542772710347), ('ARGON', 0.9341542772710347), ('TRUED', 1.0)]
# ----------------------------------------------
# clue: Detection device
# answer: RADAR
# guesses: [('RADAR', 0.0), ('SONAR', 0.0), ('RADAR', 0.0), ('RADAR', 0.0), ('SONAR', 0.0)]
# ----------------------------------------------
# clue: Avid
# answer: RAHRAH
# guesses: [('GUNGHO', 0.0), ('ATHOME', 1.0), ('DEPART', 1.0), ('MEREST', 1.0)]
# ----------------------------------------------
# clue: The veterinarian tried to
# answer: FEEDTHEKITTY
# guesses: [('ILLFIXHISWAG', 0.8797722791945541)]
# ----------------------------------------------
# clue: Place for a houseplant
# answer: SILL
# guesses: [('SILL', 0.710518681772059), ('ERST', 0.9999999999999999), ('ZEAL', 0.9999999999999999), ('SEAT', 0.9999999999999999), ('ANEW', 0.9999999999999999)]
# ----------------------------------------------
# clue: Spiral ornament
# answer: VOLUTE
# guesses: [('ENRICH', 0.7814495859075515), ('EMBOSS', 0.7814495859075515), ('HELICO', 0.8804720934614909), ('ENCOIL', 0.8919824560293634), ('GALAXY', 0.9341756223863436)]
# ----------------------------------------------
# clue: Knuckle-headed gestures of affection?
# answer: NOOGIES
# guesses: []
# ----------------------------------------------
# clue: ___ radical
# answer: ACETYL
# guesses: [('ACETYL', 0.8134509673108978)]
# ----------------------------------------------
# clue: Imagine
# answer: IDEATE
# guesses: [('IDEATE', 0.0), ('IDEATE', 0.0), ('IDEATE', 0.0), ('IDEATE', 0.0), ('ONEDAY', 1.0)]
# ----------------------------------------------
# clue: Authority
# answer: SAYSO
# guesses: [('SAYSO', 0.0), ('SAYSO', 0.0), ('SAYSO', 0.0), ('POWER', 0.0), ('SAYSO', 0.0)]
# ----------------------------------------------
# clue: Pasta request?
# answer: ALBERTDENTE
# guesses: []
# ----------------------------------------------
# clue: Cries for Joselito
# answer: OLES
# guesses: [('SOBS', 0.0), ('ASKS', 0.0), ('SOBS', 0.6191765248893295), ('RAHS', 0.6506929818206321), ('LETS', 0.6931052693178261)]
# ----------------------------------------------
# clue: Marvin Gaye's record label
# answer: TAMLA
# guesses: [('TAMLA', 1.0536712127723509e-08), ('IGETA', 0.8561869290870865)]
# ----------------------------------------------
# clue: Branch of physics: Abbr.
# answer: DYN
# guesses: [('SCI', 0.6894909238182638), ('ARM', 0.8399731971734081), ('ARM', 0.8399731971734081), ('ARM', 0.8399731971734081), ('ARM', 0.8399731971734081)]
# ----------------------------------------------
# clue: Cambridge tech. center
# answer: MIT
# guesses: [('CAL', 0.9362945846120245), ('CAL', 0.9362945846120245), ('CAL', 0.9362945846120245), ('ITT', 0.9362945846120245), ('SCH', 0.974777649073502)]
# ----------------------------------------------
# clue: Itinerant
# answer: TRAVELER
# guesses: [('STROLLER', 0.508724684904937)]
# ----------------------------------------------
# clue: G. B. Shaw play: 1903
# answer: MANANDSUPERMAN
# guesses: [('THEPHILANDERER', 0.9821416921572197)]
# ----------------------------------------------
# clue: Stout
# answer: FAT
# guesses: [('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0)]
# ----------------------------------------------
# clue: Killer whale
# answer: ORCA
# guesses: [('ORCA', 0.0), ('ORCA', 0.0), ('ORCA', 0.0), ('ORCA', 0.0), ('ORCA', 0.0)]
# ----------------------------------------------
# clue: Place for a gauge, informally
# answer: DASH
# guesses: [('STAT', 0.7496225508873834), ('TACH', 0.9482203909461215), ('TACH', 0.9580095096595966), ('DEMO', 0.9893367506881571), ('REAL', 0.9893367506881571)]
# ----------------------------------------------
# clue: Bag, in dialect
# answer: POKE
# guesses: [('NARY', 0.7099893693916408), ('SACK', 0.8200651580712142), ('SACK', 0.8200651580712142), ('GRIP', 0.8200651580712142)]
# ----------------------------------------------
# clue: "Peter Rabbit," for one
# answer: TALE
# guesses: [('CONY', 0.7217215470776873), ('BRER', 0.7918790502864177), ('BRER', 0.7918790502864177), ('BRER', 0.7918790502864177), ('BRER', 0.7918790502864177)]
# ----------------------------------------------
# clue: Llama's habitat
# answer: ANDES
# guesses: [('ANDES', 0.0), ('ANDES', 0.0), ('ANDES', 0.0), ('ANDES', 0.0), ('ANDES', 0.0)]
# ----------------------------------------------
# clue: Role for Quinn: 1964
# answer: ZORBA
# guesses: [('ZORBA', 0.5319700041017668), ('ZORBA', 0.590774751842648), ('ZORBA', 0.8750434855830934), ('ZORBA', 0.8750434855830934), ('AIDAN', 0.8851754540011991)]
# ----------------------------------------------
# clue: Nutcracker's suite
# answer: NEST
# guesses: [('NEST', 0.0), ('NEST', 0.0), ('NEST', 0.0), ('NEST', 0.0), ('NEST', 0.0)]
# ----------------------------------------------
# clue: One of the Brontes
# answer: EMILY
# guesses: [('VOWEL', 1.0), ('AREAR', 1.0), ('ABIDE', 1.0), ('HENCE', 1.0), ('REDID', 1.0)]
# ----------------------------------------------
# clue: Intertwines anew
# answer: REFOLDS
# guesses: [('FRESHLY', 0.9108501096579639), ('ALLOVER', 1.0), ('AFFRONT', 1.0)]
# ----------------------------------------------
# clue: Accepted the bait
# answer: BIT
# guesses: [('OKD', 0.7208458552641743), ('EAT', 0.8094478581794394), ('DOS', 0.9604162727398808)]
# ----------------------------------------------
# clue: What stogies do
# answer: REEK
# guesses: [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]
# ----------------------------------------------
# clue: Local life
# answer: BIOTA
# guesses: [('UNION', 0.8359227169713387), ('BIOTA', 0.8462478181159421), ('ATTEN', 0.8771818136885763), ('FAUNA', 0.8810561768205459), ('EXIST', 0.8810561768205459)]
# ----------------------------------------------
# clue: Quiet color
# answer: ASH
# guesses: [('SSH', 0.683982547223847), ('SHH', 0.683982547223847), ('SHH', 0.683982547223847), ('SHH', 0.683982547223847), ('SHH', 0.683982547223847)]
# ----------------------------------------------
# clue: Expanse also called the Euxine
# answer: BLACK
# guesses: [('OCEAN', 0.6705265451301583), ('OCEAN', 0.6705265451301583), ('OCEAN', 0.6705265451301583), ('PAGED', 0.8582313517240676), ('NAMED', 0.8582313517240676)]
# ----------------------------------------------
# clue: Superman's birth name
# answer: KALEL
# guesses: [('NATAL', 0.7829407828931064), ('NATAL', 0.7829407828931064), ('NATAL', 0.7829407828931064), ('NATAL', 0.7829407828931064), ('NATAL', 0.7829407828931064)]
# ----------------------------------------------
# clue: Leaves at 4:00?
# answer: TEA
# guesses: [('HRS', 0.6922611171585303), ('ERA', 0.8456234477594607), ('TEA', 0.8661164805991968), ('TEA', 0.8974379034685255)]
# ----------------------------------------------
# clue: Arcade game maker
# answer: ATARI
# guesses: [('ATARI', 0.7653849015404582), ('ATARI', 0.7653849015404582), ('ATARI', 0.7653849015404582), ('ATARI', 0.7793206705164393), ('PENNY', 0.8154060117647527)]
# ----------------------------------------------
# clue: Wood trimmer
# answer: ADZ
# guesses: [('ITS', 1.0), ('FEW', 1.0), ('ALL', 1.0), ('JAB', 1.0)]
# ----------------------------------------------
# clue: Get ready
# answer: GEARUP
# guesses: [('ALLSET', 0.0), ('ONCALL', 0.0), ('ALLSET', 0.0), ('ALLSET', 0.0), ('COCKED', 0.0)]
# ----------------------------------------------
# clue: Took the long way round
# answer: SKIRTED
# guesses: [('ORBITED', 0.8688651205106175), ('SPHERIC', 0.930766737380623)]
# ----------------------------------------------
# clue: Army chow
# answer: MESS
# guesses: [('MESS', 0.0), ('MESS', 0.0), ('MESS', 0.0), ('MESS', 0.0), ('MESS', 0.6993819881836466)]
# ----------------------------------------------
# clue: W African country
# answer: GHANA
# guesses: [('ZAIRE', 0.7752528251491183), ('RURAL', 0.7752528251491183), ('NOLAN', 0.7752528251491183), ('RURAL', 0.7752528251491183), ('RURAL', 0.7752528251491183)]
# ----------------------------------------------
# clue: Fleeces
# answer: SOAKS
# guesses: [('UTTER', 1.0), ('HELLO', 1.0), ('UNCLE', 1.0), ('IPASS', 1.0), ('ALIBI', 1.0)]
# ----------------------------------------------
# clue: Questions about a flight, say
# answer: DEBRIEFS
# guesses: []
# ----------------------------------------------
# clue: Some French Impressionist paintings
# answer: MONETS
# guesses: [('RENOIR', 0.6658620782037654), ('CAVERN', 0.9752098170207727), ('MANETS', 0.9860477662602904)]
# ----------------------------------------------
# clue: Sea bird
# answer: ERN
# guesses: [('ERN', 0.0), ('ERN', 0.0), ('ERN', 0.0), ('ERN', 0.0), ('ERN', 0.0)]
# ----------------------------------------------
# clue: Twosome in the gossip columns
# answer: ITEM
# guesses: [('PAIR', 0.9116489949010419), ('ITEM', 0.9116489949010419), ('ITEM', 0.9116489949010419), ('PAIR', 0.9116489949010419), ('DUET', 0.9116489949010419)]
# ----------------------------------------------
# clue: Make potable, in a way
# answer: DESALT
# guesses: [('ELIXIR', 0.9473455051997598)]
# ----------------------------------------------
# clue: Where MacArthur shops?
# answer: GENERALSTORE
# guesses: []
# ----------------------------------------------
# clue: "___ magnifique!"
# answer: TRES
# guesses: [('TRES', 0.0), ('CEST', 0.7753875350377106), ('PRES', 1.0), ('ANON', 1.0), ('OWNS', 1.0)]
# ----------------------------------------------
# clue: See 40-Down
# answer: BROTHERS
# guesses: [('EXAMINES', 0.0)]
# ----------------------------------------------
# clue: Exalt
# answer: LIONIZE
# guesses: [('ELEVATE', 0.0), ('ELEVATE', 0.0), ('ISSUERS', 1.0), ('TESTATE', 1.0)]
# ----------------------------------------------
# clue: Looney Tunes horse-drawn conveyance?
# answer: CARTONCARTOON
# guesses: []
# ----------------------------------------------
# clue: Undiluted
# answer: PURE
# guesses: [('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0)]
# ----------------------------------------------
# clue: "All ___ Do" (Sheryl Crow hit)
# answer: IWANNA
# guesses: [('SIOUAN', 0.9546560976941603)]
# ----------------------------------------------
# clue: Dog-___
# answer: EARED
# guesses: [('EARED', 0.0), ('EARED', 0.0), ('CONEY', 0.0), ('EARED', 0.0), ('EARED', 0.0)]
# ----------------------------------------------
# clue: Some newspapers
# answer: GAZETTES
# guesses: [('PIONEERS', 1.0)]
# ----------------------------------------------
# clue: Inane
# answer: FOOLISH
# guesses: [('ASININE', 0.0), ('PUERILE', 0.0)]
# ----------------------------------------------
# clue: Falls (over)
# answer: KEELS
# guesses: [('WANES', 0.0), ('KEELS', 0.0), ('KEELS', 0.0), ('BITES', 0.0), ('DROPS', 0.0)]
# ----------------------------------------------
# clue: Gait
# answer: TROT
# guesses: [('STEP', 0.0), ('PACE', 0.0), ('PACE', 0.0), ('PACE', 0.0), ('TROT', 0.0)]
# ----------------------------------------------
# clue: Red or Dead
# answer: SEA
# guesses: [('SEA', 0.0), ('SEA', 0.0), ('SEA', 0.0), ('SEA', 0.0), ('SEA', 0.0)]
# ----------------------------------------------
# clue: Rockette launchers?
# answer: LEGS
# guesses: [('AMID', 1.0), ('MOST', 1.0), ('EXIT', 1.0), ('EVEN', 1.0), ('SOLO', 1.0)]
# ----------------------------------------------
# clue: "Murder, She Wrote" locale
# answer: MAINE
# guesses: [('BERNE', 0.9707830876766789), ('NOTED', 0.9707830876766789), ('OATES', 0.9707830876766789), ('SLAIN', 1.0), ('UNDER', 1.0)]
# ----------------------------------------------
# clue: Flock females
# answer: EWES
# guesses: [('EWES', 0.0), ('EWES', 0.0), ('SHES', 0.6991019318831451), ('SHES', 0.6991019318831451), ('SHES', 0.6991019318831451)]
# ----------------------------------------------
# clue: Do wrong
# answer: ERR
# guesses: [('ERR', 0.0), ('ERR', 0.0), ('SIN', 0.0), ('ERR', 0.0), ('ERR', 0.0)]
# ----------------------------------------------
# clue: Bible town of France
# answer: DOUAI
# guesses: [('NESLE', 0.6807781235148839), ('SHALT', 0.8483805247361912)]
# ----------------------------------------------
# clue: Reminders
# answer: HINTS
# guesses: [('MEMOS', 0.47109600485162817), ('MEMOS', 0.6254001241091712), ('ACHES', 0.6900991183755644), ('ACHES', 0.6900991183755644), ('WELTS', 0.7827487667788169)]
# ----------------------------------------------
# clue: Make like
# answer: APE
# guesses: [('APE', 0.0), ('APE', 0.0), ('APE', 0.0), ('APE', 0.0), ('EKE', 0.6535335741892793)]
# ----------------------------------------------
# clue: Pt. of T.G.I.F.
# answer: FRI
# guesses: [('FRI', 0.0), ('ARR', 0.0), ('ARR', 0.0), ('EMP', 0.0), ('ARR', 0.0)]
# ----------------------------------------------
# clue: To live, to Livy
# answer: ESSE
# guesses: [('ESSE', 0.0), ('ESSE', 0.0), ('ESSE', 0.0), ('ESSE', 0.0), ('ESSE', 0.0)]
# ----------------------------------------------
# clue: Bookie's quote
# answer: ODDS
# guesses: [('ODDS', 0.0), ('ODDS', 0.0), ('ODDS', 0.0), ('ODDS', 0.0), ('ODDS', 0.8350993121012416)]
# ----------------------------------------------
# clue: Omanis, e.g.
# answer: ARABS
# guesses: [('VOWEL', 1.0), ('AREAR', 1.0), ('ABIDE', 1.0), ('HENCE', 1.0), ('REDID', 1.0)]
# ----------------------------------------------
# clue: Opposite of ppp, on scores
# answer: FFF
# guesses: [('TDS', 0.6430442544050408), ('TDS', 0.6430442544050408), ('TDS', 0.6430442544050408), ('TDS', 0.6430442544050408), ('PIU', 0.6430442544050408)]
# ----------------------------------------------
# clue: Ike's opponent, twice
# answer: ADLAI
# guesses: [('ADLAI', 0.5959316144430709), ('ADLAI', 0.5959316144430709), ('ADLAI', 0.5959316144430709), ('RIVAL', 0.9242721302845746), ('ILIKE', 0.9455507784773923)]
# ----------------------------------------------
# clue: "If I Needed ___" (Harrison-penned Beatles song)
# answer: SOMEONE
# guesses: [('FOUNDER', 1.0)]
# ----------------------------------------------
# clue: Be human
# answer: ERR
# guesses: [('ERR', 0.0), ('ERR', 0.0), ('ERR', 0.0), ('ERR', 0.0), ('ERR', 0.0)]
# ----------------------------------------------
# clue: Calembour
# answer: PUN
# guesses: [('PUN', 0.0), ('HOG', 1.0), ('GMS', 1.0), ('BRA', 1.0), ('SKY', 1.0)]
# ----------------------------------------------
# clue: Olfactory organ
# answer: NOSE
# guesses: [('NOSE', 0.0), ('NOSE', 0.0), ('STOP', 0.8502263219299332), ('ODOR', 0.9442023425195927), ('ODOR', 0.9442023425195927)]
# ----------------------------------------------
# clue: All-Star Game, e.g.
# answer: INTERLEAGUEPLAY
# guesses: [('CHINESECHECKERS', 0.6839585620943806)]
# ----------------------------------------------
# clue: Witless
# answer: INANE
# guesses: [('INANE', 0.0), ('INANE', 0.0), ('RISEN', 1.0), ('NOHOW', 1.0), ('ENEMY', 1.0)]
# ----------------------------------------------
# clue: Valued highly
# answer: TREASURED
# guesses: [('APPRAISED', 0.6671728721773095)]
# ----------------------------------------------
# clue: Govt. agent
# answer: TMAN
# guesses: [('TMAN', 0.0), ('TMAN', 0.0), ('TMAN', 0.0), ('TMAN', 0.0), ('TMAN', 0.0)]
# ----------------------------------------------
# clue: Items wrapped in friction tape
# answer: WIRES
# guesses: [('ENDED', 0.9833927707582086), ('ENDED', 0.9833927707582086), ('ENDED', 0.9833927707582086), ('SEWED', 0.9833927707582086), ('ENDED', 0.9833927707582086)]
# ----------------------------------------------
# clue: "Amos Moses" singer
# answer: REED
# guesses: [('TORI', 0.6472163759195675), ('TORI', 0.8225062535125732), ('ANDY', 0.8551458865022501), ('TORI', 0.8651084866829963), ('JOEL', 0.9401389795183694)]
# ----------------------------------------------
# clue: Eastwood's "Rawhide" role
# answer: YATES
# guesses: [('YATES', 0.0), ('CLINT', 0.8780212910383822), ('CLINT', 0.8780212910383822), ('CLINT', 0.9743952339490457), ('CLINT', 0.9743952339490457)]
# ----------------------------------------------
# clue: Choose (to)
# answer: OPT
# guesses: [('OPT', 0.0), ('OPT', 0.0), ('OPT', 0.0), ('OPT', 0.0), ('OPT', 0.0)]
# ----------------------------------------------
# clue: Gull's cousin
# answer: TERN
# guesses: [('TERN', 0.0), ('ERNE', 0.0), ('TERN', 0.0), ('DUPE', 0.621895517447178), ('DUPE', 0.621895517447178)]
# ----------------------------------------------
# clue: Seaweed
# answer: ALGA
# guesses: [('KELP', 0.0), ('KELP', 0.0), ('ALGA', 0.0), ('ALGA', 0.0), ('KELP', 0.0)]
# ----------------------------------------------
# clue: Reagan attorney general
# answer: MEESE
# guesses: [('MEESE', 0.0), ('MEESE', 0.0), ('MEESE', 0.0), ('MEESE', 0.0), ('MEESE', 0.0)]
# ----------------------------------------------
# clue: Spoke loudly
# answer: ROARED
# guesses: [('OINKED', 0.9762314516389976), ('RASPED', 0.9799235700764274), ('ORATED', 0.9924429432641514), ('RASPED', 0.9959040582844169), ('SASSED', 0.9968496912214188)]
# ----------------------------------------------
# clue: London landmark
# answer: TOWER
# guesses: [('TOWER', 0.0), ('OPERA', 0.9026670658136159), ('OHARE', 0.9080257645691806), ('CAIRN', 0.9146696335352944), ('CAIRN', 0.9146696335352944)]
# ----------------------------------------------
# clue: Cato's 151
# answer: CLI
# guesses: [('CLI', 0.0), ('CLI', 0.0), ('CLI', 0.8129509289504693), ('CLI', 0.8319185002110846), ('CLI', 0.8697076626781506)]
# ----------------------------------------------
# clue: Parts of goblets
# answer: STEMS
# guesses: [('WOMAN', 0.9999999999999999), ('RARER', 0.9999999999999999), ('AMPLE', 0.9999999999999999), ('ACCTS', 0.9999999999999999), ('NEGRO', 0.9999999999999999)]
# ----------------------------------------------
# clue: Came down
# answer: ALIT
# guesses: [('SAID', 0.0), ('ALIT', 0.0), ('ALIT', 0.0), ('ALIT', 0.0), ('ALIT', 0.0)]
# ----------------------------------------------
# clue: Round of golf tournaments
# answer: ROTA
# guesses: [('NINE', 0.8766220190969779), ('SPAR', 0.974342690548621), ('EDDY', 0.974342690548621), ('SPIN', 0.974342690548621), ('GYRE', 0.974342690548621)]
# ----------------------------------------------
# clue: Major milk maker
# answer: BORDEN
# guesses: [('LACTIC', 0.8720116700130357), ('HARVEY', 0.9635521971895227)]
# ----------------------------------------------
# clue: File
# answer: RASP
# guesses: [('RASP', 0.0), ('RASP', 0.0), ('RASP', 0.0), ('RASP', 0.0), ('SORT', 0.0)]
# ----------------------------------------------
# clue: Remain inactive
# answer: LIEBY
# guesses: [('ABIDE', 0.7872236585486047), ('ABIDE', 0.7872236585486047)]
# ----------------------------------------------
# clue: Weak and craven
# answer: UNMANLY
# guesses: [('EPICENE', 0.8291336708210514), ('RUNTISH', 0.9623650524473579)]
# ----------------------------------------------
# clue: A beast of the chase
# answer: BOAR
# guesses: [('ILKA', 0.7321554489183462), ('HUNT', 0.7321554489183462), ('ILKA', 0.7321554489183462), ('ILKA', 0.790744915935489), ('OGRE', 0.7983328249732045)]
# ----------------------------------------------
# clue: Certain vaudeville act
# answer: TAPDANCE
# guesses: [('STAGEACT', 0.9221506926178086), ('SWANSONG', 0.9500159183728227)]
# ----------------------------------------------
# clue: Capital near Casablanca
# answer: RABAT
# guesses: [('RABAT', 0.0), ('LORRE', 0.9327246656877076), ('CIRCA', 0.9575498382527232), ('CLOSE', 0.9575498382527232), ('OUTBY', 0.9575498382527232)]
# ----------------------------------------------
# clue: Lhasa apsos, e.g.
# answer: TERRIERS
# guesses: []
# ----------------------------------------------
# clue: Congressional hire
# answer: AIDE
# guesses: [('RENT', 0.7994132544823743), ('RENT', 0.7994132544823743), ('RENT', 0.7994132544823743), ('SEAT', 0.9043471594400138), ('ACTS', 0.929382615395156)]
# ----------------------------------------------
# clue: Mauna ___
# answer: LOA
# guesses: [('LOA', 0.0), ('LOA', 0.0), ('LOA', 0.0), ('LOA', 0.0), ('LOA', 0.0)]
# ----------------------------------------------
# clue: Best Picture before "12 Years a Slave"
# answer: ARGO
# guesses: [('EVER', 0.9999999999999999), ('ALVA', 0.9999999999999999), ('PRES', 0.9999999999999999), ('INTO', 0.9999999999999999), ('SOLO', 0.9999999999999999)]
# ----------------------------------------------
# clue: Outback avians
# answer: EMUS
# guesses: [('BUSH', 0.8173982196444954), ('EMUS', 0.8772586956995541), ('ANIS', 0.8868019067451731), ('MATE', 0.9882098250645924), ('EMUS', 0.9950980898345774)]
# ----------------------------------------------
# clue: Physicist who formulated the two laws of electrolysis
# answer: FARADAY
# guesses: [('PLENARY', 1.0), ('CRAFTED', 1.0)]
# ----------------------------------------------
# clue: Did some mending
# answer: DARNED
# guesses: [('USEDTO', 0.9207444646675575), ('REMADE', 0.9207444646675575)]
# ----------------------------------------------
# clue: Peen of a hammer
# answer: TOE
# guesses: [('HAD', 0.3673126684957867), ('IFI', 0.3673126684957867)]
# ----------------------------------------------
# clue: Make secure
# answer: LASH
# guesses: [('SAFE', 0.5869240106914193), ('SAFE', 0.5869240106914193), ('SAFE', 0.5869240106914193), ('MOOR', 0.5869240106914193), ('GETS', 0.5869240106914193)]
# ----------------------------------------------
# clue: "Delphine" author: 1803
# answer: DESTAEL
# guesses: [('SOTHERE', 0.9999999999999999), ('APPOSED', 0.9999999999999999)]
# ----------------------------------------------
# clue: Dionne Warwick's "Walk___"
# answer: ONBY
# guesses: [('HADA', 0.48799345608134337), ('LENS', 1.0), ('EXIT', 1.0), ('SITE', 1.0), ('REAR', 1.0)]
# ----------------------------------------------
# clue: Opening bridge bid, informally
# answer: AHEART
# guesses: []
# ----------------------------------------------
# clue: Actress Braga
# answer: SONIA
# guesses: [('SONIA', 0.0), ('SONIA', 0.0), ('SONIA', 0.0), ('SONIA', 0.0), ('SONIA', 0.0)]
# ----------------------------------------------
# clue: Murmur
# answer: BREATHE
# guesses: []
# ----------------------------------------------
# clue: Mil. verdict
# answer: AWOL
# guesses: [('ACAD', 0.8940763101223492), ('TIED', 1.0), ('TIED', 1.0), ('ANEW', 1.0), ('NONE', 1.0)]
# ----------------------------------------------
# clue: "Conan" network
# answer: TBS
# guesses: [('TBS', 0.6361962312609819), ('TBS', 0.6361962312609819), ('ABC', 0.8932029075631212), ('WEB', 0.8932029075631212), ('MTV', 0.8932029075631212)]
# ----------------------------------------------
# clue: Mideast ruler
# answer: EMIR
# guesses: [('SHAH', 0.0), ('AMIR', 0.0), ('SAUD', 0.0), ('AMIR', 0.5820706167282049), ('TSAR', 0.7599392731583469)]
# ----------------------------------------------
# clue: Tours
# answer: MOTORS
# guesses: []
# ----------------------------------------------
# clue: "___ kingdom come ?"
# answer: THY
# guesses: [('THY', 0.0)]
# ----------------------------------------------
# clue: New York and New Orleans
# answer: PORTS
# guesses: [('STRIP', 0.6919898565046844), ('RERUN', 0.7330974002018574), ('NOVEL', 0.7330974002018574)]
# ----------------------------------------------
# clue: Wooden strip
# answer: SLAT
# guesses: [('SLAT', 0.0), ('LATH', 0.0), ('PEEL', 0.8280352454821873), ('PEEL', 0.8280352454821873), ('PEEL', 0.8280352454821873)]
# ----------------------------------------------
# clue: Angler's basket
# answer: CREEL
# guesses: [('CREEL', 0.0), ('CREEL', 0.0), ('CREEL', 0.0), ('CREEL', 0.0), ('CREEL', 0.0)]
# ----------------------------------------------
# clue: Beat
# answer: CADENCE
# guesses: [('PULSATE', 0.0), ('NEMESES', 0.0), ('CADENCE', 0.0), ('CBSNEWS', 0.0)]
# ----------------------------------------------
# clue: Does hip-hop
# answer: RAPS
# guesses: [('RAPS', 0.7838089187314067), ('NATE', 0.8684168686105311), ('RAPS', 0.872223330025405)]
# ----------------------------------------------
# clue: European air hub
# answer: DEGAULLE
# guesses: []
# ----------------------------------------------
# clue: What might determine if the moon hitting your eye like a big pizza pie is truly amore?
# answer: CROONERSINQUEST
# guesses: []
# ----------------------------------------------
# clue: Of bees
# answer: APIAN
# guesses: [('APIAN', 0.0), ('APIAN', 0.0), ('SWARM', 0.0), ('APIAN', 0.0), ('APIAN', 0.0)]
# ----------------------------------------------
# clue: Grote of baseball
# answer: JERRY
# guesses: [('ENDED', 1.0), ('AGAIN', 1.0), ('AWAKE', 1.0), ('UNCLE', 1.0)]
# ----------------------------------------------
# clue: 1973 Rolling Stones ballad
# answer: ANGIE
# guesses: [('ANGIE', 1.4901161193847656e-08), ('ANGIE', 0.6442254567064921), ('ANGIE', 0.6442254567064921), ('ANGIE', 0.6442254567064921), ('ANGIE', 0.6442254567064921)]
# ----------------------------------------------
# clue: Baldwin's "The Fire ___ Time"
# answer: NEXT
# guesses: [('ALEC', 0.6013636041073975), ('ALEC', 0.6013636041073975), ('ALEC', 0.6013636041073975), ('ALEC', 0.6013636041073975), ('ALEC', 0.6013636041073975)]
# ----------------------------------------------
# clue: Encouraged by others, in a way
# answer: ONADARE
# guesses: [('EGGEDON', 0.4728794849688795), ('ABETTED', 0.4728794849688795), ('INPAIRS', 1.0), ('ENROUTE', 1.0)]
# ----------------------------------------------
# clue: Elaborate molding
# answer: GADROON
# guesses: [('EXPOUND', 0.7034345449473827), ('ORATION', 0.9114260621102954), ('PAGEANT', 0.9776689330663932)]
# ----------------------------------------------
# clue: Org. with good aims?
# answer: NRA
# guesses: [('TDS', 0.8906103867573604), ('ERE', 1.0), ('EST', 1.0), ('CDE', 1.0), ('ISL', 1.0)]
# ----------------------------------------------
# clue: Cash register part
# answer: DRAWER
# guesses: [('NOSALE', 0.5328495777699357), ('NOSALE', 0.5328495777699357), ('NOSALE', 0.5328495777699357), ('NOSALE', 0.5328495777699357), ('RINGUP', 0.5716308089139827)]
# ----------------------------------------------
# clue: Org. for Tyson
# answer: WBA
# guesses: [('KOS', 0.9257585942705184), ('NOW', 0.9999999999999999), ('OWE', 0.9999999999999999), ('CAN', 0.9999999999999999), ('ACE', 0.9999999999999999)]
# ----------------------------------------------
# clue: Longtime Times Sq. site
# answer: TKTS
# guesses: [('BWAY', 0.8226588885852418), ('NYPD', 0.8888768638489026), ('ELSE', 0.9999999999999999), ('AWRY', 0.9999999999999999), ('YVES', 0.9999999999999999)]
# ----------------------------------------------
# clue: Have good intentions
# answer: MEANWELL
# guesses: []
# ----------------------------------------------
# clue: Natural scrubber
# answer: LOOFA
# guesses: [('LOOFA', 0.8786376003465133), ('ALIEN', 0.9394225136355844)]
# ----------------------------------------------
# clue: Chowder server
# answer: LADLE
# guesses: [('TONGS', 0.9943508677070407), ('TOWIT', 1.0), ('HASTO', 1.0), ('PETIT', 1.0)]
# ----------------------------------------------
# clue: Snead's needs
# answer: TEES
# guesses: [('SAMS', 0.9168785522307762), ('SAMS', 0.9168785522307762), ('TEED', 0.934117891371172), ('NORM', 0.9596301601836988), ('ANEW', 1.0)]
# ----------------------------------------------
# clue: Tête-à-tête
# answer: CHAT
# guesses: [('CHAT', 0.0), ('CHAT', 0.0), ('ASSN', 1.0), ('DELE', 1.0), ('VEEP', 1.0)]
# ----------------------------------------------
# clue: Up-tight
# answer: TENSE
# guesses: [('OILED', 0.0), ('LOOSE', 0.0), ('PINCH', 0.0), ('TENSE', 0.0), ('TENSE', 0.0)]
# ----------------------------------------------
# clue: Drill sergeant's command
# answer: ABOUTFACE
# guesses: [('LEFTRIGHT', 0.6596410333606134)]
# ----------------------------------------------
# clue: ___ Man
# answer: ISLEOF
# guesses: []
# ----------------------------------------------
# clue: Geometric figure
# answer: HEXAGON
# guesses: [('ELLIPSE', 0.0), ('RHOMBUS', 0.0)]
# ----------------------------------------------
# clue: Jiffy
# answer: SEC
# guesses: [('SEC', 0.0), ('SEC', 0.0), ('SEC', 0.0), ('SEC', 0.0), ('SEC', 0.0)]
# ----------------------------------------------
# clue: And never
# answer: NOR
# guesses: [('RHO', 0.0), ('TIN', 0.0), ('NOW', 0.0), ('AVG', 0.0), ('ATE', 0.0)]
# ----------------------------------------------
# clue: Tenant
# answer: LESSEE
# guesses: [('LESSEE', 0.0), ('RENTED', 0.0), ('LESSEE', 0.0), ('RENTER', 0.0), ('LESSEE', 0.0)]
# ----------------------------------------------
# clue: Georgia ___
# answer: TECH
# guesses: [('TECH', 0.0), ('TECH', 0.0), ('TECH', 0.0), ('PINE', 0.0), ('ASIA', 0.3644448246956733)]
# ----------------------------------------------
# clue: Longed for
# answer: CRAVED
# guesses: [('YENNED', 0.0), ('ENCORE', 1.0), ('IDOTOO', 1.0), ('CONTRA', 1.0), ('BESTIR', 1.0)]
# ----------------------------------------------
# clue: Rams' mates
# answer: EWES
# guesses: [('EWES', 0.0), ('EWES', 0.0), ('EWES', 0.0), ('EWES', 0.0), ('EWES', 0.0)]
# ----------------------------------------------
# clue: Sales force
# answer: REPS
# guesses: [('REPS', 0.0), ('REPS', 0.0), ('REPS', 0.4517986126395235), ('REPS', 0.5253890522832735), ('REPS', 0.5253890522832735)]
# ----------------------------------------------
# clue: Onetime Spanish queen and namesakes
# answer: ENAS
# guesses: [('ENAS', 0.5522345759294227), ('ENAS', 0.5522345759294227), ('MABS', 0.9232731966275346), ('IKES', 0.9511731851881517), ('ATOP', 1.0)]
# ----------------------------------------------
# clue: Of wrath: Lat.
# answer: IRAE
# guesses: [('IRAE', 0.0), ('IRAE', 0.0), ('IRAE', 0.0), ('IRAE', 0.0)]
# ----------------------------------------------
# clue: Anderson of Jethro Tull
# answer: IAN
# guesses: [('TAG', 1.0), ('AHA', 1.0)]
# ----------------------------------------------
# clue: Prefix with center
# answer: EPI
# guesses: [('EPI', 0.0), ('EPI', 0.0), ('EPI', 0.0), ('EPI', 0.0), ('EPI', 0.0)]
# ----------------------------------------------
# clue: Xylophone cousin
# answer: MARIMBA
# guesses: [('MARIMBA', 0.0), ('MARIMBA', 0.7722702846714338)]
# ----------------------------------------------
# clue: Composer of "Daphnis et Chloé"
# answer: RAVEL
# guesses: [('RAVEL', 1.4901161193847656e-08), ('CHLOE', 0.9565998425087398), ('CHLOE', 0.9710816156982356), ('CHLOE', 0.9710816156982356), ('AHEAD', 0.9999999999999999)]
# ----------------------------------------------
# clue: O. Henry
# answer: PORTER
# guesses: [('ORATOR', 0.0), ('PORTER', 0.0), ('MORGAN', 0.0), ('TELLER', 0.7308181086252167), ('TELLER', 0.7308181086252167)]
# ----------------------------------------------
# clue: Devil-god
# answer: IDOL
# guesses: [('IDOL', 0.0), ('SLED', 0.663105051454518), ('LIMB', 0.7358011427013649), ('DARE', 0.8169552786922294), ('DARE', 0.8169552786922294)]
# ----------------------------------------------
# clue: Stuntman Knievel
# answer: EVEL
# guesses: [('CHAN', 0.9577661337526475), ('THUS', 0.9999999999999999), ('ANEW', 0.9999999999999999), ('ANTE', 0.9999999999999999), ('ELSE', 0.9999999999999999)]
# ----------------------------------------------
# clue: Italian archaeological locale
# answer: POMPEII
# guesses: [('UNEARTH', 0.8482519362684124), ('AGREETO', 1.0)]
# ----------------------------------------------
# clue: Carries
# answer: TOTES
# guesses: [('RANTS', 0.0), ('PLIES', 0.0), ('RAVES', 0.0), ('TOTES', 0.0), ('TOTES', 0.0)]
# ----------------------------------------------
# clue: Sch. in Tulsa
# answer: ORU
# guesses: [('ORU', 0.0), ('ORU', 0.0), ('ORU', 0.0), ('ORU', 0.0), ('ORU', 0.0)]
# ----------------------------------------------
# clue: "___ Mine" (1957 hit by the Platters)
# answer: HES
# guesses: [('HES', 0.7629094803645547), ('HES', 0.7629094803645547), ('LPS', 0.8082433849878873), ('EPS', 0.8082433849878873), ('CDS', 0.8082433849878873)]
# ----------------------------------------------
# clue: Longings
# answer: YENS
# guesses: [('YENS', 0.0), ('YENS', 0.0), ('YENS', 0.0), ('YENS', 0.0), ('YENS', 0.0)]
# ----------------------------------------------
# clue: Fanciful notions
# answer: CONCEITS
# guesses: [('ROMANTIC', 0.744926897943918)]
# ----------------------------------------------
# clue: Down
# answer: EAT
# guesses: [('RHO', 0.0), ('TIN', 0.0), ('NOW', 0.0), ('AVG', 0.0), ('ATE', 0.0)]
# ----------------------------------------------
# clue: Keep in the attic, maybe
# answer: STORE
# guesses: [('DUSTY', 0.7062617016146898), ('AGORA', 0.8442776218371285), ('STOAS', 0.9371198260888944)]
# ----------------------------------------------
# clue: Tale written in runes, perhaps
# answer: SAGA
# guesses: [('ORAL', 0.70745194620763), ('ORAL', 0.70745194620763), ('TEXT', 0.70745194620763), ('ORAL', 0.70745194620763), ('ORAL', 0.70745194620763)]
# ----------------------------------------------
# clue: Rabbit's tail
# answer: SCUT
# guesses: [('SCUT', 0.0), ('SCUT', 0.0), ('SCUT', 0.0), ('SCUT', 0.0), ('SCUT', 0.0)]
# ----------------------------------------------
# clue: Bounced
# answer: EJECTED
# guesses: [('DANDLED', 0.7980126894663582)]
# ----------------------------------------------
# clue: Slipper
# answer: MULE
# guesses: [('MULE', 0.0), ('MULE', 0.0), ('MULE', 0.0), ('SOLE', 0.0), ('MULE', 0.0)]
# ----------------------------------------------
# clue: Cheekiness
# answer: CHUTZPAH
# guesses: [('PARALLEL', 1.0), ('REQUIRES', 1.0)]
# ----------------------------------------------
# clue: Feast finale
# answer: DESSERT
# guesses: [('BANQUET', 0.7666941097989516)]
# ----------------------------------------------
# clue: "Stop Whining, Start Living" author
# answer: DRLAURA
# guesses: [('BLEATER', 0.9533242294229853), ('TURNPRO', 0.9994705906866546), ('MYTREAT', 1.0), ('ELECTEE', 1.0), ('ASSAULT', 1.0)]
# ----------------------------------------------
# clue: Lead strip joining glass panes
# answer: CAME
# guesses: [('ANEW', 1.0), ('INRE', 1.0), ('AMER', 1.0), ('NAME', 1.0), ('SHOO', 1.0)]
# ----------------------------------------------
# clue: Love deeply
# answer: ADORE
# guesses: [('EMBED', 0.8156695724975457), ('ADORE', 0.8914377640905352), ('DELVE', 0.8914377640905352), ('ADORE', 0.8914377640905352), ('AMORE', 0.9319445510019285)]
# ----------------------------------------------
# clue: Member of the family, for short
# answer: SIS
# guesses: [('SIS', 0.0), ('SIS', 0.0), ('SIS', 0.534995351715844), ('SON', 0.534995351715844), ('SON', 0.534995351715844)]
# ----------------------------------------------
# clue: Faun's fellow traveler
# answer: SATYR
# guesses: [('SNERD', 0.9530497631425573), ('FARER', 0.9741136978738687), ('ROLLS', 0.9840930906491799), ('SCALE', 1.0), ('RARER', 1.0)]
# ----------------------------------------------
# clue: Place of disgrace
# answer: DOGHOUSE
# guesses: [('DOGHOUSE', 0.0), ('ARTICLES', 1.0)]
# ----------------------------------------------
# clue: Do not disturb
# answer: LETBE
# guesses: [('LETBE', 0.0), ('ROUSE', 0.0), ('LETBE', 0.0), ('DONOT', 0.3146802591884167), ('DONOT', 0.3146802591884167)]
# ----------------------------------------------
# clue: Midpoint between a midi and a mini
# answer: KNEE
# guesses: [('IPOD', 0.9718672052420604), ('IPOD', 0.9718672052420604), ('ALES', 0.981914531745802), ('SELF', 0.9999999999999999), ('BOTH', 0.9999999999999999)]
# ----------------------------------------------
# clue: Sgt. O'Rourke's command, on TV
# answer: FTROOP
# guesses: [('INTACT', 1.0)]
# ----------------------------------------------
# clue: Ever
# answer: ONCE
# guesses: [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]
# ----------------------------------------------
# clue: Less slovenly
# answer: NEATER
# guesses: [('UNTIDY', 0.0), ('INTURN', 1.0), ('DONATE', 1.0)]
# ----------------------------------------------
# clue: ___ high standard
# answer: SETA
# guesses: [('SETA', 0.0), ('NORM', 0.6988074199788902), ('NORM', 0.6988074199788902), ('NORM', 0.6988074199788902), ('NORM', 0.6988074199788902)]
# ----------------------------------------------
# clue: Most musty
# answer: STALEST
# guesses: [('NOTMANY', 1.0)]
# ----------------------------------------------
# clue: Grilling test
# answer: ORAL
# guesses: [('PSAT', 0.9026760926555041), ('EXAM', 0.9026760926555041), ('EXAM', 0.9026760926555041), ('PSAT', 0.9026760926555041)]
# ----------------------------------------------
# clue: Just
# answer: FAIR
# guesses: [('EKED', 0.0), ('ONLY', 0.0), ('MERE', 0.0), ('ONLY', 0.0), ('TOAT', 0.0)]
# ----------------------------------------------
# clue: Mentally quick
# answer: NIMBLE
# guesses: [('SANEST', 0.7998406351947962), ('ASTUTE', 0.8562075148383509), ('SPEEDY', 0.8853328808153443), ('SPEEDY', 0.8853328808153443), ('ASTUTE', 0.8853328808153443)]
# ----------------------------------------------
# clue: Spontaneous remark
# answer: ADLIB
# guesses: [('ADLIB', 0.6430570702501854), ('SNIDE', 0.9804435684602549), ('COOPT', 1.0), ('GRIST', 1.0), ('NADIR', 1.0)]
# ----------------------------------------------
# clue: Bits
# answer: TADS
# guesses: [('TADS', 0.0), ('TADS', 0.0), ('TADS', 0.0), ('PEAS', 0.0), ('ERGS', 0.6211551665474044)]
# ----------------------------------------------
# clue: 1957 Harry Belafonte hit
# answer: DAYO
# guesses: [('DAYO', 0.7656442216509597), ('DAYO', 0.8765494769963039), ('DAYO', 0.8765494769963039), ('DAYO', 0.8765494769963039), ('AJOB', 0.9000181134295161)]
# ----------------------------------------------
# clue: Eyed impertinently
# answer: OGLED
# guesses: [('JACKS', 0.9341542772710347), ('OGLED', 0.9341542772710347), ('MISTY', 0.9753872367194945), ('RATIO', 1.0), ('STATE', 1.0)]
# ----------------------------------------------
# clue: Makes cry, in a way
# answer: TEARGASSES
# guesses: []
# ----------------------------------------------
# clue: Crew member
# answer: OAR
# guesses: [('OAR', 0.0), ('OAR', 0.0), ('COX', 0.0), ('OAR', 0.6563277038619381), ('ETS', 0.6639082229810451)]
# ----------------------------------------------
# clue: Kind of sch.
# answer: ELEM
# guesses: [('ELEM', 0.0), ('ELEM', 0.0), ('ELEM', 0.0), ('ELEM', 0.0), ('ELEM', 0.0)]
# ----------------------------------------------
# clue: Famous Florentine
# answer: DANTE
# guesses: [('DANTE', 0.8087031877535544), ('PISAN', 0.8088742033571373), ('LIPPI', 0.8259620106210726), ('FIORE', 0.8379566614780198), ('DANTE', 0.8405912282008177)]
# ----------------------------------------------
# clue: Something to take, carefully
# answer: AIM
# guesses: []
# ----------------------------------------------
# clue: Location of a British driver's seat
# answer: RIGHTSIDE
# guesses: []
# ----------------------------------------------
# clue: Curbside sights
# answer: TRASHCANS
# guesses: []
# ----------------------------------------------
# clue: Vocal one
# answer: SAYER
# guesses: [('SAYER', 0.768328878699844), ('OCTET', 0.7747315760550545), ('MOTET', 0.8087856911081812), ('TONES', 0.8206033462762414), ('PIPES', 0.843006321305917)]
# ----------------------------------------------
# clue: Free ___ (total control)
# answer: REIN
# guesses: [('RUIN', 0.895215149332471), ('RUIN', 0.895215149332471)]
# ----------------------------------------------
# clue: Pro ___
# answer: RATA
# guesses: [('RATA', 0.0), ('RATA', 0.0), ('RATA', 0.0), ('RATA', 0.0), ('RATA', 0.0)]
# ----------------------------------------------
# clue: Leave off
# answer: CEASE
# guesses: [('LETBE', 0.0), ('ELIDE', 0.0), ('CEASE', 0.0), ('CEASE', 0.0)]
# ----------------------------------------------
# clue: Keats's "___ on Indolence"
# answer: ODE
# guesses: [('DEN', 0.0), ('ODE', 0.0), ('ODE', 0.78563890516431), ('ERE', 0.923251225215355), ('ERE', 0.923251225215355)]
# ----------------------------------------------
# clue: Hectic hosp. areas
# answer: ERS
# guesses: [('ERS', 0.0), ('ERS', 0.0), ('ERS', 0.0), ('ERS', 0.717937661110391), ('ERS', 0.717937661110391)]
# ----------------------------------------------
# clue: War hero Murphy
# answer: AUDIE
# guesses: [('AUDIE', 0.0), ('AUDIE', 0.6912557492116913), ('AUDIE', 0.6912557492116913), ('AUDIE', 0.7493551527342033), ('DAYAN', 0.8892512383667297)]
# ----------------------------------------------
# clue: Arab cloaks
# answer: ABAS
# guesses: [('ABAS', 0.8482530480102439), ('ALIF', 0.8876056326839105), ('EMIR', 0.8876056326839105), ('EMIR', 0.8876056326839105), ('STAT', 1.0)]
# ----------------------------------------------
# clue: Ball attraction
# answer: BELLE
# guesses: [('ALERT', 0.8170792089512597), ('ALERT', 0.8170792089512597), ('ALERT', 0.8170792089512597), ('DANCE', 0.8170792089512597), ('SHARP', 0.8170792089512597)]
# ----------------------------------------------
# clue: Stock term
# answer: ATPAR
# guesses: [('NOPAR', 0.0), ('ATPAR', 0.6295220887553806), ('ATPAR', 0.7612312531459727), ('EARLY', 0.7612312531459727), ('CARRY', 0.7694986458039068)]
# ----------------------------------------------
# clue: River duck
# answer: TEAL
# guesses: [('TEAL', 0.0), ('SMEE', 0.0), ('TEAL', 0.0), ('TEAL', 0.0), ('TEAL', 0.0)]
# ----------------------------------------------
# clue: Moist
# answer: DEWY
# guesses: [('DAMP', 0.0), ('DAMP', 0.0), ('DEWY', 0.0), ('DEWY', 0.0), ('DEWY', 0.0)]
# ----------------------------------------------
# clue: T.L.C. givers
# answer: RNS
# guesses: [('RNS', 0.0), ('RNS', 0.0), ('RNS', 0.0), ('RNS', 0.0), ('RNS', 0.7715306948445035)]
# ----------------------------------------------
# clue: ___ Hari
# answer: MATA
# guesses: [('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0), ('MATA', 0.0)]
# ----------------------------------------------
# clue: Vocal ensemble, maybe
# answer: OCTET
# guesses: [('OCTET', 0.8479784328649069), ('COMBO', 0.9523869919032086), ('OBOES', 0.9806236994425388), ('PRIMO', 0.9860565864536313), ('GRADE', 1.0)]
# ----------------------------------------------
# clue: Facing, with "from"
# answer: ACROSS
# guesses: [('TOWARD', 0.0), ('TOWARD', 0.0), ('INAJAM', 0.7913171803126738)]
# ----------------------------------------------
# clue: "Game of Thrones" actress Chaplin
# answer: OONA
# guesses: [('OONA', 0.0), ('OONA', 0.0), ('OONA', 0.37294441716700794), ('OONA', 0.37294441716700794), ('OONA', 0.37294441716700794)]
# ----------------------------------------------
# clue: Navigation system
# answer: LORAN
# guesses: [('LORAN', 0.0), ('LORAN', 0.0), ('LORAN', 0.0), ('LORAN', 0.0), ('LORAN', 0.0)]
# ----------------------------------------------
# clue: Blessed act?
# answer: SNEEZE
# guesses: [('TERESA', 0.8531206968832329), ('LIAISE', 0.8724805017605468), ('OPENER', 0.8724805017605468), ('BEHAVE', 0.8724805017605468), ('SCENEI', 0.8724805017605468)]
# ----------------------------------------------
# clue: Road sign
# answer: SLO
# guesses: [('SLO', 0.0), ('GAS', 0.0), ('SLO', 0.0), ('SLO', 0.0), ('RTE', 0.0)]
# ----------------------------------------------
# clue: Actress Debra
# answer: PAGET
# guesses: [('PAGET', 0.7214789860099302), ('PAGET', 0.7234642118921152), ('SATES', 1.0), ('TOWIT', 1.0), ('NEEDY', 1.0)]
# ----------------------------------------------
# clue: "Hold that tiger"
# answer: COLLEGECHEER
# guesses: []
# ----------------------------------------------
# clue: Advance obliquely
# answer: SIDLE
# ...
# clue: Road curve
# answer: ESS
# guesses: [('ESS', 0.0), ('ESS', 0.0), ('ESS', 0.0), ('ESS', 0.0), ('ESS', 0.0)]
# ----------------------------------------------
# clue: Stain
# answer: BLOT
# guesses: [('BLOT', 0.0), ('BLOT', 0.0), ('SOIL', 0.0), ('BLOT', 0.0), ('SPOT', 0.0)]
# ----------------------------------------------
# clue: For good, to Gray
# answer: EER
# guesses: [('AGE', 0.6828186513953911), ('AGE', 0.6828186513953911), ('AGE', 0.6828186513953911), ('AGE', 0.6828186513953911), ('AGE', 0.6828186513953911)]
# ----------------------------------------------
# clue: Wildebeests
# answer: GNUS
# guesses: [('GNUS', 0.0), ('GNUS', 0.0), ('GNUS', 0.0), ('GNUS', 0.0), ('ALSO', 1.0)]
# ----------------------------------------------
# clue: Health teacher's topic, informally
# answer: SEXED
# guesses: [('PROST', 0.9726592873561581), ('SALUD', 0.9726592873561581), ('TOAST', 0.9726592873561581), ('SKOAL', 0.9726592873561581), ('SALUD', 0.9726592873561581)]
# ----------------------------------------------
# clue: Waste gases, e.g.
# answer: OXIDES
# guesses: [('SEWAGE', 0.8655424211655219), ('XENONS', 0.9299023576454492), ('INERTS', 0.9939320896813431)]
# ----------------------------------------------
# clue: "Doctor Zhivago" role
# answer: PASHA
# guesses: [('PASHA', 0.468252917717099), ('URALS', 0.6743726944854939), ('PASHA', 0.7782716278958727), ('LARAS', 0.8945916466425424), ('AMEND', 0.9019384247740723)]
# ----------------------------------------------
# clue: Two quarters
# answer: HALF
# guesses: [('DIGS', 0.0), ('HALF', 0.0), ('DORM', 0.6156565098255715), ('DORM', 0.6612972240586402), ('DORM', 0.6612972240586402)]
# ----------------------------------------------
# clue: Midterms, e.g.
# answer: EXAMS
# guesses: [('EXAMS', 0.7208461969866526), ('EXAMS', 0.7208461969866526), ('TESTS', 0.7208461969866526), ('EXAMS', 0.7208461969866526), ('TOWIT', 1.0)]
# ----------------------------------------------
# clue: Turns out
# answer: EVICTS
# guesses: [('ROTATE', 0.0), ('ROTATE', 0.0), ('UPSETS', 0.0), ('ARISES', 0.0), ('ROTATE', 0.0)]
# ----------------------------------------------
# clue: Candy, in Canterbury
# answer: SWEETS
# guesses: [('BONBON', 0.8451893543381478), ('SWEETS', 0.8451893543381478), ('SWEETS', 0.8451893543381478), ('REESES', 0.8451893543381478), ('SWEETS', 0.8451893543381478)]
# ----------------------------------------------
# clue: Diffuse, as light
# answer: SHED
# guesses: [('PALE', 0.963958577846285), ('BEER', 0.963958577846285), ('AIRY', 0.963958577846285), ('LAMP', 0.963958577846285), ('AIRY', 0.963958577846285)]
# ----------------------------------------------
# clue: Visit
# answer: COMEOVER
# guesses: []
# ----------------------------------------------
# clue: "___ la Douce"
# answer: IRMA
# guesses: [('IRMA', 0.0), ('IRMA', 0.0), ('IRMA', 0.0), ('IRMA', 0.0), ('IRMA', 0.0)]
# ----------------------------------------------
# clue: Farm sound
# answer: CAW
# guesses: [('MOO', 0.0), ('MOO', 0.0), ('BAA', 0.0), ('BAA', 0.6836899035829792), ('MOO', 0.6836899035829792)]
# ----------------------------------------------
# clue: Memorable anthropologist
# answer: MEAD
# guesses: [('MEAD', 0.0), ('MEAD', 0.0), ('MEAD', 0.641981542721582), ('MEAD', 0.8319022813475587), ('BOAS', 0.840314171700933)]
# ----------------------------------------------
# clue: Sow's opposite
# answer: REAP
# guesses: [('REAP', 0.0), ('SEED', 0.6206829348200712), ('SEED', 0.6206829348200712), ('SEED', 0.6206829348200712), ('ASYE', 0.6914993050048823)]
# ----------------------------------------------
# clue: Bristly
# answer: SETOSE
# guesses: [('SETOSE', 0.0), ('SETOSE', 0.0), ('SETOSE', 0.0), ('TEASEL', 0.5584615587581246), ('TEASEL', 0.5584615587581246)]
# ----------------------------------------------
# clue: Taxonomic suffix
# answer: OTA
# guesses: [('OTE', 0.0), ('OTE', 0.0), ('OTE', 0.0), ('HAS', 1.0), ('YET', 1.0)]
# ----------------------------------------------
# clue: See 45-Down
# answer: OFF
# guesses: [('AES', 0.0), ('ASP', 0.0), ('GAS', 0.0), ('SAY', 0.0), ('RPM', 0.37515343993673933)]
# ----------------------------------------------
# clue: ___ vin (chicken dish)
# answer: COQAU
# guesses: [('COQAU', 0.0), ('BLANC', 0.8817133711537221), ('BLANC', 0.9319277395977025), ('SISSY', 0.9652726050613222), ('BIDDY', 0.9652726050613222)]
# ----------------------------------------------
# clue: Secretary of Interior: 1961–69
# answer: UDALL
# guesses: [('UDALL', 0.693154641258608), ('ICKES', 0.7548593237377776), ('UDALL', 0.876197001808458), ('UDALL', 0.876197001808458), ('ICKES', 0.9151684534181993)]
# ----------------------------------------------
# clue: Novelist Harper
# answer: LEE
# guesses: [('LEE', 0.0), ('LEE', 0.0), ('LEE', 0.2772182711285716), ('LEE', 0.2772182711285716), ('LEE', 0.8240595367193254)]
# ----------------------------------------------
# clue: Touch up
# answer: EDIT
# guesses: [('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0)]
# ----------------------------------------------
# clue: Embarrassing sound, maybe
# answer: RIP
# guesses: [('ZIT', 0.8569621277192415), ('AND', 1.0), ('SEE', 1.0)]
# ----------------------------------------------
# clue: It has 33 letters
# answer: RUSSIANLANGUAGE
# guesses: []
# ----------------------------------------------
# clue: Lack of harmony
# answer: CLASH
# guesses: [('AGREE', 0.7399093977739439), ('ATONE', 0.7399093977739439), ('ATONE', 0.7399093977739439), ('AGREE', 0.7399093977739439), ('AGREE', 0.7399093977739439)]
# ----------------------------------------------
# clue: First name in motorcycle jumping
# answer: EVEL
# guesses: [('EVEL', 0.8821872331850235), ('PARA', 0.9623855716613837), ('ONCE', 1.0), ('ABIT', 1.0), ('TIME', 1.0)]
# ----------------------------------------------
# clue: Trolley warning
# answer: TOOT
# guesses: [('CART', 0.6865271037466011), ('BATS', 0.6865271037466011), ('TRAM', 0.6865271037466011), ('CART', 0.6865271037466011), ('DAFT', 0.6865271037466011)]
# ----------------------------------------------
# clue: Men in a monastery
# answer: FRAS
# guesses: [('CELL', 0.667094341347107), ('FRAS', 0.8443178791691064), ('FEDS', 0.8615194436207588), ('STAG', 0.8615194436207588), ('STAG', 0.8615194436207588)]
# ----------------------------------------------
# clue: Celestial flare-ups
# answer: NOVAS
# guesses: [('SOLAR', 0.9378931516221996), ('HIKES', 0.9551855005221711), ('GARBS', 0.9551855005221711), ('HIKES', 0.9551855005221711), ('ASHES', 0.9962659899519872)]
# ----------------------------------------------
# clue: Modify
# answer: ALTER
# guesses: [('AMEND', 0.0), ('ALTER', 0.0), ('ALTER', 0.0), ('ALTER', 0.0), ('ALTER', 0.0)]
# ----------------------------------------------
# clue: To the max
# answer: INSPADES
# guesses: [('HEADROOM', 0.6531607943385198), ('NERDIEST', 0.705089332941897)]
# ----------------------------------------------
# clue: Tavern order
# answer: BEER
# guesses: [('GROG', 0.0), ('MOES', 0.7945760757520304), ('BEER', 0.8459110283515149), ('ALES', 0.8649269254529276), ('ALES', 0.8649269254529276)]
# ----------------------------------------------
# clue: Dolly's family
# answer: LEVIS
# guesses: [('HELLO', 0.6635155359208913), ('HELLO', 0.7631415754238323), ('HELLO', 0.8573025832086411), ('HELLO', 0.8573025832086411), ('GENUS', 0.9323800412770409)]
# ----------------------------------------------
# clue: D.A.'s
# answer: ATTS
# guesses: [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]
# ----------------------------------------------
# clue: Ban ___ (Kofi Annan's successor)
# answer: KIMOON
# guesses: [('CAMERA', 0.9999999999999999), ('ROOFER', 0.9999999999999999), ('NECKED', 0.9999999999999999)]
# ----------------------------------------------
# clue: Ethiopian town
# answer: ADUWA
# guesses: [('ADUWA', 0.0), ('HARAR', 0.7539550342168633), ('TSANA', 0.8169418100130337), ('TIGRE', 0.8653209261908896), ('MEROE', 0.8989064052403025)]
# ----------------------------------------------
# clue: This puzzle's long-winded advice, simply put
# answer: LOOKBEFOREYOULEAP
# guesses: []
# ----------------------------------------------
# clue: 2008 Pixar robot
# answer: WALLE
# guesses: [('WALLE', 0.0), ('GOLEM', 0.9177732740788469), ('WALLE', 0.9741647243511176), ('MARKS', 0.9999999999999999), ('ALOFT', 0.9999999999999999)]
# ----------------------------------------------
# clue: Fast approaching
# answer: NEAR
# guesses: [('NIGH', 0.6018452625360905), ('NIGH', 0.6018452625360905), ('PLOY', 0.9230938564769298)]
# ----------------------------------------------
# clue: Up and about
# answer: ASTIR
# guesses: [('LEAST', 0.0), ('HEART', 0.0), ('ALIBI', 0.0), ('STAKE', 0.0), ('EWING', 0.0)]
# ----------------------------------------------
# clue: Color meaning "caution" on 13-Down
# answer: AMBER
# guesses: [('AMBER', 0.8807017624313507), ('SENSE', 0.9989954627383689), ('SENSE', 0.9989954627383689), ('POINT', 0.9989954627383689), ('ERROR', 0.9989954627383689)]
# ----------------------------------------------
# clue: Wore
# answer: HADON
# guesses: [('HADON', 0.0), ('HADON', 0.0), ('HADON', 0.0), ('HADON', 0.0), ('HADON', 0.0)]
# ----------------------------------------------
# clue: Blubber
# answer: CRY
# guesses: [('SOB', 0.0), ('SOB', 0.0), ('FAT', 0.0), ('SOB', 0.0), ('SOB', 0.0)]
# ----------------------------------------------
# clue: In the limelight
# answer: ONSTAGE
# guesses: [('ONETIME', 1.0)]
# ----------------------------------------------
# clue: Accord
# answer: AMITY
# guesses: [('AMITY', 0.0), ('ATONE', 0.0), ('ATONE', 0.0), ('UNITY', 0.0), ('AMITY', 0.0)]
# ----------------------------------------------
# clue: MacDonald's "The Egg ___"
# answer: ANDI
# guesses: [('HADA', 0.7820917632961483), ('FARM', 0.8410792828089683), ('FARM', 0.8410792828089683), ('EDDY', 0.8534646249442138), ('EDDY', 0.8534646249442138)]
# ----------------------------------------------
# clue: ___ Aviv
# answer: TEL
# guesses: [('TEL', 0.0), ('TEL', 0.0), ('TEL', 0.0), ('TEL', 0.0), ('TEL', 0.0)]
# ----------------------------------------------
# clue: "_____ o' My Heart"
# answer: PEG
# guesses: [('COR', 0.6654582750426652), ('COR', 0.6654582750426652), ('COR', 0.6654582750426652), ('COR', 0.6654582750426652)]
# ----------------------------------------------
# clue: W. W. II org.
# answer: OPA
# guesses: [('OPA', 0.0), ('OPA', 0.0), ('OSS', 0.0), ('OPA', 0.0), ('OSS', 0.0)]
# ----------------------------------------------
# clue: Syst. of measurement
# answer: CGS
# guesses: [('ABM', 0.9214725913237541), ('BMT', 0.9286779440146351), ('ENS', 0.9692257109287173), ('ABO', 0.9774303380495311), ('IGN', 0.9955585969251769)]
# ----------------------------------------------
# clue: Care for
# answer: TEND
# guesses: [('TEND', 0.0), ('EASE', 0.0), ('MIND', 0.0), ('TEND', 0.0), ('TEND', 0.0)]
# ----------------------------------------------
# clue: Scary cinema sounds
# answer: SCREAMS
# guesses: []
# ----------------------------------------------
# clue: Keats's was Grecian
# answer: URN
# guesses: [('ERE', 0.8880790211441423), ('OER', 0.8880790211441423), ('ERE', 0.8880790211441423), ('ERE', 0.8880790211441423), ('EER', 0.8880790211441423)]
# ----------------------------------------------
# clue: Full-count cry
# answer: STRIKETWO
# guesses: [('ENUMERATE', 0.0), ('ENUMERATE', 0.0), ('ENUMERATE', 0.0)]
# ----------------------------------------------
# clue: Begged
# answer: PLED
# guesses: [('PLED', 0.0), ('PLED', 0.0), ('PLED', 0.0), ('PLED', 0.0), ('PLED', 0.0)]
# ----------------------------------------------
# clue: Corset tightener
# answer: LACER
# guesses: [('LACER', 0.0), ('DITTO', 1.0), ('TOTAL', 1.0)]
# ----------------------------------------------
# clue: Swamp
# answer: MORASS
# guesses: [('MORASS', 0.0), ('MORASS', 0.0), ('MORASS', 0.0), ('MORASS', 0.0)]
# ----------------------------------------------
# clue: Excited about
# answer: KEENON
# guesses: []
# ----------------------------------------------
# clue: Clumps
# answer: TUFTS
# guesses: [('CLODS', 0.5738405682243282), ('HELLO', 1.0), ('UNCLE', 1.0), ('IPASS', 1.0), ('ALIBI', 1.0)]
# ----------------------------------------------
# clue: Sires' mates
# answer: DAMS
# guesses: [('DADS', 0.8570753757716728), ('EXES', 0.866107097219266), ('EXES', 0.866107097219266), ('PALS', 0.866107097219266), ('PALS', 0.866107097219266)]
# ----------------------------------------------
# clue: Cry at an unveiling
# answer: ETVOILA
# guesses: [('ETVOILA', 0.5542951259698595), ('ABREAST', 1.0)]
# ----------------------------------------------
# clue: Modish
# answer: CHIC
# guesses: [('CHIC', 0.0), ('CHIC', 0.0), ('CHIC', 0.0), ('ATAD', 1.0), ('ALSO', 1.0)]
# ----------------------------------------------
# clue: Word before many city names
# answer: GREATER
# guesses: [('SWEARAT', 0.7580881854364423), ('CLASSIC', 0.8398589182675112)]
# ----------------------------------------------
# clue: Napa sight
# answer: VINEYARD
# guesses: [('RELEGATE', 0.9435128741439904), ('TUCKAWAY', 0.9435128741439904)]
# ----------------------------------------------
# clue: Copland
# answer: AARON
# guesses: [('AARON', 0.0), ('AARON', 0.0), ('RODEO', 0.5790787418089183), ('AARON', 0.588328548931405), ('AARON', 0.588328548931405)]
# ----------------------------------------------
# clue: Former Alaskan governor
# answer: EGAN
# guesses: [('EGAN', 0.0), ('EGAN', 0.0), ('KEAN', 0.7767017256549829), ('KEAN', 0.7767017256549829), ('NOME', 0.885328606686172)]
# ----------------------------------------------
# clue: Tom Lea's brave bulls
# answer: TOROS
# guesses: [('PHONE', 1.0), ('ARBOR', 1.0), ('AWARD', 1.0)]
# ----------------------------------------------
# clue: Double twist
# answer: ESS
# guesses: [('ESS', 0.0), ('DNA', 0.7169343601128682)]
# ----------------------------------------------
# clue: Submitting to control
# answer: MANAGEABLE
# guesses: []
# ----------------------------------------------
# clue: Big name in paperback publishing
# answer: AVON
# guesses: [('AVON', 0.8537967312099165), ('OCHS', 0.8683207352960184), ('OCHS', 0.8959588794317542), ('ANEW', 1.0), ('OWNS', 1.0)]
# ----------------------------------------------
# clue: Rent
# answer: LET
# guesses: [('LET', 0.0), ('LET', 0.0), ('LET', 0.0), ('LET', 0.0), ('LET', 0.0)]
# ----------------------------------------------
# clue: Nicest room on a ship, probably
# answer: CAPTAINSDIMES
# guesses: []
# ----------------------------------------------
# clue: Friends and neighbors
# answer: KITH
# guesses: [('KITH', 0.0), ('KITH', 0.0), ('KITH', 0.0), ('KITH', 0.832901200610171), ('ROSS', 0.832901200610171)]
# ----------------------------------------------
# clue: Friends
# answer: ALLIES
# guesses: [('ALIENS', 0.0), ('MONICA', 0.0), ('SITCOM', 0.0), ('MONICA', 0.0)]
# ----------------------------------------------
# clue: Mountain climber's obstacle
# answer: GORGE
# guesses: [('PITON', 0.8875351053630293), ('PITON', 0.8875351053630293), ('KOALA', 0.8938038234769691), ('THOSE', 0.9999999999999999)]
# ----------------------------------------------
# clue: Crime writer Rankin
# answer: IAN
# guesses: [('ANN', 0.8119503012440201), ('PEN', 0.8740557787768939)]
# ----------------------------------------------
# clue: Omega preceded
# answer: PSI
# guesses: [('LED', 0.73276400747758), ('PSI', 0.7977331481056429), ('END', 0.7977331481056429), ('PSI', 0.7977331481056429), ('END', 0.7977331481056429)]
# ----------------------------------------------
# clue: Inability to recall the names of everyday objects
# answer: ANOMIA
# guesses: [('TINEAR', 0.9972864536488252), ('MAIDEN', 1.0), ('RELENT', 1.0)]
# ----------------------------------------------
# clue: Symphony or sonata
# answer: OPUS
# guesses: [('OPUS', 0.7191796160475025), ('OPUS', 0.7191796160475025), ('CODA', 0.7191796160475025), ('OPUS', 0.7191796160475025), ('OPUS', 0.8110807141860618)]
# ----------------------------------------------
# clue: Dawn
# answer: SUNUP
# guesses: [('ARISE', 0.0), ('ONSET', 0.0), ('SUNUP', 0.0), ('SUNUP', 0.0), ('ONSET', 0.0)]
# ----------------------------------------------
# clue: ___ Claire, Wis.
# answer: EAU
# guesses: [('EAU', 0.0), ('EAU', 0.0), ('EAU', 0.0), ('EAU', 0.47902586977193934), ('EAU', 0.7351237324070498)]
# ----------------------------------------------
# clue: Summer Olympics site: 1964
# answer: TOKYO
# guesses: [('SKEET', 0.8946523322879335), ('TOKYO', 0.9646973323329144), ('MEDAL', 0.9713898685909481), ('SEOUL', 0.9790079377328921), ('VAULT', 0.985821714635526)]
# ----------------------------------------------
# clue: Chatter
# answer: CHIN
# guesses: [('CHIN', 0.0), ('TALK', 0.0), ('IDLE', 0.4788737052121641), ('IDLE', 0.4788737052121641)]

# %%
correct_pairs = []
incorrect_pairs = []

for i, (clue, answer) in enumerate(zip(clues_test, answers_test)):
    if i % 100 == 0: print(i)
    guesses = guess(clue, len(answer), max_guesses=5)
    if answer in [g for g, _  in guesses]:
        correct_pairs.append((clue, answer, guesses))
    else:
        incorrect_pairs.append((clue, answer, guesses))

print(f"Accuracy: {len(correct_pairs) / len(clues_test):0.3%}")
# print(incorrect_pairs)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# Accuracy: 50.331%

# %%
incorrect_pairs
# Out:
# [('Squabbling',
#   'ATODDS',
#   [('BENICE', 0.6572432574979622), ('INTOTO', 1.0), ('PATENT', 1.0)]),
#  ('Wild way to go', 'APE', [('MAD', 0.6455905747691044)]),
#  ("One Fodor's guide",
#   'EUROPE',
#   [('MENTOR', 0.9178033945624456),
#    ('SHERPA', 0.9178033945624456),
#    ('ADVISE', 0.9178033945624456),
#    ('MENTOR', 0.9178033945624456),
#    ('KIMONO', 1.0)]),
#  ("Caught some Z's",
#   'TOOKANAP',
#   [('ENTANGLE', 0.0),
#    ('ENSNARED', 0.0),
#    ('OVERTOOK', 0.0),
#    ('INTHEACT', 0.0),
#    ('ENSNARED', 0.0)]),
#  ("Denver's ___ Gardens amusement park",
#   'ELITCH',
#   [('OMELET', 0.9508302750990995), ('ALLDAY', 0.9973828152624047)]),
#  ('Uses again, as Tupperware',
#   'RESEALS',
#   [('ALLOVER', 1.0), ('NOTONCE', 1.0)]),
#  ('Stigma',
#   'ODIUM',
#   [('BRAND', 0.0),
#    ('STAIN', 0.0),
#    ('BRAND', 0.0),
#    ('STAIN', 0.0),
#    ('BRAND', 0.0)]),
#  ('New Harmony, Ind., founder',
#   'OWEN',
#   [('AJAR', 0.9558203004743219),
#    ('AJAR', 0.9558203004743219),
#    ('AJAR', 0.9558203004743219),
#    ('JIBE', 0.9558203004743219),
#    ('AJAR', 0.9558203004743219)]),
#  ('Partner of bother',
#   'FUSS',
#   [('PAIN', 0.6174626515746531),
#    ('PEST', 0.6174626515746531),
#    ('PEST', 0.6174626515746531),
#    ('PEST', 0.6174626515746531),
#    ('GNAW', 0.6174626515746531)]),
#  ('Hang around',
#   'LOITER',
#   [('ADHERE', 0.0),
#    ('REMAIN', 0.0),
#    ('ONESEC', 0.0),
#    ('RETIRE', 0.0),
#    ('RETAIN', 0.0)]),
#  ('Aptitude',
#   'KNACK',
#   [('FLAIR', 0.0),
#    ('SKILL', 0.0),
#    ('FLAIR', 0.0),
#    ('FLAIR', 0.0),
#    ('RENEW', 1.0)]),
#  ('Mideast mogul',
#   'AMEER',
#   [('NABOB', 0.6644062833913065),
#    ('NABOB', 0.6644062833913065),
#    ('MAYER', 0.8551867014803649),
#    ('YASIR', 0.8640911634095398),
#    ('EMEER', 0.8640911634095398)]),
#  ('Worries',
#   'CARES',
#   [('STEWS', 0.0),
#    ('STEWS', 0.0),
#    ('STEWS', 0.0),
#    ('FRETS', 0.0),
#    ('FRETS', 0.0)]),
#  ("___ Rud, river on Afghanistan's boundary",
#   'HARI',
#   [('ABCS', 1.0), ('ATOP', 1.0), ('POOR', 1.0), ('INST', 1.0), ('ANTI', 1.0)]),
#  ('Blue',
#   'DEJECTED',
#   [('CERULEAN', 0.0), ('EROTICAL', 0.0), ('HOSPITAL', 0.0)]),
#  ('This point forward',
#   'HEREON',
#   [('ASSERT', 0.6551466118201497),
#    ('REMAIL', 0.6551466118201497),
#    ('ASSERT', 0.6551466118201497),
#    ('SHIEST', 0.6551466118201497),
#    ('RESEND', 0.6551466118201497)]),
#  ('It has a wheel on its heel',
#   'SKATE',
#   [('SEEDY', 0.6785886120720569),
#    ('SEEDY', 0.6785886120720569),
#    ('CUBAN', 0.8072478973768044),
#    ('SPOKE', 0.8504881891078403),
#    ('SPOKE', 0.8504881891078403)]),
#  ('Aristotelian element',
#   'EARTH',
#   [('LOGIC', 0.7474402947784039),
#    ('CERIC', 0.9341542772710347),
#    ('BORON', 0.9341542772710347),
#    ('ARGON', 0.9341542772710347),
#    ('TRUED', 1.0)]),
#  ('Avid',
#   'RAHRAH',
#   [('GUNGHO', 0.0), ('ATHOME', 1.0), ('DEPART', 1.0), ('MEREST', 1.0)]),
#  ('The veterinarian tried to',
#   'FEEDTHEKITTY',
#   [('ILLFIXHISWAG', 0.8797722791945541)]),
#  ('Spiral ornament',
#   'VOLUTE',
#   [('ENRICH', 0.7814495859075515),
#    ('EMBOSS', 0.7814495859075515),
#    ('HELICO', 0.8804720934614909),
#    ('ENCOIL', 0.8919824560293634),
#    ('GALAXY', 0.9341756223863436)]),
#  ('Knuckle-headed gestures of affection?', 'NOOGIES', []),
#  ('Pasta request?', 'ALBERTDENTE', []),
#  ('Cries for Joselito',
#   'OLES',
#   [('SOBS', 0.0),
#    ('ASKS', 0.0),
#    ('SOBS', 0.6191765248893295),
#    ('RAHS', 0.6506929818206321),
#    ('LETS', 0.6931052693178261)]),
#  ('Branch of physics: Abbr.',
#   'DYN',
#   [('SCI', 0.6894909238182638),
#    ('ARM', 0.8399731971734081),
#    ('ARM', 0.8399731971734081),
#    ('ARM', 0.8399731971734081),
#    ('ARM', 0.8399731971734081)]),
#  ('Cambridge tech. center',
#   'MIT',
#   [('CAL', 0.9362945846120245),
#    ('CAL', 0.9362945846120245),
#    ('CAL', 0.9362945846120245),
#    ('ITT', 0.9362945846120245),
#    ('SCH', 0.974777649073502)]),
#  ('Itinerant', 'TRAVELER', [('STROLLER', 0.508724684904937)]),
#  ('G. B. Shaw play: 1903',
#   'MANANDSUPERMAN',
#   [('THEPHILANDERER', 0.9821416921572197)]),
#  ('Stout',
#   'FAT',
#   [('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0), ('ALE', 0.0)]),
#  ('Place for a gauge, informally',
#   'DASH',
#   [('STAT', 0.7496225508873834),
#    ('TACH', 0.9482203909461215),
#    ('TACH', 0.9580095096595966),
#    ('DEMO', 0.9893367506881571),
#    ('REAL', 0.9893367506881571)]),
#  ('Bag, in dialect',
#   'POKE',
#   [('NARY', 0.7099893693916408),
#    ('SACK', 0.8200651580712142),
#    ('SACK', 0.8200651580712142),
#    ('GRIP', 0.8200651580712142)]),
#  ('"Peter Rabbit," for one',
#   'TALE',
#   [('CONY', 0.7217215470776873),
#    ('BRER', 0.7918790502864177),
#    ('BRER', 0.7918790502864177),
#    ('BRER', 0.7918790502864177),
#    ('BRER', 0.7918790502864177)]),
#  ('One of the Brontes',
#   'EMILY',
#   [('VOWEL', 1.0),
#    ('AREAR', 1.0),
#    ('ABIDE', 1.0),
#    ('HENCE', 1.0),
#    ('REDID', 1.0)]),
#  ('Intertwines anew',
#   'REFOLDS',
#   [('FRESHLY', 0.9108501096579639), ('ALLOVER', 1.0), ('AFFRONT', 1.0)]),
#  ('Accepted the bait',
#   'BIT',
#   [('OKD', 0.7208458552641743),
#    ('EAT', 0.8094478581794394),
#    ('DOS', 0.9604162727398808)]),
#  ('What stogies do',
#   'REEK',
#   [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]),
#  ('Quiet color',
#   'ASH',
#   [('SSH', 0.683982547223847),
#    ('SHH', 0.683982547223847),
#    ('SHH', 0.683982547223847),
#    ('SHH', 0.683982547223847),
#    ('SHH', 0.683982547223847)]),
#  ('Expanse also called the Euxine',
#   'BLACK',
#   [('OCEAN', 0.6705265451301583),
#    ('OCEAN', 0.6705265451301583),
#    ('OCEAN', 0.6705265451301583),
#    ('PAGED', 0.8582313517240676),
#    ('NAMED', 0.8582313517240676)]),
#  ("Superman's birth name",
#   'KALEL',
#   [('NATAL', 0.7829407828931064),
#    ('NATAL', 0.7829407828931064),
#    ('NATAL', 0.7829407828931064),
#    ('NATAL', 0.7829407828931064),
#    ('NATAL', 0.7829407828931064)]),
#  ('Wood trimmer',
#   'ADZ',
#   [('ITS', 1.0), ('FEW', 1.0), ('ALL', 1.0), ('JAB', 1.0)]),
#  ('Get ready',
#   'GEARUP',
#   [('ALLSET', 0.0),
#    ('ONCALL', 0.0),
#    ('ALLSET', 0.0),
#    ('ALLSET', 0.0),
#    ('COCKED', 0.0)]),
#  ('Took the long way round',
#   'SKIRTED',
#   [('ORBITED', 0.8688651205106175), ('SPHERIC', 0.930766737380623)]),
#  ('W African country',
#   'GHANA',
#   [('ZAIRE', 0.7752528251491183),
#    ('RURAL', 0.7752528251491183),
#    ('NOLAN', 0.7752528251491183),
#    ('RURAL', 0.7752528251491183),
#    ('RURAL', 0.7752528251491183)]),
#  ('Fleeces',
#   'SOAKS',
#   [('UTTER', 1.0),
#    ('HELLO', 1.0),
#    ('UNCLE', 1.0),
#    ('IPASS', 1.0),
#    ('ALIBI', 1.0)]),
#  ('Questions about a flight, say', 'DEBRIEFS', []),
#  ('Some French Impressionist paintings',
#   'MONETS',
#   [('RENOIR', 0.6658620782037654),
#    ('CAVERN', 0.9752098170207727),
#    ('MANETS', 0.9860477662602904)]),
#  ('Make potable, in a way', 'DESALT', [('ELIXIR', 0.9473455051997598)]),
#  ('Where MacArthur shops?', 'GENERALSTORE', []),
#  ('See 40-Down', 'BROTHERS', [('EXAMINES', 0.0)]),
#  ('Exalt',
#   'LIONIZE',
#   [('ELEVATE', 0.0), ('ELEVATE', 0.0), ('ISSUERS', 1.0), ('TESTATE', 1.0)]),
#  ('Looney Tunes horse-drawn conveyance?', 'CARTONCARTOON', []),
#  ('Undiluted',
#   'PURE',
#   [('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0), ('NEAT', 0.0)]),
#  ('"All ___ Do" (Sheryl Crow hit)',
#   'IWANNA',
#   [('SIOUAN', 0.9546560976941603)]),
#  ('Some newspapers', 'GAZETTES', [('PIONEERS', 1.0)]),
#  ('Inane', 'FOOLISH', [('ASININE', 0.0), ('PUERILE', 0.0)]),
#  ('Rockette launchers?',
#   'LEGS',
#   [('AMID', 1.0), ('MOST', 1.0), ('EXIT', 1.0), ('EVEN', 1.0), ('SOLO', 1.0)]),
#  ('"Murder, She Wrote" locale',
#   'MAINE',
#   [('BERNE', 0.9707830876766789),
#    ('NOTED', 0.9707830876766789),
#    ('OATES', 0.9707830876766789),
#    ('SLAIN', 1.0),
#    ('UNDER', 1.0)]),
#  ('Bible town of France',
#   'DOUAI',
#   [('NESLE', 0.6807781235148839), ('SHALT', 0.8483805247361912)]),
#  ('Reminders',
#   'HINTS',
#   [('MEMOS', 0.47109600485162817),
#    ('MEMOS', 0.6254001241091712),
#    ('ACHES', 0.6900991183755644),
#    ('ACHES', 0.6900991183755644),
#    ('WELTS', 0.7827487667788169)]),
#  ('Omanis, e.g.',
#   'ARABS',
#   [('VOWEL', 1.0),
#    ('AREAR', 1.0),
#    ('ABIDE', 1.0),
#    ('HENCE', 1.0),
#    ('REDID', 1.0)]),
#  ('Opposite of ppp, on scores',
#   'FFF',
#   [('TDS', 0.6430442544050408),
#    ('TDS', 0.6430442544050408),
#    ('TDS', 0.6430442544050408),
#    ('TDS', 0.6430442544050408),
#    ('PIU', 0.6430442544050408)]),
#  ('"If I Needed ___" (Harrison-penned Beatles song)',
#   'SOMEONE',
#   [('FOUNDER', 1.0)]),
#  ('All-Star Game, e.g.',
#   'INTERLEAGUEPLAY',
#   [('CHINESECHECKERS', 0.6839585620943806)]),
#  ('Valued highly', 'TREASURED', [('APPRAISED', 0.6671728721773095)]),
#  ('Items wrapped in friction tape',
#   'WIRES',
#   [('ENDED', 0.9833927707582086),
#    ('ENDED', 0.9833927707582086),
#    ('ENDED', 0.9833927707582086),
#    ('SEWED', 0.9833927707582086),
#    ('ENDED', 0.9833927707582086)]),
#  ('"Amos Moses" singer',
#   'REED',
#   [('TORI', 0.6472163759195675),
#    ('TORI', 0.8225062535125732),
#    ('ANDY', 0.8551458865022501),
#    ('TORI', 0.8651084866829963),
#    ('JOEL', 0.9401389795183694)]),
#  ('Spoke loudly',
#   'ROARED',
#   [('OINKED', 0.9762314516389976),
#    ('RASPED', 0.9799235700764274),
#    ('ORATED', 0.9924429432641514),
#    ('RASPED', 0.9959040582844169),
#    ('SASSED', 0.9968496912214188)]),
#  ('Parts of goblets',
#   'STEMS',
#   [('WOMAN', 0.9999999999999999),
#    ('RARER', 0.9999999999999999),
#    ('AMPLE', 0.9999999999999999),
#    ('ACCTS', 0.9999999999999999),
#    ('NEGRO', 0.9999999999999999)]),
#  ('Round of golf tournaments',
#   'ROTA',
#   [('NINE', 0.8766220190969779),
#    ('SPAR', 0.974342690548621),
#    ('EDDY', 0.974342690548621),
#    ('SPIN', 0.974342690548621),
#    ('GYRE', 0.974342690548621)]),
#  ('Major milk maker',
#   'BORDEN',
#   [('LACTIC', 0.8720116700130357), ('HARVEY', 0.9635521971895227)]),
#  ('Remain inactive',
#   'LIEBY',
#   [('ABIDE', 0.7872236585486047), ('ABIDE', 0.7872236585486047)]),
#  ('Weak and craven',
#   'UNMANLY',
#   [('EPICENE', 0.8291336708210514), ('RUNTISH', 0.9623650524473579)]),
#  ('A beast of the chase',
#   'BOAR',
#   [('ILKA', 0.7321554489183462),
#    ('HUNT', 0.7321554489183462),
#    ('ILKA', 0.7321554489183462),
#    ('ILKA', 0.790744915935489),
#    ('OGRE', 0.7983328249732045)]),
#  ('Certain vaudeville act',
#   'TAPDANCE',
#   [('STAGEACT', 0.9221506926178086), ('SWANSONG', 0.9500159183728227)]),
#  ('Lhasa apsos, e.g.', 'TERRIERS', []),
#  ('Congressional hire',
#   'AIDE',
#   [('RENT', 0.7994132544823743),
#    ('RENT', 0.7994132544823743),
#    ('RENT', 0.7994132544823743),
#    ('SEAT', 0.9043471594400138),
#    ('ACTS', 0.929382615395156)]),
#  ('Best Picture before "12 Years a Slave"',
#   'ARGO',
#   [('EVER', 0.9999999999999999),
#    ('ALVA', 0.9999999999999999),
#    ('PRES', 0.9999999999999999),
#    ('INTO', 0.9999999999999999),
#    ('SOLO', 0.9999999999999999)]),
#  ('Physicist who formulated the two laws of electrolysis',
#   'FARADAY',
#   [('PLENARY', 1.0), ('CRAFTED', 1.0)]),
#  ('Did some mending',
#   'DARNED',
#   [('USEDTO', 0.9207444646675575), ('REMADE', 0.9207444646675575)]),
#  ('Peen of a hammer',
#   'TOE',
#   [('HAD', 0.3673126684957867), ('IFI', 0.3673126684957867)]),
#  ('Make secure',
#   'LASH',
#   [('SAFE', 0.5869240106914193),
#    ('SAFE', 0.5869240106914193),
#    ('SAFE', 0.5869240106914193),
#    ('MOOR', 0.5869240106914193),
#    ('GETS', 0.5869240106914193)]),
#  ('"Delphine" author: 1803',
#   'DESTAEL',
#   [('SOTHERE', 0.9999999999999999), ('APPOSED', 0.9999999999999999)]),
#  ('Dionne Warwick\'s "Walk___"',
#   'ONBY',
#   [('HADA', 0.48799345608134337),
#    ('LENS', 1.0),
#    ('EXIT', 1.0),
#    ('SITE', 1.0),
#    ('REAR', 1.0)]),
#  ('Opening bridge bid, informally', 'AHEART', []),
#  ('Murmur', 'BREATHE', []),
#  ('Mil. verdict',
#   'AWOL',
#   [('ACAD', 0.8940763101223492),
#    ('TIED', 1.0),
#    ('TIED', 1.0),
#    ('ANEW', 1.0),
#    ('NONE', 1.0)]),
#  ('Mideast ruler',
#   'EMIR',
#   [('SHAH', 0.0),
#    ('AMIR', 0.0),
#    ('SAUD', 0.0),
#    ('AMIR', 0.5820706167282049),
#    ('TSAR', 0.7599392731583469)]),
#  ('Tours', 'MOTORS', []),
#  ('New York and New Orleans',
#   'PORTS',
#   [('STRIP', 0.6919898565046844),
#    ('RERUN', 0.7330974002018574),
#    ('NOVEL', 0.7330974002018574)]),
#  ('European air hub', 'DEGAULLE', []),
#  ('What might determine if the moon hitting your eye like a big pizza pie is truly amore?',
#   'CROONERSINQUEST',
#   []),
#  ('Grote of baseball',
#   'JERRY',
#   [('ENDED', 1.0), ('AGAIN', 1.0), ('AWAKE', 1.0), ('UNCLE', 1.0)]),
#  ('Baldwin\'s "The Fire ___ Time"',
#   'NEXT',
#   [('ALEC', 0.6013636041073975),
#    ('ALEC', 0.6013636041073975),
#    ('ALEC', 0.6013636041073975),
#    ('ALEC', 0.6013636041073975),
#    ('ALEC', 0.6013636041073975)]),
#  ('Encouraged by others, in a way',
#   'ONADARE',
#   [('EGGEDON', 0.4728794849688795),
#    ('ABETTED', 0.4728794849688795),
#    ('INPAIRS', 1.0),
#    ('ENROUTE', 1.0)]),
#  ('Elaborate molding',
#   'GADROON',
#   [('EXPOUND', 0.7034345449473827),
#    ('ORATION', 0.9114260621102954),
#    ('PAGEANT', 0.9776689330663932)]),
#  ('Org. with good aims?',
#   'NRA',
#   [('TDS', 0.8906103867573604),
#    ('ERE', 1.0),
#    ('EST', 1.0),
#    ('CDE', 1.0),
#    ('ISL', 1.0)]),
#  ('Cash register part',
#   'DRAWER',
#   [('NOSALE', 0.5328495777699357),
#    ('NOSALE', 0.5328495777699357),
#    ('NOSALE', 0.5328495777699357),
#    ('NOSALE', 0.5328495777699357),
#    ('RINGUP', 0.5716308089139827)]),
#  ('Org. for Tyson',
#   'WBA',
#   [('KOS', 0.9257585942705184),
#    ('NOW', 0.9999999999999999),
#    ('OWE', 0.9999999999999999),
#    ('CAN', 0.9999999999999999),
#    ('ACE', 0.9999999999999999)]),
#  ('Longtime Times Sq. site',
#   'TKTS',
#   [('BWAY', 0.8226588885852418),
#    ('NYPD', 0.8888768638489026),
#    ('ELSE', 0.9999999999999999),
#    ('AWRY', 0.9999999999999999),
#    ('YVES', 0.9999999999999999)]),
#  ('Have good intentions', 'MEANWELL', []),
#  ('Chowder server',
#   'LADLE',
#   [('TONGS', 0.9943508677070407),
#    ('TOWIT', 1.0),
#    ('HASTO', 1.0),
#    ('PETIT', 1.0)]),
#  ("Snead's needs",
#   'TEES',
#   [('SAMS', 0.9168785522307762),
#    ('SAMS', 0.9168785522307762),
#    ('TEED', 0.934117891371172),
#    ('NORM', 0.9596301601836988),
#    ('ANEW', 1.0)]),
#  ("Drill sergeant's command",
#   'ABOUTFACE',
#   [('LEFTRIGHT', 0.6596410333606134)]),
#  ('___ Man', 'ISLEOF', []),
#  ('Geometric figure', 'HEXAGON', [('ELLIPSE', 0.0), ('RHOMBUS', 0.0)]),
#  ('And never',
#   'NOR',
#   [('RHO', 0.0), ('TIN', 0.0), ('NOW', 0.0), ('AVG', 0.0), ('ATE', 0.0)]),
#  ('Longed for',
#   'CRAVED',
#   [('YENNED', 0.0),
#    ('ENCORE', 1.0),
#    ('IDOTOO', 1.0),
#    ('CONTRA', 1.0),
#    ('BESTIR', 1.0)]),
#  ('Anderson of Jethro Tull', 'IAN', [('TAG', 1.0), ('AHA', 1.0)]),
#  ('Stuntman Knievel',
#   'EVEL',
#   [('CHAN', 0.9577661337526475),
#    ('THUS', 0.9999999999999999),
#    ('ANEW', 0.9999999999999999),
#    ('ANTE', 0.9999999999999999),
#    ('ELSE', 0.9999999999999999)]),
#  ('Italian archaeological locale',
#   'POMPEII',
#   [('UNEARTH', 0.8482519362684124), ('AGREETO', 1.0)]),
#  ('Fanciful notions', 'CONCEITS', [('ROMANTIC', 0.744926897943918)]),
#  ('Down',
#   'EAT',
#   [('RHO', 0.0), ('TIN', 0.0), ('NOW', 0.0), ('AVG', 0.0), ('ATE', 0.0)]),
#  ('Keep in the attic, maybe',
#   'STORE',
#   [('DUSTY', 0.7062617016146898),
#    ('AGORA', 0.8442776218371285),
#    ('STOAS', 0.9371198260888944)]),
#  ('Tale written in runes, perhaps',
#   'SAGA',
#   [('ORAL', 0.70745194620763),
#    ('ORAL', 0.70745194620763),
#    ('TEXT', 0.70745194620763),
#    ('ORAL', 0.70745194620763),
#    ('ORAL', 0.70745194620763)]),
#  ('Bounced', 'EJECTED', [('DANDLED', 0.7980126894663582)]),
#  ('Cheekiness', 'CHUTZPAH', [('PARALLEL', 1.0), ('REQUIRES', 1.0)]),
#  ('Feast finale', 'DESSERT', [('BANQUET', 0.7666941097989516)]),
#  ('"Stop Whining, Start Living" author',
#   'DRLAURA',
#   [('BLEATER', 0.9533242294229853),
#    ('TURNPRO', 0.9994705906866546),
#    ('MYTREAT', 1.0),
#    ('ELECTEE', 1.0),
#    ('ASSAULT', 1.0)]),
#  ('Lead strip joining glass panes',
#   'CAME',
#   [('ANEW', 1.0), ('INRE', 1.0), ('AMER', 1.0), ('NAME', 1.0), ('SHOO', 1.0)]),
#  ("Faun's fellow traveler",
#   'SATYR',
#   [('SNERD', 0.9530497631425573),
#    ('FARER', 0.9741136978738687),
#    ('ROLLS', 0.9840930906491799),
#    ('SCALE', 1.0),
#    ('RARER', 1.0)]),
#  ('Midpoint between a midi and a mini',
#   'KNEE',
#   [('IPOD', 0.9718672052420604),
#    ('IPOD', 0.9718672052420604),
#    ('ALES', 0.981914531745802),
#    ('SELF', 0.9999999999999999),
#    ('BOTH', 0.9999999999999999)]),
#  ("Sgt. O'Rourke's command, on TV", 'FTROOP', [('INTACT', 1.0)]),
#  ('Ever',
#   'ONCE',
#   [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]),
#  ('Less slovenly',
#   'NEATER',
#   [('UNTIDY', 0.0), ('INTURN', 1.0), ('DONATE', 1.0)]),
#  ('Most musty', 'STALEST', [('NOTMANY', 1.0)]),
#  ('Grilling test',
#   'ORAL',
#   [('PSAT', 0.9026760926555041),
#    ('EXAM', 0.9026760926555041),
#    ('EXAM', 0.9026760926555041),
#    ('PSAT', 0.9026760926555041)]),
#  ('Just',
#   'FAIR',
#   [('EKED', 0.0), ('ONLY', 0.0), ('MERE', 0.0), ('ONLY', 0.0), ('TOAT', 0.0)]),
#  ('Mentally quick',
#   'NIMBLE',
#   [('SANEST', 0.7998406351947962),
#    ('ASTUTE', 0.8562075148383509),
#    ('SPEEDY', 0.8853328808153443),
#    ('SPEEDY', 0.8853328808153443),
#    ('ASTUTE', 0.8853328808153443)]),
#  ('Makes cry, in a way', 'TEARGASSES', []),
#  ('Something to take, carefully', 'AIM', []),
#  ("Location of a British driver's seat", 'RIGHTSIDE', []),
#  ('Curbside sights', 'TRASHCANS', []),
#  ('Free ___ (total control)',
#   'REIN',
#   [('RUIN', 0.895215149332471), ('RUIN', 0.895215149332471)]),
#  ('Ball attraction',
#   'BELLE',
#   [('ALERT', 0.8170792089512597),
#    ('ALERT', 0.8170792089512597),
#    ('ALERT', 0.8170792089512597),
#    ('DANCE', 0.8170792089512597),
#    ('SHARP', 0.8170792089512597)]),
#  ('Facing, with "from"',
#   'ACROSS',
#   [('TOWARD', 0.0), ('TOWARD', 0.0), ('INAJAM', 0.7913171803126738)]),
#  ('Blessed act?',
#   'SNEEZE',
#   [('TERESA', 0.8531206968832329),
#    ('LIAISE', 0.8724805017605468),
#    ('OPENER', 0.8724805017605468),
#    ('BEHAVE', 0.8724805017605468),
#    ('SCENEI', 0.8724805017605468)]),
#  ('"Hold that tiger"', 'COLLEGECHEER', []),
#  ('Advance obliquely',
#   'SIDLE',
#   [('ASIDE', 0.7180174688835073), ('AHEAD', 0.8122188623851347)]),
#  ('Bach wrote a concerto in A for it', 'OBOEDAMORE', []),
#  ('Halberd, e.g.',
#   'WEAPON',
#   [('BESTIR', 1.0),
#    ('IDOTOO', 1.0),
#    ('ENCORE', 1.0),
#    ('CONTRA', 1.0),
#    ('EITHER', 1.0)]),
#  ('Lean and lanky',
#   'WEEDY',
#   [('FAVOR', 0.8826893442346567),
#    ('SPARE', 0.8826893442346567),
#    ('SPARE', 0.8826893442346567),
#    ('SPARE', 0.8826893442346567)]),
#  ('Swings violently', 'WHIPSAWS', []),
#  ('UV ray-blocking stat', 'SPF', [('RHO', 1.0), ('POL', 1.0), ('NIL', 1.0)]),
#  ('Winter need',
#   'FUEL',
#   [('COAT', 0.0),
#    ('POOR', 0.787679925681222),
#    ('AMMO', 0.787679925681222),
#    ('LION', 0.8239397285013835),
#    ('TALE', 0.8239397285013835)]),
#  ('Summon',
#   'HALE',
#   [('CALL', 0.0), ('CALL', 0.0), ('PAGE', 0.0), ('CALL', 0.0), ('SEND', 0.0)]),
#  ("Bouncer's demand",
#   'OUT',
#   [('HOT', 0.8284385469600433), ('HOT', 0.972857250502879)]),
#  ('Mows',
#   'CUTS',
#   [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]),
#  ('Family in "Look Homeward, Angel"',
#   'GANTS',
#   [('TIMES', 1.0), ('ANENT', 1.0), ('ABOUT', 1.0), ('ITSOK', 1.0)]),
#  ('Ca++ and Cl-',
#   'IONS',
#   [('INST', 1.0), ('PRES', 1.0), ('ALSO', 1.0), ('DUET', 1.0), ('ONTO', 1.0)]),
#  ('High-culture entertainment',
#   'OPERAS',
#   [('ETHNIC', 0.9800212006754432), ('MANAGE', 1.0)]),
#  ('Farm group', 'GRANGE', [('HEEHAW', 0.6830592506764797)]),
#  ('Orchestra leader Baxter',
#   'LES',
#   [('EVE', 0.9234848304535961), ('SAD', 0.9999999999999999)]),
#  ('Whisk wielder',
#   'CHEF',
#   [('ELSE', 1.0), ('ANTI', 1.0), ('ATOP', 1.0), ('LIST', 1.0), ('ACME', 1.0)]),
#  ('Tiny flies', 'MIDGES', [('PETITE', 0.8348492550791885)]),
#  ('"The Naked Gun," for one',
#   'SPOOF',
#   [('STARK', 0.7190755649652688),
#    ('RIFLE', 0.870043636715298),
#    ('OATER', 0.870043636715298),
#    ('SONOF', 0.9263007937237056),
#    ('RADAR', 0.9263007937237056)]),
#  ('___ États-Unis', 'LES', []),
#  ("Nero's friend and enemy",
#   'OTHO',
#   [('THEM', 0.8791506367120488),
#    ('THEM', 0.8791506367120488),
#    ('NEMO', 0.8864596567290655),
#    ('ERAT', 0.8864596567290655),
#    ('NEMO', 0.8864596567290655)]),
#  ('Avian mimic', 'MACAW', []),
#  ('"Diana," for one',
#   'OLDIE',
#   [('TIARA', 0.7085367912126529),
#    ('ORION', 0.7403661216033156),
#    ('TIARA', 0.7924442758438178),
#    ('TIARA', 0.7986392399585559)]),
#  ('Certain resident of Yemen',
#   'ADENI',
#   [('SHEBA', 0.9343765736049099),
#    ('SANAA', 0.9566866548025642),
#    ('SANAA', 0.9566866548025642),
#    ('SANAA', 0.9566866548025642),
#    ('SANAA', 0.9566866548025642)]),
#  ('Luna Park attractions',
#   'RIDES',
#   [('FATAL', 0.9553206076920882),
#    ('ADIEU', 1.0),
#    ('ALIVE', 1.0),
#    ('ATALL', 1.0),
#    ('ASTIR', 1.0)]),
#  ('S.A. Indian',
#   'INCA',
#   [('ERIE', 0.0), ('ASEA', 0.0), ('ERIE', 0.0), ('OTOE', 0.0), ('CARA', 0.0)]),
#  ('Golf adjunct',
#   'TEE',
#   [('VCR', 0.8644493116611908),
#    ('OAR', 0.9552332789789578),
#    ('OAR', 0.9552332789789578),
#    ('OAR', 0.9552332789789578),
#    ('LEM', 0.9556996159508674)]),
#  ('Futhark units',
#   'RUNES',
#   [('RUNIC', 0.8122949717655554),
#    ('BYTES', 0.9897729414226786),
#    ('ONSET', 1.0),
#    ('ALIVE', 1.0)]),
#  ('Judges', 'TRIERS', [('GIDEON', 0.0), ('GAVELS', 0.8329216495879868)]),
#  ('Like students at Gallaudet College',
#   'DEAF',
#   [('DEAN', 0.7993091864625872),
#    ('DEAN', 0.7993091864625872),
#    ('TEXT', 0.9055234422931928),
#    ('ELON', 0.9336608535174382),
#    ('ELON', 0.9336608535174382)]),
#  ('Antidepressant brand',
#   'PROZAC',
#   [('SEARER', 0.7110718688006678),
#    ('UNUSED', 0.7191216896349172),
#    ('UNUSED', 0.7191216896349172)]),
#  ('Conspiratorial group',
#   'CABAL',
#   [('RISEN', 0.9999999999999999),
#    ('TRUED', 0.9999999999999999),
#    ('SOFAR', 0.9999999999999999),
#    ('BIGON', 0.9999999999999999),
#    ('ERASE', 0.9999999999999999)]),
#  ('Decapitates', 'BEHEADS', [('ELECTED', 0.0)]),
#  ('"___ a borrower..."', 'NEITHER', [('ELECTEE', 1.0), ('NOSCORE', 1.0)]),
#  ('Retain',
#   'SAVE',
#   [('KEEP', 0.0), ('KEEP', 0.0), ('KEEP', 0.0), ('KEEP', 0.0), ('HOLD', 0.0)]),
#  ('Badgerlike mammal',
#   'RATEL',
#   [('OTTER', 0.622429650493978),
#    ('OTTER', 0.622429650493978),
#    ('OTTER', 0.6567973324853386),
#    ('OTTER', 0.6567973324853386),
#    ('TAPIR', 0.6719242766837937)]),
#  ('News flash',
#   'ITEM',
#   [('DART', 0.6518224666932146),
#    ('WORD', 0.8760899450675628),
#    ('WORD', 0.8760899450675628),
#    ('WORD', 0.8760899450675628),
#    ('WORD', 0.8760899450675628)]),
#  ('Game with matadors and schneiders',
#   'SKAT',
#   [('OLES', 0.756892752544876),
#    ('LESS', 1.0),
#    ('SOLE', 1.0),
#    ('ASST', 1.0),
#    ('ATOP', 1.0)]),
#  ("Redactor's process",
#   'EDITAL',
#   [('EDITOR', 0.656864834419225),
#    ('EDITOR', 0.656864834419225),
#    ('EDITOR', 0.656864834419225),
#    ('SYSTEM', 0.8712899836652376),
#    ('METHOD', 0.8712899836652376)]),
#  ('Cousin of a hyena', 'AARDWOLF', []),
#  ('A law ___ itself',
#   'UNTO',
#   [('OHMS', 0.0), ('OHMS', 0.0), ('JURE', 0.0), ('OHMS', 0.0), ('OHMS', 0.0)]),
#  ('Cane',
#   'THRASH',
#   [('RATTAN', 0.0),
#    ('RATTAN', 0.5924170833403218),
#    ('TOPHAT', 0.7407725115132111),
#    ('STRIPE', 0.7863885248234335),
#    ('MEGASS', 0.8475198992013572)]),
#  ('Metaphors for serious headaches',
#   'VISES',
#   [('REDID', 0.9999999999999999),
#    ('ENDED', 0.9999999999999999),
#    ('LATER', 0.9999999999999999),
#    ('ISSUE', 0.9999999999999999),
#    ('AGAIN', 0.9999999999999999)]),
#  ('Mud ___ (bottom-dwelling fish)',
#   'EELS',
#   [('GOOP', 0.9016508226826322),
#    ('OOZE', 0.9016508226826322),
#    ('MIRE', 0.9016508226826322),
#    ('COOP', 0.9685943201627462),
#    ('COOP', 0.9685943201627462)]),
#  ("When it's least chilly in Chile",
#   'ENERO',
#   [('ALGID', 0.7134491451869555),
#    ('ALGID', 0.7134491451869555),
#    ('ANDES', 0.8166871597753659),
#    ('ANDES', 0.8166871597753659),
#    ('ANDES', 0.8166871597753659)]),
#  ('Marisa of "Crazy, Stupid, Love"',
#   'TOMEI',
#   [('INANE', 0.9655642649706673),
#    ('DENSE', 0.9655642649706673),
#    ('DENSE', 0.9655642649706673),
#    ('DENSE', 0.9655642649706673),
#    ('PAVAN', 0.9878931082724042)]),
#  ('A province of Panama', 'COLON', []),
#  ('"Directoire" artist',
#   'ERTE',
#   [('FINI', 0.0),
#    ('LIAR', 0.6927907329129002),
#    ('POSE', 0.6992598098261724),
#    ('DALI', 0.7315373348094484),
#    ('DALI', 0.7315373348094484)]),
#  ('Sondheim offering',
#   'MUSICAL',
#   [('COMPANY', 0.811179688934019), ('STEPHEN', 0.847629673732187)]),
#  ('Barbershop-quartet member', 'HARMONIZER', []),
#  ('Initials for a royal couple',
#   'TIH',
#   [('HSH', 0.6403036348697763),
#    ('HSM', 0.6403036348697763),
#    ('TWO', 0.8870151586575115),
#    ('WED', 0.8870151586575115),
#    ('FEW', 0.8870151586575115)]),
#  ('Choosing-up-sides word',
#   'MEENY',
#   [('EVENS', 0.5980428854179989),
#    ('SLAWS', 0.9024819273065938),
#    ('TEAMS', 0.9024819273065938),
#    ('ABOUT', 0.9024819273065938),
#    ('ONALL', 0.9413724056458718)]),
#  ('Another 2 Down',
#   'IDLE',
#   [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]),
#  ('Deliver by chute',
#   'DROP',
#   [('MOMS', 0.7920284410948796),
#    ('SHIP', 0.7920284410948796),
#    ('EVIL', 0.8352435962444202),
#    ('PARA', 0.8569453326616643),
#    ('LUGE', 0.9042808257528162)]),
#  ('Targets of some beatings, spelled out in detail?', 'PINTILDEATAS', []),
#  ('O\'Hara\'s "From the ___"',
#   'TERRACE',
#   [('SAMARRA', 0.8441581152894376),
#    ('SAMARRA', 0.8441581152894376),
#    ('MAUREEN', 0.8883855817583521)]),
#  ('Rock-drilling tool', 'BORINGROD', []),
#  ('Does street campaigning', 'PRESSESTHEFLESH', []),
#  ('Code on a letter',
#   'ZIP',
#   [('CEE', 0.8351323928553374),
#    ('DEE', 0.8351323928553374),
#    ('ESS', 0.8351323928553374),
#    ('ZEE', 0.8351323928553374),
#    ('ESS', 0.8351323928553374)]),
#  ('Much-read collection of verses',
#   'KORAN',
#   [('STAVE', 0.9551107008360884),
#    ('METER', 0.9596372798565743),
#    ('ROGER', 0.9596372798565743),
#    ('INFER', 0.9596372798565743),
#    ('METER', 0.9596372798565743)]),
#  ('Formation on 28-Down',
#   'RUST',
#   [('ETLA', 0.8022581082641358),
#    ('TORN', 0.8022581082641358),
#    ('EBAN', 0.8022581082641358)]),
#  ('Railroad bridges',
#   'TRESTLES',
#   [('DENTURES', 0.7382024270491759), ('TRAINMAN', 0.9717168312121744)]),
#  ("Investigator who finds someone's birth mother, say",
#   'REUNITER',
#   [('WISEUPTO', 0.9999999999999999),
#    ('DELAVEGA', 0.9999999999999999),
#    ('INSIDEOF', 0.9999999999999999)]),
#  ('"___ man\'s meat. . . "',
#   'ONE',
#   [('HER', 0.8292229641855801), ('ODD', 0.8292229641855801)]),
#  ('Shatter',
#   'SMASH',
#   [('BURST', 0.0), ('ASTIR', 1.0), ('MIXER', 1.0), ('EIDER', 1.0)]),
#  ('Rock with gold or silver, say',
#   'ORE',
#   [('RON', 0.9829717791240159),
#    ('RON', 0.9829717791240159),
#    ('WIN', 0.9889585626609556),
#    ('PAN', 0.9889585626609556),
#    ('WIN', 0.9889585626609556)]),
#  ('Remote spot?',
#   'DEN',
#   [('FAR', 0.6306849616849061),
#    ('FAR', 0.6306849616849061),
#    ('VOL', 0.763936232568444),
#    ('REC', 0.892355599652721),
#    ('REC', 0.892355599652721)]),
#  ('Bob, for one',
#   'STYLE',
#   [('SALON', 0.0),
#    ('CREEL', 0.6083463105193393),
#    ('SEGER', 0.6180487753383268),
#    ('WEAVE', 0.6458697471617525),
#    ('SAGET', 0.6666677761085824)]),
#  ('Filled Indian pastry',
#   'SAMOSA',
#   [('ECLAIR', 0.717231723646498),
#    ('CORNET', 0.717231723646498),
#    ('ECLAIR', 0.8599462708679217),
#    ('TORTES', 0.8599462708679217),
#    ('BONIER', 0.8778737073410153)]),
#  ('Frappes and parfaits', 'DESSERTS', [('THEEARTH', 0.0)]),
#  ('Part of U.S.S.R.: Abbr.',
#   'SOC',
#   [('SOV', 0.0), ('ADV', 0.0), ('RTE', 0.0), ('DEV', 0.0), ('ULT', 0.0)]),
#  ('President who won by one electoral vote',
#   'HAYES',
#   [('ASSAD', 0.9745224556054911),
#    ('EVADE', 0.9999999999999999),
#    ('DENSE', 0.9999999999999999),
#    ('RESET', 0.9999999999999999),
#    ('ROUTE', 0.9999999999999999)]),
#  ('Cloakroom item',
#   'WRAP',
#   [('HERE', 1.0), ('ATOP', 1.0), ('TART', 1.0), ('LADE', 1.0), ('SHOT', 1.0)]),
#  ('Soothes', 'ALLAYS', [('IMDONE', 1.0), ('LESSSO', 1.0), ('ANYHOW', 1.0)]),
#  ('Shipshape',
#   'NEAT',
#   [('TRIM', 0.0), ('TIDY', 0.0), ('TRIM', 0.0), ('TRIM', 0.0), ('TRIM', 0.0)]),
#  ('Mame\'s butler in "Auntie Mame"',
#   'ITO',
#   [('AND', 0.9999999999999999), ('TAB', 0.9999999999999999)]),
#  ('Make merry/mechanical part',
#   'REVELEVER',
#   [('TITFORTAT', 0.9941563404881381)]),
#  ('Pt. of a computer',
#   'STGE',
#   [('ACAD', 0.6762424241798035),
#    ('ACCT', 0.6762424241798035),
#    ('ELEM', 0.6762424241798035),
#    ('ACAD', 0.6762424241798035),
#    ('AMER', 0.6762424241798035)]),
#  ('"Each of us bears his own Hell" writer',
#   'VIRGIL',
#   [('AENEID', 0.7671477605578951),
#    ('FAMILY', 0.8769345898860557),
#    ('URSINE', 0.8769345898860557),
#    ('ABLAZE', 0.9410857111678682),
#    ('ABLAZE', 0.9410857111678682)]),
#  ('Italian doctor',
#   'MEDICO',
#   [('REVISE', 0.6863514169451798), ('THEREA', 0.7624525062351946)]),
#  ('Things first on the way up?', 'DOS', [('PAT', 0.0)]),
#  ('Moslem mystic',
#   'SUFI',
#   [('SEER', 0.6931711249490882),
#    ('SEER', 0.6931711249490882),
#    ('AMIR', 0.8364122866491346),
#    ('EMIR', 0.8364122866491346),
#    ('IMAM', 0.8364122866491346)]),
#  ('"Tsk, tsk"', 'TOOBAD', [('INTOTO', 1.0), ('PATENT', 1.0)]),
#  ('Zodiaco animal',
#   'TORO',
#   [('DEER', 0.0),
#    ('MALE', 0.4206735449492678),
#    ('SPCA', 0.6759111865565582),
#    ('SPCA', 0.6759111865565582),
#    ('BRAY', 0.6923877840548015)]),
#  ('Given preference',
#   'ELECT',
#   [('TASTE', 0.6761037548199467),
#    ('TASTE', 0.6761037548199467),
#    ('AXIOM', 0.8528776922381953),
#    ('AXIOM', 0.8528776922381953),
#    ('AXIOM', 0.8528776922381953)]),
#  ('Played the siren',
#   'ALLURED',
#   [('ENTICER', 0.6362807050308875),
#    ('ALLURER', 0.6362807050308875),
#    ('LORELEI', 0.6362807050308875),
#    ('LORELEI', 0.841736025652177),
#    ('TORNADO', 0.856468955083793)]),
#  ('Hall of Fame name', 'HOMERUNBAKER', []),
#  ('"You got me"', 'IMATALOSS', [('MADEHASTE', 0.0)]),
#  ('Heckle, in a way', 'BOO', [('AXE', 1.0)]),
#  ('Shoelace hole',
#   'EYELET',
#   [('CAVITY', 0.8574025593412502),
#    ('CAVITY', 0.8574025593412502),
#    ('CAVITY', 0.8574025593412502)]),
#  ('Reduced', 'PARED', [('RAZED', 0.813444027935139)]),
#  ('Word with smoke or cow',
#   'HOLY',
#   [('PFFT', 0.8244130408797887),
#    ('FLUE', 0.8244130408797887),
#    ('UPIN', 0.8740453067612987),
#    ('UPIN', 0.8740453067612987)]),
#  ("*Bond film that's a real gem?", 'DIAMONDSAREFOREVER', []),
#  ('Bedeck',
#   'ARRAY',
#   [('ADORN', 0.0),
#    ('ADORN', 0.0),
#    ('ADORN', 0.0),
#    ('ADORN', 0.0),
#    ('ENEMY', 1.0)]),
#  ('Some rigs', 'TANDEMS', [('SLEIGHS', 0.59565678120768)]),
#  ('Witticisms', 'JESTS', [('QUIPS', 0.0), ('EIDER', 1.0), ('MIXER', 1.0)]),
#  ('Expanding', 'UPSIZING', [('ATNOTIME', 1.0), ('EVERYONE', 1.0)]),
#  ('Model for filmdom\'s "The Greek Tycoon"',
#   'ARI',
#   [('LOS', 0.9999999999999999),
#    ('ENG', 0.9999999999999999),
#    ('PER', 0.9999999999999999),
#    ('AFT', 0.9999999999999999)]),
#  ('Directive',
#   'ORDER',
#   [('HITIT', 0.6713065328715134),
#    ('DIALM', 0.7681332899184481),
#    ('WIDER', 0.7688489235675849),
#    ('BRUSH', 0.7688489235675849)]),
#  ('Lengthy warnings', 'CAUTIONARYTALES', []),
#  ('Agreements',
#   'ASSENTS',
#   [('UNISONS', 0.0),
#    ('ACCORDS', 0.0),
#    ('ARRIVAL', 1.0),
#    ('ITSABET', 1.0),
#    ('REGRESS', 1.0)]),
#  ('Sky sight', 'CLOUD', [('COMET', 0.0), ('PIEIN', 0.7912399088701425)]),
#  ('Bond phrase',
#   'ATPAR',
#   [('AGENT', 0.7181956258896605),
#    ('UNITE', 0.7181956258896605),
#    ('AGENT', 0.7181956258896605),
#    ('UNITE', 0.7181956258896605),
#    ('JAMES', 0.7378492346934082)]),
#  ('Hotel room amenity',
#   'PEN',
#   [('ICE', 0.504603965722516),
#    ('ICE', 0.8298523498607356),
#    ('INN', 0.9445124825434916),
#    ('ACS', 0.987657180818391),
#    ('YET', 1.0)]),
#  ('Caubeen, e.g.',
#   'HAT',
#   [('RHO', 0.0), ('TIN', 0.0), ('NOW', 0.0), ('AVG', 0.0), ('ATE', 0.0)]),
#  ("Zoroaster's reputed birthplace",
#   'URMIA',
#   [('LAMAR', 0.9143257042329668),
#    ('OMAHA', 0.9143257042329668),
#    ('ONHER', 1.0),
#    ('ATALL', 1.0),
#    ('NEEDS', 1.0)]),
#  ('Exercise: Part II',
#   'ALL',
#   [('USE', 0.664146586597194),
#    ('USE', 0.664146586597194),
#    ('USE', 0.664146586597194),
#    ('GEN', 0.8643394592753225)]),
#  ('Word before and after "will be"',
#   'BOYS',
#   [('SAYS', 0.0), ('ISAY', 0.0), ('AMEN', 0.0), ('MAMA', 0.0), ('EVER', 0.0)]),
#  ('Sterling',
#   'AONE',
#   [('QUID', 0.6372133632536404),
#    ('QUID', 0.7568054217537888),
#    ('MOST', 1.0),
#    ('AMID', 1.0),
#    ('AMID', 1.0)]),
#  ('Small warbler',
#   'TIT',
#   [('TRA', 0.7890551831211498),
#    ('ONO', 0.8462816797594911),
#    ('DAB', 0.9782042200844244),
#    ('ONE', 0.9782042200844244),
#    ('TAD', 0.9782042200844244)]),
#  ('1970s Thunderbird options',
#   'TTOPS',
#   [('COOPT', 1.0), ('GRIST', 1.0), ('NADIR', 1.0), ('UNCLE', 1.0)]),
#  ('"___ Teenage Frankenstein," 1957 film',
#   'IWASA',
#   [('REAIR', 1.0),
#    ('RIFLE', 1.0),
#    ('ENDED', 1.0),
#    ('NIHIL', 1.0),
#    ('TIMES', 1.0)]),
#  ('Man of urbanity',
#   'GENT',
#   [('ALSO', 1.0), ('NICE', 1.0), ('OVER', 1.0), ('ANTI', 1.0), ('ALSO', 1.0)]),
#  ('Divine creature with six wings',
#   'SERAPH',
#   [('ADLIBS', 0.9330552862119984), ('ADLIBS', 0.9330552862119984)]),
#  ('[Grr-r-r]',
#   'IMMAD',
#   [('VOWEL', 1.0),
#    ('AREAR', 1.0),
#    ('ABIDE', 1.0),
#    ('HENCE', 1.0),
#    ('REDID', 1.0)]),
#  ('"Un Ballo in maschera" heroine',
#   'AMELIA',
#   [('ENTIRE', 0.9999999999999999),
#    ('HEALED', 0.9999999999999999),
#    ('ARISEN', 0.9999999999999999)]),
#  ('Reduce to particles', 'ATOMIZE', [('ATOMIES', 0.9574107855140597)]),
#  ('Composer of "Das Augenlicht," 1935',
#   'WEBERN',
#   [('ONAPAR', 1.0), ('APIECE', 1.0), ('IDOTOO', 1.0)]),
#  ('European capital',
#   'ZAGREB',
#   [('ATHENS', 0.0), ('TIRANA', 0.0), ('MOSCOW', 0.0)]),
#  ('Retailer beginning in 1867',
#   'SAKS',
#   [('MACY', 0.8962270736155256),
#    ('MACY', 0.9300052339722935),
#    ('GAME', 1.0),
#    ('WHEN', 1.0),
#    ('ROLE', 1.0)]),
#  ('Tax break for Gumby?', 'CLAYMANEXEMPTION', []),
#  ('What "1776" got in 1969',
#   'TONY',
#   [('DATE', 0.7984184947321381),
#    ('HALE', 0.9816201818680802),
#    ('WERE', 1.0),
#    ('DUPE', 1.0),
#    ('AHSO', 1.0)]),
#  ('For good, to Gray',
#   'EER',
#   [('AGE', 0.6828186513953911),
#    ('AGE', 0.6828186513953911),
#    ('AGE', 0.6828186513953911),
#    ('AGE', 0.6828186513953911),
#    ('AGE', 0.6828186513953911)]),
#  ("Health teacher's topic, informally",
#   'SEXED',
#   [('PROST', 0.9726592873561581),
#    ('SALUD', 0.9726592873561581),
#    ('TOAST', 0.9726592873561581),
#    ('SKOAL', 0.9726592873561581),
#    ('SALUD', 0.9726592873561581)]),
#  ('Waste gases, e.g.',
#   'OXIDES',
#   [('SEWAGE', 0.8655424211655219),
#    ('XENONS', 0.9299023576454492),
#    ('INERTS', 0.9939320896813431)]),
#  ('Turns out',
#   'EVICTS',
#   [('ROTATE', 0.0),
#    ('ROTATE', 0.0),
#    ('UPSETS', 0.0),
#    ('ARISES', 0.0),
#    ('ROTATE', 0.0)]),
#  ('Diffuse, as light',
#   'SHED',
#   [('PALE', 0.963958577846285),
#    ('BEER', 0.963958577846285),
#    ('AIRY', 0.963958577846285),
#    ('LAMP', 0.963958577846285),
#    ('AIRY', 0.963958577846285)]),
#  ('Visit', 'COMEOVER', []),
#  ('Farm sound',
#   'CAW',
#   [('MOO', 0.0),
#    ('MOO', 0.0),
#    ('BAA', 0.0),
#    ('BAA', 0.6836899035829792),
#    ('MOO', 0.6836899035829792)]),
#  ('Taxonomic suffix',
#   'OTA',
#   [('OTE', 0.0), ('OTE', 0.0), ('OTE', 0.0), ('HAS', 1.0), ('YET', 1.0)]),
#  ('See 45-Down',
#   'OFF',
#   [('AES', 0.0),
#    ('ASP', 0.0),
#    ('GAS', 0.0),
#    ('SAY', 0.0),
#    ('RPM', 0.37515343993673933)]),
#  ('Touch up',
#   'EDIT',
#   [('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0), ('ABUT', 0.0)]),
#  ('Embarrassing sound, maybe',
#   'RIP',
#   [('ZIT', 0.8569621277192415), ('AND', 1.0), ('SEE', 1.0)]),
#  ('It has 33 letters', 'RUSSIANLANGUAGE', []),
#  ('Lack of harmony',
#   'CLASH',
#   [('AGREE', 0.7399093977739439),
#    ('ATONE', 0.7399093977739439),
#    ('ATONE', 0.7399093977739439),
#    ('AGREE', 0.7399093977739439),
#    ('AGREE', 0.7399093977739439)]),
#  ('Trolley warning',
#   'TOOT',
#   [('CART', 0.6865271037466011),
#    ('BATS', 0.6865271037466011),
#    ('TRAM', 0.6865271037466011),
#    ('CART', 0.6865271037466011),
#    ('DAFT', 0.6865271037466011)]),
#  ('Celestial flare-ups',
#   'NOVAS',
#   [('SOLAR', 0.9378931516221996),
#    ('HIKES', 0.9551855005221711),
#    ('GARBS', 0.9551855005221711),
#    ('HIKES', 0.9551855005221711),
#    ('ASHES', 0.9962659899519872)]),
#  ('To the max',
#   'INSPADES',
#   [('HEADROOM', 0.6531607943385198), ('NERDIEST', 0.705089332941897)]),
#  ("Dolly's family",
#   'LEVIS',
#   [('HELLO', 0.6635155359208913),
#    ('HELLO', 0.7631415754238323),
#    ('HELLO', 0.8573025832086411),
#    ('HELLO', 0.8573025832086411),
#    ('GENUS', 0.9323800412770409)]),
#  ("D.A.'s",
#   'ATTS',
#   [('ABLE', 0.0), ('LESS', 0.0), ('PINK', 0.0), ('APOP', 0.0), ('ATOP', 0.0)]),
#  ("Ban ___ (Kofi Annan's successor)",
#   'KIMOON',
#   [('CAMERA', 0.9999999999999999),
#    ('ROOFER', 0.9999999999999999),
#    ('NECKED', 0.9999999999999999)]),
#  ("This puzzle's long-winded advice, simply put", 'LOOKBEFOREYOULEAP', []),
#  ('Fast approaching',
#   'NEAR',
#   [('NIGH', 0.6018452625360905),
#    ('NIGH', 0.6018452625360905),
#    ('PLOY', 0.9230938564769298)]),
#  ('Up and about',
#   'ASTIR',
#   [('LEAST', 0.0),
#    ('HEART', 0.0),
#    ('ALIBI', 0.0),
#    ('STAKE', 0.0),
#    ('EWING', 0.0)]),
#  ('Blubber',
#   'CRY',
#   [('SOB', 0.0), ('SOB', 0.0), ('FAT', 0.0), ('SOB', 0.0), ('SOB', 0.0)]),
#  ('In the limelight', 'ONSTAGE', [('ONETIME', 1.0)]),
#  ('MacDonald\'s "The Egg ___"',
#   'ANDI',
#   [('HADA', 0.7820917632961483),
#    ('FARM', 0.8410792828089683),
#    ('FARM', 0.8410792828089683),
#    ('EDDY', 0.8534646249442138),
#    ('EDDY', 0.8534646249442138)]),
#  ('"_____ o\' My Heart"',
#   'PEG',
#   [('COR', 0.6654582750426652),
#    ('COR', 0.6654582750426652),
#    ('COR', 0.6654582750426652),
#    ('COR', 0.6654582750426652)]),
#  ('Syst. of measurement',
#   'CGS',
#   [('ABM', 0.9214725913237541),
#    ('BMT', 0.9286779440146351),
#    ('ENS', 0.9692257109287173),
#    ('ABO', 0.9774303380495311),
#    ('IGN', 0.9955585969251769)]),
#  ('Scary cinema sounds', 'SCREAMS', []),
#  ("Keats's was Grecian",
#   'URN',
#   [('ERE', 0.8880790211441423),
#    ('OER', 0.8880790211441423),
#    ('ERE', 0.8880790211441423),
#    ('ERE', 0.8880790211441423),
#    ('EER', 0.8880790211441423)]),
#  ('Full-count cry',
#   'STRIKETWO',
#   [('ENUMERATE', 0.0), ('ENUMERATE', 0.0), ('ENUMERATE', 0.0)]),
#  ('Excited about', 'KEENON', []),
#  ('Clumps',
#   'TUFTS',
#   [('CLODS', 0.5738405682243282),
#    ('HELLO', 1.0),
#    ('UNCLE', 1.0),
#    ('IPASS', 1.0),
#    ('ALIBI', 1.0)]),
#  ("Sires' mates",
#   'DAMS',
#   [('DADS', 0.8570753757716728),
#    ('EXES', 0.866107097219266),
#    ('EXES', 0.866107097219266),
#    ('PALS', 0.866107097219266),
#    ('PALS', 0.866107097219266)]),
#  ('Word before many city names',
#   'GREATER',
#   [('SWEARAT', 0.7580881854364423), ('CLASSIC', 0.8398589182675112)]),
#  ('Napa sight',
#   'VINEYARD',
#   [('RELEGATE', 0.9435128741439904), ('TUCKAWAY', 0.9435128741439904)]),
#  ("Tom Lea's brave bulls",
#   'TOROS',
#   [('PHONE', 1.0), ('ARBOR', 1.0), ('AWARD', 1.0)]),
#  ('Submitting to control', 'MANAGEABLE', []),
#  ('Nicest room on a ship, probably', 'CAPTAINSDIMES', []),
#  ('Friends',
#   'ALLIES',
#   [('ALIENS', 0.0), ('MONICA', 0.0), ('SITCOM', 0.0), ('MONICA', 0.0)]),
#  ("Mountain climber's obstacle",
#   'GORGE',
#   [('PITON', 0.8875351053630293),
#    ('PITON', 0.8875351053630293),
#    ('KOALA', 0.8938038234769691),
#    ('THOSE', 0.9999999999999999)]),
#  ('Crime writer Rankin',
#   'IAN',
#   [('ANN', 0.8119503012440201), ('PEN', 0.8740557787768939)]),
#  ('Inability to recall the names of everyday objects',
#   'ANOMIA',
#   [('TINEAR', 0.9972864536488252), ('MAIDEN', 1.0), ('RELENT', 1.0)])]

# %%
guess("opposite of NNE")
# Out:
# [('SSW', 0.0),
#  ('SSW', 0.0),
#  ('SSW', 0.0),
#  ('LILLE', 0.8642528489300003),
#  ('LILLE', 0.8642528489300003)]

# %%
# # serialize and save model
# import pickle

# TRAINED_MODEL_PATH = "trained_model.p"

# pickle.dump((answers_train, vectorizer, model), open(TRAINED_MODEL_PATH, "wb"))
